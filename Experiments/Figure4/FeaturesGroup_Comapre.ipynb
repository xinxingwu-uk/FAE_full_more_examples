# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.style.use('seaborn-dark')

name_list = ['MNIST       ','MNIST-Fashion       ','COIL-20         ','Mice Protein      ', 'ISOLET        ', 'Activity        ']

plt.figure(figsize = (18,8))

plt.grid(axis="y",linestyle='--',lw=2.5)

plt.ylabel('Classification accuracy',fontsize=24)

num_list1 = [0.9115,0.78825, 0.9861111111111112, 0.4398148148148148, 0.8505452212957024  , 0.8746736292428199]
num_list2 = [0.80275 ,0.74075, 0.9652777777777778, 0.4444444444444444, 0.7164849262347659 , 0.8746736292428199]
num_list3 = [0.78275,0.73975, 0.9548611111111112, 0.1111111111111111, 0.6183450930083387 , 0.5883376849434291]


x =list(range(len(name_list)))
total_width, n = 0.8, 4
width = total_width / n
 
plt.bar(x, num_list1, width=width, label='All selected features',color = sns.xkcd_rgb["denim blue"], ec='white', ls='-',lw=0.8)

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x, num_list2, width=width, label='First group',tick_label = name_list,color = sns.xkcd_rgb["pale red"],hatch='/', ec='white', ls='-',lw=0.8)

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x, num_list3, width=width, label='Second group',tick_label = name_list,color = sns.xkcd_rgb["medium green"],hatch='\\', ec='white', ls='-',lw=0.8)

plt.xticks(fontsize=24)
plt.yticks(np.arange(0,1,0.1),fontsize=24)
plt.ylim([0.0, 1])
plt.legend(prop = {'size':24},loc='upper center',ncol=3,fancybox=True,shadow=True,bbox_to_anchor=(0.5,1.11))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.style.use('seaborn-dark')

name_list = ['MNIST       ','MNIST-Fashion       ','COIL-20         ','Mice Protein      ', 'ISOLET        ', 'Activity        ']

plt.figure(figsize = (18,8))

plt.grid(axis="y",linestyle='--',lw=2.5)

plt.ylabel('Classification accuracy',fontsize=24)

num_list1 = [0.92075 ,0.8145,0.9826388888888888, 0.5462962962962963, 0.8980115458627326, 0.9112271540469974]
num_list2 = [0.86825, 0.77325, 0.9756944444444444, 0.4861111111111111, 0.8210391276459269, 0.9042645778938208]
num_list3 = [0.8325, 0.78025,0.9826388888888888, 0.1111111111111111,0.7280307889672867,0.8398607484769365]

x =list(range(len(name_list)))
total_width, n = 0.8, 4
width = total_width / n
 
plt.bar(x, num_list1, width=width, label='All selected features',color = sns.xkcd_rgb["denim blue"], ec='white', ls='-',lw=0.8)

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x, num_list2, width=width, label='First group',tick_label = name_list,color = sns.xkcd_rgb["pale red"],hatch='/', ec='white', ls='-',lw=0.8)

for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x, num_list3, width=width, label='Second group',tick_label = name_list,color = sns.xkcd_rgb["medium green"],hatch='\\', ec='white', ls='-',lw=0.8)

plt.xticks(fontsize=24)
plt.yticks(np.arange(0,1,0.1),fontsize=24)
plt.ylim([0.0, 1])

plt.legend(prop = {'size':24},loc='upper center',ncol=3,fancybox=True,shadow=True,bbox_to_anchor=(0.5,1.11))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-dark')

name_list = ['MNIST','MNIST-Fashion','COIL-20','Mice Protein', 'ISOLET', 'Activity']

names=['All selected features','First group','Second group']

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(24,8))

ax1.grid(True,linestyle='--',linewidth = 2.5,zorder=-1,axis="y")

ax1.set_yticks(np.arange(0,1.2,0.2))
ax1.set_ylabel('Classification accuracy', fontsize = 28)
ax1.tick_params(axis='x',labelsize=28,labelrotation=15)
ax1.tick_params(axis='y',labelsize=28)
ax1.set_ylim([0, 1.1])

ax2.grid(True,linestyle='--',linewidth = 2.5,zorder=-1,axis="y")
ax2.set_yticks(np.arange(0,1.2,0.2))
ax2.tick_params(axis='x',labelsize=28,labelrotation=15)
ax2.tick_params(axis='y',labelsize=28)
ax2.set_ylim([0, 1.1])

num_list1 = [0.9115,0.78825, 0.9861111111111112, 0.4398148148148148, 0.8505452212957024  , 0.8746736292428199]
num_list2 = [0.80275 ,0.74075, 0.9652777777777778, 0.4444444444444444, 0.7164849262347659 , 0.8746736292428199]
num_list3 = [0.78275,0.73975, 0.9548611111111112, 0.1111111111111111, 0.6183450930083387 , 0.5883376849434291]

x =list(range(len(name_list)))
total_width, n = 0.8, 4
width = total_width / n

ax1.text(0.5, 0.95, '36 Features', fontsize = 28, horizontalalignment='center',verticalalignment='center', transform=ax1.transAxes)

ax1.bar(x, num_list1, width=width, label='All selected features',color = sns.xkcd_rgb["denim blue"], ec='white', ls='-',lw=0.8)

for i in range(len(x)):
    x[i] = x[i] + width
ax1.bar(x, num_list2, width=width, label='First group',tick_label = name_list,color = sns.xkcd_rgb["pale red"],hatch='/', ec='white', ls='-',lw=0.8)

for i in range(len(x)):
    x[i] = x[i] + width
ax1.bar(x, num_list3, width=width, label='Second group',tick_label = name_list,color = sns.xkcd_rgb["medium green"],hatch='\\', ec='white', ls='-',lw=0.8)

num_list1 = [0.92075 ,0.8145,0.9826388888888888, 0.5462962962962963, 0.8980115458627326, 0.9112271540469974]
num_list2 = [0.86825, 0.77325, 0.9756944444444444, 0.4861111111111111, 0.8210391276459269, 0.9042645778938208]
num_list3 = [0.8325, 0.78025,0.9826388888888888, 0.1111111111111111,0.7280307889672867,0.8398607484769365]

x =list(range(len(name_list)))
total_width, n = 0.8, 4
width = total_width / n

ax2.text(1.5, 0.95, '50 Features', fontsize = 28, horizontalalignment='center',verticalalignment='center', transform=ax1.transAxes)

ax2.bar(x, num_list1, width=width, label='All selected features',color = sns.xkcd_rgb["denim blue"], ec='white', ls='-',lw=0.8)

for i in range(len(x)):
    x[i] = x[i] + width
ax2.bar(x, num_list2, width=width, label='First group',tick_label = name_list,color = sns.xkcd_rgb["pale red"],hatch='/', ec='white', ls='-',lw=0.8)

for i in range(len(x)):
    x[i] = x[i] + width
ax2.bar(x, num_list3, width=width, label='Second group',tick_label = name_list,color = sns.xkcd_rgb["medium green"],hatch='\\', ec='white', ls='-',lw=0.8)


plt.subplots_adjust(right=1,wspace =0.08,hspace =0)

fig.legend(labels=names,fontsize=28, loc='upper center', bbox_to_anchor=(0.45,1.01),ncol=9,handletextpad=0.1,columnspacing=2.4, fancybox=True,framealpha=0.1,shadow=True)

plt.show()
