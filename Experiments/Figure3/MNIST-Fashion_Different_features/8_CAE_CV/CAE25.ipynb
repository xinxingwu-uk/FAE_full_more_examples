# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.model_selection import train_test_split
import scipy.sparse as sparse
from keras.datasets import fashion_mnist

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
num_data_used=10000
(x_train_, y_train_), (x_test_, y_test_) = fashion_mnist.load_data()
x_data=np.r_[x_train_,x_test_].reshape(70000, 28*28).astype('float32')/255.0
y_data=np.r_[y_train_,y_test_]

np.random.seed(seed)
x_data_num,_=x_data.shape
index=np.arange(x_data_num)
np.random.shuffle(index)

data_arr=x_data[index][0:num_data_used]
label_arr_onehot=y_data[index][0:num_data_used]

# %%
key_feture_number=25

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log"+str(key_feture_number)+"/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log"+str(key_feture_number)+"/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,5):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 25)                19601
# _________________________________________________________________
# dense_1 (Dense)              (None, 784)               20384
# =================================================================
# Total params: 39,985
# Trainable params: 39,984
# Non-trainable params: 1
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/200
# mean max of probabilities: 0.0014245565 - temperature 10.0
# 8000/8000 [==============================] - 6s 718us/step - loss: 0.0789 - val_loss: 0.0649
# Epoch 2/200
# mean max of probabilities: 0.0014783334 - temperature 9.716152
# 8000/8000 [==============================] - 4s 510us/step - loss: 0.0647 - val_loss: 0.0642
# Epoch 3/200
# mean max of probabilities: 0.0015703612 - temperature 9.440363
# 8000/8000 [==============================] - 4s 497us/step - loss: 0.0640 - val_loss: 0.0637
# Epoch 4/200
# mean max of probabilities: 0.0017016523 - temperature 9.172401
# 8000/8000 [==============================] - 4s 533us/step - loss: 0.0637 - val_loss: 0.0636
# Epoch 5/200
# mean max of probabilities: 0.0018693565 - temperature 8.912045
# 8000/8000 [==============================] - 4s 523us/step - loss: 0.0635 - val_loss: 0.0634
# Epoch 6/200
# mean max of probabilities: 0.0020646062 - temperature 8.6590805
# 8000/8000 [==============================] - 5s 575us/step - loss: 0.0634 - val_loss: 0.0634
# Epoch 7/200
# mean max of probabilities: 0.0023025218 - temperature 8.413296
# 8000/8000 [==============================] - 4s 479us/step - loss: 0.0633 - val_loss: 0.0632
# Epoch 8/200
# mean max of probabilities: 0.0025721483 - temperature 8.174487
# 8000/8000 [==============================] - 4s 458us/step - loss: 0.0632 - val_loss: 0.0631
# Epoch 9/200
# mean max of probabilities: 0.0028910562 - temperature 7.942457
# 8000/8000 [==============================] - 4s 476us/step - loss: 0.0629 - val_loss: 0.0626
# Epoch 10/200
# mean max of probabilities: 0.003297219 - temperature 7.7170134
# 8000/8000 [==============================] - 4s 520us/step - loss: 0.0625 - val_loss: 0.0619
# Epoch 11/200
# mean max of probabilities: 0.0038271311 - temperature 7.4979672
# 8000/8000 [==============================] - 4s 483us/step - loss: 0.0615 - val_loss: 0.0608
# Epoch 12/200
# mean max of probabilities: 0.0045187906 - temperature 7.2851405
# 8000/8000 [==============================] - 4s 502us/step - loss: 0.0599 - val_loss: 0.0586
# Epoch 13/200
# mean max of probabilities: 0.0053306683 - temperature 7.078353
# 8000/8000 [==============================] - 5s 660us/step - loss: 0.0575 - val_loss: 0.0556
# Epoch 14/200
# mean max of probabilities: 0.0061950977 - temperature 6.8774366
# 8000/8000 [==============================] - 6s 696us/step - loss: 0.0544 - val_loss: 0.0525
# Epoch 15/200
# mean max of probabilities: 0.0070341695 - temperature 6.6822195
# 8000/8000 [==============================] - 5s 682us/step - loss: 0.0514 - val_loss: 0.0496
# Epoch 16/200
# mean max of probabilities: 0.007802271 - temperature 6.4925466
# 8000/8000 [==============================] - 5s 620us/step - loss: 0.0490 - val_loss: 0.0476
# Epoch 17/200
# mean max of probabilities: 0.00845193 - temperature 6.3082566
# 8000/8000 [==============================] - 6s 688us/step - loss: 0.0475 - val_loss: 0.0465
# Epoch 18/200
# mean max of probabilities: 0.008971293 - temperature 6.129198
# 8000/8000 [==============================] - 5s 669us/step - loss: 0.0468 - val_loss: 0.0462
# Epoch 19/200
# mean max of probabilities: 0.009386594 - temperature 5.955221
# 8000/8000 [==============================] - 5s 610us/step - loss: 0.0465 - val_loss: 0.0460
# Epoch 20/200
# mean max of probabilities: 0.00970669 - temperature 5.786184
# 8000/8000 [==============================] - 4s 536us/step - loss: 0.0464 - val_loss: 0.0458
# Epoch 21/200
# mean max of probabilities: 0.009959524 - temperature 5.621946
# 8000/8000 [==============================] - 4s 536us/step - loss: 0.0462 - val_loss: 0.0457
# Epoch 22/200
# mean max of probabilities: 0.010192301 - temperature 5.4623694
# 8000/8000 [==============================] - 4s 544us/step - loss: 0.0460 - val_loss: 0.0455
# Epoch 23/200
# mean max of probabilities: 0.010487734 - temperature 5.307321
# 8000/8000 [==============================] - 5s 639us/step - loss: 0.0456 - val_loss: 0.0452
# Epoch 24/200
# mean max of probabilities: 0.010902957 - temperature 5.1566744
# 8000/8000 [==============================] - 5s 623us/step - loss: 0.0452 - val_loss: 0.0445
# Epoch 25/200
# mean max of probabilities: 0.011574534 - temperature 5.010304
# 8000/8000 [==============================] - 6s 733us/step - loss: 0.0446 - val_loss: 0.0438
# Epoch 26/200
# mean max of probabilities: 0.01247926 - temperature 4.8680882
# 8000/8000 [==============================] - 5s 643us/step - loss: 0.0439 - val_loss: 0.0431
# Epoch 27/200
# mean max of probabilities: 0.013622428 - temperature 4.7299085
# 8000/8000 [==============================] - 5s 579us/step - loss: 0.0430 - val_loss: 0.0422
# Epoch 28/200
# mean max of probabilities: 0.015060637 - temperature 4.595652
# 8000/8000 [==============================] - 4s 561us/step - loss: 0.0421 - val_loss: 0.0412
# Epoch 29/200
# mean max of probabilities: 0.016622776 - temperature 4.4652066
# 8000/8000 [==============================] - 5s 650us/step - loss: 0.0411 - val_loss: 0.0402
# Epoch 30/200
# mean max of probabilities: 0.018397069 - temperature 4.338463
# 8000/8000 [==============================] - 5s 593us/step - loss: 0.0401 - val_loss: 0.0392
# Epoch 31/200
# mean max of probabilities: 0.020312997 - temperature 4.2153172
# 8000/8000 [==============================] - 6s 710us/step - loss: 0.0391 - val_loss: 0.0383
# Epoch 32/200
# mean max of probabilities: 0.022255128 - temperature 4.095666
# 8000/8000 [==============================] - 6s 733us/step - loss: 0.0382 - val_loss: 0.0375
# Epoch 33/200
# mean max of probabilities: 0.024368795 - temperature 3.979412
# 8000/8000 [==============================] - 5s 643us/step - loss: 0.0373 - val_loss: 0.0367
# Epoch 34/200
# mean max of probabilities: 0.026669342 - temperature 3.8664572
# 8000/8000 [==============================] - 5s 579us/step - loss: 0.0365 - val_loss: 0.0359
# Epoch 35/200
# mean max of probabilities: 0.02916813 - temperature 3.7567089
# 8000/8000 [==============================] - 5s 589us/step - loss: 0.0356 - val_loss: 0.0351
# Epoch 36/200
# mean max of probabilities: 0.031706706 - temperature 3.650076
# 8000/8000 [==============================] - 5s 586us/step - loss: 0.0349 - val_loss: 0.0343
# Epoch 37/200
# mean max of probabilities: 0.034350928 - temperature 3.5464702
# 8000/8000 [==============================] - 5s 602us/step - loss: 0.0341 - val_loss: 0.0335
# Epoch 38/200
# mean max of probabilities: 0.037067663 - temperature 3.445804
# 8000/8000 [==============================] - 5s 686us/step - loss: 0.0332 - val_loss: 0.0327
# Epoch 39/200
# mean max of probabilities: 0.04001315 - temperature 3.3479955
# 8000/8000 [==============================] - 5s 568us/step - loss: 0.0324 - val_loss: 0.0320
# Epoch 40/200
# mean max of probabilities: 0.043578424 - temperature 3.2529633
# 8000/8000 [==============================] - 5s 602us/step - loss: 0.0317 - val_loss: 0.0313
# Epoch 41/200
# mean max of probabilities: 0.04694971 - temperature 3.1606295
# 8000/8000 [==============================] - 6s 775us/step - loss: 0.0310 - val_loss: 0.0306
# Epoch 42/200
# mean max of probabilities: 0.049778618 - temperature 3.0709162
# 8000/8000 [==============================] - 5s 629us/step - loss: 0.0304 - val_loss: 0.0301
# Epoch 43/200
# mean max of probabilities: 0.0531659 - temperature 2.9837487
# 8000/8000 [==============================] - 6s 689us/step - loss: 0.0299 - val_loss: 0.0296
# Epoch 44/200
# mean max of probabilities: 0.05618089 - temperature 2.8990557
# 8000/8000 [==============================] - 6s 755us/step - loss: 0.0294 - val_loss: 0.0293
# Epoch 45/200
# mean max of probabilities: 0.058516398 - temperature 2.8167667
# 8000/8000 [==============================] - 5s 636us/step - loss: 0.0290 - val_loss: 0.0288
# Epoch 46/200
# mean max of probabilities: 0.060740016 - temperature 2.7368128
# 8000/8000 [==============================] - 5s 613us/step - loss: 0.0286 - val_loss: 0.0285
# Epoch 47/200
# mean max of probabilities: 0.0625145 - temperature 2.659129
# 8000/8000 [==============================] - 6s 717us/step - loss: 0.0282 - val_loss: 0.0281
# Epoch 48/200
# mean max of probabilities: 0.065002784 - temperature 2.5836504
# 8000/8000 [==============================] - 5s 625us/step - loss: 0.0279 - val_loss: 0.0277
# Epoch 49/200
# mean max of probabilities: 0.067334466 - temperature 2.5103142
# 8000/8000 [==============================] - 6s 765us/step - loss: 0.0276 - val_loss: 0.0274
# Epoch 50/200
# mean max of probabilities: 0.069443494 - temperature 2.43906
# 8000/8000 [==============================] - 6s 738us/step - loss: 0.0273 - val_loss: 0.0271
# Epoch 51/200
# mean max of probabilities: 0.07121444 - temperature 2.369828
# 8000/8000 [==============================] - 6s 727us/step - loss: 0.0269 - val_loss: 0.0269
# Epoch 52/200
# mean max of probabilities: 0.07362966 - temperature 2.3025618
# 8000/8000 [==============================] - 6s 786us/step - loss: 0.0266 - val_loss: 0.0265
# Epoch 53/200
# mean max of probabilities: 0.076365426 - temperature 2.2372043
# 8000/8000 [==============================] - 5s 670us/step - loss: 0.0264 - val_loss: 0.0264
# Epoch 54/200
# mean max of probabilities: 0.078693375 - temperature 2.173702
# 8000/8000 [==============================] - 5s 636us/step - loss: 0.0261 - val_loss: 0.0261
# Epoch 55/200
# mean max of probabilities: 0.08076341 - temperature 2.1120012
# 8000/8000 [==============================] - 5s 634us/step - loss: 0.0259 - val_loss: 0.0258
# Epoch 56/200
# mean max of probabilities: 0.08244528 - temperature 2.0520527
# 8000/8000 [==============================] - 5s 630us/step - loss: 0.0258 - val_loss: 0.0258
# Epoch 57/200
# mean max of probabilities: 0.083841436 - temperature 1.993806
# 8000/8000 [==============================] - 5s 612us/step - loss: 0.0256 - val_loss: 0.0255
# Epoch 58/200
# mean max of probabilities: 0.08405881 - temperature 1.9372126
# 8000/8000 [==============================] - 5s 628us/step - loss: 0.0255 - val_loss: 0.0255
# Epoch 59/200
# mean max of probabilities: 0.08438093 - temperature 1.8822256
# 8000/8000 [==============================] - 5s 658us/step - loss: 0.0253 - val_loss: 0.0255
# Epoch 60/200
# mean max of probabilities: 0.085841425 - temperature 1.8287995
# 8000/8000 [==============================] - 6s 689us/step - loss: 0.0253 - val_loss: 0.0252
# Epoch 61/200
# mean max of probabilities: 0.086702205 - temperature 1.7768897
# 8000/8000 [==============================] - 6s 689us/step - loss: 0.0253 - val_loss: 0.0256
# Epoch 62/200
# mean max of probabilities: 0.08718461 - temperature 1.7264532
# 8000/8000 [==============================] - 5s 613us/step - loss: 0.0252 - val_loss: 0.0254
# Epoch 63/200
# mean max of probabilities: 0.08837165 - temperature 1.6774484
# 8000/8000 [==============================] - 5s 608us/step - loss: 0.0253 - val_loss: 0.0252
# Epoch 64/200
# mean max of probabilities: 0.08890568 - temperature 1.6298345
# 8000/8000 [==============================] - 5s 611us/step - loss: 0.0255 - val_loss: 0.0253
# Epoch 65/200
# mean max of probabilities: 0.089788824 - temperature 1.583572
# 8000/8000 [==============================] - 5s 652us/step - loss: 0.0256 - val_loss: 0.0256
# Epoch 66/200
# mean max of probabilities: 0.090687774 - temperature 1.5386227
# 8000/8000 [==============================] - 5s 592us/step - loss: 0.0255 - val_loss: 0.0258
# Epoch 67/200
# mean max of probabilities: 0.09224283 - temperature 1.4949492
# 8000/8000 [==============================] - 5s 605us/step - loss: 0.0257 - val_loss: 0.0259
# Epoch 68/200
# mean max of probabilities: 0.09396097 - temperature 1.4525156
# 8000/8000 [==============================] - 5s 673us/step - loss: 0.0259 - val_loss: 0.0259
# Epoch 69/200
# mean max of probabilities: 0.09556232 - temperature 1.4112862
# 8000/8000 [==============================] - 5s 670us/step - loss: 0.0261 - val_loss: 0.0258
# Epoch 70/200
# mean max of probabilities: 0.09733967 - temperature 1.3712273
# 8000/8000 [==============================] - 5s 619us/step - loss: 0.0261 - val_loss: 0.0263
# Epoch 71/200
# mean max of probabilities: 0.10022907 - temperature 1.3323054
# 8000/8000 [==============================] - 5s 596us/step - loss: 0.0263 - val_loss: 0.0265
# Epoch 72/200
# mean max of probabilities: 0.10263117 - temperature 1.2944883
# 8000/8000 [==============================] - 5s 574us/step - loss: 0.0263 - val_loss: 0.0266
# Epoch 73/200
# mean max of probabilities: 0.10529314 - temperature 1.2577448
# 8000/8000 [==============================] - 5s 602us/step - loss: 0.0266 - val_loss: 0.0271
# Epoch 74/200
# mean max of probabilities: 0.108918875 - temperature 1.2220443
# 8000/8000 [==============================] - 6s 699us/step - loss: 0.0268 - val_loss: 0.0268
# Epoch 75/200
# mean max of probabilities: 0.11175952 - temperature 1.1873572
# 8000/8000 [==============================] - 5s 643us/step - loss: 0.0269 - val_loss: 0.0277
# Epoch 76/200
# mean max of probabilities: 0.11536839 - temperature 1.1536546
# 8000/8000 [==============================] - 5s 646us/step - loss: 0.0270 - val_loss: 0.0274
# Epoch 77/200
# mean max of probabilities: 0.11888136 - temperature 1.1209084
# 8000/8000 [==============================] - 4s 507us/step - loss: 0.0273 - val_loss: 0.0274
# Epoch 78/200
# mean max of probabilities: 0.122873925 - temperature 1.089092
# 8000/8000 [==============================] - 5s 607us/step - loss: 0.0275 - val_loss: 0.0270
# Epoch 79/200
# mean max of probabilities: 0.12786569 - temperature 1.0581783
# 8000/8000 [==============================] - 5s 636us/step - loss: 0.0272 - val_loss: 0.0280
# Epoch 80/200
# mean max of probabilities: 0.132208 - temperature 1.0281421
# 8000/8000 [==============================] - 5s 631us/step - loss: 0.0276 - val_loss: 0.0278
# Epoch 81/200
# mean max of probabilities: 0.13726604 - temperature 0.9989582
# 8000/8000 [==============================] - 5s 576us/step - loss: 0.0276 - val_loss: 0.0282
# Epoch 82/200
# mean max of probabilities: 0.1429948 - temperature 0.970603
# 8000/8000 [==============================] - 5s 571us/step - loss: 0.0278 - val_loss: 0.0277
# Epoch 83/200
# mean max of probabilities: 0.14786258 - temperature 0.9430529
# 8000/8000 [==============================] - 6s 714us/step - loss: 0.0279 - val_loss: 0.0281
# Epoch 84/200
# mean max of probabilities: 0.15380579 - temperature 0.91628474
# 8000/8000 [==============================] - 6s 727us/step - loss: 0.0279 - val_loss: 0.0280
# Epoch 85/200
# mean max of probabilities: 0.16054073 - temperature 0.8902763
# 8000/8000 [==============================] - 5s 624us/step - loss: 0.0281 - val_loss: 0.0278
# Epoch 86/200
# mean max of probabilities: 0.16705348 - temperature 0.865006
# 8000/8000 [==============================] - 5s 603us/step - loss: 0.0281 - val_loss: 0.0280
# Epoch 87/200
# mean max of probabilities: 0.17467844 - temperature 0.84045327
# 8000/8000 [==============================] - 5s 603us/step - loss: 0.0283 - val_loss: 0.0284
# Epoch 88/200
# mean max of probabilities: 0.18201542 - temperature 0.8165973
# 8000/8000 [==============================] - 5s 594us/step - loss: 0.0282 - val_loss: 0.0284
# Epoch 89/200
# mean max of probabilities: 0.18961698 - temperature 0.7934184
# 8000/8000 [==============================] - 5s 582us/step - loss: 0.0287 - val_loss: 0.0284
# Epoch 90/200
# mean max of probabilities: 0.19824912 - temperature 0.7708973
# 8000/8000 [==============================] - 5s 629us/step - loss: 0.0283 - val_loss: 0.0286
# Epoch 91/200
# mean max of probabilities: 0.20666172 - temperature 0.74901587
# 8000/8000 [==============================] - 5s 595us/step - loss: 0.0284 - val_loss: 0.0287
# Epoch 92/200
# mean max of probabilities: 0.21521164 - temperature 0.7277553
# 8000/8000 [==============================] - 5s 567us/step - loss: 0.0286 - val_loss: 0.0284
# Epoch 93/200
# mean max of probabilities: 0.22398138 - temperature 0.7070981
# 8000/8000 [==============================] - 5s 577us/step - loss: 0.0286 - val_loss: 0.0283
# Epoch 94/200
# mean max of probabilities: 0.23289202 - temperature 0.68702734
# 8000/8000 [==============================] - 4s 542us/step - loss: 0.0287 - val_loss: 0.0291
# Epoch 95/200
# mean max of probabilities: 0.24200547 - temperature 0.6675263
# 8000/8000 [==============================] - 5s 622us/step - loss: 0.0287 - val_loss: 0.0286
# Epoch 96/200
# mean max of probabilities: 0.251756 - temperature 0.64857894
# 8000/8000 [==============================] - 6s 698us/step - loss: 0.0287 - val_loss: 0.0286
# Epoch 97/200
# mean max of probabilities: 0.26058856 - temperature 0.6301691
# 8000/8000 [==============================] - 5s 686us/step - loss: 0.0288 - val_loss: 0.0292
# Epoch 98/200
# mean max of probabilities: 0.2692925 - temperature 0.61228204
# 8000/8000 [==============================] - 5s 658us/step - loss: 0.0287 - val_loss: 0.0290
# Epoch 99/200
# mean max of probabilities: 0.27819082 - temperature 0.5949025
# 8000/8000 [==============================] - 6s 732us/step - loss: 0.0288 - val_loss: 0.0287
# Epoch 100/200
# mean max of probabilities: 0.28790542 - temperature 0.5780162
# 8000/8000 [==============================] - 6s 783us/step - loss: 0.0290 - val_loss: 0.0289
# Epoch 101/200
# mean max of probabilities: 0.29634756 - temperature 0.56160927
# 8000/8000 [==============================] - 5s 636us/step - loss: 0.0288 - val_loss: 0.0286
# Epoch 102/200
# mean max of probabilities: 0.30509537 - temperature 0.5456681
# 8000/8000 [==============================] - 6s 695us/step - loss: 0.0289 - val_loss: 0.0290
# Epoch 103/200
# mean max of probabilities: 0.3138522 - temperature 0.5301795
# 8000/8000 [==============================] - 5s 674us/step - loss: 0.0289 - val_loss: 0.0289
# Epoch 104/200
# mean max of probabilities: 0.3224078 - temperature 0.5151305
# 8000/8000 [==============================] - 7s 814us/step - loss: 0.0288 - val_loss: 0.0291
# Epoch 105/200
# mean max of probabilities: 0.33129942 - temperature 0.5005086
# 8000/8000 [==============================] - 6s 812us/step - loss: 0.0288 - val_loss: 0.0293
# Epoch 106/200
# mean max of probabilities: 0.34105584 - temperature 0.48630178
# 8000/8000 [==============================] - 6s 751us/step - loss: 0.0288 - val_loss: 0.0288
# Epoch 107/200
# mean max of probabilities: 0.3491839 - temperature 0.47249824
# 8000/8000 [==============================] - 7s 859us/step - loss: 0.0288 - val_loss: 0.0289
# Epoch 108/200
# mean max of probabilities: 0.35739255 - temperature 0.45908657
# 8000/8000 [==============================] - 7s 852us/step - loss: 0.0288 - val_loss: 0.0286
# Epoch 109/200
# mean max of probabilities: 0.3666913 - temperature 0.44605547
# 8000/8000 [==============================] - 7s 860us/step - loss: 0.0287 - val_loss: 0.0289
# Epoch 110/200
# mean max of probabilities: 0.37531462 - temperature 0.43339437
# 8000/8000 [==============================] - 6s 790us/step - loss: 0.0286 - val_loss: 0.0290
# Epoch 111/200
# mean max of probabilities: 0.38261083 - temperature 0.42109263
# 8000/8000 [==============================] - 7s 824us/step - loss: 0.0287 - val_loss: 0.0290
# Epoch 112/200
# mean max of probabilities: 0.3907589 - temperature 0.40914014
# 8000/8000 [==============================] - 7s 843us/step - loss: 0.0286 - val_loss: 0.0288
# Epoch 113/200
# mean max of probabilities: 0.39945376 - temperature 0.39752677
# 8000/8000 [==============================] - 6s 788us/step - loss: 0.0289 - val_loss: 0.0289
# Epoch 114/200
# mean max of probabilities: 0.40786648 - temperature 0.38624313
# 8000/8000 [==============================] - 6s 752us/step - loss: 0.0288 - val_loss: 0.0287
# Epoch 115/200
# mean max of probabilities: 0.41650376 - temperature 0.37527984
# 8000/8000 [==============================] - 6s 746us/step - loss: 0.0288 - val_loss: 0.0288
# Epoch 116/200
# mean max of probabilities: 0.4237949 - temperature 0.36462763
# 8000/8000 [==============================] - 6s 690us/step - loss: 0.0285 - val_loss: 0.0288
# Epoch 117/200
# mean max of probabilities: 0.4309191 - temperature 0.35427782
# 8000/8000 [==============================] - 6s 791us/step - loss: 0.0287 - val_loss: 0.0286
# Epoch 118/200
# mean max of probabilities: 0.438599 - temperature 0.34422177
# 8000/8000 [==============================] - 6s 768us/step - loss: 0.0285 - val_loss: 0.0286
# Epoch 119/200
# mean max of probabilities: 0.4469689 - temperature 0.3344512
# 8000/8000 [==============================] - 7s 833us/step - loss: 0.0286 - val_loss: 0.0291
# Epoch 120/200
# mean max of probabilities: 0.45302495 - temperature 0.32495785
# 8000/8000 [==============================] - 7s 890us/step - loss: 0.0285 - val_loss: 0.0284
# Epoch 121/200
# mean max of probabilities: 0.46041748 - temperature 0.31573397
# 8000/8000 [==============================] - 6s 759us/step - loss: 0.0285 - val_loss: 0.0284
# Epoch 122/200
# mean max of probabilities: 0.4678789 - temperature 0.30677187
# 8000/8000 [==============================] - 6s 752us/step - loss: 0.0285 - val_loss: 0.0283
# Epoch 123/200
# mean max of probabilities: 0.47479478 - temperature 0.29806426
# 8000/8000 [==============================] - 6s 808us/step - loss: 0.0283 - val_loss: 0.0283
# Epoch 124/200
# mean max of probabilities: 0.48278913 - temperature 0.28960377
# 8000/8000 [==============================] - 6s 719us/step - loss: 0.0284 - val_loss: 0.0285
# Epoch 125/200
# mean max of probabilities: 0.48954505 - temperature 0.28138345
# 8000/8000 [==============================] - 6s 691us/step - loss: 0.0283 - val_loss: 0.0288
# Epoch 126/200
# mean max of probabilities: 0.49611354 - temperature 0.27339643
# 8000/8000 [==============================] - 5s 622us/step - loss: 0.0285 - val_loss: 0.0280
# Epoch 127/200
# mean max of probabilities: 0.50269467 - temperature 0.26563624
# 8000/8000 [==============================] - 7s 828us/step - loss: 0.0283 - val_loss: 0.0283
# Epoch 128/200
# mean max of probabilities: 0.5081312 - temperature 0.25809625
# 8000/8000 [==============================] - 7s 853us/step - loss: 0.0283 - val_loss: 0.0285
# Epoch 129/200
# mean max of probabilities: 0.51275015 - temperature 0.25077027
# 8000/8000 [==============================] - 6s 801us/step - loss: 0.0283 - val_loss: 0.0282
# Epoch 130/200
# mean max of probabilities: 0.5191031 - temperature 0.24365218
# 8000/8000 [==============================] - 6s 781us/step - loss: 0.0281 - val_loss: 0.0283
# Epoch 131/200
# mean max of probabilities: 0.52528715 - temperature 0.23673621
# 8000/8000 [==============================] - 6s 717us/step - loss: 0.0285 - val_loss: 0.0283
# Epoch 132/200
# mean max of probabilities: 0.5321156 - temperature 0.23001644
# 8000/8000 [==============================] - 6s 723us/step - loss: 0.0281 - val_loss: 0.0282
# Epoch 133/200
# mean max of probabilities: 0.53752655 - temperature 0.22348751
# 8000/8000 [==============================] - 6s 779us/step - loss: 0.0281 - val_loss: 0.0282
# Epoch 134/200
# mean max of probabilities: 0.5416041 - temperature 0.21714388
# 8000/8000 [==============================] - 7s 824us/step - loss: 0.0281 - val_loss: 0.0281
# Epoch 135/200
# mean max of probabilities: 0.5473756 - temperature 0.21098028
# 8000/8000 [==============================] - 4s 512us/step - loss: 0.0280 - val_loss: 0.0282
# Epoch 136/200
# mean max of probabilities: 0.553467 - temperature 0.20499171
# 8000/8000 [==============================] - 6s 714us/step - loss: 0.0283 - val_loss: 0.0280
# Epoch 137/200
# mean max of probabilities: 0.55965877 - temperature 0.1991731
# 8000/8000 [==============================] - 6s 698us/step - loss: 0.0279 - val_loss: 0.0278
# Epoch 138/200
# mean max of probabilities: 0.5652255 - temperature 0.19351965
# 8000/8000 [==============================] - 6s 696us/step - loss: 0.0281 - val_loss: 0.0280
# Epoch 139/200
# mean max of probabilities: 0.5704643 - temperature 0.18802667
# 8000/8000 [==============================] - 6s 705us/step - loss: 0.0280 - val_loss: 0.0280
# Epoch 140/200
# mean max of probabilities: 0.5758884 - temperature 0.18268959
# 8000/8000 [==============================] - 5s 684us/step - loss: 0.0280 - val_loss: 0.0280
# Epoch 141/200
# mean max of probabilities: 0.5809337 - temperature 0.177504
# 8000/8000 [==============================] - 5s 659us/step - loss: 0.0279 - val_loss: 0.0281
# Epoch 142/200
# mean max of probabilities: 0.5858157 - temperature 0.17246558
# 8000/8000 [==============================] - 5s 638us/step - loss: 0.0281 - val_loss: 0.0282
# Epoch 143/200
# mean max of probabilities: 0.58940566 - temperature 0.16757023
# 8000/8000 [==============================] - 5s 665us/step - loss: 0.0278 - val_loss: 0.0277
# Epoch 144/200
# mean max of probabilities: 0.5948518 - temperature 0.16281381
# 8000/8000 [==============================] - 5s 658us/step - loss: 0.0278 - val_loss: 0.0279
# Epoch 145/200
# mean max of probabilities: 0.5996564 - temperature 0.15819237
# 8000/8000 [==============================] - 5s 677us/step - loss: 0.0280 - val_loss: 0.0279
# Epoch 146/200
# mean max of probabilities: 0.60639143 - temperature 0.15370214
# 8000/8000 [==============================] - 6s 706us/step - loss: 0.0279 - val_loss: 0.0279
# Epoch 147/200
# mean max of probabilities: 0.6116677 - temperature 0.14933935
# 8000/8000 [==============================] - 5s 648us/step - loss: 0.0278 - val_loss: 0.0279
# Epoch 148/200
# mean max of probabilities: 0.6166291 - temperature 0.14510038
# 8000/8000 [==============================] - 5s 665us/step - loss: 0.0278 - val_loss: 0.0280
# Epoch 149/200
# mean max of probabilities: 0.6207137 - temperature 0.14098178
# 8000/8000 [==============================] - 6s 777us/step - loss: 0.0278 - val_loss: 0.0278
# Epoch 150/200
# mean max of probabilities: 0.62557596 - temperature 0.13698006
# 8000/8000 [==============================] - 6s 692us/step - loss: 0.0278 - val_loss: 0.0280
# Epoch 151/200
# mean max of probabilities: 0.6313802 - temperature 0.13309194
# 8000/8000 [==============================] - 5s 640us/step - loss: 0.0278 - val_loss: 0.0275
# Epoch 152/200
# mean max of probabilities: 0.63606 - temperature 0.12931417
# 8000/8000 [==============================] - 6s 758us/step - loss: 0.0277 - val_loss: 0.0277
# Epoch 153/200
# mean max of probabilities: 0.6406885 - temperature 0.12564364
# 8000/8000 [==============================] - 6s 765us/step - loss: 0.0277 - val_loss: 0.0277
# Epoch 154/200
# mean max of probabilities: 0.6467413 - temperature 0.12207729
# 8000/8000 [==============================] - 6s 728us/step - loss: 0.0276 - val_loss: 0.0278
# Epoch 155/200
# mean max of probabilities: 0.6517336 - temperature 0.11861218
# 8000/8000 [==============================] - 5s 662us/step - loss: 0.0277 - val_loss: 0.0275
# Epoch 156/200
# mean max of probabilities: 0.655298 - temperature 0.11524539
# 8000/8000 [==============================] - 5s 638us/step - loss: 0.0276 - val_loss: 0.0274
# Epoch 157/200
# mean max of probabilities: 0.65938926 - temperature 0.11197418
# 8000/8000 [==============================] - 5s 615us/step - loss: 0.0275 - val_loss: 0.0275
# Epoch 158/200
# mean max of probabilities: 0.6634559 - temperature 0.10879583
# 8000/8000 [==============================] - 5s 610us/step - loss: 0.0276 - val_loss: 0.0274
# Epoch 159/200
# mean max of probabilities: 0.6683661 - temperature 0.105707705
# 8000/8000 [==============================] - 5s 658us/step - loss: 0.0276 - val_loss: 0.0278
# Epoch 160/200
# mean max of probabilities: 0.6720511 - temperature 0.10270717
# 8000/8000 [==============================] - 6s 773us/step - loss: 0.0275 - val_loss: 0.0274
# Epoch 161/200
# mean max of probabilities: 0.6768343 - temperature 0.1
# 8000/8000 [==============================] - 6s 718us/step - loss: 0.0275 - val_loss: 0.0277
# Epoch 162/200
# mean max of probabilities: 0.6809548 - temperature 0.1
# 8000/8000 [==============================] - 6s 745us/step - loss: 0.0274 - val_loss: 0.0278
# Epoch 163/200
# mean max of probabilities: 0.6853881 - temperature 0.1
# 8000/8000 [==============================] - 5s 599us/step - loss: 0.0274 - val_loss: 0.0274
# Epoch 164/200
# mean max of probabilities: 0.69049585 - temperature 0.1
# 8000/8000 [==============================] - 5s 675us/step - loss: 0.0275 - val_loss: 0.0274
# Epoch 165/200
# mean max of probabilities: 0.69355893 - temperature 0.1
# 8000/8000 [==============================] - 6s 733us/step - loss: 0.0275 - val_loss: 0.0272
# Epoch 166/200
# mean max of probabilities: 0.69782907 - temperature 0.1
# 8000/8000 [==============================] - 6s 728us/step - loss: 0.0274 - val_loss: 0.0273
# Epoch 167/200
# mean max of probabilities: 0.70235145 - temperature 0.1
# 8000/8000 [==============================] - 6s 767us/step - loss: 0.0274 - val_loss: 0.0275
# Epoch 168/200
# mean max of probabilities: 0.707021 - temperature 0.1
# 8000/8000 [==============================] - 5s 677us/step - loss: 0.0274 - val_loss: 0.0273
# Epoch 169/200
# mean max of probabilities: 0.7110543 - temperature 0.1
# 8000/8000 [==============================] - 6s 723us/step - loss: 0.0273 - val_loss: 0.0273
# Epoch 170/200
# mean max of probabilities: 0.71484476 - temperature 0.1
# 8000/8000 [==============================] - 6s 796us/step - loss: 0.0273 - val_loss: 0.0273
# Epoch 171/200
# mean max of probabilities: 0.718168 - temperature 0.1
# 8000/8000 [==============================] - 6s 690us/step - loss: 0.0272 - val_loss: 0.0269
# Epoch 172/200
# mean max of probabilities: 0.7220633 - temperature 0.1
# 8000/8000 [==============================] - 6s 700us/step - loss: 0.0271 - val_loss: 0.0272
# Epoch 173/200
# mean max of probabilities: 0.7259832 - temperature 0.1
# 8000/8000 [==============================] - 7s 855us/step - loss: 0.0272 - val_loss: 0.0272
# Epoch 174/200
# mean max of probabilities: 0.7307543 - temperature 0.1
# 8000/8000 [==============================] - 6s 732us/step - loss: 0.0272 - val_loss: 0.0271
# Epoch 175/200
# mean max of probabilities: 0.73479027 - temperature 0.1
# 8000/8000 [==============================] - 6s 790us/step - loss: 0.0272 - val_loss: 0.0273
# Epoch 176/200
# mean max of probabilities: 0.73969704 - temperature 0.1
# 8000/8000 [==============================] - 6s 794us/step - loss: 0.0270 - val_loss: 0.0272
# Epoch 177/200
# mean max of probabilities: 0.7427903 - temperature 0.1
# 8000/8000 [==============================] - 7s 827us/step - loss: 0.0271 - val_loss: 0.0272
# Epoch 178/200
# mean max of probabilities: 0.74620456 - temperature 0.1
# 8000/8000 [==============================] - 7s 829us/step - loss: 0.0272 - val_loss: 0.0273
# Epoch 179/200
# mean max of probabilities: 0.74992734 - temperature 0.1
# 8000/8000 [==============================] - 8s 952us/step - loss: 0.0271 - val_loss: 0.0270
# Epoch 180/200
# mean max of probabilities: 0.7536791 - temperature 0.1
# 8000/8000 [==============================] - 6s 796us/step - loss: 0.0270 - val_loss: 0.0271
# Epoch 181/200
# mean max of probabilities: 0.7573015 - temperature 0.1
# 8000/8000 [==============================] - 6s 782us/step - loss: 0.0270 - val_loss: 0.0271
# Epoch 182/200
# mean max of probabilities: 0.76029706 - temperature 0.1
# 8000/8000 [==============================] - 6s 718us/step - loss: 0.0270 - val_loss: 0.0273
# Epoch 183/200
# mean max of probabilities: 0.7643044 - temperature 0.1
# 8000/8000 [==============================] - 6s 806us/step - loss: 0.0271 - val_loss: 0.0269
# Epoch 184/200
# mean max of probabilities: 0.76813966 - temperature 0.1
# 8000/8000 [==============================] - 6s 800us/step - loss: 0.0270 - val_loss: 0.0269
# Epoch 185/200
# mean max of probabilities: 0.7726579 - temperature 0.1
# 8000/8000 [==============================] - 7s 900us/step - loss: 0.0268 - val_loss: 0.0272
# Epoch 186/200
# mean max of probabilities: 0.77588356 - temperature 0.1
# 8000/8000 [==============================] - 7s 890us/step - loss: 0.0269 - val_loss: 0.0268
# Epoch 187/200
# mean max of probabilities: 0.77947927 - temperature 0.1
# 8000/8000 [==============================] - 6s 725us/step - loss: 0.0269 - val_loss: 0.0268
# Epoch 188/200
# mean max of probabilities: 0.78410035 - temperature 0.1
# 8000/8000 [==============================] - 6s 693us/step - loss: 0.0269 - val_loss: 0.0268
# Epoch 189/200
# mean max of probabilities: 0.78767866 - temperature 0.1
# 8000/8000 [==============================] - 7s 843us/step - loss: 0.0268 - val_loss: 0.0269
# Epoch 190/200
# mean max of probabilities: 0.7900077 - temperature 0.1
# 8000/8000 [==============================] - 7s 865us/step - loss: 0.0269 - val_loss: 0.0270
# Epoch 191/200
# mean max of probabilities: 0.7942104 - temperature 0.1
# 8000/8000 [==============================] - 7s 879us/step - loss: 0.0268 - val_loss: 0.0270
# Epoch 192/200
# mean max of probabilities: 0.79781663 - temperature 0.1
# 8000/8000 [==============================] - 7s 843us/step - loss: 0.0269 - val_loss: 0.0267
# Epoch 193/200
# mean max of probabilities: 0.80059564 - temperature 0.1
# 8000/8000 [==============================] - 7s 893us/step - loss: 0.0268 - val_loss: 0.0267
# Epoch 194/200
# mean max of probabilities: 0.8046119 - temperature 0.1
# 8000/8000 [==============================] - 6s 766us/step - loss: 0.0268 - val_loss: 0.0267
# Epoch 195/200
# mean max of probabilities: 0.80771613 - temperature 0.1
# 8000/8000 [==============================] - 7s 918us/step - loss: 0.0267 - val_loss: 0.0266
# Epoch 196/200
# mean max of probabilities: 0.8108697 - temperature 0.1
# 8000/8000 [==============================] - 6s 748us/step - loss: 0.0269 - val_loss: 0.0268
# Epoch 197/200
# mean max of probabilities: 0.8133165 - temperature 0.1
# 8000/8000 [==============================] - 7s 840us/step - loss: 0.0267 - val_loss: 0.0268
# Epoch 198/200
# mean max of probabilities: 0.816615 - temperature 0.1
# 8000/8000 [==============================] - 7s 829us/step - loss: 0.0267 - val_loss: 0.0267
# Epoch 199/200
# mean max of probabilities: 0.8193187 - temperature 0.1
# 8000/8000 [==============================] - 7s 842us/step - loss: 0.0266 - val_loss: 0.0267
# Epoch 200/200
# mean max of probabilities: 0.82169986 - temperature 0.1
# 8000/8000 [==============================] - 7s 824us/step - loss: 0.0266 - val_loss: 0.0273
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.8525
# Testing accuracy： 0.8525
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.805
# Testing accuracy： 0.805
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 25)                19601
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               20384
# =================================================================
# Total params: 39,985
# Trainable params: 39,984
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/200
# mean max of probabilities: 0.0014252727 - temperature 10.0
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0792 - val_loss: 0.0646
# Epoch 2/200
# mean max of probabilities: 0.001477568 - temperature 9.716152
# 8000/8000 [==============================] - 6s 774us/step - loss: 0.0647 - val_loss: 0.0639
# Epoch 3/200
# mean max of probabilities: 0.0015722392 - temperature 9.440363
# 8000/8000 [==============================] - 6s 759us/step - loss: 0.0641 - val_loss: 0.0635
# Epoch 4/200
# mean max of probabilities: 0.0017067903 - temperature 9.172401
# 6293/8000 [======================>.......] - ETA: 1s - loss: 0.0636
