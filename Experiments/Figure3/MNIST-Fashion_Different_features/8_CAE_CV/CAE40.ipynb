# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.model_selection import train_test_split
import scipy.sparse as sparse
from keras.datasets import fashion_mnist

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
num_data_used=10000
(x_train_, y_train_), (x_test_, y_test_) = fashion_mnist.load_data()
x_data=np.r_[x_train_,x_test_].reshape(70000, 28*28).astype('float32')/255.0
y_data=np.r_[y_train_,y_test_]

np.random.seed(seed)
x_data_num,_=x_data.shape
index=np.arange(x_data_num)
np.random.shuffle(index)

data_arr=x_data[index][0:num_data_used]
label_arr_onehot=y_data[index][0:num_data_used]

# %%
key_feture_number=40

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log"+str(key_feture_number)+"/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log"+str(key_feture_number)+"/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,5):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 40)                31361
# _________________________________________________________________
# dense_1 (Dense)              (None, 784)               32144
# =================================================================
# Total params: 63,505
# Trainable params: 63,504
# Non-trainable params: 1
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/200
# mean max of probabilities: 0.0014232335 - temperature 10.0
# 8000/8000 [==============================] - 6s 810us/step - loss: 0.0746 - val_loss: 0.0648
# Epoch 2/200
# mean max of probabilities: 0.0014548299 - temperature 9.716152
# 8000/8000 [==============================] - 6s 695us/step - loss: 0.0646 - val_loss: 0.0642
# Epoch 3/200
# mean max of probabilities: 0.0015207402 - temperature 9.440363
# 8000/8000 [==============================] - 6s 753us/step - loss: 0.0640 - val_loss: 0.0637
# Epoch 4/200
# mean max of probabilities: 0.0016144596 - temperature 9.172401
# 8000/8000 [==============================] - 6s 768us/step - loss: 0.0638 - val_loss: 0.0636
# Epoch 5/200
# mean max of probabilities: 0.0017360076 - temperature 8.912045
# 8000/8000 [==============================] - 6s 697us/step - loss: 0.0636 - val_loss: 0.0635
# Epoch 6/200
# mean max of probabilities: 0.001880065 - temperature 8.6590805
# 8000/8000 [==============================] - 5s 636us/step - loss: 0.0635 - val_loss: 0.0635
# Epoch 7/200
# mean max of probabilities: 0.0020595028 - temperature 8.413296
# 8000/8000 [==============================] - 5s 651us/step - loss: 0.0634 - val_loss: 0.0632
# Epoch 8/200
# mean max of probabilities: 0.0022958294 - temperature 8.174487
# 8000/8000 [==============================] - 5s 643us/step - loss: 0.0631 - val_loss: 0.0630
# Epoch 9/200
# mean max of probabilities: 0.002620653 - temperature 7.942457
# 8000/8000 [==============================] - 6s 787us/step - loss: 0.0626 - val_loss: 0.0621
# Epoch 10/200
# mean max of probabilities: 0.0030632894 - temperature 7.7170134
# 8000/8000 [==============================] - 7s 824us/step - loss: 0.0615 - val_loss: 0.0605
# Epoch 11/200
# mean max of probabilities: 0.0036422536 - temperature 7.4979672
# 8000/8000 [==============================] - 6s 803us/step - loss: 0.0596 - val_loss: 0.0582
# Epoch 12/200
# mean max of probabilities: 0.004340262 - temperature 7.2851405
# 8000/8000 [==============================] - 7s 855us/step - loss: 0.0567 - val_loss: 0.0549
# Epoch 13/200
# mean max of probabilities: 0.0050926497 - temperature 7.078353
# 8000/8000 [==============================] - 7s 896us/step - loss: 0.0534 - val_loss: 0.0512
# Epoch 14/200
# mean max of probabilities: 0.005831788 - temperature 6.8774366
# 8000/8000 [==============================] - 7s 835us/step - loss: 0.0502 - val_loss: 0.0487
# Epoch 15/200
# mean max of probabilities: 0.006498101 - temperature 6.6822195
# 8000/8000 [==============================] - 6s 747us/step - loss: 0.0481 - val_loss: 0.0470
# Epoch 16/200
# mean max of probabilities: 0.0070336787 - temperature 6.4925466
# 8000/8000 [==============================] - 6s 710us/step - loss: 0.0471 - val_loss: 0.0463
# Epoch 17/200
# mean max of probabilities: 0.007425072 - temperature 6.3082566
# 8000/8000 [==============================] - 6s 712us/step - loss: 0.0467 - val_loss: 0.0460
# Epoch 18/200
# mean max of probabilities: 0.0077026277 - temperature 6.129198
# 8000/8000 [==============================] - 6s 804us/step - loss: 0.0465 - val_loss: 0.0461
# Epoch 19/200
# mean max of probabilities: 0.007933145 - temperature 5.955221
# 8000/8000 [==============================] - 7s 897us/step - loss: 0.0464 - val_loss: 0.0458
# Epoch 20/200
# mean max of probabilities: 0.008158767 - temperature 5.786184
# 8000/8000 [==============================] - 7s 908us/step - loss: 0.0462 - val_loss: 0.0456
# Epoch 21/200
# mean max of probabilities: 0.008449541 - temperature 5.621946
# 8000/8000 [==============================] - 6s 690us/step - loss: 0.0459 - val_loss: 0.0453
# Epoch 22/200
# mean max of probabilities: 0.008813505 - temperature 5.4623694
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0455 - val_loss: 0.0450
# Epoch 23/200
# mean max of probabilities: 0.009328463 - temperature 5.307321
# 8000/8000 [==============================] - 8s 951us/step - loss: 0.0449 - val_loss: 0.0443
# Epoch 24/200
# mean max of probabilities: 0.010042792 - temperature 5.1566744
# 8000/8000 [==============================] - 7s 924us/step - loss: 0.0442 - val_loss: 0.0433
# Epoch 25/200
# mean max of probabilities: 0.010906285 - temperature 5.010304
# 8000/8000 [==============================] - 6s 798us/step - loss: 0.0433 - val_loss: 0.0423
# Epoch 26/200
# mean max of probabilities: 0.011954677 - temperature 4.8680882
# 8000/8000 [==============================] - 6s 787us/step - loss: 0.0423 - val_loss: 0.0415
# Epoch 27/200
# mean max of probabilities: 0.013167428 - temperature 4.7299085
# 8000/8000 [==============================] - 6s 734us/step - loss: 0.0412 - val_loss: 0.0402
# Epoch 28/200
# mean max of probabilities: 0.014534786 - temperature 4.595652
# 8000/8000 [==============================] - 6s 784us/step - loss: 0.0401 - val_loss: 0.0392
# Epoch 29/200
# mean max of probabilities: 0.016007606 - temperature 4.4652066
# 8000/8000 [==============================] - 6s 772us/step - loss: 0.0390 - val_loss: 0.0382
# Epoch 30/200
# mean max of probabilities: 0.017516712 - temperature 4.338463
# 8000/8000 [==============================] - 8s 969us/step - loss: 0.0380 - val_loss: 0.0373
# Epoch 31/200
# mean max of probabilities: 0.01915495 - temperature 4.2153172
# 8000/8000 [==============================] - 7s 865us/step - loss: 0.0371 - val_loss: 0.0364
# Epoch 32/200
# mean max of probabilities: 0.02092868 - temperature 4.095666
# 8000/8000 [==============================] - 5s 668us/step - loss: 0.0362 - val_loss: 0.0356
# Epoch 33/200
# mean max of probabilities: 0.022738725 - temperature 3.979412
# 8000/8000 [==============================] - 7s 819us/step - loss: 0.0354 - val_loss: 0.0349
# Epoch 34/200
# mean max of probabilities: 0.024727577 - temperature 3.8664572
# 8000/8000 [==============================] - 5s 642us/step - loss: 0.0346 - val_loss: 0.0340
# Epoch 35/200
# mean max of probabilities: 0.02679063 - temperature 3.7567089
# 8000/8000 [==============================] - 7s 883us/step - loss: 0.0338 - val_loss: 0.0333
# Epoch 36/200
# mean max of probabilities: 0.029033268 - temperature 3.650076
# 8000/8000 [==============================] - 7s 844us/step - loss: 0.0330 - val_loss: 0.0325
# Epoch 37/200
# mean max of probabilities: 0.03137861 - temperature 3.5464702
# 8000/8000 [==============================] - 8s 953us/step - loss: 0.0322 - val_loss: 0.0317
# Epoch 38/200
# mean max of probabilities: 0.033921815 - temperature 3.445804
# 8000/8000 [==============================] - 6s 783us/step - loss: 0.0315 - val_loss: 0.0311
# Epoch 39/200
# mean max of probabilities: 0.036469582 - temperature 3.3479955
# 8000/8000 [==============================] - 6s 777us/step - loss: 0.0309 - val_loss: 0.0306
# Epoch 40/200
# mean max of probabilities: 0.03905761 - temperature 3.2529633
# 8000/8000 [==============================] - 8s 977us/step - loss: 0.0303 - val_loss: 0.0301
# Epoch 41/200
# mean max of probabilities: 0.041529447 - temperature 3.1606295
# 8000/8000 [==============================] - 7s 826us/step - loss: 0.0298 - val_loss: 0.0296
# Epoch 42/200
# mean max of probabilities: 0.0437516 - temperature 3.0709162
# 8000/8000 [==============================] - 6s 801us/step - loss: 0.0293 - val_loss: 0.0292
# Epoch 43/200
# mean max of probabilities: 0.045822047 - temperature 2.9837487
# 8000/8000 [==============================] - 7s 832us/step - loss: 0.0289 - val_loss: 0.0287
# Epoch 44/200
# mean max of probabilities: 0.047753654 - temperature 2.8990557
# 8000/8000 [==============================] - 8s 983us/step - loss: 0.0285 - val_loss: 0.0284
# Epoch 45/200
# mean max of probabilities: 0.04985066 - temperature 2.8167667
# 8000/8000 [==============================] - 6s 788us/step - loss: 0.0281 - val_loss: 0.0279
# Epoch 46/200
# mean max of probabilities: 0.052246045 - temperature 2.7368128
# 8000/8000 [==============================] - 7s 837us/step - loss: 0.0277 - val_loss: 0.0275
# Epoch 47/200
# mean max of probabilities: 0.054941155 - temperature 2.659129
# 8000/8000 [==============================] - 6s 764us/step - loss: 0.0273 - val_loss: 0.0272
# Epoch 48/200
# mean max of probabilities: 0.0582285 - temperature 2.5836504
# 8000/8000 [==============================] - 7s 833us/step - loss: 0.0269 - val_loss: 0.0268
# Epoch 49/200
# mean max of probabilities: 0.061312716 - temperature 2.5103142
# 8000/8000 [==============================] - 6s 737us/step - loss: 0.0266 - val_loss: 0.0265
# Epoch 50/200
# mean max of probabilities: 0.06381958 - temperature 2.43906
# 8000/8000 [==============================] - 6s 766us/step - loss: 0.0262 - val_loss: 0.0261
# Epoch 51/200
# mean max of probabilities: 0.06682238 - temperature 2.369828
# 8000/8000 [==============================] - 6s 794us/step - loss: 0.0259 - val_loss: 0.0258
# Epoch 52/200
# mean max of probabilities: 0.069832996 - temperature 2.3025618
# 8000/8000 [==============================] - 6s 798us/step - loss: 0.0256 - val_loss: 0.0255
# Epoch 53/200
# mean max of probabilities: 0.07299237 - temperature 2.2372043
# 8000/8000 [==============================] - 7s 823us/step - loss: 0.0252 - val_loss: 0.0253
# Epoch 54/200
# mean max of probabilities: 0.07566321 - temperature 2.173702
# 8000/8000 [==============================] - 6s 804us/step - loss: 0.0249 - val_loss: 0.0249
# Epoch 55/200
# mean max of probabilities: 0.077854276 - temperature 2.1120012
# 8000/8000 [==============================] - 7s 819us/step - loss: 0.0247 - val_loss: 0.0247
# Epoch 56/200
# mean max of probabilities: 0.08014975 - temperature 2.0520527
# 8000/8000 [==============================] - 7s 858us/step - loss: 0.0245 - val_loss: 0.0244
# Epoch 57/200
# mean max of probabilities: 0.08221654 - temperature 1.993806
# 8000/8000 [==============================] - 7s 883us/step - loss: 0.0243 - val_loss: 0.0242
# Epoch 58/200
# mean max of probabilities: 0.084047444 - temperature 1.9372126
# 8000/8000 [==============================] - 6s 694us/step - loss: 0.0241 - val_loss: 0.0242
# Epoch 59/200
# mean max of probabilities: 0.08600519 - temperature 1.8822256
# 8000/8000 [==============================] - 7s 879us/step - loss: 0.0240 - val_loss: 0.0241
# Epoch 60/200
# mean max of probabilities: 0.08737544 - temperature 1.8287995
# 8000/8000 [==============================] - 7s 816us/step - loss: 0.0238 - val_loss: 0.0239
# Epoch 61/200
# mean max of probabilities: 0.08887494 - temperature 1.7768897
# 8000/8000 [==============================] - 6s 750us/step - loss: 0.0237 - val_loss: 0.0236
# Epoch 62/200
# mean max of probabilities: 0.09051354 - temperature 1.7264532
# 8000/8000 [==============================] - 6s 695us/step - loss: 0.0237 - val_loss: 0.0239
# Epoch 63/200
# mean max of probabilities: 0.09276887 - temperature 1.6774484
# 8000/8000 [==============================] - 5s 633us/step - loss: 0.0238 - val_loss: 0.0238
# Epoch 64/200
# mean max of probabilities: 0.094288036 - temperature 1.6298345
# 8000/8000 [==============================] - 6s 722us/step - loss: 0.0238 - val_loss: 0.0238
# Epoch 65/200
# mean max of probabilities: 0.09588915 - temperature 1.583572
# 8000/8000 [==============================] - 7s 827us/step - loss: 0.0238 - val_loss: 0.0239
# Epoch 66/200
# mean max of probabilities: 0.09753899 - temperature 1.5386227
# 8000/8000 [==============================] - 6s 795us/step - loss: 0.0238 - val_loss: 0.0242
# Epoch 67/200
# mean max of probabilities: 0.09918321 - temperature 1.4949492
# 8000/8000 [==============================] - 8s 965us/step - loss: 0.0238 - val_loss: 0.0238
# Epoch 68/200
# mean max of probabilities: 0.1014779 - temperature 1.4525156
# 8000/8000 [==============================] - 7s 826us/step - loss: 0.0240 - val_loss: 0.0241
# Epoch 69/200
# mean max of probabilities: 0.10350585 - temperature 1.4112862
# 8000/8000 [==============================] - 6s 771us/step - loss: 0.0241 - val_loss: 0.0240
# Epoch 70/200
# mean max of probabilities: 0.10524587 - temperature 1.3712273
# 8000/8000 [==============================] - 4s 558us/step - loss: 0.0242 - val_loss: 0.0242
# Epoch 71/200
# mean max of probabilities: 0.107791625 - temperature 1.3323054
# 8000/8000 [==============================] - 7s 814us/step - loss: 0.0242 - val_loss: 0.0242
# Epoch 72/200
# mean max of probabilities: 0.110716745 - temperature 1.2944883
# 8000/8000 [==============================] - 6s 738us/step - loss: 0.0241 - val_loss: 0.0246
# Epoch 73/200
# mean max of probabilities: 0.11361285 - temperature 1.2577448
# 8000/8000 [==============================] - 6s 720us/step - loss: 0.0244 - val_loss: 0.0244
# Epoch 74/200
# mean max of probabilities: 0.11696454 - temperature 1.2220443
# 8000/8000 [==============================] - 6s 717us/step - loss: 0.0245 - val_loss: 0.0246
# Epoch 75/200
# mean max of probabilities: 0.12061749 - temperature 1.1873572
# 8000/8000 [==============================] - 6s 790us/step - loss: 0.0245 - val_loss: 0.0247
# Epoch 76/200
# mean max of probabilities: 0.12460456 - temperature 1.1536546
# 8000/8000 [==============================] - 7s 852us/step - loss: 0.0244 - val_loss: 0.0245
# Epoch 77/200
# mean max of probabilities: 0.12966958 - temperature 1.1209084
# 8000/8000 [==============================] - 6s 804us/step - loss: 0.0246 - val_loss: 0.0250
# Epoch 78/200
# mean max of probabilities: 0.13523035 - temperature 1.089092
# 8000/8000 [==============================] - 6s 717us/step - loss: 0.0247 - val_loss: 0.0248
# Epoch 79/200
# mean max of probabilities: 0.14065392 - temperature 1.0581783
# 8000/8000 [==============================] - 7s 901us/step - loss: 0.0247 - val_loss: 0.0243
# Epoch 80/200
# mean max of probabilities: 0.14675996 - temperature 1.0281421
# 8000/8000 [==============================] - 6s 778us/step - loss: 0.0247 - val_loss: 0.0245
# Epoch 81/200
# mean max of probabilities: 0.15335509 - temperature 0.9989582
# 8000/8000 [==============================] - 7s 871us/step - loss: 0.0247 - val_loss: 0.0247
# Epoch 82/200
# mean max of probabilities: 0.16009662 - temperature 0.970603
# 8000/8000 [==============================] - 7s 845us/step - loss: 0.0248 - val_loss: 0.0249
# Epoch 83/200
# mean max of probabilities: 0.16710797 - temperature 0.9430529
# 8000/8000 [==============================] - 7s 866us/step - loss: 0.0247 - val_loss: 0.0248
# Epoch 84/200
# mean max of probabilities: 0.17443366 - temperature 0.91628474
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0248 - val_loss: 0.0251
# Epoch 85/200
# mean max of probabilities: 0.18243976 - temperature 0.8902763
# 8000/8000 [==============================] - 8s 957us/step - loss: 0.0249 - val_loss: 0.0248
# Epoch 86/200
# mean max of probabilities: 0.1911954 - temperature 0.865006
# 8000/8000 [==============================] - 8s 938us/step - loss: 0.0249 - val_loss: 0.0250
# Epoch 87/200
# mean max of probabilities: 0.20033428 - temperature 0.84045327
# 8000/8000 [==============================] - 7s 901us/step - loss: 0.0247 - val_loss: 0.0250
# Epoch 88/200
# mean max of probabilities: 0.20932415 - temperature 0.8165973
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0248 - val_loss: 0.0247
# Epoch 89/200
# mean max of probabilities: 0.22014566 - temperature 0.7934184
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0248 - val_loss: 0.0248
# Epoch 90/200
# mean max of probabilities: 0.23006615 - temperature 0.7708973
# 8000/8000 [==============================] - 8s 973us/step - loss: 0.0248 - val_loss: 0.0252
# Epoch 91/200
# mean max of probabilities: 0.23998412 - temperature 0.74901587
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0248 - val_loss: 0.0248
# Epoch 92/200
# mean max of probabilities: 0.2508244 - temperature 0.7277553
# 8000/8000 [==============================] - 8s 970us/step - loss: 0.0248 - val_loss: 0.0248
# Epoch 93/200
# mean max of probabilities: 0.26072842 - temperature 0.7070981
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0247 - val_loss: 0.0250
# Epoch 94/200
# mean max of probabilities: 0.27161962 - temperature 0.68702734
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.0247 - val_loss: 0.0247
# Epoch 95/200
# mean max of probabilities: 0.2820238 - temperature 0.6675263
# 8000/8000 [==============================] - 7s 880us/step - loss: 0.0247 - val_loss: 0.0248
# Epoch 96/200
# mean max of probabilities: 0.29320544 - temperature 0.64857894
# 8000/8000 [==============================] - 7s 877us/step - loss: 0.0246 - val_loss: 0.0247
# Epoch 97/200
# mean max of probabilities: 0.30376983 - temperature 0.6301691
# 8000/8000 [==============================] - 7s 875us/step - loss: 0.0246 - val_loss: 0.0245
# Epoch 98/200
# mean max of probabilities: 0.31478626 - temperature 0.61228204
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0245 - val_loss: 0.0245
# Epoch 99/200
# mean max of probabilities: 0.32660902 - temperature 0.5949025
# 8000/8000 [==============================] - 8s 967us/step - loss: 0.0245 - val_loss: 0.0243
# Epoch 100/200
# mean max of probabilities: 0.3383966 - temperature 0.5780162
# 8000/8000 [==============================] - 6s 791us/step - loss: 0.0244 - val_loss: 0.0243
# Epoch 101/200
# mean max of probabilities: 0.35070032 - temperature 0.56160927
# 8000/8000 [==============================] - 8s 993us/step - loss: 0.0244 - val_loss: 0.0242
# Epoch 102/200
# mean max of probabilities: 0.36219868 - temperature 0.5456681
# 8000/8000 [==============================] - 6s 797us/step - loss: 0.0243 - val_loss: 0.0241
# Epoch 103/200
# mean max of probabilities: 0.37386388 - temperature 0.5301795
# 8000/8000 [==============================] - 7s 930us/step - loss: 0.0243 - val_loss: 0.0247
# Epoch 104/200
# mean max of probabilities: 0.38476855 - temperature 0.5151305
# 8000/8000 [==============================] - 7s 927us/step - loss: 0.0241 - val_loss: 0.0241
# Epoch 105/200
# mean max of probabilities: 0.39475685 - temperature 0.5005086
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0240 - val_loss: 0.0241
# Epoch 106/200
# mean max of probabilities: 0.40478936 - temperature 0.48630178
# 8000/8000 [==============================] - 8s 979us/step - loss: 0.0240 - val_loss: 0.0242
# Epoch 107/200
# mean max of probabilities: 0.41540685 - temperature 0.47249824
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0240 - val_loss: 0.0238
# Epoch 108/200
# mean max of probabilities: 0.42491788 - temperature 0.45908657
# 8000/8000 [==============================] - 8s 952us/step - loss: 0.0240 - val_loss: 0.0239
# Epoch 109/200
# mean max of probabilities: 0.43442994 - temperature 0.44605547
# 8000/8000 [==============================] - 7s 906us/step - loss: 0.0239 - val_loss: 0.0238
# Epoch 110/200
# mean max of probabilities: 0.4435566 - temperature 0.43339437
# 8000/8000 [==============================] - 7s 921us/step - loss: 0.0239 - val_loss: 0.0239
# Epoch 111/200
# mean max of probabilities: 0.45279437 - temperature 0.42109263
# 8000/8000 [==============================] - 6s 775us/step - loss: 0.0238 - val_loss: 0.0237
# Epoch 112/200
# mean max of probabilities: 0.46099004 - temperature 0.40914014
# 8000/8000 [==============================] - 7s 892us/step - loss: 0.0236 - val_loss: 0.0236
# Epoch 113/200
# mean max of probabilities: 0.4692622 - temperature 0.39752677
# 8000/8000 [==============================] - 7s 895us/step - loss: 0.0237 - val_loss: 0.0237
# Epoch 114/200
# mean max of probabilities: 0.47743216 - temperature 0.38624313
# 8000/8000 [==============================] - 7s 908us/step - loss: 0.0236 - val_loss: 0.0237
# Epoch 115/200
# mean max of probabilities: 0.48546475 - temperature 0.37527984
# 8000/8000 [==============================] - 8s 946us/step - loss: 0.0236 - val_loss: 0.0234
# Epoch 116/200
# mean max of probabilities: 0.49233618 - temperature 0.36462763
# 8000/8000 [==============================] - 7s 837us/step - loss: 0.0235 - val_loss: 0.0232
# Epoch 117/200
# mean max of probabilities: 0.4991561 - temperature 0.35427782
# 8000/8000 [==============================] - 7s 913us/step - loss: 0.0235 - val_loss: 0.0233
# Epoch 118/200
# mean max of probabilities: 0.5057944 - temperature 0.34422177
# 8000/8000 [==============================] - 6s 743us/step - loss: 0.0233 - val_loss: 0.0234
# Epoch 119/200
# mean max of probabilities: 0.51163304 - temperature 0.3344512
# 8000/8000 [==============================] - 7s 899us/step - loss: 0.0233 - val_loss: 0.0234
# Epoch 120/200
# mean max of probabilities: 0.51769716 - temperature 0.32495785
# 8000/8000 [==============================] - 7s 858us/step - loss: 0.0233 - val_loss: 0.0230
# Epoch 121/200
# mean max of probabilities: 0.5245141 - temperature 0.31573397
# 8000/8000 [==============================] - 7s 870us/step - loss: 0.0231 - val_loss: 0.0233
# Epoch 122/200
# mean max of probabilities: 0.53133404 - temperature 0.30677187
# 8000/8000 [==============================] - 7s 849us/step - loss: 0.0232 - val_loss: 0.0233
# Epoch 123/200
# mean max of probabilities: 0.5381772 - temperature 0.29806426
# 8000/8000 [==============================] - 6s 760us/step - loss: 0.0232 - val_loss: 0.0229
# Epoch 124/200
# mean max of probabilities: 0.5448623 - temperature 0.28960377
# 8000/8000 [==============================] - 7s 814us/step - loss: 0.0231 - val_loss: 0.0231
# Epoch 125/200
# mean max of probabilities: 0.5521077 - temperature 0.28138345
# 8000/8000 [==============================] - 7s 872us/step - loss: 0.0230 - val_loss: 0.0231
# Epoch 126/200
# mean max of probabilities: 0.5583657 - temperature 0.27339643
# 8000/8000 [==============================] - 7s 871us/step - loss: 0.0232 - val_loss: 0.0228
# Epoch 127/200
# mean max of probabilities: 0.5660324 - temperature 0.26563624
# 8000/8000 [==============================] - 7s 821us/step - loss: 0.0230 - val_loss: 0.0231
# Epoch 128/200
# mean max of probabilities: 0.57348365 - temperature 0.25809625
# 8000/8000 [==============================] - 6s 803us/step - loss: 0.0229 - val_loss: 0.0232
# Epoch 129/200
# mean max of probabilities: 0.57950246 - temperature 0.25077027
# 8000/8000 [==============================] - 6s 770us/step - loss: 0.0230 - val_loss: 0.0229
# Epoch 130/200
# mean max of probabilities: 0.5865099 - temperature 0.24365218
# 8000/8000 [==============================] - 7s 816us/step - loss: 0.0231 - val_loss: 0.0230
# Epoch 131/200
# mean max of probabilities: 0.5939474 - temperature 0.23673621
# 8000/8000 [==============================] - 7s 899us/step - loss: 0.0229 - val_loss: 0.0227
# Epoch 132/200
# mean max of probabilities: 0.5999859 - temperature 0.23001644
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0229 - val_loss: 0.0228
# Epoch 133/200
# mean max of probabilities: 0.60654294 - temperature 0.22348751
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0228 - val_loss: 0.0226
# Epoch 134/200
# mean max of probabilities: 0.61273766 - temperature 0.21714388
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0227 - val_loss: 0.0230
# Epoch 135/200
# mean max of probabilities: 0.6190615 - temperature 0.21098028
# 8000/8000 [==============================] - 6s 778us/step - loss: 0.0229 - val_loss: 0.0228
# Epoch 136/200
# mean max of probabilities: 0.6254508 - temperature 0.20499171
# 8000/8000 [==============================] - 6s 771us/step - loss: 0.0228 - val_loss: 0.0228
# Epoch 137/200
# mean max of probabilities: 0.63232774 - temperature 0.1991731
# 8000/8000 [==============================] - 7s 831us/step - loss: 0.0226 - val_loss: 0.0228
# Epoch 138/200
# mean max of probabilities: 0.6388529 - temperature 0.19351965
# 8000/8000 [==============================] - 7s 827us/step - loss: 0.0228 - val_loss: 0.0228
# Epoch 139/200
# mean max of probabilities: 0.6442418 - temperature 0.18802667
# 8000/8000 [==============================] - 7s 909us/step - loss: 0.0227 - val_loss: 0.0228
# Epoch 140/200
# mean max of probabilities: 0.64895904 - temperature 0.18268959
# 8000/8000 [==============================] - 8s 943us/step - loss: 0.0227 - val_loss: 0.0224
# Epoch 141/200
# mean max of probabilities: 0.65427047 - temperature 0.177504
# 8000/8000 [==============================] - 7s 842us/step - loss: 0.0226 - val_loss: 0.0227
# Epoch 142/200
# mean max of probabilities: 0.66071236 - temperature 0.17246558
# 8000/8000 [==============================] - 7s 891us/step - loss: 0.0226 - val_loss: 0.0225
# Epoch 143/200
# mean max of probabilities: 0.66596794 - temperature 0.16757023
# 8000/8000 [==============================] - 7s 841us/step - loss: 0.0227 - val_loss: 0.0227
# Epoch 144/200
# mean max of probabilities: 0.67215985 - temperature 0.16281381
# 8000/8000 [==============================] - 7s 898us/step - loss: 0.0225 - val_loss: 0.0226
# Epoch 145/200
# mean max of probabilities: 0.6771307 - temperature 0.15819237
# 8000/8000 [==============================] - 7s 929us/step - loss: 0.0225 - val_loss: 0.0223
# Epoch 146/200
# mean max of probabilities: 0.6815734 - temperature 0.15370214
# 8000/8000 [==============================] - 8s 941us/step - loss: 0.0225 - val_loss: 0.0223
# Epoch 147/200
# mean max of probabilities: 0.6864419 - temperature 0.14933935
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0225 - val_loss: 0.0227
# Epoch 148/200
# mean max of probabilities: 0.69152856 - temperature 0.14510038
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0224 - val_loss: 0.0225
# Epoch 149/200
# mean max of probabilities: 0.6959105 - temperature 0.14098178
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0224 - val_loss: 0.0225
# Epoch 150/200
# mean max of probabilities: 0.70050466 - temperature 0.13698006
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0224 - val_loss: 0.0224
# Epoch 151/200
# mean max of probabilities: 0.7048447 - temperature 0.13309194
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0224 - val_loss: 0.0224
# Epoch 152/200
# mean max of probabilities: 0.7093841 - temperature 0.12931417
# 8000/8000 [==============================] - 8s 962us/step - loss: 0.0225 - val_loss: 0.0223
# Epoch 153/200
# mean max of probabilities: 0.7136704 - temperature 0.12564364
# 8000/8000 [==============================] - 7s 898us/step - loss: 0.0223 - val_loss: 0.0224
# Epoch 154/200
# mean max of probabilities: 0.71770006 - temperature 0.12207729
# 8000/8000 [==============================] - 7s 911us/step - loss: 0.0223 - val_loss: 0.0223
# Epoch 155/200
# mean max of probabilities: 0.72218627 - temperature 0.11861218
# 8000/8000 [==============================] - 7s 874us/step - loss: 0.0222 - val_loss: 0.0222
# Epoch 156/200
# mean max of probabilities: 0.7260343 - temperature 0.11524539
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.0223 - val_loss: 0.0223
# Epoch 157/200
# mean max of probabilities: 0.72957194 - temperature 0.11197418
# 8000/8000 [==============================] - 6s 791us/step - loss: 0.0222 - val_loss: 0.0224
# Epoch 158/200
# mean max of probabilities: 0.7332034 - temperature 0.10879583
# 8000/8000 [==============================] - 8s 941us/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 159/200
# mean max of probabilities: 0.736941 - temperature 0.105707705
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0223 - val_loss: 0.0222
# Epoch 160/200
# mean max of probabilities: 0.7398799 - temperature 0.10270717
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0223 - val_loss: 0.0224
# Epoch 161/200
# mean max of probabilities: 0.7432203 - temperature 0.1
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0222 - val_loss: 0.0222
# Epoch 162/200
# mean max of probabilities: 0.74654406 - temperature 0.1
# 8000/8000 [==============================] - 8s 945us/step - loss: 0.0222 - val_loss: 0.0223
# Epoch 163/200
# mean max of probabilities: 0.75085163 - temperature 0.1
# 8000/8000 [==============================] - 8s 955us/step - loss: 0.0221 - val_loss: 0.0222
# Epoch 164/200
# mean max of probabilities: 0.75424373 - temperature 0.1
# 8000/8000 [==============================] - 8s 953us/step - loss: 0.0222 - val_loss: 0.0226
# Epoch 165/200
# mean max of probabilities: 0.75847757 - temperature 0.1
# 8000/8000 [==============================] - 8s 950us/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 166/200
# mean max of probabilities: 0.7626481 - temperature 0.1
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 167/200
# mean max of probabilities: 0.765476 - temperature 0.1
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0220 - val_loss: 0.0220
# Epoch 168/200
# mean max of probabilities: 0.7685009 - temperature 0.1
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0220 - val_loss: 0.0220
# Epoch 169/200
# mean max of probabilities: 0.7717988 - temperature 0.1
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0220 - val_loss: 0.0220
# Epoch 170/200
# mean max of probabilities: 0.77441394 - temperature 0.1
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0220 - val_loss: 0.0219
# Epoch 171/200
# mean max of probabilities: 0.777868 - temperature 0.1
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0219 - val_loss: 0.0221
# Epoch 172/200
# mean max of probabilities: 0.78123486 - temperature 0.1
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0220 - val_loss: 0.0220
# Epoch 173/200
# mean max of probabilities: 0.7844757 - temperature 0.1
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0220 - val_loss: 0.0218
# Epoch 174/200
# mean max of probabilities: 0.7873291 - temperature 0.1
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0219 - val_loss: 0.0218
# Epoch 175/200
# mean max of probabilities: 0.79038894 - temperature 0.1
# 8000/8000 [==============================] - 8s 990us/step - loss: 0.0219 - val_loss: 0.0217
# Epoch 176/200
# mean max of probabilities: 0.7928715 - temperature 0.1
# 8000/8000 [==============================] - 8s 1ms/step - loss: 0.0218 - val_loss: 0.0220
