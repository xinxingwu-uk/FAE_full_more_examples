# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
train_data_frame=np.array(pd.read_csv('../Dataset/isolet1+2+3+4.data',header=None))
test_data_frame=np.array(pd.read_csv('../Dataset/isolet5.data',header=None))

train_data_arr=(train_data_frame[:,0:617]).copy()
train_label_arr=((train_data_frame[:,617]).copy()-1)
test_data_arr=(test_data_frame[:,0:617]).copy()
test_label_arr=((test_data_frame[:,617]).copy()-1)

data_arr=MinMaxScaler(feature_range=(0,1)).fit_transform(np.r_[train_data_arr,test_data_arr])

label_arr_onehot=np.r_[train_label_arr,test_label_arr]#to_categorical(train_label_arr)

# %%
key_feture_number=70

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log"+str(key_feture_number)+"/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log"+str(key_feture_number)+"/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,50):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 617)               0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 70)                43191
# _________________________________________________________________
# dense_1 (Dense)              (None, 617)               43807
# =================================================================
# Total params: 86,998
# Trainable params: 86,997
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 6237 samples, validate on 1560 samples
# Epoch 1/200
# mean max of probabilities: 0.0018262927 - temperature 10.0
# 6237/6237 [==============================] - 40s 6ms/step - loss: 0.0603 - val_loss: 0.0475
# Epoch 2/200
# mean max of probabilities: 0.0018356851 - temperature 9.716229
# 6237/6237 [==============================] - 25s 4ms/step - loss: 0.0476 - val_loss: 0.0474
# Epoch 3/200
# mean max of probabilities: 0.0018624897 - temperature 9.440515
# 6237/6237 [==============================] - 22s 3ms/step - loss: 0.0476 - val_loss: 0.0475
# Epoch 4/200
# mean max of probabilities: 0.0019068024 - temperature 9.172621
# 6237/6237 [==============================] - 21s 3ms/step - loss: 0.0475 - val_loss: 0.0476
# Epoch 5/200
# mean max of probabilities: 0.0019663738 - temperature 8.91233
# 6237/6237 [==============================] - 20s 3ms/step - loss: 0.0475 - val_loss: 0.0472
# Epoch 6/200
# mean max of probabilities: 0.0020453862 - temperature 8.659425
# 6237/6237 [==============================] - 27s 4ms/step - loss: 0.0475 - val_loss: 0.0469
# Epoch 7/200
# mean max of probabilities: 0.0021548255 - temperature 8.413696
# 6237/6237 [==============================] - 33s 5ms/step - loss: 0.0473 - val_loss: 0.0469
# Epoch 8/200
# mean max of probabilities: 0.0023032385 - temperature 8.174943
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0471 - val_loss: 0.0482
# Epoch 9/200
# mean max of probabilities: 0.0025040214 - temperature 7.9429646
# 6237/6237 [==============================] - 12s 2ms/step - loss: 0.0469 - val_loss: 0.0464
# Epoch 10/200
# mean max of probabilities: 0.002774102 - temperature 7.7175684
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0465 - val_loss: 0.0460
# Epoch 11/200
# mean max of probabilities: 0.0031483585 - temperature 7.498568
# 6237/6237 [==============================] - 28s 5ms/step - loss: 0.0460 - val_loss: 0.0453
# Epoch 12/200
# mean max of probabilities: 0.0036472098 - temperature 7.285782
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0451 - val_loss: 0.0442
# Epoch 13/200
# mean max of probabilities: 0.0042838156 - temperature 7.079034
# 6237/6237 [==============================] - 19s 3ms/step - loss: 0.0435 - val_loss: 0.0429
# Epoch 14/200
# mean max of probabilities: 0.0050514853 - temperature 6.878153
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0418 - val_loss: 0.0406
# Epoch 15/200
# mean max of probabilities: 0.0059158634 - temperature 6.68297
# 6237/6237 [==============================] - 19s 3ms/step - loss: 0.0396 - val_loss: 0.0383
# Epoch 16/200
# mean max of probabilities: 0.006807646 - temperature 6.4933286
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0376 - val_loss: 0.0367
# Epoch 17/200
# mean max of probabilities: 0.007638929 - temperature 6.3090687
# 6237/6237 [==============================] - 26s 4ms/step - loss: 0.0362 - val_loss: 0.0356
# Epoch 18/200
# mean max of probabilities: 0.008342961 - temperature 6.1300373
# 6237/6237 [==============================] - 23s 4ms/step - loss: 0.0353 - val_loss: 0.0350
# Epoch 19/200
# mean max of probabilities: 0.008866665 - temperature 5.9560833
# 6237/6237 [==============================] - 26s 4ms/step - loss: 0.0349 - val_loss: 0.0348
# Epoch 20/200
# mean max of probabilities: 0.009209086 - temperature 5.7870684
# 6237/6237 [==============================] - 24s 4ms/step - loss: 0.0348 - val_loss: 0.0346
# Epoch 21/200
# mean max of probabilities: 0.009433118 - temperature 5.6228485
# 6237/6237 [==============================] - 21s 3ms/step - loss: 0.0347 - val_loss: 0.0345
# Epoch 22/200
# mean max of probabilities: 0.009631031 - temperature 5.4632907
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0345 - val_loss: 0.0347
# Epoch 23/200
# mean max of probabilities: 0.009874945 - temperature 5.308259
# 6237/6237 [==============================] - 25s 4ms/step - loss: 0.0344 - val_loss: 0.0343
# Epoch 24/200
# mean max of probabilities: 0.0102500245 - temperature 5.1576276
# 6237/6237 [==============================] - 22s 4ms/step - loss: 0.0343 - val_loss: 0.0342
# Epoch 25/200
# mean max of probabilities: 0.010811641 - temperature 5.0112705
# 6237/6237 [==============================] - 21s 3ms/step - loss: 0.0341 - val_loss: 0.0346
# Epoch 26/200
# mean max of probabilities: 0.011608852 - temperature 4.8690653
# 6237/6237 [==============================] - 19s 3ms/step - loss: 0.0338 - val_loss: 0.0337
# Epoch 27/200
# mean max of probabilities: 0.012700744 - temperature 4.7308965
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0336 - val_loss: 0.0334
# Epoch 28/200
# mean max of probabilities: 0.01406832 - temperature 4.5966487
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0332 - val_loss: 0.0331
# Epoch 29/200
# mean max of probabilities: 0.01577315 - temperature 4.4662094
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0328 - val_loss: 0.0327
# Epoch 30/200
# mean max of probabilities: 0.017860264 - temperature 4.339473
# 6237/6237 [==============================] - 19s 3ms/step - loss: 0.0324 - val_loss: 0.0321
# Epoch 31/200
# mean max of probabilities: 0.02031173 - temperature 4.2163315
# 6237/6237 [==============================] - 23s 4ms/step - loss: 0.0318 - val_loss: 0.0315
# Epoch 32/200
# mean max of probabilities: 0.023051236 - temperature 4.0966854
# 6237/6237 [==============================] - 21s 3ms/step - loss: 0.0313 - val_loss: 0.0313
# Epoch 33/200
# mean max of probabilities: 0.026166089 - temperature 3.9804332
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0307 - val_loss: 0.0304
# Epoch 34/200
# mean max of probabilities: 0.029543329 - temperature 3.8674803
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0187 - val_loss: 0.0187
# Epoch 69/200
# mean max of probabilities: 0.1407637 - temperature 1.4120538
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0186 - val_loss: 0.0189
# Epoch 70/200
# mean max of probabilities: 0.14390093 - temperature 1.371984
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0188 - val_loss: 0.0187
# Epoch 71/200
# mean max of probabilities: 0.1477907 - temperature 1.3330511
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0186 - val_loss: 0.0188
# Epoch 72/200
# mean max of probabilities: 0.15170439 - temperature 1.2952231
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0181 - val_loss: 0.0179
# Epoch 81/200
# mean max of probabilities: 0.20922941 - temperature 0.99959683
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0179 - val_loss: 0.0178
# Epoch 82/200
# mean max of probabilities: 0.21865216 - temperature 0.97123134
# 6237/6237 [==============================] - 16s 3ms/step - loss: 0.0179 - val_loss: 0.0179
# Epoch 83/200
# mean max of probabilities: 0.2289477 - temperature 0.9436705
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0177 - val_loss: 0.0176
# Epoch 84/200
# mean max of probabilities: 0.23886605 - temperature 0.916892
# 6237/6237 [==============================] - 12s 2ms/step - loss: 0.0176 - val_loss: 0.0174
# Epoch 85/200
# mean max of probabilities: 0.24933647 - temperature 0.89087355
# 6237/6237 [==============================] - 16s 3ms/step - loss: 0.0176 - val_loss: 0.0180
# Epoch 86/200
# mean max of probabilities: 0.26054728 - temperature 0.8655933
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0174 - val_loss: 0.0172
# Epoch 87/200
# mean max of probabilities: 0.27249467 - temperature 0.8410305
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0172 - val_loss: 0.0174
# Epoch 88/200
# mean max of probabilities: 0.283657 - temperature 0.8171646
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0172 - val_loss: 0.0172
# Epoch 89/200
# mean max of probabilities: 0.2958685 - temperature 0.7939759
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0169 - val_loss: 0.0169
# Epoch 90/200
# mean max of probabilities: 0.30690116 - temperature 0.7714453
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0167 - val_loss: 0.0169
# Epoch 91/200
# mean max of probabilities: 0.3193114 - temperature 0.74955404
# 6237/6237 [==============================] - 12s 2ms/step - loss: 0.0168 - val_loss: 0.0168
# Epoch 92/200
# mean max of probabilities: 0.3315606 - temperature 0.72828394
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0165 - val_loss: 0.0167
# Epoch 93/200
# mean max of probabilities: 0.34334546 - temperature 0.7076175
# 6237/6237 [==============================] - 25s 4ms/step - loss: 0.0137 - val_loss: 0.0140
# Epoch 128/200
# mean max of probabilities: 0.72276217 - temperature 0.25835866
# 6237/6237 [==============================] - 24s 4ms/step - loss: 0.0135 - val_loss: 0.0136
# Epoch 129/200
# mean max of probabilities: 0.7296372 - temperature 0.25102723
# 6237/6237 [==============================] - 21s 3ms/step - loss: 0.0135 - val_loss: 0.0137
# Epoch 130/200
# mean max of probabilities: 0.7363664 - temperature 0.24390385
# 6237/6237 [==============================] - 21s 3ms/step - loss: 0.0131 - val_loss: 0.0132
# Epoch 141/200
# mean max of probabilities: 0.7970828 - temperature 0.17770286
# 6237/6237 [==============================] - 20s 3ms/step - loss: 0.0131 - val_loss: 0.0133
# Epoch 142/200
# mean max of probabilities: 0.8018569 - temperature 0.17266022
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0130 - val_loss: 0.0132
# Epoch 143/200
# mean max of probabilities: 0.80628914 - temperature 0.16776067
# 6237/6237 [==============================] - 23s 4ms/step - loss: 0.0129 - val_loss: 0.0129
# Epoch 152/200
# mean max of probabilities: 0.8405247 - temperature 0.12947047
# 5232/6237 [========================>.....] - ETA: 2s - loss: 0.0128
