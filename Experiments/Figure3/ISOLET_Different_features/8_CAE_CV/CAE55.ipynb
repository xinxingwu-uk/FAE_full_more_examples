# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
train_data_frame=np.array(pd.read_csv('../Dataset/isolet1+2+3+4.data',header=None))
test_data_frame=np.array(pd.read_csv('../Dataset/isolet5.data',header=None))

train_data_arr=(train_data_frame[:,0:617]).copy()
train_label_arr=((train_data_frame[:,617]).copy()-1)
test_data_arr=(test_data_frame[:,0:617]).copy()
test_label_arr=((test_data_frame[:,617]).copy()-1)

data_arr=MinMaxScaler(feature_range=(0,1)).fit_transform(np.r_[train_data_arr,test_data_arr])

label_arr_onehot=np.r_[train_label_arr,test_label_arr]#to_categorical(train_label_arr)

# %%
key_feture_number=55

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log"+str(key_feture_number)+"/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log"+str(key_feture_number)+"/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,50):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 617)               0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 55)                33936
# _________________________________________________________________
# dense_1 (Dense)              (None, 617)               34552
# =================================================================
# Total params: 68,488
# Trainable params: 68,487
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 6237 samples, validate on 1560 samples
# Epoch 1/200
# mean max of probabilities: 0.001828947 - temperature 10.0
# 6237/6237 [==============================] - 37s 6ms/step - loss: 0.0622 - val_loss: 0.0474
# Epoch 2/200
# mean max of probabilities: 0.001838738 - temperature 9.716229
# 6237/6237 [==============================] - 20s 3ms/step - loss: 0.0475 - val_loss: 0.0474
# Epoch 3/200
# mean max of probabilities: 0.00186409 - temperature 9.440515
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0475 - val_loss: 0.0474
# Epoch 4/200
# mean max of probabilities: 0.0019051374 - temperature 9.172621
# 6237/6237 [==============================] - 20s 3ms/step - loss: 0.0474 - val_loss: 0.0474
# Epoch 5/200
# mean max of probabilities: 0.0019619332 - temperature 8.91233
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0474 - val_loss: 0.0471
# Epoch 6/200
# mean max of probabilities: 0.002039206 - temperature 8.659425
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0474 - val_loss: 0.0469
# Epoch 7/200
# mean max of probabilities: 0.0021482043 - temperature 8.413696
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0472 - val_loss: 0.0469
# Epoch 8/200
# mean max of probabilities: 0.0022925443 - temperature 8.174943
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0471 - val_loss: 0.0481
# Epoch 9/200
# mean max of probabilities: 0.002489065 - temperature 7.9429646
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0469 - val_loss: 0.0465
# Epoch 10/200
# mean max of probabilities: 0.0027538578 - temperature 7.7175684
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0466 - val_loss: 0.0462
# Epoch 11/200
# mean max of probabilities: 0.0031119906 - temperature 7.498568
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0462 - val_loss: 0.0457
# Epoch 12/200
# mean max of probabilities: 0.0035911181 - temperature 7.285782
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0455 - val_loss: 0.0448
# Epoch 13/200
# mean max of probabilities: 0.0042212633 - temperature 7.079034
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0443 - val_loss: 0.0437
# Epoch 14/200
# mean max of probabilities: 0.00497899 - temperature 6.878153
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0428 - val_loss: 0.0417
# Epoch 15/200
# mean max of probabilities: 0.005846774 - temperature 6.68297
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0408 - val_loss: 0.0395
# Epoch 16/200
# mean max of probabilities: 0.006763022 - temperature 6.4933286
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0387 - val_loss: 0.0377
# Epoch 17/200
# mean max of probabilities: 0.0076736137 - temperature 6.3090687
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0369 - val_loss: 0.0361
# Epoch 18/200
# mean max of probabilities: 0.008497332 - temperature 6.1300373
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0357 - val_loss: 0.0352
# Epoch 19/200
# mean max of probabilities: 0.0091737425 - temperature 5.9560833
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0350 - val_loss: 0.0348
# Epoch 20/200
# mean max of probabilities: 0.009675357 - temperature 5.7870684
# 6237/6237 [==============================] - 25s 4ms/step - loss: 0.0347 - val_loss: 0.0346
# Epoch 21/200
# mean max of probabilities: 0.0100219175 - temperature 5.6228485
# 6237/6237 [==============================] - 10s 2ms/step - loss: 0.0346 - val_loss: 0.0344
# Epoch 22/200
# mean max of probabilities: 0.01029183 - temperature 5.4632907
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0345 - val_loss: 0.0346
# Epoch 23/200
# mean max of probabilities: 0.01056659 - temperature 5.308259
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0344 - val_loss: 0.0342
# Epoch 24/200
# mean max of probabilities: 0.010958692 - temperature 5.1576276
# 6237/6237 [==============================] - 22s 4ms/step - loss: 0.0342 - val_loss: 0.0341
# Epoch 25/200
# mean max of probabilities: 0.011460938 - temperature 5.0112705
# 6237/6237 [==============================] - 20s 3ms/step - loss: 0.0341 - val_loss: 0.0345
# Epoch 26/200
# mean max of probabilities: 0.012195694 - temperature 4.8690653
# 6237/6237 [==============================] - 21s 3ms/step - loss: 0.0338 - val_loss: 0.0337
# Epoch 27/200
# mean max of probabilities: 0.01321697 - temperature 4.7308965
# 6237/6237 [==============================] - 21s 3ms/step - loss: 0.0336 - val_loss: 0.0335
# Epoch 28/200
# mean max of probabilities: 0.014561798 - temperature 4.5966487
# 6237/6237 [==============================] - 21s 3ms/step - loss: 0.0333 - val_loss: 0.0332
# Epoch 29/200
# mean max of probabilities: 0.016229345 - temperature 4.4662094
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0329 - val_loss: 0.0328
# Epoch 30/200
# mean max of probabilities: 0.018307505 - temperature 4.339473
# 6237/6237 [==============================] - 21s 3ms/step - loss: 0.0325 - val_loss: 0.0323
# Epoch 31/200
# mean max of probabilities: 0.020797899 - temperature 4.2163315
# 6237/6237 [==============================] - 19s 3ms/step - loss: 0.0320 - val_loss: 0.0318
# Epoch 32/200
# mean max of probabilities: 0.023686977 - temperature 4.0966854
# 6237/6237 [==============================] - 19s 3ms/step - loss: 0.0315 - val_loss: 0.0314
# Epoch 33/200
# mean max of probabilities: 0.026884882 - temperature 3.9804332
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0310 - val_loss: 0.0307
# Epoch 34/200
# mean max of probabilities: 0.030349504 - temperature 3.8674803
# 6237/6237 [==============================] - 16s 3ms/step - loss: 0.0304 - val_loss: 0.0301
# Epoch 35/200
# mean max of probabilities: 0.034173563 - temperature 3.7577333
# 6237/6237 [==============================] - 16s 3ms/step - loss: 0.0299 - val_loss: 0.0297
# Epoch 36/200
# mean max of probabilities: 0.038327582 - temperature 3.6511
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0293 - val_loss: 0.0292
# Epoch 37/200
# mean max of probabilities: 0.042952295 - temperature 3.5474925
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0189 - val_loss: 0.0192
# Epoch 72/200
# mean max of probabilities: 0.15385094 - temperature 1.2952231
# 6237/6237 [==============================] - 8s 1ms/step - loss: 0.0189 - val_loss: 0.0193
# Epoch 73/200
# mean max of probabilities: 0.15826592 - temperature 1.2584686
# 6237/6237 [==============================] - 10s 2ms/step - loss: 0.0189 - val_loss: 0.0189
# Epoch 74/200
# mean max of probabilities: 0.16335075 - temperature 1.2227571
# 6237/6237 [==============================] - 9s 1ms/step - loss: 0.0188 - val_loss: 0.0189
# Epoch 75/200
# mean max of probabilities: 0.16876814 - temperature 1.1880591
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0183 - val_loss: 0.0183
# Epoch 84/200
# mean max of probabilities: 0.24675126 - temperature 0.916892
# 6237/6237 [==============================] - 10s 2ms/step - loss: 0.0180 - val_loss: 0.0184
# Epoch 85/200
# mean max of probabilities: 0.25805852 - temperature 0.89087355
# 6237/6237 [==============================] - 9s 1ms/step - loss: 0.0180 - val_loss: 0.0179
# Epoch 86/200
# mean max of probabilities: 0.27028996 - temperature 0.8655933
# 6237/6237 [==============================] - 10s 2ms/step - loss: 0.0179 - val_loss: 0.0183
# Epoch 87/200
# mean max of probabilities: 0.28316203 - temperature 0.8410305
#  672/6237 [==>...........................] - ETA: 19s - loss: 0.0179Epoch 96/200
# mean max of probabilities: 0.4029084 - temperature 0.64907086
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0169 - val_loss: 0.0170
# Epoch 97/200
# mean max of probabilities: 0.41581157 - temperature 0.6306524
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0169 - val_loss: 0.0166
# Epoch 98/200
# mean max of probabilities: 0.42793778 - temperature 0.61275643
# 6237/6237 [==============================] - 9s 1ms/step - loss: 0.0165 - val_loss: 0.0166
# Epoch 99/200
# mean max of probabilities: 0.4394419 - temperature 0.5953683
# 5184/6237 [=======================>......] - ETA: 1s - loss: 0.0167Epoch 110/200
# mean max of probabilities: 0.55956095 - temperature 0.43377236
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0159 - val_loss: 0.0161
# Epoch 111/200
# mean max of probabilities: 0.5695794 - temperature 0.42146328
# 6237/6237 [==============================] - 12s 2ms/step - loss: 0.0158 - val_loss: 0.0160
# Epoch 112/200
# mean max of probabilities: 0.5787275 - temperature 0.4095035
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0157 - val_loss: 0.0158
# Epoch 113/200
# mean max of probabilities: 0.588523 - temperature 0.39788303
# 6237/6237 [==============================] - 19s 3ms/step - loss: 0.0153 - val_loss: 0.0154
# Epoch 122/200
# mean max of probabilities: 0.6581373 - temperature 0.30706894
# 6237/6237 [==============================] - 16s 3ms/step - loss: 0.0152 - val_loss: 0.0152
# Epoch 123/200
# mean max of probabilities: 0.66542447 - temperature 0.2983553
# 6237/6237 [==============================] - 12s 2ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 124/200
# mean max of probabilities: 0.6723775 - temperature 0.28988886
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0150 - val_loss: 0.0150
# Epoch 135/200
# mean max of probabilities: 0.7321478 - temperature 0.21120661
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 136/200
# mean max of probabilities: 0.73641527 - temperature 0.2052132
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0148 - val_loss: 0.0148
# Epoch 137/200
# mean max of probabilities: 0.7408664 - temperature 0.1993899
# 6237/6237 [==============================] - 23s 4ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 138/200
# mean max of probabilities: 0.7453971 - temperature 0.19373183
# 6237/6237 [==============================] - 19s 3ms/step - loss: 0.0148 - val_loss: 0.0149
# Epoch 139/200
# mean max of probabilities: 0.74998856 - temperature 0.18823428
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0148 - val_loss: 0.0148
# Epoch 140/200
# mean max of probabilities: 0.7548248 - temperature 0.18289278
# 6237/6237 [==============================] - 21s 3ms/step - loss: 0.0148 - val_loss: 0.0149
# Epoch 141/200
# mean max of probabilities: 0.7598223 - temperature 0.17770286
# 6237/6237 [==============================] - 23s 4ms/step - loss: 0.0147 - val_loss: 0.0149
# Epoch 142/200
# mean max of probabilities: 0.764008 - temperature 0.17266022
# 1800/6237 [=======>......................] - ETA: 22s - loss: 0.0148
