# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
train_data_frame=np.array(pd.read_csv('../Dataset/isolet1+2+3+4.data',header=None))
test_data_frame=np.array(pd.read_csv('../Dataset/isolet5.data',header=None))

train_data_arr=(train_data_frame[:,0:617]).copy()
train_label_arr=((train_data_frame[:,617]).copy()-1)
test_data_arr=(test_data_frame[:,0:617]).copy()
test_label_arr=((test_data_frame[:,617]).copy()-1)

data_arr=MinMaxScaler(feature_range=(0,1)).fit_transform(np.r_[train_data_arr,test_data_arr])

label_arr_onehot=np.r_[train_label_arr,test_label_arr]#to_categorical(train_label_arr)

# %%
key_feture_number=40

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log"+str(key_feture_number)+"/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log"+str(key_feture_number)+"/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,50):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 617)               0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 40)                24681
# _________________________________________________________________
# dense_1 (Dense)              (None, 617)               25297
# =================================================================
# Total params: 49,978
# Trainable params: 49,977
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 6237 samples, validate on 1560 samples
# Epoch 1/200
# mean max of probabilities: 0.0018315779 - temperature 10.0
# 6237/6237 [==============================] - 34s 5ms/step - loss: 0.0658 - val_loss: 0.0473
# Epoch 2/200
# mean max of probabilities: 0.0018464562 - temperature 9.716229
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0474 - val_loss: 0.0473
# Epoch 3/200
# mean max of probabilities: 0.0018689055 - temperature 9.440515
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0474 - val_loss: 0.0473
# Epoch 4/200
# mean max of probabilities: 0.001906079 - temperature 9.172621
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0473 - val_loss: 0.0473
# Epoch 5/200
# mean max of probabilities: 0.001959961 - temperature 8.91233
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0473 - val_loss: 0.0470
# Epoch 6/200
# mean max of probabilities: 0.0020358253 - temperature 8.659425
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0472 - val_loss: 0.0469
# Epoch 7/200
# mean max of probabilities: 0.002141685 - temperature 8.413696
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0471 - val_loss: 0.0469
# Epoch 8/200
# mean max of probabilities: 0.0022813024 - temperature 8.174943
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0470 - val_loss: 0.0476
# Epoch 9/200
# mean max of probabilities: 0.0024642502 - temperature 7.9429646
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0469 - val_loss: 0.0466
# Epoch 10/200
# mean max of probabilities: 0.002706234 - temperature 7.7175684
# 6237/6237 [==============================] - 9s 2ms/step - loss: 0.0466 - val_loss: 0.0464
# Epoch 11/200
# mean max of probabilities: 0.0030348392 - temperature 7.498568
# 6237/6237 [==============================] - 10s 2ms/step - loss: 0.0464 - val_loss: 0.0460
# Epoch 12/200
# mean max of probabilities: 0.0034696285 - temperature 7.285782
# 6237/6237 [==============================] - 8s 1ms/step - loss: 0.0459 - val_loss: 0.0454
# Epoch 13/200
# mean max of probabilities: 0.004046456 - temperature 7.079034
# 6237/6237 [==============================] - 9s 1ms/step - loss: 0.0451 - val_loss: 0.0445
# Epoch 14/200
# mean max of probabilities: 0.0047649285 - temperature 6.878153
# 6237/6237 [==============================] - 9s 2ms/step - loss: 0.0440 - val_loss: 0.0432
# Epoch 15/200
# mean max of probabilities: 0.00561002 - temperature 6.68297
# 6237/6237 [==============================] - 9s 1ms/step - loss: 0.0425 - val_loss: 0.0413
# Epoch 16/200
# mean max of probabilities: 0.006547483 - temperature 6.4933286
# 6237/6237 [==============================] - 10s 2ms/step - loss: 0.0406 - val_loss: 0.0394
# Epoch 17/200
# mean max of probabilities: 0.007515823 - temperature 6.3090687
# 6237/6237 [==============================] - 9s 2ms/step - loss: 0.0385 - val_loss: 0.0374
# Epoch 18/200
# mean max of probabilities: 0.008479675 - temperature 6.1300373
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0368 - val_loss: 0.0360
# Epoch 19/200
# mean max of probabilities: 0.009344241 - temperature 5.9560833
# 6237/6237 [==============================] - 12s 2ms/step - loss: 0.0356 - val_loss: 0.0351
# Epoch 20/200
# mean max of probabilities: 0.0100917835 - temperature 5.7870684
#  288/6237 [>.............................] - ETA: 18s - loss: 0.0353
# /usr/local/lib/python3.7/site-packages/keras/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.173939). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0349 - val_loss: 0.0347
# Epoch 21/200
# mean max of probabilities: 0.01068607 - temperature 5.6228485
# 6237/6237 [==============================] - 12s 2ms/step - loss: 0.0346 - val_loss: 0.0345
# Epoch 22/200
# mean max of probabilities: 0.011125495 - temperature 5.4632907
# 6237/6237 [==============================] - 12s 2ms/step - loss: 0.0344 - val_loss: 0.0346
# Epoch 23/200
# mean max of probabilities: 0.0114930365 - temperature 5.308259
# 6237/6237 [==============================] - 12s 2ms/step - loss: 0.0343 - val_loss: 0.0342
# Epoch 24/200
# mean max of probabilities: 0.011918716 - temperature 5.1576276
# 6237/6237 [==============================] - 10s 2ms/step - loss: 0.0342 - val_loss: 0.0341
# Epoch 25/200
# mean max of probabilities: 0.012471383 - temperature 5.0112705
# 6237/6237 [==============================] - 9s 1ms/step - loss: 0.0340 - val_loss: 0.0343
# Epoch 26/200
# mean max of probabilities: 0.013193068 - temperature 4.8690653
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0339 - val_loss: 0.0337
# Epoch 27/200
# mean max of probabilities: 0.014169797 - temperature 4.7308965
# 6237/6237 [==============================] - 9s 1ms/step - loss: 0.0336 - val_loss: 0.0336
# Epoch 28/200
# mean max of probabilities: 0.015425853 - temperature 4.5966487
# 6237/6237 [==============================] - 8s 1ms/step - loss: 0.0334 - val_loss: 0.0334
# Epoch 29/200
# mean max of probabilities: 0.0170009 - temperature 4.4662094
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0331 - val_loss: 0.0331
# Epoch 30/200
# mean max of probabilities: 0.018960284 - temperature 4.339473
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0327 - val_loss: 0.0326
# Epoch 31/200
# mean max of probabilities: 0.02134681 - temperature 4.2163315
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0323 - val_loss: 0.0322
# Epoch 32/200
# mean max of probabilities: 0.024202272 - temperature 4.0966854
# 6237/6237 [==============================] - 16s 3ms/step - loss: 0.0319 - val_loss: 0.0318
# Epoch 33/200
# mean max of probabilities: 0.027475843 - temperature 3.9804332
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0314 - val_loss: 0.0312
# Epoch 34/200
# mean max of probabilities: 0.031235168 - temperature 3.8674803
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0308 - val_loss: 0.0307
# Epoch 35/200
# mean max of probabilities: 0.035380602 - temperature 3.7577333
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0304 - val_loss: 0.0302
# Epoch 36/200
# mean max of probabilities: 0.039989006 - temperature 3.6511
# 6237/6237 [==============================] - 16s 3ms/step - loss: 0.0298 - val_loss: 0.0298
# Epoch 37/200
# mean max of probabilities: 0.045055352 - temperature 3.5474925
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0293 - val_loss: 0.0293
# Epoch 38/200
# mean max of probabilities: 0.05083999 - temperature 3.4468255
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0289 - val_loss: 0.0287
# Epoch 39/200
# mean max of probabilities: 0.0571435 - temperature 3.3490164
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0284 - val_loss: 0.0282
# Epoch 40/200
# mean max of probabilities: 0.064111784 - temperature 3.2539816
# 6237/6237 [==============================] - 23s 4ms/step - loss: 0.0279 - val_loss: 0.0278
# Epoch 41/200
# mean max of probabilities: 0.0715366 - temperature 3.1616435
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0275 - val_loss: 0.0273
# Epoch 42/200
# mean max of probabilities: 0.079510495 - temperature 3.0719256
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0270 - val_loss: 0.0268
# Epoch 43/200
# mean max of probabilities: 0.08711127 - temperature 2.9847543
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0265 - val_loss: 0.0263
# Epoch 44/200
# mean max of probabilities: 0.09489376 - temperature 2.9000561
# 6237/6237 [==============================] - 6s 960us/step - loss: 0.0186 - val_loss: 0.0190
# Epoch 89/200
# mean max of probabilities: 0.3299832 - temperature 0.7939759
# 6237/6237 [==============================] - 13s 2ms/step - loss: 0.0186 - val_loss: 0.0186
# Epoch 90/200
# mean max of probabilities: 0.34140846 - temperature 0.7714453
# 6237/6237 [==============================] - 8s 1ms/step - loss: 0.0187 - val_loss: 0.0187
# Epoch 91/200
# mean max of probabilities: 0.3534692 - temperature 0.74955404
# 6237/6237 [==============================] - 8s 1ms/step - loss: 0.0184 - val_loss: 0.0184
# Epoch 92/200
# mean max of probabilities: 0.36785436 - temperature 0.72828394
# 6237/6237 [==============================] - 7s 1ms/step - loss: 0.0183 - val_loss: 0.0183
# Epoch 93/200
# mean max of probabilities: 0.38245633 - temperature 0.7076175
# 5904/6237 [===========================>..] - ETA: 0s - loss: 0.0184Epoch 103/200
# mean max of probabilities: 0.5172495 - temperature 0.53061175
# 6237/6237 [==============================] - 10s 2ms/step - loss: 0.0175 - val_loss: 0.0174
# Epoch 104/200
# mean max of probabilities: 0.5292403 - temperature 0.5155548
# 6237/6237 [==============================] - 7s 1ms/step - loss: 0.0174 - val_loss: 0.0172
# Epoch 105/200
# mean max of probabilities: 0.54104406 - temperature 0.5009249
# 6237/6237 [==============================] - 7s 1ms/step - loss: 0.0174 - val_loss: 0.0173
# Epoch 106/200
# mean max of probabilities: 0.5522042 - temperature 0.48671025
# 6237/6237 [==============================] - 7s 1ms/step - loss: 0.0174 - val_loss: 0.0173
# Epoch 107/200
# mean max of probabilities: 0.56293553 - temperature 0.47289896
# 6237/6237 [==============================] - 8s 1ms/step - loss: 0.0173 - val_loss: 0.0173
# Epoch 108/200
# mean max of probabilities: 0.57321763 - temperature 0.45947954
# 6237/6237 [==============================] - 10s 2ms/step - loss: 0.0167 - val_loss: 0.0169
# Epoch 119/200
# mean max of probabilities: 0.66829437 - temperature 0.3347669
# 6237/6237 [==============================] - 8s 1ms/step - loss: 0.0166 - val_loss: 0.0166
# Epoch 120/200
# mean max of probabilities: 0.6752073 - temperature 0.32526726
# 6237/6237 [==============================] - 9s 1ms/step - loss: 0.0167 - val_loss: 0.0169
# Epoch 121/200
# mean max of probabilities: 0.6822506 - temperature 0.31603712
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0167 - val_loss: 0.0168
# Epoch 122/200
# mean max of probabilities: 0.68811613 - temperature 0.30706894
# 6237/6237 [==============================] - 9s 1ms/step - loss: 0.0163 - val_loss: 0.0165
# Epoch 135/200
# mean max of probabilities: 0.76093704 - temperature 0.21120661
# 6237/6237 [==============================] - 9s 1ms/step - loss: 0.0163 - val_loss: 0.0167
# Epoch 136/200
# mean max of probabilities: 0.76522744 - temperature 0.2052132
# 6237/6237 [==============================] - 11s 2ms/step - loss: 0.0163 - val_loss: 0.0167
# Epoch 137/200
# mean max of probabilities: 0.76947534 - temperature 0.1993899
# 6237/6237 [==============================] - 9s 1ms/step - loss: 0.0163 - val_loss: 0.0164
# Epoch 138/200
# mean max of probabilities: 0.7746166 - temperature 0.19373183
# 6237/6237 [==============================] - 18s 3ms/step - loss: 0.0161 - val_loss: 0.0163
# Epoch 147/200
# mean max of probabilities: 0.805648 - temperature 0.14951389
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0160 - val_loss: 0.0163
# Epoch 148/200
# mean max of probabilities: 0.8085966 - temperature 0.14527117
# 6237/6237 [==============================] - 12s 2ms/step - loss: 0.0161 - val_loss: 0.0163
# Epoch 149/200
# mean max of probabilities: 0.8116145 - temperature 0.14114884
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0160 - val_loss: 0.0162
# Epoch 150/200
# mean max of probabilities: 0.8147335 - temperature 0.13714345
# 6237/6237 [==============================] - 15s 2ms/step - loss: 0.0160 - val_loss: 0.0160
# Epoch 161/200
# mean max of probabilities: 0.84353197 - temperature 0.1
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0160 - val_loss: 0.0162
# Epoch 162/200
# mean max of probabilities: 0.8456358 - temperature 0.1
# 6237/6237 [==============================] - 14s 2ms/step - loss: 0.0160 - val_loss: 0.0159
# Epoch 163/200
# mean max of probabilities: 0.8474604 - temperature 0.1
# 4368/6237 [====================>.........] - ETA: 6s - loss: 0.0160mean max of probabilities: 0.8729755 - temperature 0.1
# 6237/6237 [==============================] - 20s 3ms/step - loss: 0.0157 - val_loss: 0.0161
# Epoch 176/200
# mean max of probabilities: 0.8754953 - temperature 0.1
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0158 - val_loss: 0.0162
# Epoch 177/200
# mean max of probabilities: 0.877396 - temperature 0.1
# 6192/6237 [============================>.] - ETA: 0s - loss: 0.0157Epoch 190/200
# mean max of probabilities: 0.8972586 - temperature 0.1
# 6237/6237 [==============================] - 16s 3ms/step - loss: 0.0156 - val_loss: 0.0159
# Epoch 191/200
# mean max of probabilities: 0.8981655 - temperature 0.1
# 6237/6237 [==============================] - 17s 3ms/step - loss: 0.0156 - val_loss: 0.0159
# Epoch 192/200
# mean max of probabilities: 0.8997482 - temperature 0.1
# 1824/6237 [=======>......................] - ETA: 17s - loss: 0.0156
