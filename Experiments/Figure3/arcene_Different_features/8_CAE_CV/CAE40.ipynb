# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.model_selection import train_test_split
import scipy.sparse as sparse
from keras.datasets import fashion_mnist
import scipy.io

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
data_path="../Dataset/arcene.mat"
Data = scipy.io.loadmat(data_path)

data_arr=Data['X']
label_arr_=Data['Y'][:, 0]

label_arr=np.array([0 if label_arr_i<0 else label_arr_i for label_arr_i in label_arr_])
data_arr=MinMaxScaler(feature_range=(0,1)).fit_transform(data_arr)
label_arr_onehot=label_arr

# %%
key_feture_number=40

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log"+str(key_feture_number)+"/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log"+str(key_feture_number)+"/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,5):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10000)             0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 40)                400001
# _________________________________________________________________
# dense_1 (Dense)              (None, 10000)             410000
# =================================================================
# Total params: 810,001
# Trainable params: 810,000
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 160 samples, validate on 40 samples
# Epoch 1/200
# mean max of probabilities: 0.00010324989 - temperature 10.0
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0889 - val_loss: 0.0795
# Epoch 2/200
# mean max of probabilities: 0.00010324987 - temperature 9.705095
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0699 - val_loss: 0.0635
# Epoch 3/200
# mean max of probabilities: 0.00010325201 - temperature 9.418887
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0576 - val_loss: 0.0542
# Epoch 4/200
# mean max of probabilities: 0.0001032601 - temperature 9.141122
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0506 - val_loss: 0.0491
# Epoch 5/200
# mean max of probabilities: 0.00010327273 - temperature 8.871547
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0469 - val_loss: 0.0464
# Epoch 6/200
# mean max of probabilities: 0.000103287515 - temperature 8.609923
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0449 - val_loss: 0.0451
# Epoch 7/200
# mean max of probabilities: 0.00010330211 - temperature 8.356012
# 160/160 [==============================] - 2s 9ms/step - loss: 0.0438 - val_loss: 0.0445
# Epoch 8/200
# mean max of probabilities: 0.00010331471 - temperature 8.1095915
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0433 - val_loss: 0.0440
# Epoch 9/200
# mean max of probabilities: 0.000103325394 - temperature 7.8704367
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0430 - val_loss: 0.0438
# Epoch 10/200
# mean max of probabilities: 0.000103334314 - temperature 7.6383343
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0428 - val_loss: 0.0438
# Epoch 11/200
# mean max of probabilities: 0.00010334256 - temperature 7.413077
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0427 - val_loss: 0.0437
# Epoch 12/200
# mean max of probabilities: 0.000103349696 - temperature 7.1944623
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0426 - val_loss: 0.0437
# Epoch 13/200
# mean max of probabilities: 0.00010335564 - temperature 6.9822946
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0426 - val_loss: 0.0438
# Epoch 14/200
# mean max of probabilities: 0.00010336109 - temperature 6.7763844
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0426 - val_loss: 0.0436
# Epoch 15/200
# mean max of probabilities: 0.000103365885 - temperature 6.576546
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0425 - val_loss: 0.0436
# Epoch 16/200
# mean max of probabilities: 0.00010337074 - temperature 6.3826013
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0425 - val_loss: 0.0436
# Epoch 17/200
# mean max of probabilities: 0.00010337502 - temperature 6.194376
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0424 - val_loss: 0.0436
# Epoch 18/200
# mean max of probabilities: 0.00010337886 - temperature 6.0117006
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0424 - val_loss: 0.0435
# Epoch 19/200
# mean max of probabilities: 0.00010338195 - temperature 5.8344135
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0423 - val_loss: 0.0435
# Epoch 20/200
# mean max of probabilities: 0.00010338534 - temperature 5.662354
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0424 - val_loss: 0.0433
# Epoch 21/200
# mean max of probabilities: 0.000103388855 - temperature 5.495369
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0423 - val_loss: 0.0434
# Epoch 22/200
# mean max of probabilities: 0.000103392755 - temperature 5.3333087
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0423 - val_loss: 0.0436
# Epoch 23/200
# mean max of probabilities: 0.000103395396 - temperature 5.176028
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0422 - val_loss: 0.0433
# Epoch 24/200
# mean max of probabilities: 0.00010339611 - temperature 5.023384
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0421 - val_loss: 0.0432
# Epoch 25/200
# mean max of probabilities: 0.00010339838 - temperature 4.8752427
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0421 - val_loss: 0.0432
# Epoch 26/200
# mean max of probabilities: 0.00010340087 - temperature 4.73147
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0420 - val_loss: 0.0433
# Epoch 27/200
# mean max of probabilities: 0.00010340333 - temperature 4.5919366
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0420 - val_loss: 0.0432
# Epoch 28/200
# mean max of probabilities: 0.000103404556 - temperature 4.4565187
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0419 - val_loss: 0.0431
# Epoch 29/200
# mean max of probabilities: 0.00010340632 - temperature 4.325094
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0419 - val_loss: 0.0431
# Epoch 30/200
# mean max of probabilities: 0.00010340931 - temperature 4.1975446
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0419 - val_loss: 0.0431
# Epoch 31/200
# mean max of probabilities: 0.00010341336 - temperature 4.0737567
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0418 - val_loss: 0.0429
# Epoch 32/200
# mean max of probabilities: 0.0001034166 - temperature 3.9536202
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0418 - val_loss: 0.0431
# Epoch 33/200
# mean max of probabilities: 0.00010342025 - temperature 3.8370266
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0417 - val_loss: 0.0430
# Epoch 34/200
# mean max of probabilities: 0.0001034274 - temperature 3.7238712
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0417 - val_loss: 0.0429
# Epoch 35/200
# mean max of probabilities: 0.0001034368 - temperature 3.6140528
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0417 - val_loss: 0.0428
# Epoch 36/200
# mean max of probabilities: 0.00010344805 - temperature 3.5074725
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0416 - val_loss: 0.0428
# Epoch 37/200
# mean max of probabilities: 0.00010346233 - temperature 3.4040358
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0416 - val_loss: 0.0428
# Epoch 38/200
# mean max of probabilities: 0.00010348212 - temperature 3.3036494
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0415 - val_loss: 0.0427
# Epoch 39/200
# mean max of probabilities: 0.00010350655 - temperature 3.2062237
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0415 - val_loss: 0.0427
# Epoch 40/200
# mean max of probabilities: 0.00010353697 - temperature 3.1116705
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0415 - val_loss: 0.0427
# Epoch 41/200
# mean max of probabilities: 0.00010356798 - temperature 3.0199058
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0414 - val_loss: 0.0426
# Epoch 42/200
# mean max of probabilities: 0.00010360407 - temperature 2.9308476
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0413 - val_loss: 0.0425
# Epoch 43/200
# mean max of probabilities: 0.000103640254 - temperature 2.8444157
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0413 - val_loss: 0.0426
# Epoch 44/200
# mean max of probabilities: 0.0001036817 - temperature 2.7605326
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0413 - val_loss: 0.0425
# Epoch 45/200
# mean max of probabilities: 0.00010372768 - temperature 2.6791236
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0412 - val_loss: 0.0426
# Epoch 46/200
# mean max of probabilities: 0.0001037796 - temperature 2.6001153
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0412 - val_loss: 0.0424
# Epoch 47/200
# mean max of probabilities: 0.00010383866 - temperature 2.5234365
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0412 - val_loss: 0.0424
# Epoch 48/200
# mean max of probabilities: 0.0001038983 - temperature 2.4490192
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0411 - val_loss: 0.0423
# Epoch 49/200
# mean max of probabilities: 0.00010396021 - temperature 2.3767967
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0411 - val_loss: 0.0422
# Epoch 50/200
# mean max of probabilities: 0.00010402836 - temperature 2.306704
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0410 - val_loss: 0.0423
# Epoch 51/200
# mean max of probabilities: 0.00010410095 - temperature 2.2386785
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0410 - val_loss: 0.0423
# Epoch 52/200
# mean max of probabilities: 0.00010417741 - temperature 2.172659
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0409 - val_loss: 0.0424
# Epoch 53/200
# mean max of probabilities: 0.000104257415 - temperature 2.108586
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0409 - val_loss: 0.0420
# Epoch 54/200
# mean max of probabilities: 0.000104352715 - temperature 2.0464027
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0409 - val_loss: 0.0421
# Epoch 55/200
# mean max of probabilities: 0.00010446149 - temperature 1.9860538
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0408 - val_loss: 0.0421
# Epoch 56/200
# mean max of probabilities: 0.00010456345 - temperature 1.9274842
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0408 - val_loss: 0.0421
# Epoch 57/200
# mean max of probabilities: 0.00010466422 - temperature 1.8706421
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0408 - val_loss: 0.0422
# Epoch 58/200
# mean max of probabilities: 0.00010478648 - temperature 1.8154762
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0408 - val_loss: 0.0418
# Epoch 59/200
# mean max of probabilities: 0.0001049086 - temperature 1.761937
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0407 - val_loss: 0.0419
# Epoch 60/200
# mean max of probabilities: 0.00010504222 - temperature 1.7099768
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0406 - val_loss: 0.0420
# Epoch 61/200
# mean max of probabilities: 0.000105186075 - temperature 1.659549
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0405 - val_loss: 0.0420
# Epoch 62/200
# mean max of probabilities: 0.00010534192 - temperature 1.6106081
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0405 - val_loss: 0.0420
# Epoch 63/200
# mean max of probabilities: 0.000105514875 - temperature 1.5631108
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0405 - val_loss: 0.0418
# Epoch 64/200
# mean max of probabilities: 0.000105687286 - temperature 1.5170141
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0404 - val_loss: 0.0418
# Epoch 65/200
# mean max of probabilities: 0.000105861596 - temperature 1.4722769
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0405 - val_loss: 0.0419
# Epoch 66/200
# mean max of probabilities: 0.00010605506 - temperature 1.4288589
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0403 - val_loss: 0.0417
# Epoch 67/200
# mean max of probabilities: 0.000106236 - temperature 1.3867214
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0403 - val_loss: 0.0417
# Epoch 68/200
# mean max of probabilities: 0.000106433 - temperature 1.3458263
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0403 - val_loss: 0.0416
# Epoch 69/200
# mean max of probabilities: 0.0001066258 - temperature 1.3061373
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0403 - val_loss: 0.0415
# Epoch 70/200
# mean max of probabilities: 0.00010683923 - temperature 1.267619
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0401 - val_loss: 0.0418
# Epoch 71/200
# mean max of probabilities: 0.0001070722 - temperature 1.2302365
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0401 - val_loss: 0.0418
# Epoch 72/200
# mean max of probabilities: 0.000107394604 - temperature 1.1939563
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0403 - val_loss: 0.0415
# Epoch 73/200
# mean max of probabilities: 0.00010765693 - temperature 1.158746
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0402 - val_loss: 0.0412
# Epoch 74/200
# mean max of probabilities: 0.000107890904 - temperature 1.1245742
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0400 - val_loss: 0.0414
# Epoch 75/200
# mean max of probabilities: 0.0001081235 - temperature 1.09141
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0400 - val_loss: 0.0418
# Epoch 76/200
# mean max of probabilities: 0.00010834031 - temperature 1.0592241
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0400 - val_loss: 0.0416
# Epoch 77/200
# mean max of probabilities: 0.00010858964 - temperature 1.0279874
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0401 - val_loss: 0.0412
# Epoch 78/200
# mean max of probabilities: 0.000108833796 - temperature 0.9976718
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0405 - val_loss: 0.0412
# Epoch 79/200
# mean max of probabilities: 0.000109056054 - temperature 0.96825004
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0401 - val_loss: 0.0419
# Epoch 80/200
# mean max of probabilities: 0.000109263114 - temperature 0.939696
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0400 - val_loss: 0.0414
# Epoch 81/200
# mean max of probabilities: 0.00010945754 - temperature 0.911984
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0402 - val_loss: 0.0411
# Epoch 82/200
# mean max of probabilities: 0.00010972039 - temperature 0.8850892
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0401 - val_loss: 0.0417
# Epoch 83/200
# mean max of probabilities: 0.000109967295 - temperature 0.85898757
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0400 - val_loss: 0.0421
# Epoch 84/200
# mean max of probabilities: 0.000110139685 - temperature 0.83365566
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0401 - val_loss: 0.0416
# Epoch 85/200
# mean max of probabilities: 0.00011030056 - temperature 0.8090709
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0404 - val_loss: 0.0418
# Epoch 86/200
# mean max of probabilities: 0.00011047484 - temperature 0.7852111
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0399 - val_loss: 0.0417
# Epoch 87/200
# mean max of probabilities: 0.00011064463 - temperature 0.762055
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0401 - val_loss: 0.0422
# Epoch 88/200
# mean max of probabilities: 0.000110787725 - temperature 0.7395817
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0398 - val_loss: 0.0415
# Epoch 89/200
# mean max of probabilities: 0.000110944406 - temperature 0.7177711
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0404 - val_loss: 0.0415
# Epoch 90/200
# mean max of probabilities: 0.00011105593 - temperature 0.69660366
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0404 - val_loss: 0.0425
# Epoch 91/200
# mean max of probabilities: 0.00011119489 - temperature 0.67606056
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0404 - val_loss: 0.0409
# Epoch 92/200
# mean max of probabilities: 0.000111336725 - temperature 0.6561233
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0402 - val_loss: 0.0441
# Epoch 93/200
# mean max of probabilities: 0.00011147179 - temperature 0.63677377
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0402 - val_loss: 0.0409
# Epoch 94/200
# mean max of probabilities: 0.00011162022 - temperature 0.617995
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0398 - val_loss: 0.0444
# Epoch 95/200
# mean max of probabilities: 0.00011178388 - temperature 0.5997701
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0395 - val_loss: 0.0417
# Epoch 96/200
# mean max of probabilities: 0.000111911024 - temperature 0.5820826
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0412 - val_loss: 0.0404
# Epoch 97/200
# mean max of probabilities: 0.000111988105 - temperature 0.5649167
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0396 - val_loss: 0.0419
# Epoch 98/200
# mean max of probabilities: 0.00011206141 - temperature 0.5482572
# 160/160 [==============================] - 1s 6ms/step - loss: 0.0403 - val_loss: 0.0410
# Epoch 99/200
# mean max of probabilities: 0.00011216127 - temperature 0.53208894
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0411 - val_loss: 0.0442
# Epoch 100/200
# mean max of probabilities: 0.000112294874 - temperature 0.51639754
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0405 - val_loss: 0.0429
# Epoch 101/200
# mean max of probabilities: 0.00011240939 - temperature 0.50116867
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0404 - val_loss: 0.0415
# Epoch 102/200
# mean max of probabilities: 0.00011254063 - temperature 0.48638898
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0398 - val_loss: 0.0419
# Epoch 103/200
# mean max of probabilities: 0.00011266556 - temperature 0.47204518
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0400 - val_loss: 0.0416
# Epoch 104/200
# mean max of probabilities: 0.00011277649 - temperature 0.45812437
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0415 - val_loss: 0.0413
# Epoch 105/200
# mean max of probabilities: 0.00011285101 - temperature 0.4446141
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0410 - val_loss: 0.0416
# Epoch 106/200
# mean max of probabilities: 0.00011295071 - temperature 0.43150225
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0400 - val_loss: 0.0410
# Epoch 107/200
# mean max of probabilities: 0.00011306859 - temperature 0.41877705
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0410 - val_loss: 0.0408
# Epoch 108/200
# mean max of probabilities: 0.00011313807 - temperature 0.40642717
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0401 - val_loss: 0.0415
# Epoch 109/200
# mean max of probabilities: 0.000113221795 - temperature 0.3944415
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0405 - val_loss: 0.0417
# Epoch 110/200
# mean max of probabilities: 0.000113291855 - temperature 0.38280922
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0405 - val_loss: 0.0410
# Epoch 111/200
# mean max of probabilities: 0.00011336287 - temperature 0.37151998
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0393 - val_loss: 0.0414
# Epoch 112/200
# mean max of probabilities: 0.0001134207 - temperature 0.36056373
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0396 - val_loss: 0.0424
# Epoch 113/200
# mean max of probabilities: 0.00011345847 - temperature 0.34993058
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0417 - val_loss: 0.0417
# Epoch 114/200
# mean max of probabilities: 0.00011353241 - temperature 0.33961096
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0409 - val_loss: 0.0404
# Epoch 115/200
# mean max of probabilities: 0.00011358557 - temperature 0.32959563
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0397 - val_loss: 0.0410
# Epoch 116/200
# mean max of probabilities: 0.000113630354 - temperature 0.31987572
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0403 - val_loss: 0.0407
# Epoch 117/200
# mean max of probabilities: 0.000113682254 - temperature 0.31044245
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0406 - val_loss: 0.0433
# Epoch 118/200
# mean max of probabilities: 0.00011371684 - temperature 0.30128738
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0407 - val_loss: 0.0413
# Epoch 119/200
# mean max of probabilities: 0.00011372834 - temperature 0.2924023
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0401 - val_loss: 0.0418
# Epoch 120/200
# mean max of probabilities: 0.00011378671 - temperature 0.28377923
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0399 - val_loss: 0.0444
# Epoch 121/200
# mean max of probabilities: 0.00011385942 - temperature 0.2754104
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0405 - val_loss: 0.0414
# Epoch 122/200
# mean max of probabilities: 0.000113889575 - temperature 0.2672884
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0408 - val_loss: 0.0430
# Epoch 123/200
# mean max of probabilities: 0.00011392783 - temperature 0.25940588
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0411 - val_loss: 0.0411
# Epoch 124/200
# mean max of probabilities: 0.00011396775 - temperature 0.2517559
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0400 - val_loss: 0.0426
# Epoch 125/200
# mean max of probabilities: 0.000113998816 - temperature 0.24433151
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0404 - val_loss: 0.0401
# Epoch 126/200
# mean max of probabilities: 0.00011401521 - temperature 0.23712608
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0416 - val_loss: 0.0436
# Epoch 127/200
# mean max of probabilities: 0.0001140361 - temperature 0.23013313
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0408 - val_loss: 0.0451
# Epoch 128/200
# mean max of probabilities: 0.00011408016 - temperature 0.22334641
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0409 - val_loss: 0.0425
# Epoch 129/200
# mean max of probabilities: 0.000114119866 - temperature 0.21675983
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0410 - val_loss: 0.0406
# Epoch 130/200
# mean max of probabilities: 0.00011417819 - temperature 0.2103675
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0410 - val_loss: 0.0405
# Epoch 131/200
# mean max of probabilities: 0.0001142343 - temperature 0.20416367
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0397 - val_loss: 0.0423
# Epoch 132/200
# mean max of probabilities: 0.00011430137 - temperature 0.19814283
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0420 - val_loss: 0.0405
# Epoch 133/200
# mean max of probabilities: 0.00011438546 - temperature 0.19229952
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0404 - val_loss: 0.0404
# Epoch 134/200
# mean max of probabilities: 0.000114436516 - temperature 0.18662854
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0424 - val_loss: 0.0405
# Epoch 135/200
# mean max of probabilities: 0.00011448236 - temperature 0.18112479
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0406 - val_loss: 0.0448
# Epoch 136/200
# mean max of probabilities: 0.00011451311 - temperature 0.17578335
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0396 - val_loss: 0.0424
# Epoch 137/200
# mean max of probabilities: 0.000114548464 - temperature 0.17059945
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0406 - val_loss: 0.0387
# Epoch 138/200
# mean max of probabilities: 0.0001145634 - temperature 0.16556841
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0408 - val_loss: 0.0436
# Epoch 139/200
# mean max of probabilities: 0.00011457594 - temperature 0.16068572
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0411 - val_loss: 0.0443
# Epoch 140/200
# mean max of probabilities: 0.000114615854 - temperature 0.15594701
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0408 - val_loss: 0.0419
# Epoch 141/200
# mean max of probabilities: 0.00011464136 - temperature 0.15134808
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0427 - val_loss: 0.0404
# Epoch 142/200
# mean max of probabilities: 0.00011466465 - temperature 0.14688475
# 160/160 [==============================] - 2s 9ms/step - loss: 0.0421 - val_loss: 0.0426
# Epoch 143/200
# mean max of probabilities: 0.0001146845 - temperature 0.14255308
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0397 - val_loss: 0.0417
# Epoch 144/200
# mean max of probabilities: 0.00011469949 - temperature 0.13834915
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0407 - val_loss: 0.0423
# Epoch 145/200
# mean max of probabilities: 0.00011472658 - temperature 0.13426918
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0404 - val_loss: 0.0415
# Epoch 146/200
# mean max of probabilities: 0.000114746355 - temperature 0.13030952
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0392 - val_loss: 0.0394
# Epoch 147/200
# mean max of probabilities: 0.00011475377 - temperature 0.12646663
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0395 - val_loss: 0.0420
# Epoch 148/200
# mean max of probabilities: 0.00011475629 - temperature 0.12273709
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0402 - val_loss: 0.0397
# Epoch 149/200
# mean max of probabilities: 0.000114765004 - temperature 0.11911752
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0411 - val_loss: 0.0403
# Epoch 150/200
# mean max of probabilities: 0.00011476911 - temperature 0.1156047
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0413 - val_loss: 0.0417
# Epoch 151/200
# mean max of probabilities: 0.0001147703 - temperature 0.11219547
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0392 - val_loss: 0.0474
# Epoch 152/200
# mean max of probabilities: 0.00011477126 - temperature 0.10888678
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0394 - val_loss: 0.0408
# Epoch 153/200
# mean max of probabilities: 0.00011477482 - temperature 0.10567566
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0398 - val_loss: 0.0419
# Epoch 154/200
# mean max of probabilities: 0.0001147826 - temperature 0.10255923
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0399 - val_loss: 0.0431
# Epoch 155/200
# mean max of probabilities: 0.000114800736 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0387 - val_loss: 0.0413
# Epoch 156/200
# mean max of probabilities: 0.000114893795 - temperature 0.1
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0406 - val_loss: 0.0419
# Epoch 157/200
# mean max of probabilities: 0.00011493403 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0413 - val_loss: 0.0432
# Epoch 158/200
# mean max of probabilities: 0.000114968374 - temperature 0.1
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0403 - val_loss: 0.0425
# Epoch 159/200
# mean max of probabilities: 0.00011499845 - temperature 0.1
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0411 - val_loss: 0.0420
# Epoch 160/200
# mean max of probabilities: 0.00011500889 - temperature 0.1
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0374 - val_loss: 0.0402
# Epoch 161/200
# mean max of probabilities: 0.00011501296 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0391 - val_loss: 0.0406
# Epoch 162/200
# mean max of probabilities: 0.000115014846 - temperature 0.1
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0403 - val_loss: 0.0421
# Epoch 163/200
# mean max of probabilities: 0.0001150153 - temperature 0.1
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0399 - val_loss: 0.0469
# Epoch 164/200
# mean max of probabilities: 0.000115015275 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0389 - val_loss: 0.0407
# Epoch 165/200
# mean max of probabilities: 0.00011502884 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0383 - val_loss: 0.0397
# Epoch 166/200
# mean max of probabilities: 0.00011505566 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0395 - val_loss: 0.0400
# Epoch 167/200
# mean max of probabilities: 0.00011506898 - temperature 0.1
# 160/160 [==============================] - 2s 9ms/step - loss: 0.0414 - val_loss: 0.0456
# Epoch 168/200
# mean max of probabilities: 0.00011508246 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0406 - val_loss: 0.0394
# Epoch 169/200
# mean max of probabilities: 0.00011509679 - temperature 0.1
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0398 - val_loss: 0.0441
# Epoch 170/200
# mean max of probabilities: 0.00011512546 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0415 - val_loss: 0.0391
# Epoch 171/200
# mean max of probabilities: 0.00011513524 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0393 - val_loss: 0.0409
# Epoch 172/200
# mean max of probabilities: 0.00011514076 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0410 - val_loss: 0.0433
# Epoch 173/200
# mean max of probabilities: 0.00011519964 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0412 - val_loss: 0.0411
# Epoch 174/200
# mean max of probabilities: 0.00011522288 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0386 - val_loss: 0.0401
# Epoch 175/200
# mean max of probabilities: 0.00011528733 - temperature 0.1
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0385 - val_loss: 0.0408
# Epoch 176/200
# mean max of probabilities: 0.00011536118 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0402 - val_loss: 0.0488
# Epoch 177/200
# mean max of probabilities: 0.00011538803 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0393 - val_loss: 0.0386
# Epoch 178/200
# mean max of probabilities: 0.00011539727 - temperature 0.1
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0428 - val_loss: 0.0428
# Epoch 179/200
# mean max of probabilities: 0.00011540195 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0391 - val_loss: 0.0401
# Epoch 180/200
# mean max of probabilities: 0.00011542705 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0406 - val_loss: 0.0420
# Epoch 181/200
# mean max of probabilities: 0.00011543813 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0407 - val_loss: 0.0392
# Epoch 182/200
# mean max of probabilities: 0.00011544807 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0390 - val_loss: 0.0423
# Epoch 183/200
# mean max of probabilities: 0.00011545144 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0400 - val_loss: 0.0414
# Epoch 184/200
# mean max of probabilities: 0.00011545245 - temperature 0.1
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0394 - val_loss: 0.0390
# Epoch 185/200
# mean max of probabilities: 0.00011545257 - temperature 0.1
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0396 - val_loss: 0.0417
# Epoch 186/200
# mean max of probabilities: 0.00011545239 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0395 - val_loss: 0.0441
# Epoch 187/200
# mean max of probabilities: 0.000115454546 - temperature 0.1
# 160/160 [==============================] - 2s 9ms/step - loss: 0.0393 - val_loss: 0.0417
# Epoch 188/200
# mean max of probabilities: 0.0001154599 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0406 - val_loss: 0.0413
# Epoch 189/200
# mean max of probabilities: 0.00011547147 - temperature 0.1
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0386 - val_loss: 0.0410
# Epoch 190/200
# mean max of probabilities: 0.00011547552 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0400 - val_loss: 0.0448
# Epoch 191/200
# mean max of probabilities: 0.000115529205 - temperature 0.1
# 160/160 [==============================] - 2s 9ms/step - loss: 0.0394 - val_loss: 0.0414
# Epoch 192/200
# mean max of probabilities: 0.00011556153 - temperature 0.1
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0410 - val_loss: 0.0413
# Epoch 193/200
# mean max of probabilities: 0.000115614246 - temperature 0.1
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0399 - val_loss: 0.0442
# Epoch 194/200
# mean max of probabilities: 0.000115643255 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0381 - val_loss: 0.0425
# Epoch 195/200
# mean max of probabilities: 0.00011566528 - temperature 0.1
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0421 - val_loss: 0.0400
# Epoch 196/200
# mean max of probabilities: 0.00011567729 - temperature 0.1
# 160/160 [==============================] - 2s 9ms/step - loss: 0.0404 - val_loss: 0.0399
# Epoch 197/200
# mean max of probabilities: 0.00011568158 - temperature 0.1
# 160/160 [==============================] - 2s 9ms/step - loss: 0.0391 - val_loss: 0.0452
# Epoch 198/200
# mean max of probabilities: 0.00011568288 - temperature 0.1
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0409 - val_loss: 0.0434
# Epoch 199/200
# mean max of probabilities: 0.00011569427 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0380 - val_loss: 0.0406
# Epoch 200/200
# mean max of probabilities: 0.0001157112 - temperature 0.1
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0402 - val_loss: 0.0442
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.85
# Testing accuracy： 0.85
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.8
# Testing accuracy： 0.8
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 10000)             0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 40)                400001
# _________________________________________________________________
# dense_2 (Dense)              (None, 10000)             410000
# =================================================================
# Total params: 810,001
# Trainable params: 810,000
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 160 samples, validate on 40 samples
# Epoch 1/200
# mean max of probabilities: 0.00010324996 - temperature 10.0
# 160/160 [==============================] - 3s 21ms/step - loss: 0.0889 - val_loss: 0.0779
# Epoch 2/200
# mean max of probabilities: 0.00010324978 - temperature 9.705095
# 160/160 [==============================] - 2s 9ms/step - loss: 0.0699 - val_loss: 0.0627
# Epoch 3/200
# mean max of probabilities: 0.00010325047 - temperature 9.418887
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0574 - val_loss: 0.0539
# Epoch 4/200
# mean max of probabilities: 0.00010325684 - temperature 9.141122
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0506 - val_loss: 0.0491
# Epoch 5/200
# mean max of probabilities: 0.00010326823 - temperature 8.871547
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0469 - val_loss: 0.0465
# Epoch 6/200
# mean max of probabilities: 0.0001032815 - temperature 8.609923
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0449 - val_loss: 0.0450
# Epoch 7/200
# mean max of probabilities: 0.00010329394 - temperature 8.356012
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0439 - val_loss: 0.0443
# Epoch 8/200
# mean max of probabilities: 0.00010330461 - temperature 8.1095915
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0434 - val_loss: 0.0438
# Epoch 9/200
# mean max of probabilities: 0.00010331358 - temperature 7.8704367
# 160/160 [==============================] - 1s 7ms/step - loss: 0.0431 - val_loss: 0.0436
# Epoch 10/200
# mean max of probabilities: 0.00010332091 - temperature 7.6383343
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0429 - val_loss: 0.0434
# Epoch 11/200
# mean max of probabilities: 0.00010332712 - temperature 7.413077
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0429 - val_loss: 0.0433
# Epoch 12/200
# mean max of probabilities: 0.000103332495 - temperature 7.1944623
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0428 - val_loss: 0.0432
# Epoch 13/200
# mean max of probabilities: 0.0001033372 - temperature 6.9822946
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0427 - val_loss: 0.0433
# Epoch 14/200
# mean max of probabilities: 0.00010334151 - temperature 6.7763844
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0427 - val_loss: 0.0432
# Epoch 15/200
# mean max of probabilities: 0.000103344966 - temperature 6.576546
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0426 - val_loss: 0.0433
# Epoch 16/200
# mean max of probabilities: 0.00010334795 - temperature 6.3826013
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0426 - val_loss: 0.0432
# Epoch 17/200
# mean max of probabilities: 0.000103350336 - temperature 6.194376
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0426 - val_loss: 0.0430
# Epoch 18/200
# mean max of probabilities: 0.00010335242 - temperature 6.0117006
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0425 - val_loss: 0.0431
# Epoch 19/200
# mean max of probabilities: 0.00010335517 - temperature 5.8344135
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0425 - val_loss: 0.0431
# Epoch 20/200
# mean max of probabilities: 0.00010335769 - temperature 5.662354
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0424 - val_loss: 0.0430
# Epoch 21/200
# mean max of probabilities: 0.00010336 - temperature 5.495369
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0424 - val_loss: 0.0429
# Epoch 22/200
# mean max of probabilities: 0.00010336157 - temperature 5.3333087
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0424 - val_loss: 0.0428
# Epoch 23/200
# mean max of probabilities: 0.000103363745 - temperature 5.176028
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0423 - val_loss: 0.0428
# Epoch 24/200
# mean max of probabilities: 0.00010336524 - temperature 5.023384
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0423 - val_loss: 0.0427
# Epoch 25/200
# mean max of probabilities: 0.000103366445 - temperature 4.8752427
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0422 - val_loss: 0.0428
# Epoch 26/200
# mean max of probabilities: 0.00010336782 - temperature 4.73147
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0422 - val_loss: 0.0429
# Epoch 27/200
# mean max of probabilities: 0.0001033685 - temperature 4.5919366
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0422 - val_loss: 0.0426
# Epoch 28/200
# mean max of probabilities: 0.00010337003 - temperature 4.4565187
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0422 - val_loss: 0.0428
# Epoch 29/200
# mean max of probabilities: 0.00010337353 - temperature 4.325094
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0421 - val_loss: 0.0426
# Epoch 30/200
# mean max of probabilities: 0.000103376384 - temperature 4.1975446
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0420 - val_loss: 0.0425
# Epoch 31/200
# mean max of probabilities: 0.00010338172 - temperature 4.0737567
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0420 - val_loss: 0.0425
# Epoch 32/200
# mean max of probabilities: 0.000103387734 - temperature 3.9536202
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0420 - val_loss: 0.0426
# Epoch 33/200
# mean max of probabilities: 0.00010339702 - temperature 3.8370266
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0419 - val_loss: 0.0425
# Epoch 34/200
# mean max of probabilities: 0.000103407794 - temperature 3.7238712
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0419 - val_loss: 0.0426
# Epoch 35/200
# mean max of probabilities: 0.00010342411 - temperature 3.6140528
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0418 - val_loss: 0.0423
# Epoch 36/200
# mean max of probabilities: 0.00010344116 - temperature 3.5074725
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0418 - val_loss: 0.0422
# Epoch 37/200
# mean max of probabilities: 0.00010346146 - temperature 3.4040358
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0417 - val_loss: 0.0423
# Epoch 38/200
# mean max of probabilities: 0.00010348564 - temperature 3.3036494
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0417 - val_loss: 0.0423
# Epoch 39/200
# mean max of probabilities: 0.000103513245 - temperature 3.2062237
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0416 - val_loss: 0.0422
# Epoch 40/200
# mean max of probabilities: 0.000103543 - temperature 3.1116705
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0416 - val_loss: 0.0422
# Epoch 41/200
# mean max of probabilities: 0.00010357519 - temperature 3.0199058
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0416 - val_loss: 0.0422
# Epoch 42/200
# mean max of probabilities: 0.000103612416 - temperature 2.9308476
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0415 - val_loss: 0.0421
# Epoch 43/200
# mean max of probabilities: 0.00010365147 - temperature 2.8444157
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0415 - val_loss: 0.0421
# Epoch 44/200
# mean max of probabilities: 0.000103694365 - temperature 2.7605326
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0415 - val_loss: 0.0419
# Epoch 45/200
# mean max of probabilities: 0.000103737184 - temperature 2.6791236
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0414 - val_loss: 0.0420
# Epoch 46/200
# mean max of probabilities: 0.00010378375 - temperature 2.6001153
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0414 - val_loss: 0.0421
# Epoch 47/200
# mean max of probabilities: 0.00010383793 - temperature 2.5234365
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0413 - val_loss: 0.0419
# Epoch 48/200
# mean max of probabilities: 0.00010389385 - temperature 2.4490192
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0413 - val_loss: 0.0419
# Epoch 49/200
# mean max of probabilities: 0.000103956045 - temperature 2.3767967
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0412 - val_loss: 0.0419
# Epoch 50/200
# mean max of probabilities: 0.00010402487 - temperature 2.306704
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0412 - val_loss: 0.0418
# Epoch 51/200
# mean max of probabilities: 0.00010410212 - temperature 2.2386785
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0412 - val_loss: 0.0418
# Epoch 52/200
# mean max of probabilities: 0.000104181956 - temperature 2.172659
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0411 - val_loss: 0.0419
# Epoch 53/200
# mean max of probabilities: 0.00010427297 - temperature 2.108586
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0411 - val_loss: 0.0416
# Epoch 54/200
# mean max of probabilities: 0.00010436928 - temperature 2.0464027
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0410 - val_loss: 0.0415
# Epoch 55/200
# mean max of probabilities: 0.000104466526 - temperature 1.9860538
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0410 - val_loss: 0.0415
# Epoch 56/200
# mean max of probabilities: 0.00010457325 - temperature 1.9274842
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0410 - val_loss: 0.0416
# Epoch 57/200
# mean max of probabilities: 0.00010467567 - temperature 1.8706421
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0409 - val_loss: 0.0416
# Epoch 58/200
# mean max of probabilities: 0.00010478108 - temperature 1.8154762
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0408 - val_loss: 0.0415
# Epoch 59/200
# mean max of probabilities: 0.0001048937 - temperature 1.761937
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0408 - val_loss: 0.0415
# Epoch 60/200
# mean max of probabilities: 0.000105036306 - temperature 1.7099768
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0408 - val_loss: 0.0413
# Epoch 61/200
# mean max of probabilities: 0.00010517633 - temperature 1.659549
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0408 - val_loss: 0.0413
# Epoch 62/200
# mean max of probabilities: 0.00010536511 - temperature 1.6106081
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0407 - val_loss: 0.0413
# Epoch 63/200
# mean max of probabilities: 0.00010556638 - temperature 1.5631108
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0406 - val_loss: 0.0415
# Epoch 64/200
# mean max of probabilities: 0.000105762134 - temperature 1.5170141
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0406 - val_loss: 0.0413
# Epoch 65/200
# mean max of probabilities: 0.00010597154 - temperature 1.4722769
# 160/160 [==============================] - 1s 8ms/step - loss: 0.0406 - val_loss: 0.0414
# Epoch 66/200
# mean max of probabilities: 0.00010618057 - temperature 1.4288589
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0405 - val_loss: 0.0413
# Epoch 67/200
# mean max of probabilities: 0.000106367675 - temperature 1.3867214
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0405 - val_loss: 0.0411
# Epoch 68/200
# mean max of probabilities: 0.00010654984 - temperature 1.3458263
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0405 - val_loss: 0.0415
# Epoch 69/200
# mean max of probabilities: 0.000106751184 - temperature 1.3061373
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0405 - val_loss: 0.0412
# Epoch 70/200
# mean max of probabilities: 0.000106952095 - temperature 1.267619
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0404 - val_loss: 0.0410
# Epoch 71/200
# mean max of probabilities: 0.0001071556 - temperature 1.2302365
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0403 - val_loss: 0.0410
# Epoch 72/200
# mean max of probabilities: 0.00010738119 - temperature 1.1939563
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0402 - val_loss: 0.0409
# Epoch 73/200
# mean max of probabilities: 0.00010765276 - temperature 1.158746
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0404 - val_loss: 0.0411
# Epoch 74/200
# mean max of probabilities: 0.00010785852 - temperature 1.1245742
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0402 - val_loss: 0.0411
# Epoch 75/200
# mean max of probabilities: 0.00010807207 - temperature 1.09141
# 160/160 [==============================] - 1s 9ms/step - loss: 0.0404 - val_loss: 0.0407
# Epoch 76/200
# mean max of probabilities: 0.000108333465 - temperature 1.0592241
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0403 - val_loss: 0.0409
# Epoch 77/200
# mean max of probabilities: 0.00010859254 - temperature 1.0279874
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0401 - val_loss: 0.0407
# Epoch 78/200
# mean max of probabilities: 0.000108810455 - temperature 0.9976718
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0401 - val_loss: 0.0414
# Epoch 79/200
# mean max of probabilities: 0.00010908859 - temperature 0.96825004
#  64/160 [===========>..................] - ETA: 1s - loss: 0.0391
