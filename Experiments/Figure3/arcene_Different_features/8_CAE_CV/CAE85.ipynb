# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.model_selection import train_test_split
import scipy.sparse as sparse
from keras.datasets import fashion_mnist
import scipy.io

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
data_path="../Dataset/arcene.mat"
Data = scipy.io.loadmat(data_path)

data_arr=Data['X']
label_arr_=Data['Y'][:, 0]

label_arr=np.array([0 if label_arr_i<0 else label_arr_i for label_arr_i in label_arr_])
data_arr=MinMaxScaler(feature_range=(0,1)).fit_transform(data_arr)
label_arr_onehot=label_arr

# %%
key_feture_number=85

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log"+str(key_feture_number)+"/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log"+str(key_feture_number)+"/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,5):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10000)             0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 85)                850001
# _________________________________________________________________
# dense_1 (Dense)              (None, 10000)             860000
# =================================================================
# Total params: 1,710,001
# Trainable params: 1,710,000
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 160 samples, validate on 40 samples
# Epoch 1/200
# mean max of probabilities: 0.00010324261 - temperature 10.0
# 160/160 [==============================] - 4s 25ms/step - loss: 0.0820 - val_loss: 0.0650
# Epoch 2/200
# mean max of probabilities: 0.00010324266 - temperature 9.705095
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0555 - val_loss: 0.0493
# Epoch 3/200
# mean max of probabilities: 0.00010324355 - temperature 9.418887
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0462 - val_loss: 0.0451
# Epoch 4/200
# mean max of probabilities: 0.000103245504 - temperature 9.141122
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0439 - val_loss: 0.0442
# Epoch 5/200
# mean max of probabilities: 0.00010324676 - temperature 8.871547
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0432 - val_loss: 0.0441
# Epoch 6/200
# mean max of probabilities: 0.00010324714 - temperature 8.609923
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0430 - val_loss: 0.0443
# Epoch 7/200
# mean max of probabilities: 0.000103247374 - temperature 8.356012
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0429 - val_loss: 0.0443
# Epoch 8/200
# mean max of probabilities: 0.00010324774 - temperature 8.1095915
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0428 - val_loss: 0.0438
# Epoch 9/200
# mean max of probabilities: 0.000103248385 - temperature 7.8704367
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0428 - val_loss: 0.0437
# Epoch 10/200
# mean max of probabilities: 0.00010324947 - temperature 7.6383343
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0427 - val_loss: 0.0438
# Epoch 11/200
# mean max of probabilities: 0.000103250975 - temperature 7.413077
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0428 - val_loss: 0.0438
# Epoch 12/200
# mean max of probabilities: 0.000103252445 - temperature 7.1944623
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0426 - val_loss: 0.0438
# Epoch 13/200
# mean max of probabilities: 0.00010325383 - temperature 6.9822946
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0426 - val_loss: 0.0439
# Epoch 14/200
# mean max of probabilities: 0.00010325533 - temperature 6.7763844
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0428 - val_loss: 0.0435
# Epoch 15/200
# mean max of probabilities: 0.000103256774 - temperature 6.576546
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0425 - val_loss: 0.0436
# Epoch 16/200
# mean max of probabilities: 0.000103258484 - temperature 6.3826013
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0425 - val_loss: 0.0437
# Epoch 17/200
# mean max of probabilities: 0.00010325965 - temperature 6.194376
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0424 - val_loss: 0.0436
# Epoch 18/200
# mean max of probabilities: 0.00010326027 - temperature 6.0117006
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0424 - val_loss: 0.0434
# Epoch 19/200
# mean max of probabilities: 0.000103261 - temperature 5.8344135
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0423 - val_loss: 0.0434
# Epoch 20/200
# mean max of probabilities: 0.00010326222 - temperature 5.662354
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0424 - val_loss: 0.0431
# Epoch 21/200
# mean max of probabilities: 0.000103263264 - temperature 5.495369
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0422 - val_loss: 0.0436
# Epoch 22/200
# mean max of probabilities: 0.00010326418 - temperature 5.3333087
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0423 - val_loss: 0.0437
# Epoch 23/200
# mean max of probabilities: 0.00010326362 - temperature 5.176028
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0421 - val_loss: 0.0430
# Epoch 24/200
# mean max of probabilities: 0.00010326249 - temperature 5.023384
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0421 - val_loss: 0.0431
# Epoch 25/200
# mean max of probabilities: 0.00010326315 - temperature 4.8752427
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0420 - val_loss: 0.0432
# Epoch 26/200
# mean max of probabilities: 0.00010326401 - temperature 4.73147
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0420 - val_loss: 0.0434
# Epoch 27/200
# mean max of probabilities: 0.00010326433 - temperature 4.5919366
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0419 - val_loss: 0.0430
# Epoch 28/200
# mean max of probabilities: 0.000103264414 - temperature 4.4565187
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0419 - val_loss: 0.0429
# Epoch 29/200
# mean max of probabilities: 0.000103265964 - temperature 4.325094
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0419 - val_loss: 0.0430
# Epoch 30/200
# mean max of probabilities: 0.00010326862 - temperature 4.1975446
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0418 - val_loss: 0.0431
# Epoch 31/200
# mean max of probabilities: 0.000103271304 - temperature 4.0737567
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0418 - val_loss: 0.0428
# Epoch 32/200
# mean max of probabilities: 0.00010327438 - temperature 3.9536202
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0417 - val_loss: 0.0431
# Epoch 33/200
# mean max of probabilities: 0.00010327927 - temperature 3.8370266
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0416 - val_loss: 0.0429
# Epoch 34/200
# mean max of probabilities: 0.000103286504 - temperature 3.7238712
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0416 - val_loss: 0.0427
# Epoch 35/200
# mean max of probabilities: 0.000103295046 - temperature 3.6140528
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0416 - val_loss: 0.0427
# Epoch 36/200
# mean max of probabilities: 0.000103304104 - temperature 3.5074725
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0415 - val_loss: 0.0427
# Epoch 37/200
# mean max of probabilities: 0.00010331462 - temperature 3.4040358
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0415 - val_loss: 0.0428
# Epoch 38/200
# mean max of probabilities: 0.000103326965 - temperature 3.3036494
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0414 - val_loss: 0.0425
# Epoch 39/200
# mean max of probabilities: 0.00010334046 - temperature 3.2062237
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0414 - val_loss: 0.0426
# Epoch 40/200
# mean max of probabilities: 0.00010335565 - temperature 3.1116705
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0413 - val_loss: 0.0425
# Epoch 41/200
# mean max of probabilities: 0.00010337206 - temperature 3.0199058
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0413 - val_loss: 0.0425
# Epoch 42/200
# mean max of probabilities: 0.000103390696 - temperature 2.9308476
# 160/160 [==============================] - 2s 16ms/step - loss: 0.0412 - val_loss: 0.0424
# Epoch 43/200
# mean max of probabilities: 0.00010340986 - temperature 2.8444157
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0412 - val_loss: 0.0424
# Epoch 44/200
# mean max of probabilities: 0.000103432554 - temperature 2.7605326
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0411 - val_loss: 0.0424
# Epoch 45/200
# mean max of probabilities: 0.00010345753 - temperature 2.6791236
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0411 - val_loss: 0.0425
# Epoch 46/200
# mean max of probabilities: 0.00010348499 - temperature 2.6001153
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0411 - val_loss: 0.0422
# Epoch 47/200
# mean max of probabilities: 0.000103513725 - temperature 2.5234365
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0410 - val_loss: 0.0422
# Epoch 48/200
# mean max of probabilities: 0.00010354484 - temperature 2.4490192
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0410 - val_loss: 0.0421
# Epoch 49/200
# mean max of probabilities: 0.000103578845 - temperature 2.3767967
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0409 - val_loss: 0.0421
# Epoch 50/200
# mean max of probabilities: 0.00010361566 - temperature 2.306704
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0408 - val_loss: 0.0423
# Epoch 51/200
# mean max of probabilities: 0.00010365402 - temperature 2.2386785
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0408 - val_loss: 0.0422
# Epoch 52/200
# mean max of probabilities: 0.000103705286 - temperature 2.172659
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0408 - val_loss: 0.0421
# Epoch 53/200
# mean max of probabilities: 0.00010375684 - temperature 2.108586
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0408 - val_loss: 0.0416
# Epoch 54/200
# mean max of probabilities: 0.00010381165 - temperature 2.0464027
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0407 - val_loss: 0.0420
# Epoch 55/200
# mean max of probabilities: 0.00010386656 - temperature 1.9860538
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0406 - val_loss: 0.0420
# Epoch 56/200
# mean max of probabilities: 0.00010392495 - temperature 1.9274842
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0406 - val_loss: 0.0420
# Epoch 57/200
# mean max of probabilities: 0.000103995466 - temperature 1.8706421
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0407 - val_loss: 0.0421
# Epoch 58/200
# mean max of probabilities: 0.000104068145 - temperature 1.8154762
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0408 - val_loss: 0.0414
# Epoch 59/200
# mean max of probabilities: 0.00010414175 - temperature 1.761937
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0405 - val_loss: 0.0417
# Epoch 60/200
# mean max of probabilities: 0.00010420953 - temperature 1.7099768
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0404 - val_loss: 0.0421
# Epoch 61/200
# mean max of probabilities: 0.00010429541 - temperature 1.659549
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0405 - val_loss: 0.0418
# Epoch 62/200
# mean max of probabilities: 0.00010439361 - temperature 1.6106081
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0403 - val_loss: 0.0417
# Epoch 63/200
# mean max of probabilities: 0.00010449084 - temperature 1.5631108
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0403 - val_loss: 0.0417
# Epoch 64/200
# mean max of probabilities: 0.0001045927 - temperature 1.5170141
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0403 - val_loss: 0.0416
# Epoch 65/200
# mean max of probabilities: 0.0001046942 - temperature 1.4722769
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0402 - val_loss: 0.0419
# Epoch 66/200
# mean max of probabilities: 0.000104803 - temperature 1.4288589
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0402 - val_loss: 0.0412
# Epoch 67/200
# mean max of probabilities: 0.00010493086 - temperature 1.3867214
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0401 - val_loss: 0.0415
# Epoch 68/200
# mean max of probabilities: 0.00010507098 - temperature 1.3458263
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0401 - val_loss: 0.0411
# Epoch 69/200
# mean max of probabilities: 0.00010520259 - temperature 1.3061373
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0401 - val_loss: 0.0418
# Epoch 70/200
# mean max of probabilities: 0.00010534777 - temperature 1.267619
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0400 - val_loss: 0.0415
# Epoch 71/200
# mean max of probabilities: 0.000105490086 - temperature 1.2302365
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0399 - val_loss: 0.0413
# Epoch 72/200
# mean max of probabilities: 0.000105633895 - temperature 1.1939563
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0401 - val_loss: 0.0412
# Epoch 73/200
# mean max of probabilities: 0.00010575764 - temperature 1.158746
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0400 - val_loss: 0.0412
# Epoch 74/200
# mean max of probabilities: 0.00010590823 - temperature 1.1245742
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0399 - val_loss: 0.0417
# Epoch 75/200
# mean max of probabilities: 0.00010606248 - temperature 1.09141
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0400 - val_loss: 0.0415
# Epoch 76/200
# mean max of probabilities: 0.00010621182 - temperature 1.0592241
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0399 - val_loss: 0.0406
# Epoch 77/200
# mean max of probabilities: 0.00010635021 - temperature 1.0279874
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0399 - val_loss: 0.0413
# Epoch 78/200
# mean max of probabilities: 0.00010648638 - temperature 0.9976718
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0400 - val_loss: 0.0415
# Epoch 79/200
# mean max of probabilities: 0.00010666789 - temperature 0.96825004
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0398 - val_loss: 0.0410
# Epoch 80/200
# mean max of probabilities: 0.00010685311 - temperature 0.939696
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0398 - val_loss: 0.0413
# Epoch 81/200
# mean max of probabilities: 0.00010701566 - temperature 0.911984
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0400 - val_loss: 0.0415
# Epoch 82/200
# mean max of probabilities: 0.00010716408 - temperature 0.8850892
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0402 - val_loss: 0.0406
# Epoch 83/200
# mean max of probabilities: 0.00010731491 - temperature 0.85898757
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0399 - val_loss: 0.0414
# Epoch 84/200
# mean max of probabilities: 0.00010746745 - temperature 0.83365566
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0398 - val_loss: 0.0418
# Epoch 85/200
# mean max of probabilities: 0.00010761829 - temperature 0.8090709
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0400 - val_loss: 0.0411
# Epoch 86/200
# mean max of probabilities: 0.00010775766 - temperature 0.7852111
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0397 - val_loss: 0.0417
# Epoch 87/200
# mean max of probabilities: 0.00010789495 - temperature 0.762055
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0395 - val_loss: 0.0414
# Epoch 88/200
# mean max of probabilities: 0.00010803108 - temperature 0.7395817
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0403 - val_loss: 0.0417
# Epoch 89/200
# mean max of probabilities: 0.000108159205 - temperature 0.7177711
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0397 - val_loss: 0.0417
# Epoch 90/200
# mean max of probabilities: 0.000108283646 - temperature 0.69660366
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0401 - val_loss: 0.0398
# Epoch 91/200
# mean max of probabilities: 0.000108423475 - temperature 0.67606056
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0398 - val_loss: 0.0413
# Epoch 92/200
# mean max of probabilities: 0.000108571665 - temperature 0.6561233
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0400 - val_loss: 0.0411
# Epoch 93/200
# mean max of probabilities: 0.000108691944 - temperature 0.63677377
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0403 - val_loss: 0.0419
# Epoch 94/200
# mean max of probabilities: 0.00010877647 - temperature 0.617995
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0403 - val_loss: 0.0399
# Epoch 95/200
# mean max of probabilities: 0.00010884884 - temperature 0.5997701
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0405 - val_loss: 0.0406
# Epoch 96/200
# mean max of probabilities: 0.00010895205 - temperature 0.5820826
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0393 - val_loss: 0.0416
# Epoch 97/200
# mean max of probabilities: 0.0001090503 - temperature 0.5649167
# 160/160 [==============================] - 3s 22ms/step - loss: 0.0403 - val_loss: 0.0425
# Epoch 98/200
# mean max of probabilities: 0.00010915129 - temperature 0.5482572
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0404 - val_loss: 0.0400
# Epoch 99/200
# mean max of probabilities: 0.000109252345 - temperature 0.53208894
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0400 - val_loss: 0.0407
# Epoch 100/200
# mean max of probabilities: 0.00010935919 - temperature 0.51639754
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0388 - val_loss: 0.0415
# Epoch 101/200
# mean max of probabilities: 0.0001094688 - temperature 0.50116867
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0402 - val_loss: 0.0412
# Epoch 102/200
# mean max of probabilities: 0.000109558016 - temperature 0.48638898
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0399 - val_loss: 0.0416
# Epoch 103/200
# mean max of probabilities: 0.00010964001 - temperature 0.47204518
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0400 - val_loss: 0.0419
# Epoch 104/200
# mean max of probabilities: 0.00010969637 - temperature 0.45812437
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0404 - val_loss: 0.0417
# Epoch 105/200
# mean max of probabilities: 0.00010973245 - temperature 0.4446141
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0408 - val_loss: 0.0394
# Epoch 106/200
# mean max of probabilities: 0.00010977389 - temperature 0.43150225
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0409 - val_loss: 0.0420
# Epoch 107/200
# mean max of probabilities: 0.000109827946 - temperature 0.41877705
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0402 - val_loss: 0.0425
# Epoch 108/200
# mean max of probabilities: 0.00010988207 - temperature 0.40642717
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0393 - val_loss: 0.0422
# Epoch 109/200
# mean max of probabilities: 0.000109934146 - temperature 0.3944415
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0398 - val_loss: 0.0432
# Epoch 110/200
# mean max of probabilities: 0.00011000628 - temperature 0.38280922
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0394 - val_loss: 0.0426
# Epoch 111/200
# mean max of probabilities: 0.00011006358 - temperature 0.37151998
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0401 - val_loss: 0.0432
# Epoch 112/200
# mean max of probabilities: 0.00011014066 - temperature 0.36056373
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0396 - val_loss: 0.0410
# Epoch 113/200
# mean max of probabilities: 0.000110233246 - temperature 0.34993058
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0401 - val_loss: 0.0407
# Epoch 114/200
# mean max of probabilities: 0.00011028912 - temperature 0.33961096
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0384 - val_loss: 0.0398
# Epoch 115/200
# mean max of probabilities: 0.00011034081 - temperature 0.32959563
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0402 - val_loss: 0.0405
# Epoch 116/200
# mean max of probabilities: 0.00011039313 - temperature 0.31987572
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0409 - val_loss: 0.0448
# Epoch 117/200
# mean max of probabilities: 0.00011045223 - temperature 0.31044245
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0390 - val_loss: 0.0417
# Epoch 118/200
# mean max of probabilities: 0.0001105037 - temperature 0.30128738
# 160/160 [==============================] - 2s 16ms/step - loss: 0.0417 - val_loss: 0.0400
# Epoch 119/200
# mean max of probabilities: 0.000110533176 - temperature 0.2924023
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0398 - val_loss: 0.0402
# Epoch 120/200
# mean max of probabilities: 0.0001105839 - temperature 0.28377923
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0389 - val_loss: 0.0411
# Epoch 121/200
# mean max of probabilities: 0.00011065587 - temperature 0.2754104
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0406 - val_loss: 0.0420
# Epoch 122/200
# mean max of probabilities: 0.00011070114 - temperature 0.2672884
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0400 - val_loss: 0.0403
# Epoch 123/200
# mean max of probabilities: 0.000110732064 - temperature 0.25940588
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0393 - val_loss: 0.0401
# Epoch 124/200
# mean max of probabilities: 0.000110748246 - temperature 0.2517559
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0393 - val_loss: 0.0425
# Epoch 125/200
# mean max of probabilities: 0.000110774534 - temperature 0.24433151
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0395 - val_loss: 0.0387
# Epoch 126/200
# mean max of probabilities: 0.00011080575 - temperature 0.23712608
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0407 - val_loss: 0.0413
# Epoch 127/200
# mean max of probabilities: 0.00011081734 - temperature 0.23013313
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0402 - val_loss: 0.0381
# Epoch 128/200
# mean max of probabilities: 0.00011081979 - temperature 0.22334641
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0403 - val_loss: 0.0393
# Epoch 129/200
# mean max of probabilities: 0.00011083343 - temperature 0.21675983
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0397 - val_loss: 0.0418
# Epoch 130/200
# mean max of probabilities: 0.00011085121 - temperature 0.2103675
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0409 - val_loss: 0.0454
# Epoch 131/200
# mean max of probabilities: 0.00011087632 - temperature 0.20416367
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0412 - val_loss: 0.0439
# Epoch 132/200
# mean max of probabilities: 0.00011089583 - temperature 0.19814283
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0392 - val_loss: 0.0425
# Epoch 133/200
# mean max of probabilities: 0.00011092009 - temperature 0.19229952
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0402 - val_loss: 0.0405
# Epoch 134/200
# mean max of probabilities: 0.00011095563 - temperature 0.18662854
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0383 - val_loss: 0.0442
# Epoch 135/200
# mean max of probabilities: 0.00011099085 - temperature 0.18112479
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0398 - val_loss: 0.0455
# Epoch 136/200
# mean max of probabilities: 0.00011102534 - temperature 0.17578335
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0411 - val_loss: 0.0445
# Epoch 137/200
# mean max of probabilities: 0.0001110508 - temperature 0.17059945
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0385 - val_loss: 0.0430
# Epoch 138/200
# mean max of probabilities: 0.00011106597 - temperature 0.16556841
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0410 - val_loss: 0.0414
# Epoch 139/200
# mean max of probabilities: 0.00011108236 - temperature 0.16068572
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0385 - val_loss: 0.0442
# Epoch 140/200
# mean max of probabilities: 0.00011111445 - temperature 0.15594701
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0396 - val_loss: 0.0396
# Epoch 141/200
# mean max of probabilities: 0.00011114655 - temperature 0.15134808
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0401 - val_loss: 0.0404
# Epoch 142/200
# mean max of probabilities: 0.00011115983 - temperature 0.14688475
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0396 - val_loss: 0.0431
# Epoch 143/200
# mean max of probabilities: 0.00011117046 - temperature 0.14255308
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0382 - val_loss: 0.0417
# Epoch 144/200
# mean max of probabilities: 0.00011119372 - temperature 0.13834915
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0386 - val_loss: 0.0383
# Epoch 145/200
# mean max of probabilities: 0.0001112225 - temperature 0.13426918
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0399 - val_loss: 0.0418
# Epoch 146/200
# mean max of probabilities: 0.00011128062 - temperature 0.13030952
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0383 - val_loss: 0.0433
# Epoch 147/200
# mean max of probabilities: 0.00011131714 - temperature 0.12646663
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0404 - val_loss: 0.0418
# Epoch 148/200
# mean max of probabilities: 0.00011135926 - temperature 0.12273709
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0395 - val_loss: 0.0395
# Epoch 149/200
# mean max of probabilities: 0.00011138662 - temperature 0.11911752
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0405 - val_loss: 0.0381
# Epoch 150/200
# mean max of probabilities: 0.00011140989 - temperature 0.1156047
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0405 - val_loss: 0.0450
# Epoch 151/200
# mean max of probabilities: 0.00011144589 - temperature 0.11219547
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0402 - val_loss: 0.0402
# Epoch 152/200
# mean max of probabilities: 0.00011145943 - temperature 0.10888678
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0397 - val_loss: 0.0443
# Epoch 153/200
# mean max of probabilities: 0.00011146862 - temperature 0.10567566
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0398 - val_loss: 0.0423
# Epoch 154/200
# mean max of probabilities: 0.0001114754 - temperature 0.10255923
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0403 - val_loss: 0.0451
# Epoch 155/200
# mean max of probabilities: 0.00011147766 - temperature 0.1
# 160/160 [==============================] - 3s 19ms/step - loss: 0.0408 - val_loss: 0.0415
# Epoch 156/200
# mean max of probabilities: 0.00011148048 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0391 - val_loss: 0.0418
# Epoch 157/200
# mean max of probabilities: 0.00011149066 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0413 - val_loss: 0.0419
# Epoch 158/200
# mean max of probabilities: 0.00011152099 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0403 - val_loss: 0.0402
# Epoch 159/200
# mean max of probabilities: 0.00011156049 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0397 - val_loss: 0.0440
# Epoch 160/200
# mean max of probabilities: 0.000111582165 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0397 - val_loss: 0.0390
# Epoch 161/200
# mean max of probabilities: 0.00011158962 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0399 - val_loss: 0.0420
# Epoch 162/200
# mean max of probabilities: 0.00011161064 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0399 - val_loss: 0.0415
# Epoch 163/200
# mean max of probabilities: 0.000111623194 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0398 - val_loss: 0.0418
# Epoch 164/200
# mean max of probabilities: 0.000111631874 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0390 - val_loss: 0.0410
# Epoch 165/200
# mean max of probabilities: 0.00011164135 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0391 - val_loss: 0.0423
# Epoch 166/200
# mean max of probabilities: 0.00011164937 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0407 - val_loss: 0.0447
# Epoch 167/200
# mean max of probabilities: 0.0001116537 - temperature 0.1
# 160/160 [==============================] - 3s 19ms/step - loss: 0.0386 - val_loss: 0.0396
# Epoch 168/200
# mean max of probabilities: 0.00011167637 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0414 - val_loss: 0.0388
# Epoch 169/200
# mean max of probabilities: 0.00011169553 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0405 - val_loss: 0.0398
# Epoch 170/200
# mean max of probabilities: 0.000111726935 - temperature 0.1
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0382 - val_loss: 0.0424
# Epoch 171/200
# mean max of probabilities: 0.000111758534 - temperature 0.1
# 160/160 [==============================] - 3s 19ms/step - loss: 0.0395 - val_loss: 0.0371
# Epoch 172/200
# mean max of probabilities: 0.00011179209 - temperature 0.1
# 160/160 [==============================] - 3s 19ms/step - loss: 0.0401 - val_loss: 0.0406
# Epoch 173/200
# mean max of probabilities: 0.00011180579 - temperature 0.1
# 160/160 [==============================] - 3s 22ms/step - loss: 0.0388 - val_loss: 0.0407
# Epoch 174/200
# mean max of probabilities: 0.00011181048 - temperature 0.1
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0402 - val_loss: 0.0405
# Epoch 175/200
# mean max of probabilities: 0.00011181396 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0394 - val_loss: 0.0398
# Epoch 176/200
# mean max of probabilities: 0.00011183416 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0382 - val_loss: 0.0420
# Epoch 177/200
# mean max of probabilities: 0.00011185067 - temperature 0.1
#  96/160 [=================>............] - ETA: 1s - loss: 0.0383
