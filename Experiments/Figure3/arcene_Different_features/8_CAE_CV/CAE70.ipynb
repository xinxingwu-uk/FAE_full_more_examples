# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.model_selection import train_test_split
import scipy.sparse as sparse
from keras.datasets import fashion_mnist
import scipy.io

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
data_path="../Dataset/arcene.mat"
Data = scipy.io.loadmat(data_path)

data_arr=Data['X']
label_arr_=Data['Y'][:, 0]

label_arr=np.array([0 if label_arr_i<0 else label_arr_i for label_arr_i in label_arr_])
data_arr=MinMaxScaler(feature_range=(0,1)).fit_transform(data_arr)
label_arr_onehot=label_arr

# %%
key_feture_number=70

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log"+str(key_feture_number)+"/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log"+str(key_feture_number)+"/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,5):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10000)             0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 70)                700001
# _________________________________________________________________
# dense_1 (Dense)              (None, 10000)             710000
# =================================================================
# Total params: 1,410,001
# Trainable params: 1,410,000
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 160 samples, validate on 40 samples
# Epoch 1/200
# mean max of probabilities: 0.00010324448 - temperature 10.0
# 160/160 [==============================] - 4s 22ms/step - loss: 0.0841 - val_loss: 0.0692
# Epoch 2/200
# mean max of probabilities: 0.000103244536 - temperature 9.705095
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0593 - val_loss: 0.0524
# Epoch 3/200
# mean max of probabilities: 0.00010324588 - temperature 9.418887
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0484 - val_loss: 0.0464
# Epoch 4/200
# mean max of probabilities: 0.00010324918 - temperature 9.141122
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0446 - val_loss: 0.0445
# Epoch 5/200
# mean max of probabilities: 0.00010325274 - temperature 8.871547
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0434 - val_loss: 0.0440
# Epoch 6/200
# mean max of probabilities: 0.00010325509 - temperature 8.609923
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0430 - val_loss: 0.0441
# Epoch 7/200
# mean max of probabilities: 0.00010325653 - temperature 8.356012
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0429 - val_loss: 0.0442
# Epoch 8/200
# mean max of probabilities: 0.00010325758 - temperature 8.1095915
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0428 - val_loss: 0.0439
# Epoch 9/200
# mean max of probabilities: 0.00010325872 - temperature 7.8704367
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0427 - val_loss: 0.0438
# Epoch 10/200
# mean max of probabilities: 0.00010326021 - temperature 7.6383343
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0427 - val_loss: 0.0438
# Epoch 11/200
# mean max of probabilities: 0.00010326211 - temperature 7.413077
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0427 - val_loss: 0.0438
# Epoch 12/200
# mean max of probabilities: 0.00010326407 - temperature 7.1944623
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0426 - val_loss: 0.0438
# Epoch 13/200
# mean max of probabilities: 0.00010326593 - temperature 6.9822946
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0426 - val_loss: 0.0439
# Epoch 14/200
# mean max of probabilities: 0.00010326796 - temperature 6.7763844
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0427 - val_loss: 0.0435
# Epoch 15/200
# mean max of probabilities: 0.000103269966 - temperature 6.576546
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0425 - val_loss: 0.0436
# Epoch 16/200
# mean max of probabilities: 0.00010327238 - temperature 6.3826013
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0425 - val_loss: 0.0436
# Epoch 17/200
# mean max of probabilities: 0.00010327423 - temperature 6.194376
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0424 - val_loss: 0.0436
# Epoch 18/200
# mean max of probabilities: 0.0001032754 - temperature 6.0117006
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0424 - val_loss: 0.0434
# Epoch 19/200
# mean max of probabilities: 0.00010327645 - temperature 5.8344135
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0423 - val_loss: 0.0434
# Epoch 20/200
# mean max of probabilities: 0.000103278064 - temperature 5.662354
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0424 - val_loss: 0.0432
# Epoch 21/200
# mean max of probabilities: 0.000103279686 - temperature 5.495369
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0422 - val_loss: 0.0435
# Epoch 22/200
# mean max of probabilities: 0.00010328123 - temperature 5.3333087
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0423 - val_loss: 0.0437
# Epoch 23/200
# mean max of probabilities: 0.000103280916 - temperature 5.176028
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0421 - val_loss: 0.0431
# Epoch 24/200
# mean max of probabilities: 0.000103279635 - temperature 5.023384
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0421 - val_loss: 0.0431
# Epoch 25/200
# mean max of probabilities: 0.00010328039 - temperature 4.8752427
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0420 - val_loss: 0.0431
# Epoch 26/200
# mean max of probabilities: 0.00010328154 - temperature 4.73147
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0420 - val_loss: 0.0433
# Epoch 27/200
# mean max of probabilities: 0.00010328236 - temperature 4.5919366
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0419 - val_loss: 0.0431
# Epoch 28/200
# mean max of probabilities: 0.00010328277 - temperature 4.4565187
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0419 - val_loss: 0.0430
# Epoch 29/200
# mean max of probabilities: 0.00010328428 - temperature 4.325094
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0419 - val_loss: 0.0430
# Epoch 30/200
# mean max of probabilities: 0.000103286904 - temperature 4.1975446
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0418 - val_loss: 0.0431
# Epoch 31/200
# mean max of probabilities: 0.00010328997 - temperature 4.0737567
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0418 - val_loss: 0.0428
# Epoch 32/200
# mean max of probabilities: 0.00010329303 - temperature 3.9536202
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0417 - val_loss: 0.0431
# Epoch 33/200
# mean max of probabilities: 0.000103297876 - temperature 3.8370266
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0417 - val_loss: 0.0429
# Epoch 34/200
# mean max of probabilities: 0.000103305436 - temperature 3.7238712
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0416 - val_loss: 0.0427
# Epoch 35/200
# mean max of probabilities: 0.000103315724 - temperature 3.6140528
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0416 - val_loss: 0.0427
# Epoch 36/200
# mean max of probabilities: 0.00010332754 - temperature 3.5074725
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0415 - val_loss: 0.0427
# Epoch 37/200
# mean max of probabilities: 0.00010334011 - temperature 3.4040358
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0415 - val_loss: 0.0428
# Epoch 38/200
# mean max of probabilities: 0.00010335481 - temperature 3.3036494
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0414 - val_loss: 0.0426
# Epoch 39/200
# mean max of probabilities: 0.00010337088 - temperature 3.2062237
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0414 - val_loss: 0.0426
# Epoch 40/200
# mean max of probabilities: 0.00010338914 - temperature 3.1116705
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0414 - val_loss: 0.0425
# Epoch 41/200
# mean max of probabilities: 0.000103408216 - temperature 3.0199058
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0413 - val_loss: 0.0425
# Epoch 42/200
# mean max of probabilities: 0.00010343056 - temperature 2.9308476
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0412 - val_loss: 0.0424
# Epoch 43/200
# mean max of probabilities: 0.00010345325 - temperature 2.8444157
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0412 - val_loss: 0.0425
# Epoch 44/200
# mean max of probabilities: 0.0001034793 - temperature 2.7605326
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0412 - val_loss: 0.0424
# Epoch 45/200
# mean max of probabilities: 0.00010350776 - temperature 2.6791236
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0411 - val_loss: 0.0425
# Epoch 46/200
# mean max of probabilities: 0.00010354124 - temperature 2.6001153
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0411 - val_loss: 0.0423
# Epoch 47/200
# mean max of probabilities: 0.00010357771 - temperature 2.5234365
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0410 - val_loss: 0.0422
# Epoch 48/200
# mean max of probabilities: 0.00010361635 - temperature 2.4490192
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0410 - val_loss: 0.0421
# Epoch 49/200
# mean max of probabilities: 0.00010365684 - temperature 2.3767967
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0409 - val_loss: 0.0421
# Epoch 50/200
# mean max of probabilities: 0.00010370066 - temperature 2.306704
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0409 - val_loss: 0.0423
# Epoch 51/200
# mean max of probabilities: 0.000103744875 - temperature 2.2386785
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0408 - val_loss: 0.0422
# Epoch 52/200
# mean max of probabilities: 0.000103792416 - temperature 2.172659
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0408 - val_loss: 0.0422
# Epoch 53/200
# mean max of probabilities: 0.00010384621 - temperature 2.108586
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0409 - val_loss: 0.0417
# Epoch 54/200
# mean max of probabilities: 0.000103905295 - temperature 2.0464027
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0407 - val_loss: 0.0420
# Epoch 55/200
# mean max of probabilities: 0.00010396836 - temperature 1.9860538
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0406 - val_loss: 0.0420
# Epoch 56/200
# mean max of probabilities: 0.00010403366 - temperature 1.9274842
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0406 - val_loss: 0.0420
# Epoch 57/200
# mean max of probabilities: 0.00010410527 - temperature 1.8706421
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0407 - val_loss: 0.0421
# Epoch 58/200
# mean max of probabilities: 0.0001041858 - temperature 1.8154762
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0408 - val_loss: 0.0415
# Epoch 59/200
# mean max of probabilities: 0.00010426407 - temperature 1.761937
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0405 - val_loss: 0.0417
# Epoch 60/200
# mean max of probabilities: 0.00010435345 - temperature 1.7099768
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0404 - val_loss: 0.0420
# Epoch 61/200
# mean max of probabilities: 0.00010445578 - temperature 1.659549
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0404 - val_loss: 0.0419
# Epoch 62/200
# mean max of probabilities: 0.00010456448 - temperature 1.6106081
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0403 - val_loss: 0.0418
# Epoch 63/200
# mean max of probabilities: 0.00010469392 - temperature 1.5631108
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0403 - val_loss: 0.0416
# Epoch 64/200
# mean max of probabilities: 0.00010483474 - temperature 1.5170141
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0403 - val_loss: 0.0416
# Epoch 65/200
# mean max of probabilities: 0.000104975246 - temperature 1.4722769
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0403 - val_loss: 0.0419
# Epoch 66/200
# mean max of probabilities: 0.00010510619 - temperature 1.4288589
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0402 - val_loss: 0.0414
# Epoch 67/200
# mean max of probabilities: 0.00010526117 - temperature 1.3867214
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0401 - val_loss: 0.0416
# Epoch 68/200
# mean max of probabilities: 0.000105384504 - temperature 1.3458263
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0403 - val_loss: 0.0414
# Epoch 69/200
# mean max of probabilities: 0.00010555403 - temperature 1.3061373
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0401 - val_loss: 0.0415
# Epoch 70/200
# mean max of probabilities: 0.000105715095 - temperature 1.267619
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0400 - val_loss: 0.0416
# Epoch 71/200
# mean max of probabilities: 0.00010586288 - temperature 1.2302365
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0400 - val_loss: 0.0412
# Epoch 72/200
# mean max of probabilities: 0.00010601838 - temperature 1.1939563
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0400 - val_loss: 0.0411
# Epoch 73/200
# mean max of probabilities: 0.00010617788 - temperature 1.158746
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0400 - val_loss: 0.0410
# Epoch 74/200
# mean max of probabilities: 0.00010635182 - temperature 1.1245742
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0399 - val_loss: 0.0412
# Epoch 75/200
# mean max of probabilities: 0.00010650619 - temperature 1.09141
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0398 - val_loss: 0.0416
# Epoch 76/200
# mean max of probabilities: 0.00010667986 - temperature 1.0592241
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0400 - val_loss: 0.0409
# Epoch 77/200
# mean max of probabilities: 0.00010685958 - temperature 1.0279874
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0400 - val_loss: 0.0415
# Epoch 78/200
# mean max of probabilities: 0.00010704234 - temperature 0.9976718
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0399 - val_loss: 0.0412
# Epoch 79/200
# mean max of probabilities: 0.00010722346 - temperature 0.96825004
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0396 - val_loss: 0.0416
# Epoch 80/200
# mean max of probabilities: 0.00010738472 - temperature 0.939696
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0400 - val_loss: 0.0407
# Epoch 81/200
# mean max of probabilities: 0.00010754849 - temperature 0.911984
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0399 - val_loss: 0.0420
# Epoch 82/200
# mean max of probabilities: 0.0001077109 - temperature 0.8850892
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0400 - val_loss: 0.0413
# Epoch 83/200
# mean max of probabilities: 0.000107867076 - temperature 0.85898757
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0400 - val_loss: 0.0414
# Epoch 84/200
# mean max of probabilities: 0.00010800145 - temperature 0.83365566
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0399 - val_loss: 0.0411
# Epoch 85/200
# mean max of probabilities: 0.00010813472 - temperature 0.8090709
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0399 - val_loss: 0.0421
# Epoch 86/200
# mean max of probabilities: 0.00010826198 - temperature 0.7852111
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0396 - val_loss: 0.0419
# Epoch 87/200
# mean max of probabilities: 0.00010839887 - temperature 0.762055
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0402 - val_loss: 0.0411
# Epoch 88/200
# mean max of probabilities: 0.000108583554 - temperature 0.7395817
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0401 - val_loss: 0.0416
# Epoch 89/200
# mean max of probabilities: 0.00010874574 - temperature 0.7177711
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0394 - val_loss: 0.0416
# Epoch 90/200
# mean max of probabilities: 0.0001088843 - temperature 0.69660366
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0397 - val_loss: 0.0406
# Epoch 91/200
# mean max of probabilities: 0.000109017245 - temperature 0.67606056
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0403 - val_loss: 0.0422
# Epoch 92/200
# mean max of probabilities: 0.000109105276 - temperature 0.6561233
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0394 - val_loss: 0.0420
# Epoch 93/200
# mean max of probabilities: 0.0001092226 - temperature 0.63677377
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0395 - val_loss: 0.0407
# Epoch 94/200
# mean max of probabilities: 0.00010930513 - temperature 0.617995
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0400 - val_loss: 0.0418
# Epoch 95/200
# mean max of probabilities: 0.00010939926 - temperature 0.5997701
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0390 - val_loss: 0.0405
# Epoch 96/200
# mean max of probabilities: 0.00010950401 - temperature 0.5820826
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0403 - val_loss: 0.0430
# Epoch 97/200
# mean max of probabilities: 0.000109609704 - temperature 0.5649167
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0405 - val_loss: 0.0417
# Epoch 98/200
# mean max of probabilities: 0.000109691995 - temperature 0.5482572
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0406 - val_loss: 0.0412
# Epoch 99/200
# mean max of probabilities: 0.000109786844 - temperature 0.53208894
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0404 - val_loss: 0.0423
# Epoch 100/200
# mean max of probabilities: 0.00010987545 - temperature 0.51639754
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0402 - val_loss: 0.0391
# Epoch 101/200
# mean max of probabilities: 0.000109967026 - temperature 0.50116867
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0398 - val_loss: 0.0424
# Epoch 102/200
# mean max of probabilities: 0.000110064364 - temperature 0.48638898
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0406 - val_loss: 0.0430
# Epoch 103/200
# mean max of probabilities: 0.00011017297 - temperature 0.47204518
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0399 - val_loss: 0.0404
# Epoch 104/200
# mean max of probabilities: 0.000110253255 - temperature 0.45812437
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0400 - val_loss: 0.0397
# Epoch 105/200
# mean max of probabilities: 0.00011033362 - temperature 0.4446141
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0401 - val_loss: 0.0422
# Epoch 106/200
# mean max of probabilities: 0.00011040391 - temperature 0.43150225
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0391 - val_loss: 0.0426
# Epoch 107/200
# mean max of probabilities: 0.00011048237 - temperature 0.41877705
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0395 - val_loss: 0.0406
# Epoch 108/200
# mean max of probabilities: 0.00011057773 - temperature 0.40642717
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0397 - val_loss: 0.0418
# Epoch 109/200
# mean max of probabilities: 0.00011063806 - temperature 0.3944415
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0400 - val_loss: 0.0405
# Epoch 110/200
# mean max of probabilities: 0.000110690125 - temperature 0.38280922
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0399 - val_loss: 0.0420
# Epoch 111/200
# mean max of probabilities: 0.0001107646 - temperature 0.37151998
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0396 - val_loss: 0.0417
# Epoch 112/200
# mean max of probabilities: 0.00011083078 - temperature 0.36056373
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0400 - val_loss: 0.0411
# Epoch 113/200
# mean max of probabilities: 0.000110874906 - temperature 0.34993058
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0395 - val_loss: 0.0428
# Epoch 114/200
# mean max of probabilities: 0.00011089689 - temperature 0.33961096
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0402 - val_loss: 0.0444
# Epoch 115/200
# mean max of probabilities: 0.00011092366 - temperature 0.32959563
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0401 - val_loss: 0.0439
# Epoch 116/200
# mean max of probabilities: 0.00011096402 - temperature 0.31987572
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0418 - val_loss: 0.0418
# Epoch 117/200
# mean max of probabilities: 0.0001110088 - temperature 0.31044245
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0396 - val_loss: 0.0412
# Epoch 118/200
# mean max of probabilities: 0.000111034045 - temperature 0.30128738
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0411 - val_loss: 0.0390
# Epoch 119/200
# mean max of probabilities: 0.00011105133 - temperature 0.2924023
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0386 - val_loss: 0.0417
# Epoch 120/200
# mean max of probabilities: 0.000111083915 - temperature 0.28377923
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0411 - val_loss: 0.0398
# Epoch 121/200
# mean max of probabilities: 0.0001111282 - temperature 0.2754104
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0410 - val_loss: 0.0392
# Epoch 122/200
# mean max of probabilities: 0.000111160574 - temperature 0.2672884
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0409 - val_loss: 0.0432
# Epoch 123/200
# mean max of probabilities: 0.000111201385 - temperature 0.25940588
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0421 - val_loss: 0.0419
# Epoch 124/200
# mean max of probabilities: 0.000111234614 - temperature 0.2517559
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0392 - val_loss: 0.0399
# Epoch 125/200
# mean max of probabilities: 0.0001112639 - temperature 0.24433151
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0412 - val_loss: 0.0418
# Epoch 126/200
# mean max of probabilities: 0.00011128901 - temperature 0.23712608
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0419 - val_loss: 0.0395
# Epoch 127/200
# mean max of probabilities: 0.000111319445 - temperature 0.23013313
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0389 - val_loss: 0.0398
# Epoch 128/200
# mean max of probabilities: 0.00011135263 - temperature 0.22334641
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0400 - val_loss: 0.0415
# Epoch 129/200
# mean max of probabilities: 0.00011137931 - temperature 0.21675983
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0407 - val_loss: 0.0407
# Epoch 130/200
# mean max of probabilities: 0.00011141754 - temperature 0.2103675
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0400 - val_loss: 0.0440
# Epoch 131/200
# mean max of probabilities: 0.000111460926 - temperature 0.20416367
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0400 - val_loss: 0.0407
# Epoch 132/200
# mean max of probabilities: 0.000111492154 - temperature 0.19814283
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0404 - val_loss: 0.0388
# Epoch 133/200
# mean max of probabilities: 0.00011152399 - temperature 0.19229952
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0389 - val_loss: 0.0408
# Epoch 134/200
# mean max of probabilities: 0.00011156655 - temperature 0.18662854
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0399 - val_loss: 0.0417
# Epoch 135/200
# mean max of probabilities: 0.00011161222 - temperature 0.18112479
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0402 - val_loss: 0.0412
# Epoch 136/200
# mean max of probabilities: 0.00011164559 - temperature 0.17578335
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0410 - val_loss: 0.0415
# Epoch 137/200
# mean max of probabilities: 0.00011167388 - temperature 0.17059945
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0384 - val_loss: 0.0432
# Epoch 138/200
# mean max of probabilities: 0.000111706526 - temperature 0.16556841
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0398 - val_loss: 0.0436
# Epoch 139/200
# mean max of probabilities: 0.00011173247 - temperature 0.16068572
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0396 - val_loss: 0.0397
# Epoch 140/200
# mean max of probabilities: 0.00011176931 - temperature 0.15594701
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0406 - val_loss: 0.0406
# Epoch 141/200
# mean max of probabilities: 0.000111823705 - temperature 0.15134808
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0392 - val_loss: 0.0450
# Epoch 142/200
# mean max of probabilities: 0.00011186706 - temperature 0.14688475
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0421 - val_loss: 0.0398
# Epoch 143/200
# mean max of probabilities: 0.00011190901 - temperature 0.14255308
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0402 - val_loss: 0.0401
# Epoch 144/200
# mean max of probabilities: 0.0001119595 - temperature 0.13834915
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0411 - val_loss: 0.0445
# Epoch 145/200
# mean max of probabilities: 0.000111995425 - temperature 0.13426918
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0406 - val_loss: 0.0414
# Epoch 146/200
# mean max of probabilities: 0.00011203285 - temperature 0.13030952
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0394 - val_loss: 0.0389
# Epoch 147/200
# mean max of probabilities: 0.00011205837 - temperature 0.12646663
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0410 - val_loss: 0.0429
# Epoch 148/200
# mean max of probabilities: 0.000112069865 - temperature 0.12273709
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0393 - val_loss: 0.0405
# Epoch 149/200
# mean max of probabilities: 0.000112084555 - temperature 0.11911752
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0403 - val_loss: 0.0397
# Epoch 150/200
# mean max of probabilities: 0.00011210237 - temperature 0.1156047
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0409 - val_loss: 0.0440
# Epoch 151/200
# mean max of probabilities: 0.000112111695 - temperature 0.11219547
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0408 - val_loss: 0.0415
# Epoch 152/200
# mean max of probabilities: 0.00011211529 - temperature 0.10888678
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0395 - val_loss: 0.0436
# Epoch 153/200
# mean max of probabilities: 0.00011212745 - temperature 0.10567566
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0396 - val_loss: 0.0404
# Epoch 154/200
# mean max of probabilities: 0.00011214248 - temperature 0.10255923
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0395 - val_loss: 0.0439
# Epoch 155/200
# mean max of probabilities: 0.00011214953 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0401 - val_loss: 0.0456
# Epoch 156/200
# mean max of probabilities: 0.00011215388 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0395 - val_loss: 0.0420
# Epoch 157/200
# mean max of probabilities: 0.00011215902 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0378 - val_loss: 0.0404
# Epoch 158/200
# mean max of probabilities: 0.00011216168 - temperature 0.1
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0390 - val_loss: 0.0399
# Epoch 159/200
# mean max of probabilities: 0.000112178604 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0395 - val_loss: 0.0433
# Epoch 160/200
# mean max of probabilities: 0.00011222703 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0409 - val_loss: 0.0447
# Epoch 161/200
# mean max of probabilities: 0.00011225763 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0395 - val_loss: 0.0438
# Epoch 162/200
# mean max of probabilities: 0.00011227158 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0396 - val_loss: 0.0416
# Epoch 163/200
# mean max of probabilities: 0.000112298265 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0386 - val_loss: 0.0396
# Epoch 164/200
# mean max of probabilities: 0.000112316266 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0407 - val_loss: 0.0423
# Epoch 165/200
# mean max of probabilities: 0.00011232547 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0386 - val_loss: 0.0402
# Epoch 166/200
# mean max of probabilities: 0.00011235225 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0389 - val_loss: 0.0410
# Epoch 167/200
# mean max of probabilities: 0.000112382455 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0391 - val_loss: 0.0411
# Epoch 168/200
# mean max of probabilities: 0.000112420996 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0389 - val_loss: 0.0404
# Epoch 169/200
# mean max of probabilities: 0.000112438815 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0402 - val_loss: 0.0409
# Epoch 170/200
# mean max of probabilities: 0.000112445305 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0389 - val_loss: 0.0377
# Epoch 171/200
# mean max of probabilities: 0.000112463335 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0409 - val_loss: 0.0402
# Epoch 172/200
# mean max of probabilities: 0.00011247782 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0401 - val_loss: 0.0402
# Epoch 173/200
# mean max of probabilities: 0.0001124828 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0389 - val_loss: 0.0400
# Epoch 174/200
# mean max of probabilities: 0.00011248442 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0371 - val_loss: 0.0405
# Epoch 175/200
# mean max of probabilities: 0.000112485104 - temperature 0.1
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0382 - val_loss: 0.0402
# Epoch 176/200
# mean max of probabilities: 0.00011249074 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0380 - val_loss: 0.0413
# Epoch 177/200
# mean max of probabilities: 0.0001125169 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0408 - val_loss: 0.0421
# Epoch 178/200
# mean max of probabilities: 0.00011252593 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0392 - val_loss: 0.0411
# Epoch 179/200
# mean max of probabilities: 0.00011255587 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0398 - val_loss: 0.0385
# Epoch 180/200
# mean max of probabilities: 0.00011259469 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0389 - val_loss: 0.0418
# Epoch 181/200
# mean max of probabilities: 0.00011261177 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0390 - val_loss: 0.0457
# Epoch 182/200
# mean max of probabilities: 0.000112654496 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0380 - val_loss: 0.0432
# Epoch 183/200
# mean max of probabilities: 0.0001126802 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0383 - val_loss: 0.0393
# Epoch 184/200
# mean max of probabilities: 0.00011270162 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0402 - val_loss: 0.0412
# Epoch 185/200
# mean max of probabilities: 0.00011271245 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0395 - val_loss: 0.0406
# Epoch 186/200
# mean max of probabilities: 0.00011272827 - temperature 0.1
# 160/160 [==============================] - 2s 16ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 187/200
# mean max of probabilities: 0.00011277446 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0398 - val_loss: 0.0410
# Epoch 188/200
# mean max of probabilities: 0.00011281367 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0404 - val_loss: 0.0436
# Epoch 189/200
# mean max of probabilities: 0.00011282876 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0386 - val_loss: 0.0420
# Epoch 190/200
# mean max of probabilities: 0.00011283956 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0396 - val_loss: 0.0404
# Epoch 191/200
# mean max of probabilities: 0.00011287137 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0386 - val_loss: 0.0427
# Epoch 192/200
# mean max of probabilities: 0.000112904585 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0390 - val_loss: 0.0415
# Epoch 193/200
# mean max of probabilities: 0.000112928705 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0384 - val_loss: 0.0436
# Epoch 194/200
# mean max of probabilities: 0.00011294794 - temperature 0.1
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0383 - val_loss: 0.0406
# Epoch 195/200
# mean max of probabilities: 0.0001129614 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0391 - val_loss: 0.0417
# Epoch 196/200
# mean max of probabilities: 0.00011297792 - temperature 0.1
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0403 - val_loss: 0.0407
# Epoch 197/200
# mean max of probabilities: 0.00011298727 - temperature 0.1
# 160/160 [==============================] - 2s 14ms/step - loss: 0.0402 - val_loss: 0.0370
# Epoch 198/200
# mean max of probabilities: 0.000112998656 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0388 - val_loss: 0.0411
# Epoch 199/200
# mean max of probabilities: 0.0001130171 - temperature 0.1
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0396 - val_loss: 0.0420
# Epoch 200/200
# mean max of probabilities: 0.00011302938 - temperature 0.1
# 144/160 [==========================>...] - ETA: 0s - loss: 0.0387
