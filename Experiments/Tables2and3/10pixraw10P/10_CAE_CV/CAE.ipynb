# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.model_selection import train_test_split
import scipy.sparse as sparse
from keras.datasets import fashion_mnist
import scipy.io

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
data_path="../Dataset/pixraw10P.mat"
Data = scipy.io.loadmat(data_path)

data_arr=Data['X'].astype('float32')/255
label_arr=Data['Y'][:, 0]
label_arr_onehot=label_arr

# %%
key_feture_number=64

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,50):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10000)             0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                640001
# _________________________________________________________________
# dense_1 (Dense)              (None, 10000)             650000
# =================================================================
# Total params: 1,290,001
# Trainable params: 1,290,000
# Non-trainable params: 1
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 80 samples, validate on 20 samples
# Epoch 1/200
# mean max of probabilities: 0.0001032453 - temperature 10.0
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0184 - val_loss: 0.0164
# Epoch 2/200
# mean max of probabilities: 0.0001032453 - temperature 9.682779
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0125 - val_loss: 0.0104
# Epoch 3/200
# mean max of probabilities: 0.0001032453 - temperature 9.375622
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0076 - val_loss: 0.0065
# Epoch 4/200
# mean max of probabilities: 0.00010324533 - temperature 9.078209
# 80/80 [==============================] - 6s 69ms/step - loss: 0.0048 - val_loss: 0.0042
# Epoch 5/200
# mean max of probabilities: 0.00010324538 - temperature 8.790229
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 6/200
# mean max of probabilities: 0.00010324545 - temperature 8.511385
# 80/80 [==============================] - 33s 419ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 7/200
# mean max of probabilities: 0.00010324552 - temperature 8.241387
# 80/80 [==============================] - 10s 127ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 8/200
# mean max of probabilities: 0.00010324558 - temperature 7.979954
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 9/200
# mean max of probabilities: 0.000103245584 - temperature 7.7268133
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 10/200
# mean max of probabilities: 0.00010324556 - temperature 7.481703
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 11/200
# mean max of probabilities: 0.00010324552 - temperature 7.244368
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 12/200
# mean max of probabilities: 0.00010324549 - temperature 7.0145626
# 80/80 [==============================] - 11s 138ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 13/200
# mean max of probabilities: 0.00010324545 - temperature 6.792047
# 80/80 [==============================] - 13s 165ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 14/200
# mean max of probabilities: 0.00010324543 - temperature 6.5765896
# 80/80 [==============================] - 2s 28ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 15/200
# mean max of probabilities: 0.00010324543 - temperature 6.3679667
# 80/80 [==============================] - 13s 161ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 16/200
# mean max of probabilities: 0.00010324543 - temperature 6.1659613
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 17/200
# mean max of probabilities: 0.000103245446 - temperature 5.9703646
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 18/200
# mean max of probabilities: 0.00010324547 - temperature 5.780973
# 80/80 [==============================] - 3s 32ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 19/200
# mean max of probabilities: 0.0001032455 - temperature 5.597588
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 20/200
# mean max of probabilities: 0.00010324553 - temperature 5.4200206
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 21/200
# mean max of probabilities: 0.000103245555 - temperature 5.2480865
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 22/200
# mean max of probabilities: 0.00010324559 - temperature 5.0816064
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 23/200
# mean max of probabilities: 0.00010324562 - temperature 4.920408
# 80/80 [==============================] - 3s 36ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 24/200
# mean max of probabilities: 0.000103245664 - temperature 4.7643223
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 25/200
# mean max of probabilities: 0.0001032457 - temperature 4.6131873
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 26/200
# mean max of probabilities: 0.000103245744 - temperature 4.466848
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 27/200
# mean max of probabilities: 0.0001032458 - temperature 4.32515
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 28/200
# mean max of probabilities: 0.00010324585 - temperature 4.1879478
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 29/200
# mean max of probabilities: 0.000103245926 - temperature 4.055098
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 30/200
# mean max of probabilities: 0.000103245984 - temperature 3.9264624
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 31/200
# mean max of probabilities: 0.000103246064 - temperature 3.801907
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 32/200
# mean max of probabilities: 0.00010324616 - temperature 3.6813028
# 80/80 [==============================] - 11s 133ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 33/200
# mean max of probabilities: 0.00010324626 - temperature 3.5645244
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 34/200
# mean max of probabilities: 0.00010324638 - temperature 3.4514508
# 80/80 [==============================] - 6s 80ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 35/200
# mean max of probabilities: 0.00010324649 - temperature 3.341964
# 80/80 [==============================] - 5s 57ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 36/200
# mean max of probabilities: 0.00010324664 - temperature 3.23595
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 37/200
# mean max of probabilities: 0.0001032468 - temperature 3.133299
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 38/200
# mean max of probabilities: 0.00010324699 - temperature 3.0339048
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 39/200
# mean max of probabilities: 0.00010324721 - temperature 2.9376633
# 80/80 [==============================] - 3s 36ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 40/200
# mean max of probabilities: 0.00010324746 - temperature 2.8444746
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 41/200
# mean max of probabilities: 0.00010324773 - temperature 2.7542422
# 80/80 [==============================] - 3s 33ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 42/200
# mean max of probabilities: 0.00010324801 - temperature 2.666872
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 43/200
# mean max of probabilities: 0.00010324829 - temperature 2.5822737
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 44/200
# mean max of probabilities: 0.00010324861 - temperature 2.5003588
# 80/80 [==============================] - 2s 27ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 45/200
# mean max of probabilities: 0.00010324893 - temperature 2.4210424
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 46/200
# mean max of probabilities: 0.000103249244 - temperature 2.344242
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 47/200
# mean max of probabilities: 0.00010324961 - temperature 2.269878
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 48/200
# mean max of probabilities: 0.00010324995 - temperature 2.1978726
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 49/200
# mean max of probabilities: 0.00010325035 - temperature 2.1281517
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 50/200
# mean max of probabilities: 0.000103250786 - temperature 2.0606422
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 51/200
# mean max of probabilities: 0.00010325125 - temperature 1.9952742
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 52/200
# mean max of probabilities: 0.00010325172 - temperature 1.93198
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 53/200
# mean max of probabilities: 0.00010325221 - temperature 1.8706938
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 54/200
# mean max of probabilities: 0.00010325283 - temperature 1.8113518
# 80/80 [==============================] - 4s 48ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 55/200
# mean max of probabilities: 0.000103253406 - temperature 1.7538921
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 56/200
# mean max of probabilities: 0.000103253944 - temperature 1.698255
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 57/200
# mean max of probabilities: 0.0001032546 - temperature 1.6443831
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 58/200
# mean max of probabilities: 0.00010325528 - temperature 1.5922198
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 59/200
# mean max of probabilities: 0.00010325601 - temperature 1.5417116
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 60/200
# mean max of probabilities: 0.000103256796 - temperature 1.4928054
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 61/200
# mean max of probabilities: 0.000103257626 - temperature 1.4454505
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 62/200
# mean max of probabilities: 0.000103258455 - temperature 1.3995979
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 63/200
# mean max of probabilities: 0.000103259736 - temperature 1.3551999
# 80/80 [==============================] - 3s 36ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 64/200
# mean max of probabilities: 0.000103260776 - temperature 1.3122103
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 65/200
# mean max of probabilities: 0.000103261875 - temperature 1.2705843
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 66/200
# mean max of probabilities: 0.000103263694 - temperature 1.2302788
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 67/200
# mean max of probabilities: 0.000103266204 - temperature 1.1912519
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 68/200
# mean max of probabilities: 0.000103269005 - temperature 1.1534631
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 69/200
# mean max of probabilities: 0.00010327193 - temperature 1.1168729
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 70/200
# mean max of probabilities: 0.00010327414 - temperature 1.0814433
# 80/80 [==============================] - 3s 36ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 71/200
# mean max of probabilities: 0.00010327817 - temperature 1.0471379
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 72/200
# mean max of probabilities: 0.00010328369 - temperature 1.0139205
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 73/200
# mean max of probabilities: 0.000103292085 - temperature 0.98175687
# 80/80 [==============================] - 2s 31ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 74/200
# mean max of probabilities: 0.000103300736 - temperature 0.9506136
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 75/200
# mean max of probabilities: 0.00010330679 - temperature 0.92045826
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 76/200
# mean max of probabilities: 0.00010331259 - temperature 0.8912594
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 77/200
# mean max of probabilities: 0.00010332307 - temperature 0.8629868
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 78/200
# mean max of probabilities: 0.00010333498 - temperature 0.8356111
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 79/200
# mean max of probabilities: 0.000103343904 - temperature 0.80910385
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 80/200
# mean max of probabilities: 0.00010335326 - temperature 0.7834375
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 81/200
# mean max of probabilities: 0.00010336449 - temperature 0.7585853
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 82/200
# mean max of probabilities: 0.00010337797 - temperature 0.7345214
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 83/200
# mean max of probabilities: 0.000103397695 - temperature 0.71122086
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 84/200
# mean max of probabilities: 0.0001034316 - temperature 0.6886594
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 85/200
# mean max of probabilities: 0.000103464925 - temperature 0.66681373
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 86/200
# mean max of probabilities: 0.0001034939 - temperature 0.645661
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 87/200
# mean max of probabilities: 0.00010352396 - temperature 0.62517935
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 88/200
# mean max of probabilities: 0.00010354615 - temperature 0.6053474
# 80/80 [==============================] - 3s 44ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 89/200
# mean max of probabilities: 0.00010356693 - temperature 0.58614457
# 80/80 [==============================] - 3s 44ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 90/200
# mean max of probabilities: 0.00010359315 - temperature 0.5675509
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 91/200
# mean max of probabilities: 0.0001036208 - temperature 0.549547
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 92/200
# mean max of probabilities: 0.000103640356 - temperature 0.53211427
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 93/200
# mean max of probabilities: 0.00010366556 - temperature 0.51523453
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 94/200
# mean max of probabilities: 0.00010368816 - temperature 0.49889034
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 95/200
# mean max of probabilities: 0.00010371403 - temperature 0.4830645
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 96/200
# mean max of probabilities: 0.00010373972 - temperature 0.46774074
# 80/80 [==============================] - 3s 44ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 97/200
# mean max of probabilities: 0.00010376162 - temperature 0.4529031
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 98/200
# mean max of probabilities: 0.000103784776 - temperature 0.4385361
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 99/200
# mean max of probabilities: 0.000103811544 - temperature 0.42462486
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 100/200
# mean max of probabilities: 0.00010383241 - temperature 0.4111549
# 80/80 [==============================] - 4s 48ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 101/200
# mean max of probabilities: 0.0001038469 - temperature 0.39811224
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 102/200
# mean max of probabilities: 0.00010387514 - temperature 0.38548332
# 80/80 [==============================] - 4s 48ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 103/200
# mean max of probabilities: 0.00010391463 - temperature 0.37325504
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 104/200
# mean max of probabilities: 0.000103955936 - temperature 0.36141464
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 105/200
# mean max of probabilities: 0.000104000355 - temperature 0.3499498
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 106/200
# mean max of probabilities: 0.000104034654 - temperature 0.3388487
# 80/80 [==============================] - 3s 36ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 107/200
# mean max of probabilities: 0.00010406621 - temperature 0.3280997
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 108/200
# mean max of probabilities: 0.00010409279 - temperature 0.31769174
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 109/200
# mean max of probabilities: 0.00010412544 - temperature 0.3076139
# 80/80 [==============================] - 6s 71ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 110/200
# mean max of probabilities: 0.00010415519 - temperature 0.29785576
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 111/200
# mean max of probabilities: 0.000104177496 - temperature 0.28840715
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 112/200
# mean max of probabilities: 0.00010420069 - temperature 0.27925828
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 113/200
# mean max of probabilities: 0.00010422324 - temperature 0.27039963
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 114/200
# mean max of probabilities: 0.00010424102 - temperature 0.26182202
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 115/200
# mean max of probabilities: 0.00010425586 - temperature 0.25351644
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 116/200
# mean max of probabilities: 0.00010428596 - temperature 0.24547435
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 117/200
# mean max of probabilities: 0.00010430743 - temperature 0.2376874
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 118/200
# mean max of probabilities: 0.000104328035 - temperature 0.23014747
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 119/200
# mean max of probabilities: 0.000104346655 - temperature 0.22284672
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 120/200
# mean max of probabilities: 0.00010436191 - temperature 0.21577755
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 121/200
# mean max of probabilities: 0.000104380386 - temperature 0.20893264
# 80/80 [==============================] - 4s 52ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 122/200
# mean max of probabilities: 0.000104398176 - temperature 0.20230487
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 123/200
# mean max of probabilities: 0.00010441019 - temperature 0.19588736
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 124/200
# mean max of probabilities: 0.000104418745 - temperature 0.18967342
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 125/200
# mean max of probabilities: 0.00010442571 - temperature 0.1836566
# 80/80 [==============================] - 4s 52ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 126/200
# mean max of probabilities: 0.00010443844 - temperature 0.17783064
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 127/200
# mean max of probabilities: 0.00010445742 - temperature 0.17218949
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 128/200
# mean max of probabilities: 0.00010447815 - temperature 0.1667273
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 129/200
# mean max of probabilities: 0.00010449445 - temperature 0.16143836
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 130/200
# mean max of probabilities: 0.000104515435 - temperature 0.1563172
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 131/200
# mean max of probabilities: 0.00010453212 - temperature 0.1513585
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 132/200
# mean max of probabilities: 0.000104545514 - temperature 0.14655712
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 133/200
# mean max of probabilities: 0.00010456996 - temperature 0.14190803
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 134/200
# mean max of probabilities: 0.00010460109 - temperature 0.13740644
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 135/200
# mean max of probabilities: 0.0001046268 - temperature 0.13304763
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 136/200
# mean max of probabilities: 0.000104645806 - temperature 0.12882708
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 137/200
# mean max of probabilities: 0.0001046636 - temperature 0.124740414
# 80/80 [==============================] - 4s 52ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 138/200
# mean max of probabilities: 0.00010468388 - temperature 0.120783396
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 139/200
# mean max of probabilities: 0.00010472018 - temperature 0.1169519
# 80/80 [==============================] - 5s 61ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 140/200
# mean max of probabilities: 0.00010474245 - temperature 0.11324195
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 141/200
# mean max of probabilities: 0.00010475567 - temperature 0.10964968
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 142/200
# mean max of probabilities: 0.0001047647 - temperature 0.10617137
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 143/200
# mean max of probabilities: 0.0001047737 - temperature 0.10280339
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 144/200
# mean max of probabilities: 0.00010478361 - temperature 0.1
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 145/200
# mean max of probabilities: 0.000104794904 - temperature 0.1
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 146/200
# mean max of probabilities: 0.000104804814 - temperature 0.1
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 147/200
# mean max of probabilities: 0.00010482741 - temperature 0.1
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 148/200
# mean max of probabilities: 0.0001048515 - temperature 0.1
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 149/200
# mean max of probabilities: 0.00010487018 - temperature 0.1
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 150/200
# mean max of probabilities: 0.000104888444 - temperature 0.1
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 151/200
# mean max of probabilities: 0.00010490421 - temperature 0.1
# 80/80 [==============================] - 3s 44ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 152/200
# mean max of probabilities: 0.00010491387 - temperature 0.1
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 153/200
# mean max of probabilities: 0.00010493332 - temperature 0.1
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 154/200
# mean max of probabilities: 0.000104957464 - temperature 0.1
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 155/200
# mean max of probabilities: 0.000104975814 - temperature 0.1
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 156/200
# mean max of probabilities: 0.000104988016 - temperature 0.1
# 80/80 [==============================] - 4s 52ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 157/200
# mean max of probabilities: 0.000104995575 - temperature 0.1
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 158/200
# mean max of probabilities: 0.00010500116 - temperature 0.1
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 159/200
# mean max of probabilities: 0.00010500928 - temperature 0.1
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 160/200
# mean max of probabilities: 0.00010502264 - temperature 0.1
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 161/200
# mean max of probabilities: 0.00010503447 - temperature 0.1
# 80/80 [==============================] - 4s 52ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 162/200
# mean max of probabilities: 0.00010504841 - temperature 0.1
# 80/80 [==============================] - 5s 56ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 163/200
# mean max of probabilities: 0.00010506167 - temperature 0.1
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 164/200
# mean max of probabilities: 0.00010507695 - temperature 0.1
# 80/80 [==============================] - 4s 52ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 165/200
# mean max of probabilities: 0.00010508961 - temperature 0.1
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 166/200
# mean max of probabilities: 0.000105097235 - temperature 0.1
# 80/80 [==============================] - 5s 56ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 167/200
# mean max of probabilities: 0.00010510204 - temperature 0.1
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 168/200
# mean max of probabilities: 0.000105106985 - temperature 0.1
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 169/200
# mean max of probabilities: 0.000105112165 - temperature 0.1
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 170/200
# mean max of probabilities: 0.000105115454 - temperature 0.1
# 80/80 [==============================] - 5s 56ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 171/200
# mean max of probabilities: 0.00010512104 - temperature 0.1
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 172/200
# mean max of probabilities: 0.00010512465 - temperature 0.1
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 173/200
# mean max of probabilities: 0.00010513277 - temperature 0.1
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 174/200
# mean max of probabilities: 0.00010514293 - temperature 0.1
# 80/80 [==============================] - 4s 56ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 175/200
# mean max of probabilities: 0.000105169056 - temperature 0.1
# 80/80 [==============================] - 5s 65ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 176/200
# mean max of probabilities: 0.00010519108 - temperature 0.1
# 80/80 [==============================] - 5s 61ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 177/200
# mean max of probabilities: 0.000105209394 - temperature 0.1
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 178/200
# mean max of probabilities: 0.00010522191 - temperature 0.1
# 80/80 [==============================] - 4s 56ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 179/200
# mean max of probabilities: 0.000105236235 - temperature 0.1
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 180/200
# mean max of probabilities: 0.00010524523 - temperature 0.1
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 181/200
# mean max of probabilities: 0.00010525326 - temperature 0.1
# 80/80 [==============================] - 4s 52ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 182/200
# mean max of probabilities: 0.00010526966 - temperature 0.1
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 183/200
# mean max of probabilities: 0.00010528446 - temperature 0.1
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 184/200
# mean max of probabilities: 0.00010529578 - temperature 0.1
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 185/200
# mean max of probabilities: 0.00010530535 - temperature 0.1
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 186/200
# mean max of probabilities: 0.00010531421 - temperature 0.1
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 187/200
# mean max of probabilities: 0.00010531947 - temperature 0.1
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 188/200
# mean max of probabilities: 0.00010532276 - temperature 0.1
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 189/200
# mean max of probabilities: 0.00010532548 - temperature 0.1
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 190/200
# mean max of probabilities: 0.00010533385 - temperature 0.1
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 191/200
# mean max of probabilities: 0.00010534142 - temperature 0.1
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 192/200
# mean max of probabilities: 0.000105346306 - temperature 0.1
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 193/200
# mean max of probabilities: 0.0001053492 - temperature 0.1
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 194/200
# mean max of probabilities: 0.0001053509 - temperature 0.1
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 195/200
# mean max of probabilities: 0.00010535889 - temperature 0.1
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 196/200
# mean max of probabilities: 0.00010536903 - temperature 0.1
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 197/200
# mean max of probabilities: 0.00010537938 - temperature 0.1
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 198/200
# mean max of probabilities: 0.00010539301 - temperature 0.1
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 199/200
# mean max of probabilities: 0.00010540172 - temperature 0.1
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 200/200
# mean max of probabilities: 0.000105409636 - temperature 0.1
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0022 - val_loss: 0.0027
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 1.0
# Testing accuracy： 1.0
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 1.0
# Testing accuracy： 1.0
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 10000)             0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                640001
# _________________________________________________________________
# dense_2 (Dense)              (None, 10000)             650000
# =================================================================
# Total params: 1,290,001
# Trainable params: 1,290,000
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 80 samples, validate on 20 samples
# Epoch 1/200
# mean max of probabilities: 0.00010324425 - temperature 10.0
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0190 - val_loss: 0.0141
# Epoch 2/200
# mean max of probabilities: 0.000103244245 - temperature 9.682779
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0128 - val_loss: 0.0090
# Epoch 3/200
# mean max of probabilities: 0.00010324424 - temperature 9.375622
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0080 - val_loss: 0.0055
# Epoch 4/200
# mean max of probabilities: 0.00010324426 - temperature 9.078209
# 80/80 [==============================] - 4s 56ms/step - loss: 0.0049 - val_loss: 0.0036
# Epoch 5/200
# mean max of probabilities: 0.00010324431 - temperature 8.790229
# 80/80 [==============================] - 5s 57ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 6/200
# mean max of probabilities: 0.00010324438 - temperature 8.511385
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 7/200
# mean max of probabilities: 0.000103244456 - temperature 8.241387
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 8/200
# mean max of probabilities: 0.000103244514 - temperature 7.979954
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 9/200
# mean max of probabilities: 0.00010324453 - temperature 7.7268133
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 10/200
# mean max of probabilities: 0.000103244514 - temperature 7.481703
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 11/200
# mean max of probabilities: 0.000103244485 - temperature 7.244368
# 80/80 [==============================] - 5s 56ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 12/200
# mean max of probabilities: 0.00010324444 - temperature 7.0145626
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 13/200
# mean max of probabilities: 0.00010324442 - temperature 6.792047
# 80/80 [==============================] - 4s 48ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 14/200
# mean max of probabilities: 0.00010324441 - temperature 6.5765896
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 15/200
# mean max of probabilities: 0.00010324441 - temperature 6.3679667
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 16/200
# mean max of probabilities: 0.000103244434 - temperature 6.1659613
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 17/200
# mean max of probabilities: 0.00010324446 - temperature 5.9703646
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 18/200
# mean max of probabilities: 0.0001032445 - temperature 5.780973
# 80/80 [==============================] - 4s 52ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 19/200
# mean max of probabilities: 0.00010324454 - temperature 5.597588
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 20/200
# mean max of probabilities: 0.0001032446 - temperature 5.4200206
# 80/80 [==============================] - 4s 52ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 21/200
# mean max of probabilities: 0.00010324465 - temperature 5.2480865
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 22/200
# mean max of probabilities: 0.00010324472 - temperature 5.0816064
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 23/200
# mean max of probabilities: 0.00010324478 - temperature 4.920408
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 24/200
# mean max of probabilities: 0.00010324485 - temperature 4.7643223
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 25/200
# mean max of probabilities: 0.00010324493 - temperature 4.6131873
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 26/200
# mean max of probabilities: 0.00010324501 - temperature 4.466848
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 27/200
# mean max of probabilities: 0.000103245126 - temperature 4.32515
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 28/200
# mean max of probabilities: 0.00010324523 - temperature 4.1879478
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 29/200
# mean max of probabilities: 0.00010324535 - temperature 4.055098
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 30/200
# mean max of probabilities: 0.0001032455 - temperature 3.9264624
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 31/200
# mean max of probabilities: 0.00010324565 - temperature 3.801907
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 32/200
# mean max of probabilities: 0.0001032458 - temperature 3.6813028
# 80/80 [==============================] - 3s 44ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 33/200
# mean max of probabilities: 0.00010324597 - temperature 3.5645244
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 34/200
# mean max of probabilities: 0.00010324617 - temperature 3.4514508
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 35/200
# mean max of probabilities: 0.00010324638 - temperature 3.341964
# 80/80 [==============================] - 3s 36ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 36/200
# mean max of probabilities: 0.000103246595 - temperature 3.23595
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 37/200
# mean max of probabilities: 0.00010324681 - temperature 3.133299
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 38/200
# mean max of probabilities: 0.000103247046 - temperature 3.0339048
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 39/200
# mean max of probabilities: 0.00010324728 - temperature 2.9376633
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 40/200
# mean max of probabilities: 0.00010324752 - temperature 2.8444746
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 41/200
# mean max of probabilities: 0.00010324782 - temperature 2.7542422
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 42/200
# mean max of probabilities: 0.00010324811 - temperature 2.666872
# 80/80 [==============================] - 4s 48ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 43/200
# mean max of probabilities: 0.000103248436 - temperature 2.5822737
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 44/200
# mean max of probabilities: 0.000103248785 - temperature 2.5003588
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 45/200
# mean max of probabilities: 0.00010324916 - temperature 2.4210424
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 46/200
# mean max of probabilities: 0.000103249535 - temperature 2.344242
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 47/200
# mean max of probabilities: 0.000103249986 - temperature 2.269878
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 48/200
# mean max of probabilities: 0.00010325044 - temperature 2.1978726
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 49/200
# mean max of probabilities: 0.00010325092 - temperature 2.1281517
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 50/200
# mean max of probabilities: 0.00010325141 - temperature 2.0606422
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 51/200
# mean max of probabilities: 0.00010325192 - temperature 1.9952742
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 52/200
# mean max of probabilities: 0.00010325246 - temperature 1.93198
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 53/200
# mean max of probabilities: 0.000103253 - temperature 1.8706938
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 54/200
# mean max of probabilities: 0.00010325358 - temperature 1.8113518
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 55/200
# mean max of probabilities: 0.00010325418 - temperature 1.7538921
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 56/200
# mean max of probabilities: 0.000103254875 - temperature 1.698255
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 57/200
# mean max of probabilities: 0.00010325559 - temperature 1.6443831
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 58/200
# mean max of probabilities: 0.00010325624 - temperature 1.5922198
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 59/200
# mean max of probabilities: 0.00010325694 - temperature 1.5417116
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 60/200
# mean max of probabilities: 0.00010325769 - temperature 1.4928054
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 61/200
# mean max of probabilities: 0.00010325857 - temperature 1.4454505
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 62/200
# mean max of probabilities: 0.000103259525 - temperature 1.3995979
# 80/80 [==============================] - 6s 72ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 63/200
# mean max of probabilities: 0.000103260456 - temperature 1.3551999
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 64/200
# mean max of probabilities: 0.00010326164 - temperature 1.3122103
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 65/200
# mean max of probabilities: 0.000103263344 - temperature 1.2705843
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 66/200
# mean max of probabilities: 0.00010326468 - temperature 1.2302788
# 80/80 [==============================] - 5s 66ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 67/200
# mean max of probabilities: 0.00010326579 - temperature 1.1912519
# 80/80 [==============================] - 2s 27ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 68/200
# mean max of probabilities: 0.000103267084 - temperature 1.1534631
# 80/80 [==============================] - 3s 33ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 69/200
# mean max of probabilities: 0.00010326898 - temperature 1.1168729
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 70/200
# mean max of probabilities: 0.000103271625 - temperature 1.0814433
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 71/200
# mean max of probabilities: 0.00010327655 - temperature 1.0471379
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 72/200
# mean max of probabilities: 0.000103280574 - temperature 1.0139205
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 73/200
# mean max of probabilities: 0.000103283885 - temperature 0.98175687
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 74/200
# mean max of probabilities: 0.000103289596 - temperature 0.9506136
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 75/200
# mean max of probabilities: 0.00010329861 - temperature 0.92045826
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 76/200
# mean max of probabilities: 0.00010330633 - temperature 0.8912594
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 77/200
# mean max of probabilities: 0.000103319515 - temperature 0.8629868
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 78/200
# mean max of probabilities: 0.000103334925 - temperature 0.8356111
# 80/80 [==============================] - 5s 61ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 79/200
# mean max of probabilities: 0.000103353406 - temperature 0.80910385
# 80/80 [==============================] - 5s 57ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 80/200
# mean max of probabilities: 0.00010338327 - temperature 0.7834375
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 81/200
# mean max of probabilities: 0.00010341141 - temperature 0.7585853
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 82/200
# mean max of probabilities: 0.000103432 - temperature 0.7345214
# 80/80 [==============================] - 5s 60ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 83/200
# mean max of probabilities: 0.00010345367 - temperature 0.71122086
# 80/80 [==============================] - 4s 48ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 84/200
# mean max of probabilities: 0.00010347499 - temperature 0.6886594
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 85/200
# mean max of probabilities: 0.000103491475 - temperature 0.66681373
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 86/200
# mean max of probabilities: 0.00010350792 - temperature 0.645661
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 87/200
# mean max of probabilities: 0.0001035317 - temperature 0.62517935
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 88/200
# mean max of probabilities: 0.00010356744 - temperature 0.6053474
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 89/200
# mean max of probabilities: 0.000103604354 - temperature 0.58614457
# 80/80 [==============================] - 5s 57ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 90/200
# mean max of probabilities: 0.00010363947 - temperature 0.5675509
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 91/200
# mean max of probabilities: 0.00010367567 - temperature 0.549547
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 92/200
# mean max of probabilities: 0.00010371482 - temperature 0.53211427
# 80/80 [==============================] - 5s 56ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 93/200
# mean max of probabilities: 0.00010375846 - temperature 0.51523453
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 94/200
# mean max of probabilities: 0.0001037916 - temperature 0.49889034
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 95/200
# mean max of probabilities: 0.00010382292 - temperature 0.4830645
# 80/80 [==============================] - 5s 65ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 96/200
# mean max of probabilities: 0.00010385333 - temperature 0.46774074
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 97/200
# mean max of probabilities: 0.00010387811 - temperature 0.4529031
# 80/80 [==============================] - 5s 60ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 98/200
# mean max of probabilities: 0.00010389679 - temperature 0.4385361
# 80/80 [==============================] - 5s 67ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 99/200
# mean max of probabilities: 0.00010391839 - temperature 0.42462486
# 80/80 [==============================] - 5s 60ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 100/200
# mean max of probabilities: 0.00010395167 - temperature 0.4111549
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 101/200
# mean max of probabilities: 0.000103978164 - temperature 0.39811224
# 80/80 [==============================] - 4s 49ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 102/200
# mean max of probabilities: 0.00010401498 - temperature 0.38548332
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 103/200
# mean max of probabilities: 0.000104047154 - temperature 0.37325504
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 104/200
# mean max of probabilities: 0.000104074184 - temperature 0.36141464
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 105/200
# mean max of probabilities: 0.000104111794 - temperature 0.3499498
# 80/80 [==============================] - 4s 50ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 106/200
# mean max of probabilities: 0.00010414045 - temperature 0.3388487
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 107/200
# mean max of probabilities: 0.000104162355 - temperature 0.3280997
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 108/200
# mean max of probabilities: 0.00010418583 - temperature 0.31769174
# 80/80 [==============================] - 4s 48ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 109/200
