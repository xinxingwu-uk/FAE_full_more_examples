# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.model_selection import train_test_split
import scipy.sparse as sparse
from keras.datasets import fashion_mnist
import scipy.io

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
data_path="../Dataset/warpAR10P.mat"
Data = scipy.io.loadmat(data_path)

data_arr_=Data['X'].astype('float32')/255
label_arr=Data['Y'][:, 0]

Data=MinMaxScaler(feature_range=(0,1)).fit_transform(data_arr_)

data_arr=Data
label_arr_onehot=label_arr

# %%
key_feture_number=64

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,50):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2400)              0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                153601
# _________________________________________________________________
# dense_1 (Dense)              (None, 2400)              156000
# =================================================================
# Total params: 309,601
# Trainable params: 309,600
# Non-trainable params: 1
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 104 samples, validate on 26 samples
# Epoch 1/200
# mean max of probabilities: 0.00044423537 - temperature 10.0
# 104/104 [==============================] - 4s 42ms/step - loss: 0.3690 - val_loss: 0.2258
# Epoch 2/200
# mean max of probabilities: 0.00044423455 - temperature 9.708295
# 104/104 [==============================] - 1s 7ms/step - loss: 0.1740 - val_loss: 0.1110
# Epoch 3/200
# mean max of probabilities: 0.00044424186 - temperature 9.425098
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0903 - val_loss: 0.0795
# Epoch 4/200
# mean max of probabilities: 0.00044427323 - temperature 9.150163
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0719 - val_loss: 0.0768
# Epoch 5/200
# mean max of probabilities: 0.00044429093 - temperature 8.883247
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0707 - val_loss: 0.0748
# Epoch 6/200
# mean max of probabilities: 0.00044427643 - temperature 8.624119
# 104/104 [==============================] - 0s 4ms/step - loss: 0.0690 - val_loss: 0.0722
# Epoch 7/200
# mean max of probabilities: 0.00044425036 - temperature 8.372548
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0668 - val_loss: 0.0709
# Epoch 8/200
# mean max of probabilities: 0.00044423944 - temperature 8.128316
# 104/104 [==============================] - 0s 4ms/step - loss: 0.0653 - val_loss: 0.0701
# Epoch 9/200
# mean max of probabilities: 0.00044424465 - temperature 7.8912086
# 104/104 [==============================] - 0s 4ms/step - loss: 0.0647 - val_loss: 0.0698
# Epoch 10/200
# mean max of probabilities: 0.00044424954 - temperature 7.6610184
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0646 - val_loss: 0.0697
# Epoch 11/200
# mean max of probabilities: 0.00044425242 - temperature 7.4375434
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0645 - val_loss: 0.0698
# Epoch 12/200
# mean max of probabilities: 0.00044425554 - temperature 7.2205873
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0644 - val_loss: 0.0701
# Epoch 13/200
# mean max of probabilities: 0.00044426112 - temperature 7.009959
# 104/104 [==============================] - 0s 1ms/step - loss: 0.0644 - val_loss: 0.0698
# Epoch 14/200
# mean max of probabilities: 0.0004442683 - temperature 6.8054743
# 104/104 [==============================] - 0s 4ms/step - loss: 0.0643 - val_loss: 0.0698
# Epoch 15/200
# mean max of probabilities: 0.0004442781 - temperature 6.6069555
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0642 - val_loss: 0.0697
# Epoch 16/200
# mean max of probabilities: 0.00044428994 - temperature 6.4142275
# 104/104 [==============================] - 0s 4ms/step - loss: 0.0642 - val_loss: 0.0695
# Epoch 17/200
# mean max of probabilities: 0.0004443026 - temperature 6.227122
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0643 - val_loss: 0.0696
# Epoch 18/200
# mean max of probabilities: 0.00044431788 - temperature 6.0454736
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0642 - val_loss: 0.0696
# Epoch 19/200
# mean max of probabilities: 0.00044433595 - temperature 5.8691244
# 104/104 [==============================] - 2s 15ms/step - loss: 0.0643 - val_loss: 0.0696
# Epoch 20/200
# mean max of probabilities: 0.00044435743 - temperature 5.6979184
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0641 - val_loss: 0.0695
# Epoch 21/200
# mean max of probabilities: 0.00044438013 - temperature 5.5317073
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0641 - val_loss: 0.0695
# Epoch 22/200
# mean max of probabilities: 0.00044440437 - temperature 5.3703446
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0642 - val_loss: 0.0697
# Epoch 23/200
# mean max of probabilities: 0.00044443161 - temperature 5.213689
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0641 - val_loss: 0.0693
# Epoch 24/200
# mean max of probabilities: 0.0004444586 - temperature 5.061603
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0640 - val_loss: 0.0695
# Epoch 25/200
# mean max of probabilities: 0.00044449244 - temperature 4.913953
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0640 - val_loss: 0.0695
# Epoch 26/200
# mean max of probabilities: 0.00044453196 - temperature 4.7706113
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0641 - val_loss: 0.0696
# Epoch 27/200
# mean max of probabilities: 0.00044457195 - temperature 4.63145
# 104/104 [==============================] - 0s 1ms/step - loss: 0.0639 - val_loss: 0.0694
# Epoch 28/200
# mean max of probabilities: 0.00044461733 - temperature 4.4963484
# 104/104 [==============================] - 2s 15ms/step - loss: 0.0640 - val_loss: 0.0693
# Epoch 29/200
# mean max of probabilities: 0.00044466567 - temperature 4.365188
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0640 - val_loss: 0.0693
# Epoch 30/200
# mean max of probabilities: 0.00044471538 - temperature 4.237853
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0639 - val_loss: 0.0692
# Epoch 31/200
# mean max of probabilities: 0.00044477134 - temperature 4.1142325
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0639 - val_loss: 0.0691
# Epoch 32/200
# mean max of probabilities: 0.0004448336 - temperature 3.9942179
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0640 - val_loss: 0.0697
# Epoch 33/200
# mean max of probabilities: 0.00044489594 - temperature 3.8777046
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0639 - val_loss: 0.0694
# Epoch 34/200
# mean max of probabilities: 0.00044495994 - temperature 3.76459
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0639 - val_loss: 0.0689
# Epoch 35/200
# mean max of probabilities: 0.000445031 - temperature 3.6547751
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0637 - val_loss: 0.0694
# Epoch 36/200
# mean max of probabilities: 0.00044510493 - temperature 3.5481632
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0639 - val_loss: 0.0690
# Epoch 37/200
# mean max of probabilities: 0.00044518115 - temperature 3.4446616
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0636 - val_loss: 0.0694
# Epoch 38/200
# mean max of probabilities: 0.00044526163 - temperature 3.3441787
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0636 - val_loss: 0.0697
# Epoch 39/200
# mean max of probabilities: 0.00044534975 - temperature 3.2466273
# 104/104 [==============================] - 0s 4ms/step - loss: 0.0635 - val_loss: 0.0692
# Epoch 40/200
# mean max of probabilities: 0.00044544268 - temperature 3.1519213
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0637 - val_loss: 0.0688
# Epoch 41/200
# mean max of probabilities: 0.00044553968 - temperature 3.0599782
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0635 - val_loss: 0.0690
# Epoch 42/200
# mean max of probabilities: 0.00044564766 - temperature 2.9707172
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0635 - val_loss: 0.0695
# Epoch 43/200
# mean max of probabilities: 0.0004457535 - temperature 2.88406
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0635 - val_loss: 0.0695
# Epoch 44/200
# mean max of probabilities: 0.0004458672 - temperature 2.79993
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0635 - val_loss: 0.0690
# Epoch 45/200
# mean max of probabilities: 0.00044598727 - temperature 2.7182546
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0636 - val_loss: 0.0689
# Epoch 46/200
# mean max of probabilities: 0.00044611076 - temperature 2.6389616
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0634 - val_loss: 0.0688
# Epoch 47/200
# mean max of probabilities: 0.00044623754 - temperature 2.5619814
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0634 - val_loss: 0.0690
# Epoch 48/200
# mean max of probabilities: 0.0004463658 - temperature 2.4872475
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0635 - val_loss: 0.0689
# Epoch 49/200
# mean max of probabilities: 0.0004465019 - temperature 2.4146929
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0633 - val_loss: 0.0695
# Epoch 50/200
# mean max of probabilities: 0.0004466469 - temperature 2.3442552
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0635 - val_loss: 0.0692
# Epoch 51/200
# mean max of probabilities: 0.00044679968 - temperature 2.2758718
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0633 - val_loss: 0.0691
# Epoch 52/200
# mean max of probabilities: 0.00044695803 - temperature 2.2094836
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0634 - val_loss: 0.0689
# Epoch 53/200
# mean max of probabilities: 0.00044711778 - temperature 2.1450317
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0633 - val_loss: 0.0689
# Epoch 54/200
# mean max of probabilities: 0.00044728187 - temperature 2.08246
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0633 - val_loss: 0.0693
# Epoch 55/200
# mean max of probabilities: 0.0004474603 - temperature 2.0217133
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0632 - val_loss: 0.0685
# Epoch 56/200
# mean max of probabilities: 0.00044764896 - temperature 1.9627389
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0633 - val_loss: 0.0683
# Epoch 57/200
# mean max of probabilities: 0.00044783822 - temperature 1.9054846
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0631 - val_loss: 0.0688
# Epoch 58/200
# mean max of probabilities: 0.00044804122 - temperature 1.8499007
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0631 - val_loss: 0.0690
# Epoch 59/200
# mean max of probabilities: 0.0004482641 - temperature 1.795938
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0631 - val_loss: 0.0689
# Epoch 60/200
# mean max of probabilities: 0.000448506 - temperature 1.7435495
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0634 - val_loss: 0.0688
# Epoch 61/200
# mean max of probabilities: 0.00044874946 - temperature 1.6926892
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0630 - val_loss: 0.0689
# Epoch 62/200
# mean max of probabilities: 0.00044900487 - temperature 1.6433126
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0635 - val_loss: 0.0685
# Epoch 63/200
# mean max of probabilities: 0.00044925607 - temperature 1.5953764
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0631 - val_loss: 0.0690
# Epoch 64/200
# mean max of probabilities: 0.00044952525 - temperature 1.5488384
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0629 - val_loss: 0.0689
# Epoch 65/200
# mean max of probabilities: 0.00044981355 - temperature 1.503658
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0630 - val_loss: 0.0688
# Epoch 66/200
# mean max of probabilities: 0.0004501472 - temperature 1.4597956
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0629 - val_loss: 0.0685
# Epoch 67/200
# mean max of probabilities: 0.00045045558 - temperature 1.4172126
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0631 - val_loss: 0.0688
# Epoch 68/200
# mean max of probabilities: 0.00045080646 - temperature 1.3758719
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0628 - val_loss: 0.0689
# Epoch 69/200
# mean max of probabilities: 0.00045111892 - temperature 1.335737
# 104/104 [==============================] - 0s 5ms/step - loss: 0.0632 - val_loss: 0.0690
# Epoch 70/200
# mean max of probabilities: 0.00045144412 - temperature 1.2967727
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0632 - val_loss: 0.0683
# Epoch 71/200
# mean max of probabilities: 0.00045178004 - temperature 1.2589452
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0629 - val_loss: 0.0688
# Epoch 72/200
# mean max of probabilities: 0.0004521478 - temperature 1.222221
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0628 - val_loss: 0.0691
# Epoch 73/200
# mean max of probabilities: 0.0004525149 - temperature 1.1865681
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0630 - val_loss: 0.0690
# Epoch 74/200
# mean max of probabilities: 0.00045284897 - temperature 1.1519552
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0630 - val_loss: 0.0689
# Epoch 75/200
# mean max of probabilities: 0.00045327545 - temperature 1.1183522
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0631 - val_loss: 0.0686
# Epoch 76/200
# mean max of probabilities: 0.0004536488 - temperature 1.0857294
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0633 - val_loss: 0.0689
# Epoch 77/200
# mean max of probabilities: 0.00045399263 - temperature 1.054058
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0631 - val_loss: 0.0692
# Epoch 78/200
# mean max of probabilities: 0.00045431894 - temperature 1.0233104
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0632 - val_loss: 0.0693
# Epoch 79/200
# mean max of probabilities: 0.0004546892 - temperature 0.99346
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0636 - val_loss: 0.0694
# Epoch 80/200
# mean max of probabilities: 0.00045510367 - temperature 0.9644802
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0632 - val_loss: 0.0693
# Epoch 81/200
# mean max of probabilities: 0.00045555347 - temperature 0.9363459
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0637 - val_loss: 0.0692
# Epoch 82/200
# mean max of probabilities: 0.00045595333 - temperature 0.90903217
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0634 - val_loss: 0.0699
# Epoch 83/200
# mean max of probabilities: 0.00045635353 - temperature 0.88251525
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0638 - val_loss: 0.0692
# Epoch 84/200
# mean max of probabilities: 0.000456831 - temperature 0.8567719
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0638 - val_loss: 0.0690
# Epoch 85/200
# mean max of probabilities: 0.00045736448 - temperature 0.83177936
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0635 - val_loss: 0.0699
# Epoch 86/200
# mean max of probabilities: 0.0004579699 - temperature 0.8075159
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0639 - val_loss: 0.0705
# Epoch 87/200
# mean max of probabilities: 0.00045846964 - temperature 0.78396034
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0640 - val_loss: 0.0696
# Epoch 88/200
# mean max of probabilities: 0.00045892445 - temperature 0.7610919
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0642 - val_loss: 0.0690
# Epoch 89/200
# mean max of probabilities: 0.00045945437 - temperature 0.73889047
# 104/104 [==============================] - 0s 4ms/step - loss: 0.0639 - val_loss: 0.0703
# Epoch 90/200
# mean max of probabilities: 0.00045994652 - temperature 0.71733665
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0640 - val_loss: 0.0701
# Epoch 91/200
# mean max of probabilities: 0.00046033593 - temperature 0.69641155
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0642 - val_loss: 0.0698
# Epoch 92/200
# mean max of probabilities: 0.0004607392 - temperature 0.67609686
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0641 - val_loss: 0.0712
# Epoch 93/200
# mean max of probabilities: 0.000461134 - temperature 0.6563748
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0647 - val_loss: 0.0700
# Epoch 94/200
# mean max of probabilities: 0.00046151155 - temperature 0.637228
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0642 - val_loss: 0.0712
# Epoch 95/200
# mean max of probabilities: 0.0004618753 - temperature 0.61863965
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0644 - val_loss: 0.0693
# Epoch 96/200
# mean max of probabilities: 0.00046222686 - temperature 0.60059357
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0651 - val_loss: 0.0708
# Epoch 97/200
# mean max of probabilities: 0.00046258786 - temperature 0.5830739
# 104/104 [==============================] - 2s 15ms/step - loss: 0.0649 - val_loss: 0.0690
# Epoch 98/200
# mean max of probabilities: 0.00046290475 - temperature 0.5660653
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0642 - val_loss: 0.0708
# Epoch 99/200
# mean max of probabilities: 0.00046315917 - temperature 0.5495529
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0644 - val_loss: 0.0705
# Epoch 100/200
# mean max of probabilities: 0.00046343883 - temperature 0.5335222
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0642 - val_loss: 0.0704
# Epoch 101/200
# mean max of probabilities: 0.00046359238 - temperature 0.5179591
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0649 - val_loss: 0.0706
# Epoch 102/200
# mean max of probabilities: 0.000463905 - temperature 0.50285006
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0648 - val_loss: 0.0715
# Epoch 103/200
# mean max of probabilities: 0.0004642401 - temperature 0.48818165
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0650 - val_loss: 0.0717
# Epoch 104/200
# mean max of probabilities: 0.00046450866 - temperature 0.47394115
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0655 - val_loss: 0.0706
# Epoch 105/200
# mean max of probabilities: 0.0004648059 - temperature 0.460116
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0647 - val_loss: 0.0716
# Epoch 106/200
# mean max of probabilities: 0.0004651037 - temperature 0.4466942
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0657 - val_loss: 0.0710
# Epoch 107/200
# mean max of probabilities: 0.000465355 - temperature 0.4336639
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0650 - val_loss: 0.0711
# Epoch 108/200
# mean max of probabilities: 0.00046555523 - temperature 0.4210137
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0651 - val_loss: 0.0714
# Epoch 109/200
# mean max of probabilities: 0.00046589057 - temperature 0.40873253
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0644 - val_loss: 0.0701
# Epoch 110/200
# mean max of probabilities: 0.00046618417 - temperature 0.3968096
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0649 - val_loss: 0.0707
# Epoch 111/200
# mean max of probabilities: 0.0004664698 - temperature 0.38523442
# 104/104 [==============================] - 2s 15ms/step - loss: 0.0651 - val_loss: 0.0704
# Epoch 112/200
# mean max of probabilities: 0.00046660975 - temperature 0.37399697
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0659 - val_loss: 0.0721
# Epoch 113/200
# mean max of probabilities: 0.00046669503 - temperature 0.36308733
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0652 - val_loss: 0.0713
# Epoch 114/200
# mean max of probabilities: 0.0004669215 - temperature 0.3524959
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0648 - val_loss: 0.0699
# Epoch 115/200
# mean max of probabilities: 0.00046706168 - temperature 0.3422134
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0648 - val_loss: 0.0713
# Epoch 116/200
# mean max of probabilities: 0.00046725958 - temperature 0.33223087
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0646 - val_loss: 0.0726
# Epoch 117/200
# mean max of probabilities: 0.000467417 - temperature 0.3225395
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0666 - val_loss: 0.0693
# Epoch 118/200
# mean max of probabilities: 0.00046751517 - temperature 0.31313086
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0653 - val_loss: 0.0716
# Epoch 119/200
# mean max of probabilities: 0.0004676269 - temperature 0.30399668
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0658 - val_loss: 0.0711
# Epoch 120/200
# mean max of probabilities: 0.00046778162 - temperature 0.29512894
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0648 - val_loss: 0.0727
# Epoch 121/200
# mean max of probabilities: 0.00046791614 - temperature 0.28651986
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0647 - val_loss: 0.0715
# Epoch 122/200
# mean max of probabilities: 0.00046802324 - temperature 0.2781619
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0650 - val_loss: 0.0717
# Epoch 123/200
# mean max of probabilities: 0.00046811177 - temperature 0.27004778
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0656 - val_loss: 0.0730
# Epoch 124/200
# mean max of probabilities: 0.0004682081 - temperature 0.26217034
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0654 - val_loss: 0.0724
# Epoch 125/200
# mean max of probabilities: 0.00046838942 - temperature 0.2545227
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0656 - val_loss: 0.0713
# Epoch 126/200
# mean max of probabilities: 0.00046864702 - temperature 0.24709816
# 104/104 [==============================] - 2s 15ms/step - loss: 0.0663 - val_loss: 0.0711
# Epoch 127/200
# mean max of probabilities: 0.0004688325 - temperature 0.23989019
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0654 - val_loss: 0.0709
# Epoch 128/200
# mean max of probabilities: 0.0004689961 - temperature 0.23289245
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0653 - val_loss: 0.0701
# Epoch 129/200
# mean max of probabilities: 0.00046915095 - temperature 0.22609885
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0655 - val_loss: 0.0703
# Epoch 130/200
# mean max of probabilities: 0.00046930055 - temperature 0.21950343
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0651 - val_loss: 0.0713
# Epoch 131/200
# mean max of probabilities: 0.000469468 - temperature 0.21310039
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0650 - val_loss: 0.0709
# Epoch 132/200
# mean max of probabilities: 0.00046978824 - temperature 0.20688413
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0652 - val_loss: 0.0718
# Epoch 133/200
# mean max of probabilities: 0.00047002296 - temperature 0.20084922
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0639 - val_loss: 0.0700
# Epoch 134/200
# mean max of probabilities: 0.000470135 - temperature 0.19499035
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0666 - val_loss: 0.0724
# Epoch 135/200
# mean max of probabilities: 0.00047020547 - temperature 0.18930236
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0650 - val_loss: 0.0697
# Epoch 136/200
# mean max of probabilities: 0.0004702831 - temperature 0.18378028
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0651 - val_loss: 0.0713
# Epoch 137/200
# mean max of probabilities: 0.0004703387 - temperature 0.1784193
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0644 - val_loss: 0.0714
# Epoch 138/200
# mean max of probabilities: 0.00047037652 - temperature 0.1732147
# 104/104 [==============================] - 4s 34ms/step - loss: 0.0642 - val_loss: 0.0696
# Epoch 139/200
# mean max of probabilities: 0.00047042326 - temperature 0.16816194
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0642 - val_loss: 0.0704
# Epoch 140/200
# mean max of probabilities: 0.00047054054 - temperature 0.16325657
# 104/104 [==============================] - 2s 24ms/step - loss: 0.0657 - val_loss: 0.0700
# Epoch 141/200
# mean max of probabilities: 0.0004706973 - temperature 0.1584943
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0650 - val_loss: 0.0686
# Epoch 142/200
# mean max of probabilities: 0.00047084037 - temperature 0.15387091
# 104/104 [==============================] - 4s 34ms/step - loss: 0.0652 - val_loss: 0.0698
# Epoch 143/200
# mean max of probabilities: 0.0004709139 - temperature 0.14938241
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0646 - val_loss: 0.0723
# Epoch 144/200
# mean max of probabilities: 0.00047100347 - temperature 0.14502488
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0641 - val_loss: 0.0715
# Epoch 145/200
# mean max of probabilities: 0.00047112943 - temperature 0.14079443
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0648 - val_loss: 0.0702
# Epoch 146/200
# mean max of probabilities: 0.00047122556 - temperature 0.13668738
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0637 - val_loss: 0.0704
# Epoch 147/200
# mean max of probabilities: 0.0004712735 - temperature 0.13270015
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0635 - val_loss: 0.0708
# Epoch 148/200
# mean max of probabilities: 0.00047136354 - temperature 0.12882923
# 104/104 [==============================] - 2s 24ms/step - loss: 0.0659 - val_loss: 0.0697
# Epoch 149/200
# mean max of probabilities: 0.00047143636 - temperature 0.12507118
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0638 - val_loss: 0.0737
# Epoch 150/200
# mean max of probabilities: 0.00047152757 - temperature 0.12142279
# 104/104 [==============================] - 2s 23ms/step - loss: 0.0644 - val_loss: 0.0706
# Epoch 151/200
# mean max of probabilities: 0.00047163985 - temperature 0.11788083
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0647 - val_loss: 0.0717
# Epoch 152/200
# mean max of probabilities: 0.00047171777 - temperature 0.114442185
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0645 - val_loss: 0.0713
# Epoch 153/200
# mean max of probabilities: 0.00047180505 - temperature 0.11110385
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0643 - val_loss: 0.0694
# Epoch 154/200
# mean max of probabilities: 0.00047187708 - temperature 0.1078629
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0645 - val_loss: 0.0727
# Epoch 155/200
# mean max of probabilities: 0.00047193584 - temperature 0.10471648
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0655 - val_loss: 0.0686
# Epoch 156/200
# mean max of probabilities: 0.00047198785 - temperature 0.101661846
# 104/104 [==============================] - 2s 15ms/step - loss: 0.0643 - val_loss: 0.0725
# Epoch 157/200
# mean max of probabilities: 0.0004720535 - temperature 0.1
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0635 - val_loss: 0.0700
# Epoch 158/200
# mean max of probabilities: 0.00047216268 - temperature 0.1
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0642 - val_loss: 0.0688
# Epoch 159/200
# mean max of probabilities: 0.00047223325 - temperature 0.1
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0638 - val_loss: 0.0713
# Epoch 160/200
# mean max of probabilities: 0.00047226687 - temperature 0.1
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0645 - val_loss: 0.0712
# Epoch 161/200
# mean max of probabilities: 0.00047228177 - temperature 0.1
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0644 - val_loss: 0.0707
# Epoch 162/200
# mean max of probabilities: 0.00047230744 - temperature 0.1
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0635 - val_loss: 0.0685
# Epoch 163/200
# mean max of probabilities: 0.00047239175 - temperature 0.1
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0643 - val_loss: 0.0714
# Epoch 164/200
# mean max of probabilities: 0.0004724778 - temperature 0.1
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0638 - val_loss: 0.0720
# Epoch 165/200
# mean max of probabilities: 0.00047245467 - temperature 0.1
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0640 - val_loss: 0.0687
# Epoch 166/200
# mean max of probabilities: 0.00047248031 - temperature 0.1
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0645 - val_loss: 0.0690
# Epoch 167/200
# mean max of probabilities: 0.0004724938 - temperature 0.1
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0638 - val_loss: 0.0704
# Epoch 168/200
# mean max of probabilities: 0.00047252068 - temperature 0.1
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0641 - val_loss: 0.0718
# Epoch 169/200
# mean max of probabilities: 0.00047253375 - temperature 0.1
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0627 - val_loss: 0.0708
# Epoch 170/200
# mean max of probabilities: 0.0004725568 - temperature 0.1
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0641 - val_loss: 0.0680
# Epoch 171/200
# mean max of probabilities: 0.00047262962 - temperature 0.1
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0637 - val_loss: 0.0690
# Epoch 172/200
# mean max of probabilities: 0.00047275325 - temperature 0.1
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0652 - val_loss: 0.0691
# Epoch 173/200
# mean max of probabilities: 0.00047283922 - temperature 0.1
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0633 - val_loss: 0.0699
# Epoch 174/200
# mean max of probabilities: 0.0004729099 - temperature 0.1
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0634 - val_loss: 0.0676
# Epoch 175/200
# mean max of probabilities: 0.00047297863 - temperature 0.1
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0628 - val_loss: 0.0710
# Epoch 176/200
# mean max of probabilities: 0.00047308818 - temperature 0.1
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0636 - val_loss: 0.0708
# Epoch 177/200
# mean max of probabilities: 0.000473146 - temperature 0.1
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0633 - val_loss: 0.0709
# Epoch 178/200
# mean max of probabilities: 0.00047324557 - temperature 0.1
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0631 - val_loss: 0.0709
# Epoch 179/200
# mean max of probabilities: 0.0004733061 - temperature 0.1
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0630 - val_loss: 0.0709
# Epoch 180/200
# mean max of probabilities: 0.0004733554 - temperature 0.1
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0622 - val_loss: 0.0703
# Epoch 181/200
# mean max of probabilities: 0.000473404 - temperature 0.1
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0636 - val_loss: 0.0705
# Epoch 182/200
# mean max of probabilities: 0.0004734823 - temperature 0.1
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0640 - val_loss: 0.0705
# Epoch 183/200
# mean max of probabilities: 0.000473521 - temperature 0.1
# 104/104 [==============================] - 2s 23ms/step - loss: 0.0626 - val_loss: 0.0703
# Epoch 184/200
# mean max of probabilities: 0.0004735666 - temperature 0.1
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0635 - val_loss: 0.0680
# Epoch 185/200
# mean max of probabilities: 0.00047359455 - temperature 0.1
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0633 - val_loss: 0.0677
# Epoch 186/200
# mean max of probabilities: 0.00047360815 - temperature 0.1
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0634 - val_loss: 0.0685
# Epoch 187/200
# mean max of probabilities: 0.0004736133 - temperature 0.1
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0633 - val_loss: 0.0711
# Epoch 188/200
# mean max of probabilities: 0.00047361467 - temperature 0.1
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0632 - val_loss: 0.0672
# Epoch 189/200
# mean max of probabilities: 0.000473626 - temperature 0.1
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0650 - val_loss: 0.0702
# Epoch 190/200
# mean max of probabilities: 0.00047366484 - temperature 0.1
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0634 - val_loss: 0.0725
# Epoch 191/200
# mean max of probabilities: 0.00047378766 - temperature 0.1
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0630 - val_loss: 0.0720
# Epoch 192/200
# mean max of probabilities: 0.00047388306 - temperature 0.1
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0620 - val_loss: 0.0701
# Epoch 193/200
# mean max of probabilities: 0.00047403446 - temperature 0.1
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0627 - val_loss: 0.0698
# Epoch 194/200
# mean max of probabilities: 0.0004741501 - temperature 0.1
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0631 - val_loss: 0.0706
# Epoch 195/200
# mean max of probabilities: 0.00047420713 - temperature 0.1
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0633 - val_loss: 0.0697
# Epoch 196/200
# mean max of probabilities: 0.0004742326 - temperature 0.1
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0639 - val_loss: 0.0684
# Epoch 197/200
# mean max of probabilities: 0.00047436988 - temperature 0.1
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0631 - val_loss: 0.0690
# Epoch 198/200
# mean max of probabilities: 0.000474484 - temperature 0.1
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0630 - val_loss: 0.0687
# Epoch 199/200
# mean max of probabilities: 0.00047455812 - temperature 0.1
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0635 - val_loss: 0.0674
# Epoch 200/200
# mean max of probabilities: 0.00047459727 - temperature 0.1
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0619 - val_loss: 0.0704
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.8461538461538461
# Testing accuracy： 0.8461538461538461
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.8846153846153846
# Testing accuracy： 0.8846153846153846
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2400)              0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                153601
# _________________________________________________________________
# dense_2 (Dense)              (None, 2400)              156000
# =================================================================
# Total params: 309,601
# Trainable params: 309,600
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 104 samples, validate on 26 samples
# Epoch 1/200
# mean max of probabilities: 0.0004443157 - temperature 10.0
# 104/104 [==============================] - 8s 72ms/step - loss: 0.3627 - val_loss: 0.2318
# Epoch 2/200
# mean max of probabilities: 0.00044431735 - temperature 9.708295
# 104/104 [==============================] - 2s 22ms/step - loss: 0.1750 - val_loss: 0.1010
# Epoch 3/200
# mean max of probabilities: 0.0004443339 - temperature 9.425098
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0931 - val_loss: 0.0639
# Epoch 4/200
# mean max of probabilities: 0.00044436962 - temperature 9.150163
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0756 - val_loss: 0.0599
# Epoch 5/200
# mean max of probabilities: 0.00044439183 - temperature 8.883247
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0741 - val_loss: 0.0588
# Epoch 6/200
# mean max of probabilities: 0.00044437905 - temperature 8.624119
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0724 - val_loss: 0.0569
# Epoch 7/200
# mean max of probabilities: 0.0004443537 - temperature 8.372548
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0704 - val_loss: 0.0556
# Epoch 8/200
# mean max of probabilities: 0.00044433802 - temperature 8.128316
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0692 - val_loss: 0.0549
# Epoch 9/200
# mean max of probabilities: 0.0004443375 - temperature 7.8912086
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0689 - val_loss: 0.0543
# Epoch 10/200
# mean max of probabilities: 0.0004443421 - temperature 7.6610184
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0685 - val_loss: 0.0540
# Epoch 11/200
# mean max of probabilities: 0.0004443481 - temperature 7.4375434
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0683 - val_loss: 0.0541
# Epoch 12/200
# mean max of probabilities: 0.000444356 - temperature 7.2205873
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0683 - val_loss: 0.0543
# Epoch 13/200
# mean max of probabilities: 0.00044436636 - temperature 7.009959
# 104/104 [==============================] - 4s 37ms/step - loss: 0.0685 - val_loss: 0.0540
# Epoch 14/200
# mean max of probabilities: 0.00044437803 - temperature 6.8054743
# 104/104 [==============================] - 4s 42ms/step - loss: 0.0683 - val_loss: 0.0540
# Epoch 15/200
# mean max of probabilities: 0.00044439267 - temperature 6.6069555
# 104/104 [==============================] - 4s 37ms/step - loss: 0.0682 - val_loss: 0.0539
# Epoch 16/200
# mean max of probabilities: 0.00044440923 - temperature 6.4142275
# 104/104 [==============================] - 4s 41ms/step - loss: 0.0682 - val_loss: 0.0540
# Epoch 17/200
# mean max of probabilities: 0.00044442754 - temperature 6.227122
# 104/104 [==============================] - 5s 44ms/step - loss: 0.0683 - val_loss: 0.0536
# Epoch 18/200
# mean max of probabilities: 0.00044444695 - temperature 6.0454736
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0681 - val_loss: 0.0539
# Epoch 19/200
# mean max of probabilities: 0.00044446904 - temperature 5.8691244
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0681 - val_loss: 0.0539
# Epoch 20/200
# mean max of probabilities: 0.00044449363 - temperature 5.6979184
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0681 - val_loss: 0.0540
# Epoch 21/200
# mean max of probabilities: 0.0004445188 - temperature 5.5317073
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0683 - val_loss: 0.0537
# Epoch 22/200
# mean max of probabilities: 0.00044454655 - temperature 5.3703446
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0683 - val_loss: 0.0540
# Epoch 23/200
# mean max of probabilities: 0.0004445755 - temperature 5.213689
# 104/104 [==============================] - 4s 34ms/step - loss: 0.0681 - val_loss: 0.0540
# Epoch 24/200
# mean max of probabilities: 0.00044460734 - temperature 5.061603
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0679 - val_loss: 0.0536
# Epoch 25/200
# mean max of probabilities: 0.0004446425 - temperature 4.913953
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0680 - val_loss: 0.0536
# Epoch 26/200
# mean max of probabilities: 0.00044468287 - temperature 4.7706113
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0681 - val_loss: 0.0536
# Epoch 27/200
# mean max of probabilities: 0.0004447271 - temperature 4.63145
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0679 - val_loss: 0.0539
# Epoch 28/200
# mean max of probabilities: 0.00044477277 - temperature 4.4963484
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0679 - val_loss: 0.0537
# Epoch 29/200
# mean max of probabilities: 0.00044481858 - temperature 4.365188
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0679 - val_loss: 0.0539
# Epoch 30/200
# mean max of probabilities: 0.00044486573 - temperature 4.237853
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0680 - val_loss: 0.0540
# Epoch 31/200
# mean max of probabilities: 0.00044491427 - temperature 4.1142325
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0678 - val_loss: 0.0535
# Epoch 32/200
# mean max of probabilities: 0.00044496852 - temperature 3.9942179
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0677 - val_loss: 0.0533
# Epoch 33/200
# mean max of probabilities: 0.00044502591 - temperature 3.8777046
# 104/104 [==============================] - 2s 23ms/step - loss: 0.0678 - val_loss: 0.0539
# Epoch 34/200
# mean max of probabilities: 0.00044508575 - temperature 3.76459
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0678 - val_loss: 0.0535
# Epoch 35/200
# mean max of probabilities: 0.0004451489 - temperature 3.6547751
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0677 - val_loss: 0.0538
# Epoch 36/200
# mean max of probabilities: 0.00044521462 - temperature 3.5481632
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0677 - val_loss: 0.0538
# Epoch 37/200
# mean max of probabilities: 0.0004452808 - temperature 3.4446616
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0676 - val_loss: 0.0533
# Epoch 38/200
# mean max of probabilities: 0.00044535467 - temperature 3.3441787
#  48/104 [============>.................] - ETA: 20s - loss: 0.0719
# /usr/local/lib/python3.7/site-packages/keras/callbacks/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.356544). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# /usr/local/lib/python3.7/site-packages/keras/callbacks/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.179749). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 104/104 [==============================] - 18s 169ms/step - loss: 0.0676 - val_loss: 0.0534
# Epoch 39/200
# mean max of probabilities: 0.00044543494 - temperature 3.2466273
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0677 - val_loss: 0.0533
# Epoch 40/200
# mean max of probabilities: 0.0004455218 - temperature 3.1519213
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0675 - val_loss: 0.0533
# Epoch 41/200
# mean max of probabilities: 0.0004456181 - temperature 3.0599782
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0676 - val_loss: 0.0534
# Epoch 42/200
# mean max of probabilities: 0.00044571643 - temperature 2.9707172
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0675 - val_loss: 0.0534
# Epoch 43/200
# mean max of probabilities: 0.00044582004 - temperature 2.88406
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0677 - val_loss: 0.0531
# Epoch 44/200
# mean max of probabilities: 0.00044593215 - temperature 2.79993
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0675 - val_loss: 0.0540
# Epoch 45/200
# mean max of probabilities: 0.00044604845 - temperature 2.7182546
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0675 - val_loss: 0.0537
# Epoch 46/200
# mean max of probabilities: 0.00044618497 - temperature 2.6389616
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0675 - val_loss: 0.0529
# Epoch 47/200
# mean max of probabilities: 0.00044631673 - temperature 2.5619814
# 104/104 [==============================] - 4s 37ms/step - loss: 0.0673 - val_loss: 0.0531
# Epoch 48/200
# mean max of probabilities: 0.00044645646 - temperature 2.4872475
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0675 - val_loss: 0.0534
# Epoch 49/200
# mean max of probabilities: 0.00044662145 - temperature 2.4146929
# 104/104 [==============================] - 4s 34ms/step - loss: 0.0673 - val_loss: 0.0535
# Epoch 50/200
# mean max of probabilities: 0.0004467916 - temperature 2.3442552
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0673 - val_loss: 0.0532
# Epoch 51/200
# mean max of probabilities: 0.00044696068 - temperature 2.2758718
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0672 - val_loss: 0.0532
# Epoch 52/200
# mean max of probabilities: 0.00044712384 - temperature 2.2094836
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0673 - val_loss: 0.0535
# Epoch 53/200
# mean max of probabilities: 0.0004472994 - temperature 2.1450317
# 104/104 [==============================] - 4s 40ms/step - loss: 0.0674 - val_loss: 0.0533
# Epoch 54/200
# mean max of probabilities: 0.00044748455 - temperature 2.08246
# 104/104 [==============================] - 4s 43ms/step - loss: 0.0673 - val_loss: 0.0529
# Epoch 55/200
# mean max of probabilities: 0.00044766895 - temperature 2.0217133
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0672 - val_loss: 0.0533
# Epoch 56/200
# mean max of probabilities: 0.0004478786 - temperature 1.9627389
# 104/104 [==============================] - 4s 41ms/step - loss: 0.0671 - val_loss: 0.0528
# Epoch 57/200
# mean max of probabilities: 0.00044811628 - temperature 1.9054846
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0671 - val_loss: 0.0532
# Epoch 58/200
# mean max of probabilities: 0.0004483647 - temperature 1.8499007
# 104/104 [==============================] - 4s 41ms/step - loss: 0.0671 - val_loss: 0.0532
# Epoch 59/200
# mean max of probabilities: 0.00044860388 - temperature 1.795938
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0669 - val_loss: 0.0532
# Epoch 60/200
# mean max of probabilities: 0.00044885388 - temperature 1.7435495
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0672 - val_loss: 0.0531
# Epoch 61/200
# mean max of probabilities: 0.0004491279 - temperature 1.6926892
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0671 - val_loss: 0.0532
# Epoch 62/200
# mean max of probabilities: 0.000449399 - temperature 1.6433126
# 104/104 [==============================] - 4s 40ms/step - loss: 0.0669 - val_loss: 0.0528
# Epoch 63/200
# mean max of probabilities: 0.0004497331 - temperature 1.5953764
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0670 - val_loss: 0.0528
# Epoch 64/200
# mean max of probabilities: 0.0004500684 - temperature 1.5488384
# 104/104 [==============================] - 5s 50ms/step - loss: 0.0670 - val_loss: 0.0530
# Epoch 65/200
# mean max of probabilities: 0.00045037377 - temperature 1.503658
# 104/104 [==============================] - 4s 38ms/step - loss: 0.0670 - val_loss: 0.0534
# Epoch 66/200
# mean max of probabilities: 0.00045069496 - temperature 1.4597956
# 104/104 [==============================] - 4s 38ms/step - loss: 0.0670 - val_loss: 0.0533
# Epoch 67/200
# mean max of probabilities: 0.0004510306 - temperature 1.4172126
# 104/104 [==============================] - ETA: 0s - loss: 0.067 - 4s 34ms/step - loss: 0.0670 - val_loss: 0.0529
# Epoch 68/200
# mean max of probabilities: 0.00045138336 - temperature 1.3758719
# 104/104 [==============================] - 6s 56ms/step - loss: 0.0670 - val_loss: 0.0528
# Epoch 69/200
# mean max of probabilities: 0.00045174803 - temperature 1.335737
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0669 - val_loss: 0.0534
# Epoch 70/200
# mean max of probabilities: 0.0004521071 - temperature 1.2967727
# 104/104 [==============================] - 3s 34ms/step - loss: 0.0670 - val_loss: 0.0529
# Epoch 71/200
# mean max of probabilities: 0.00045245493 - temperature 1.2589452
# 104/104 [==============================] - 4s 42ms/step - loss: 0.0669 - val_loss: 0.0532
# Epoch 72/200
# mean max of probabilities: 0.00045286634 - temperature 1.222221
# 104/104 [==============================] - 4s 38ms/step - loss: 0.0673 - val_loss: 0.0535
# Epoch 73/200
# mean max of probabilities: 0.0004533358 - temperature 1.1865681
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0674 - val_loss: 0.0530
# Epoch 74/200
# mean max of probabilities: 0.0004538356 - temperature 1.1519552
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0670 - val_loss: 0.0532
# Epoch 75/200
# mean max of probabilities: 0.00045434074 - temperature 1.1183522
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0670 - val_loss: 0.0533
# Epoch 76/200
# mean max of probabilities: 0.0004548415 - temperature 1.0857294
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0670 - val_loss: 0.0533
# Epoch 77/200
# mean max of probabilities: 0.0004552541 - temperature 1.054058
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0670 - val_loss: 0.0534
# Epoch 78/200
# mean max of probabilities: 0.000455704 - temperature 1.0233104
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0673 - val_loss: 0.0531
# Epoch 79/200
# mean max of probabilities: 0.00045610365 - temperature 0.99346
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0674 - val_loss: 0.0536
# Epoch 80/200
# mean max of probabilities: 0.00045653473 - temperature 0.9644802
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0672 - val_loss: 0.0534
# Epoch 81/200
# mean max of probabilities: 0.0004570554 - temperature 0.9363459
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0672 - val_loss: 0.0529
# Epoch 82/200
# mean max of probabilities: 0.00045765913 - temperature 0.90903217
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0672 - val_loss: 0.0534
# Epoch 83/200
# mean max of probabilities: 0.00045830087 - temperature 0.88251525
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0675 - val_loss: 0.0536
# Epoch 84/200
# mean max of probabilities: 0.00045883917 - temperature 0.8567719
#  96/104 [==========================>...] - ETA: 0s - loss: 0.0686
# /usr/local/lib/python3.7/site-packages/keras/callbacks/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.172347). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0676 - val_loss: 0.0533
# Epoch 85/200
# mean max of probabilities: 0.00045927765 - temperature 0.83177936
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0674 - val_loss: 0.0537
# Epoch 86/200
# mean max of probabilities: 0.00045969465 - temperature 0.8075159
# 104/104 [==============================] - 5s 47ms/step - loss: 0.0679 - val_loss: 0.0540
# Epoch 87/200
# mean max of probabilities: 0.00046022027 - temperature 0.78396034
# 104/104 [==============================] - 4s 42ms/step - loss: 0.0678 - val_loss: 0.0544
# Epoch 88/200
# mean max of probabilities: 0.0004606474 - temperature 0.7610919
# 104/104 [==============================] - 5s 48ms/step - loss: 0.0683 - val_loss: 0.0542
# Epoch 89/200
# mean max of probabilities: 0.00046098395 - temperature 0.73889047
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0682 - val_loss: 0.0541
# Epoch 90/200
# mean max of probabilities: 0.00046128163 - temperature 0.71733665
# 104/104 [==============================] - 5s 48ms/step - loss: 0.0680 - val_loss: 0.0539
# Epoch 91/200
# mean max of probabilities: 0.0004615797 - temperature 0.69641155
# 104/104 [==============================] - 4s 41ms/step - loss: 0.0682 - val_loss: 0.0550
# Epoch 92/200
# mean max of probabilities: 0.0004619466 - temperature 0.67609686
# 104/104 [==============================] - 4s 40ms/step - loss: 0.0685 - val_loss: 0.0542
# Epoch 93/200
# mean max of probabilities: 0.00046236377 - temperature 0.6563748
# 104/104 [==============================] - 4s 42ms/step - loss: 0.0682 - val_loss: 0.0545
# Epoch 94/200
# mean max of probabilities: 0.0004626942 - temperature 0.637228
# 104/104 [==============================] - 4s 41ms/step - loss: 0.0684 - val_loss: 0.0546
# Epoch 95/200
# mean max of probabilities: 0.0004631275 - temperature 0.61863965
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0685 - val_loss: 0.0550
# Epoch 96/200
# mean max of probabilities: 0.00046352192 - temperature 0.60059357
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0684 - val_loss: 0.0538
# Epoch 97/200
# mean max of probabilities: 0.00046390502 - temperature 0.5830739
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0691 - val_loss: 0.0546
# Epoch 98/200
# mean max of probabilities: 0.00046437525 - temperature 0.5660653
# 104/104 [==============================] - 4s 40ms/step - loss: 0.0684 - val_loss: 0.0546
# Epoch 99/200
# mean max of probabilities: 0.00046482185 - temperature 0.5495529
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0685 - val_loss: 0.0549
# Epoch 100/200
# mean max of probabilities: 0.0004652398 - temperature 0.5335222
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0690 - val_loss: 0.0542
# Epoch 101/200
# mean max of probabilities: 0.00046550974 - temperature 0.5179591
# 104/104 [==============================] - 4s 40ms/step - loss: 0.0685 - val_loss: 0.0546
# Epoch 102/200
# mean max of probabilities: 0.00046574546 - temperature 0.50285006
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0685 - val_loss: 0.0544
# Epoch 103/200
# mean max of probabilities: 0.00046600815 - temperature 0.48818165
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0689 - val_loss: 0.0537
# Epoch 104/200
# mean max of probabilities: 0.00046631476 - temperature 0.47394115
# 104/104 [==============================] - 4s 42ms/step - loss: 0.0690 - val_loss: 0.0548
# Epoch 105/200
# mean max of probabilities: 0.00046657125 - temperature 0.460116
# 104/104 [==============================] - 2s 24ms/step - loss: 0.0695 - val_loss: 0.0564
# Epoch 106/200
# mean max of probabilities: 0.0004668713 - temperature 0.4466942
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0691 - val_loss: 0.0541
# Epoch 107/200
# mean max of probabilities: 0.0004670999 - temperature 0.4336639
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0690 - val_loss: 0.0541
# Epoch 108/200
# mean max of probabilities: 0.0004673191 - temperature 0.4210137
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0693 - val_loss: 0.0563
# Epoch 109/200
# mean max of probabilities: 0.00046757804 - temperature 0.40873253
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0692 - val_loss: 0.0547
# Epoch 110/200
# mean max of probabilities: 0.0004678332 - temperature 0.3968096
# 104/104 [==============================] - 5s 44ms/step - loss: 0.0690 - val_loss: 0.0554
# Epoch 111/200
# mean max of probabilities: 0.0004680201 - temperature 0.38523442
# 104/104 [==============================] - 47s 450ms/step - loss: 0.0690 - val_loss: 0.0544
# Epoch 112/200
# mean max of probabilities: 0.0004681889 - temperature 0.37399697
# 104/104 [==============================] - 2s 23ms/step - loss: 0.0693 - val_loss: 0.0550
# Epoch 113/200
# mean max of probabilities: 0.0004683533 - temperature 0.36308733
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0686 - val_loss: 0.0544
# Epoch 114/200
# mean max of probabilities: 0.00046842312 - temperature 0.3524959
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0682 - val_loss: 0.0553
# Epoch 115/200
# mean max of probabilities: 0.00046854487 - temperature 0.3422134
# 104/104 [==============================] - 2s 23ms/step - loss: 0.0683 - val_loss: 0.0545
# Epoch 116/200
# mean max of probabilities: 0.00046878474 - temperature 0.33223087
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0685 - val_loss: 0.0552
# Epoch 117/200
# mean max of probabilities: 0.00046899036 - temperature 0.3225395
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0697 - val_loss: 0.0558
# Epoch 118/200
# mean max of probabilities: 0.00046920037 - temperature 0.31313086
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0686 - val_loss: 0.0546
# Epoch 119/200
# mean max of probabilities: 0.00046937368 - temperature 0.30399668
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0682 - val_loss: 0.0551
# Epoch 120/200
# mean max of probabilities: 0.00046955215 - temperature 0.29512894
# 104/104 [==============================] - 4s 38ms/step - loss: 0.0681 - val_loss: 0.0554
# Epoch 121/200
# mean max of probabilities: 0.00046975864 - temperature 0.28651986
# 104/104 [==============================] - 4s 38ms/step - loss: 0.0691 - val_loss: 0.0553
# Epoch 122/200
# mean max of probabilities: 0.00046991915 - temperature 0.2781619
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0690 - val_loss: 0.0570
# Epoch 123/200
# mean max of probabilities: 0.00047012587 - temperature 0.27004778
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0699 - val_loss: 0.0559
# Epoch 124/200
# mean max of probabilities: 0.0004701774 - temperature 0.26217034
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0691 - val_loss: 0.0543
# Epoch 125/200
# mean max of probabilities: 0.0004702775 - temperature 0.2545227
# 104/104 [==============================] - 4s 38ms/step - loss: 0.0686 - val_loss: 0.0560
# Epoch 126/200
# mean max of probabilities: 0.00047041223 - temperature 0.24709816
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0686 - val_loss: 0.0552
# Epoch 127/200
# mean max of probabilities: 0.00047054183 - temperature 0.23989019
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0676 - val_loss: 0.0543
# Epoch 128/200
# mean max of probabilities: 0.00047066546 - temperature 0.23289245
# 104/104 [==============================] - 4s 37ms/step - loss: 0.0690 - val_loss: 0.0536
# Epoch 129/200
# mean max of probabilities: 0.00047078714 - temperature 0.22609885
# 104/104 [==============================] - 4s 34ms/step - loss: 0.0680 - val_loss: 0.0547
# Epoch 130/200
# mean max of probabilities: 0.00047092067 - temperature 0.21950343
# 104/104 [==============================] - 4s 38ms/step - loss: 0.0683 - val_loss: 0.0563
# Epoch 131/200
# mean max of probabilities: 0.000471049 - temperature 0.21310039
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0688 - val_loss: 0.0540
# Epoch 132/200
# mean max of probabilities: 0.00047126482 - temperature 0.20688413
# 104/104 [==============================] - 5s 45ms/step - loss: 0.0688 - val_loss: 0.0559
# Epoch 133/200
# mean max of probabilities: 0.0004714923 - temperature 0.20084922
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0691 - val_loss: 0.0574
# Epoch 134/200
# mean max of probabilities: 0.00047173354 - temperature 0.19499035
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0683 - val_loss: 0.0555
# Epoch 135/200
# mean max of probabilities: 0.00047186008 - temperature 0.18930236
# 104/104 [==============================] - 4s 34ms/step - loss: 0.0692 - val_loss: 0.0559
# Epoch 136/200
# mean max of probabilities: 0.00047195546 - temperature 0.18378028
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0689 - val_loss: 0.0549
# Epoch 137/200
# mean max of probabilities: 0.00047204737 - temperature 0.1784193
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0690 - val_loss: 0.0555
# Epoch 138/200
# mean max of probabilities: 0.00047212525 - temperature 0.1732147
# 104/104 [==============================] - 4s 41ms/step - loss: 0.0700 - val_loss: 0.0557
# Epoch 139/200
# mean max of probabilities: 0.00047224425 - temperature 0.16816194
# 104/104 [==============================] - 4s 40ms/step - loss: 0.0682 - val_loss: 0.0555
# Epoch 140/200
# mean max of probabilities: 0.00047239207 - temperature 0.16325657
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0691 - val_loss: 0.0553
# Epoch 141/200
# mean max of probabilities: 0.00047250936 - temperature 0.1584943
# 104/104 [==============================] - 4s 34ms/step - loss: 0.0688 - val_loss: 0.0564
# Epoch 142/200
# mean max of probabilities: 0.00047258486 - temperature 0.15387091
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0689 - val_loss: 0.0568
