# %%
import numpy as np
import pandas as pd
import os

# %%
fold_path=['1_LS_CV','2_SPEC_CV','3_NDFS_CV','4_AEFS_CV','5_UDFS_CV','6_MCFS_CV','7_PFA_CV','8_InfFS_CV','9_AgnoSS_CV','10_CAE_CV','11_FAE_64_CV','12_FAE_50_CV']

# %%
cv_times_from=0
cv_times_to=5

# %%
file_path="/log/"

for fold_path_i in fold_path:
    fold_name=fold_path_i.split('_')[1]
    print(fold_name+":\n")
    
    if fold_path_i in ['11_FAE_64_CV','12_FAE_50_CV']:
        print("Do not use bias!",fold_path_i)
        p_is_use_bias=False
        path_results='./'+fold_path_i+file_path+"FAE_results_bias_"+str(p_is_use_bias)+".csv" 
        results_analysis=np.array(pd.read_csv(path_results,header=None))
        results_analysis_test_acc__=results_analysis[:,3]
        results_analysis_test_acc_=results_analysis_test_acc__[np.where(results_analysis[:,3]>=0)]
        cv_cal_times=len(results_analysis_test_acc__)
        if cv_cal_times >=(cv_times_to-cv_times_from):
        
            print("cv times: ",cv_cal_times)
        
            results_analysis_test_acc=results_analysis_test_acc_[cv_times_from:cv_times_to]
            results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]
        
            print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
            print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

            path_time='./'+fold_path_i+file_path+"FAE_time_bias_"+str(p_is_use_bias)+".csv"
            time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
            print("Calculation times: ", len(results_analysis_test_acc))  
        
            print("Use bias!",fold_path_i)
            p_is_use_bias=True
            path_results='./'+fold_path_i+file_path+"FAE_results_bias_"+str(p_is_use_bias)+".csv"  
            results_analysis=np.array(pd.read_csv(path_results,header=None))
            results_analysis_test_acc=results_analysis[:,3][np.where(results_analysis[:,3]>=0)][cv_times_from:cv_times_to]
            results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]
        
            print(results_analysis_test_acc)
            print(results_analysis_linear_rec)
            print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
            print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

            path_time='./'+fold_path_i+file_path+"FAE_time_bias_"+str(p_is_use_bias)+".csv"
            time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
            print("Calculation times: ", len(results_analysis_test_acc))          
    
    else:
        path_results='./'+fold_path_i+file_path+fold_name+'_results.csv'
        
        if os.path.exists(path_results):
            results_analysis=np.array(pd.read_csv(path_results,header=None))

            results_analysis_test_acc__=results_analysis[:,3]
            results_analysis_test_acc_=results_analysis_test_acc__[np.where(results_analysis[:,3]>=0)]
            cv_cal_times=len(results_analysis_test_acc__)
                
            cv_cal_times=len(results_analysis_test_acc_)
            if cv_cal_times>=(cv_times_to-cv_times_from):

                print("cv times: ",cv_cal_times)        
                
                results_analysis_test_acc=results_analysis_test_acc_[cv_times_from:cv_times_to]
                results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]

                print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
                print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

                path_time='./'+fold_path_i+file_path+fold_path_i.split('_')[1]+'_time.csv'
                time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
                print("Calculation times: ", len(results_analysis_test_acc))
    
                print("\n\n")
        else:
            print("Nan")
            print("\n\n")
# Out:
# LS:
#
# cv times:  50
# Testing accuarcy:0.115 ±0.0544
# Testing Linear reconstruction: 1.277 ±0.6057
# Calculation times:  5
#
#
#
# SPEC:
#
# cv times:  50
# Testing accuarcy:0.077 ±0.0487
# Testing Linear reconstruction: 4.734 ±3.9503
# Calculation times:  5
#
#
#
# NDFS:
#
# cv times:  50
# Testing accuarcy:0.123 ±0.0705
# Testing Linear reconstruction: 0.597 ±0.1184
# Calculation times:  5
#
#
#
# AEFS:
#
# cv times:  50
# Testing accuarcy:0.769 ±0.0544
# Testing Linear reconstruction: 0.039 ±0.0072
# Calculation times:  5
#
#
#
# UDFS:
#
# cv times:  50
# Testing accuarcy:0.646 ±0.0890
# Testing Linear reconstruction: 0.086 ±0.0288
# Calculation times:  5
#
#
#
# MCFS:
#
# cv times:  50
# Testing accuarcy:0.154 ±0.0544
# Testing Linear reconstruction: 1.077 ±0.3250
# Calculation times:  5
#
#
#
# PFA:
#
# cv times:  50
# Testing accuarcy:0.823 ±0.0671
# Testing Linear reconstruction: 0.036 ±0.0047
# Calculation times:  5
#
#
#
# InfFS:
#
# cv times:  50
# Testing accuarcy:0.108 ±0.0377
# Testing Linear reconstruction: 3.677 ±1.1488
# Calculation times:  5
#
#
#
# AgnoSS:
#
# cv times:  50
# Testing accuarcy:0.715 ±0.0713
# Testing Linear reconstruction: 0.045 ±0.0064
# Calculation times:  5
#
#
#
# CAE:
#
# cv times:  50
# Testing accuarcy:0.700 ±0.1071
# Testing Linear reconstruction: 0.074 ±0.0267
# Calculation times:  5
#
#
#
# FAE:
#
# Do not use bias! 11_FAE_64_CV
# cv times:  44
# Testing accuarcy:0.654 ±0.0807
# Testing Linear reconstruction: 0.042 ±0.0057
# Calculation times:  5
# Use bias! 11_FAE_64_CV
# [0.76923077 0.73076923 0.69230769 0.69230769 0.69230769]
# [0.04194223 0.03533793 0.0453021  0.03372576 0.04582177]
# Testing accuarcy:0.715 ±0.0308
# Testing Linear reconstruction: 0.040 ±0.0050
# Calculation times:  5
# FAE:
#
# Do not use bias! 12_FAE_50_CV
# cv times:  47
# Testing accuarcy:0.685 ±0.0662
# Testing Linear reconstruction: 0.035 ±0.0043
# Calculation times:  5
# Use bias! 12_FAE_50_CV
# [0.65384615 0.69230769 0.73076923 0.5        0.61538462]
# [0.03747565 0.02820478 0.03929481 0.02792558 0.03334361]
# Testing accuarcy:0.638 ±0.0792
# Testing Linear reconstruction: 0.033 ±0.0047
# Calculation times:  5
