# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.model_selection import train_test_split
import scipy.sparse as sparse
from keras.datasets import fashion_mnist
import scipy.io

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
data_path="../Dataset/SMK_CAN_187.mat"
Data = scipy.io.loadmat(data_path)

data_arr=Data['X']
label_arr=Data['Y'][:, 0]
label_arr_onehot=label_arr

# %%
key_feture_number=64

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,50):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 19993)             0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                1279553
# _________________________________________________________________
# dense_1 (Dense)              (None, 19993)             1299545
# =================================================================
# Total params: 2,579,098
# Trainable params: 2,579,097
# Non-trainable params: 1
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 149 samples, validate on 38 samples
# Epoch 1/200
# mean max of probabilities: 5.1163945e-05 - temperature 10.0
# 149/149 [==============================] - 19s 129ms/step - loss: 23.9835 - val_loss: 8.8538
# Epoch 2/200
# mean max of probabilities: 5.1262294e-05 - temperature 9.705095
# 149/149 [==============================] - 12s 81ms/step - loss: 4.3712 - val_loss: 1.2961
# Epoch 3/200
# mean max of probabilities: 5.1530595e-05 - temperature 9.418887
# 149/149 [==============================] - 10s 67ms/step - loss: 1.0642 - val_loss: 0.8842
# Epoch 4/200
# mean max of probabilities: 5.1626037e-05 - temperature 9.141122
# 149/149 [==============================] - 11s 73ms/step - loss: 0.7197 - val_loss: 0.4485
# Epoch 5/200
# mean max of probabilities: 5.1484298e-05 - temperature 8.871547
# 149/149 [==============================] - 14s 92ms/step - loss: 0.3605 - val_loss: 0.2398
# Epoch 6/200
# mean max of probabilities: 5.1320276e-05 - temperature 8.609923
# 149/149 [==============================] - 14s 92ms/step - loss: 0.2327 - val_loss: 0.1863
# Epoch 7/200
# mean max of probabilities: 5.124905e-05 - temperature 8.356012
# 149/149 [==============================] - 13s 85ms/step - loss: 0.1950 - val_loss: 0.1635
# Epoch 8/200
# mean max of probabilities: 5.124163e-05 - temperature 8.1095915
# 149/149 [==============================] - 15s 100ms/step - loss: 0.1784 - val_loss: 0.1544
# Epoch 9/200
# mean max of probabilities: 5.1248746e-05 - temperature 7.8704367
# 149/149 [==============================] - 17s 112ms/step - loss: 0.1722 - val_loss: 0.1513
# Epoch 10/200
# mean max of probabilities: 5.12511e-05 - temperature 7.6383343
# 149/149 [==============================] - 12s 84ms/step - loss: 0.1703 - val_loss: 0.1503
# Epoch 11/200
# mean max of probabilities: 5.125178e-05 - temperature 7.413077
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1697 - val_loss: 0.1498
# Epoch 12/200
# mean max of probabilities: 5.1254137e-05 - temperature 7.1944623
# 149/149 [==============================] - 13s 87ms/step - loss: 0.1696 - val_loss: 0.1499
# Epoch 13/200
# mean max of probabilities: 5.1258015e-05 - temperature 6.9822946
# 149/149 [==============================] - 12s 80ms/step - loss: 0.1698 - val_loss: 0.1500
# Epoch 14/200
# mean max of probabilities: 5.1261537e-05 - temperature 6.7763844
# 149/149 [==============================] - 9s 63ms/step - loss: 0.1694 - val_loss: 0.1502
# Epoch 15/200
# mean max of probabilities: 5.1265666e-05 - temperature 6.576546
# 149/149 [==============================] - 11s 77ms/step - loss: 0.1694 - val_loss: 0.1499
# Epoch 16/200
# mean max of probabilities: 5.1272393e-05 - temperature 6.3826013
# 149/149 [==============================] - 11s 75ms/step - loss: 0.1696 - val_loss: 0.1500
# Epoch 17/200
# mean max of probabilities: 5.1280083e-05 - temperature 6.194376
# 149/149 [==============================] - 12s 82ms/step - loss: 0.1697 - val_loss: 0.1502
# Epoch 18/200
# mean max of probabilities: 5.1285868e-05 - temperature 6.0117006
# 149/149 [==============================] - 17s 111ms/step - loss: 0.1693 - val_loss: 0.1495
# Epoch 19/200
# mean max of probabilities: 5.129173e-05 - temperature 5.8344135
# 149/149 [==============================] - 13s 84ms/step - loss: 0.1698 - val_loss: 0.1497
# Epoch 20/200
# mean max of probabilities: 5.1299336e-05 - temperature 5.662354
# 149/149 [==============================] - 16s 105ms/step - loss: 0.1703 - val_loss: 0.1506
# Epoch 21/200
# mean max of probabilities: 5.1309285e-05 - temperature 5.495369
# 149/149 [==============================] - 12s 79ms/step - loss: 0.1698 - val_loss: 0.1499
# Epoch 22/200
# mean max of probabilities: 5.132076e-05 - temperature 5.3333087
# 149/149 [==============================] - 12s 81ms/step - loss: 0.1701 - val_loss: 0.1501
# Epoch 23/200
# mean max of probabilities: 5.1331644e-05 - temperature 5.176028
# 149/149 [==============================] - 14s 97ms/step - loss: 0.1704 - val_loss: 0.1503
# Epoch 24/200
# mean max of probabilities: 5.1339965e-05 - temperature 5.023384
# 149/149 [==============================] - 12s 82ms/step - loss: 0.1700 - val_loss: 0.1504
# Epoch 25/200
# mean max of probabilities: 5.1354124e-05 - temperature 4.8752427
# 149/149 [==============================] - 10s 69ms/step - loss: 0.1701 - val_loss: 0.1506
# Epoch 26/200
# mean max of probabilities: 5.1373205e-05 - temperature 4.73147
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1703 - val_loss: 0.1495
# Epoch 27/200
# mean max of probabilities: 5.1388182e-05 - temperature 4.5919366
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1704 - val_loss: 0.1501
# Epoch 28/200
# mean max of probabilities: 5.14028e-05 - temperature 4.4565187
# 149/149 [==============================] - 16s 108ms/step - loss: 0.1702 - val_loss: 0.1504
# Epoch 29/200
# mean max of probabilities: 5.1421357e-05 - temperature 4.325094
# 149/149 [==============================] - 13s 86ms/step - loss: 0.1706 - val_loss: 0.1499
# Epoch 30/200
# mean max of probabilities: 5.143994e-05 - temperature 4.1975446
# 149/149 [==============================] - 16s 105ms/step - loss: 0.1702 - val_loss: 0.1496
# Epoch 31/200
# mean max of probabilities: 5.1458956e-05 - temperature 4.0737567
# 149/149 [==============================] - 15s 102ms/step - loss: 0.1698 - val_loss: 0.1498
# Epoch 32/200
# mean max of probabilities: 5.1481195e-05 - temperature 3.9536202
# 149/149 [==============================] - 16s 106ms/step - loss: 0.1701 - val_loss: 0.1505
# Epoch 33/200
# mean max of probabilities: 5.150373e-05 - temperature 3.8370266
# 149/149 [==============================] - 16s 109ms/step - loss: 0.1712 - val_loss: 0.1502
# Epoch 34/200
# mean max of probabilities: 5.1528426e-05 - temperature 3.7238712
# 149/149 [==============================] - 18s 124ms/step - loss: 0.1711 - val_loss: 0.1508
# Epoch 35/200
# mean max of probabilities: 5.1558993e-05 - temperature 3.6140528
# 149/149 [==============================] - 30s 204ms/step - loss: 0.1709 - val_loss: 0.1509
# Epoch 36/200
# mean max of probabilities: 5.158475e-05 - temperature 3.5074725
# 149/149 [==============================] - 16s 106ms/step - loss: 0.1713 - val_loss: 0.1509
# Epoch 37/200
# mean max of probabilities: 5.1615072e-05 - temperature 3.4040358
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1710 - val_loss: 0.1503
# Epoch 38/200
# mean max of probabilities: 5.1650826e-05 - temperature 3.3036494
# 149/149 [==============================] - 15s 99ms/step - loss: 0.1711 - val_loss: 0.1505
# Epoch 39/200
# mean max of probabilities: 5.1682408e-05 - temperature 3.2062237
# 149/149 [==============================] - 14s 96ms/step - loss: 0.1715 - val_loss: 0.1506
# Epoch 40/200
# mean max of probabilities: 5.1717092e-05 - temperature 3.1116705
# 149/149 [==============================] - 20s 131ms/step - loss: 0.1704 - val_loss: 0.1501
# Epoch 41/200
# mean max of probabilities: 5.1752235e-05 - temperature 3.0199058
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1698 - val_loss: 0.1496
# Epoch 42/200
# mean max of probabilities: 5.1787043e-05 - temperature 2.9308476
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1702 - val_loss: 0.1500
# Epoch 43/200
# mean max of probabilities: 5.1825198e-05 - temperature 2.8444157
# 149/149 [==============================] - 15s 101ms/step - loss: 0.1720 - val_loss: 0.1502
# Epoch 44/200
# mean max of probabilities: 5.1865245e-05 - temperature 2.7605326
# 149/149 [==============================] - 14s 96ms/step - loss: 0.1753 - val_loss: 0.1511
# Epoch 45/200
# mean max of probabilities: 5.1914387e-05 - temperature 2.6791236
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1713 - val_loss: 0.1512
# Epoch 46/200
# mean max of probabilities: 5.195682e-05 - temperature 2.6001153
# 149/149 [==============================] - 13s 85ms/step - loss: 0.1713 - val_loss: 0.1507
# Epoch 47/200
# mean max of probabilities: 5.201016e-05 - temperature 2.5234365
# 149/149 [==============================] - 14s 97ms/step - loss: 0.1704 - val_loss: 0.1500
# Epoch 48/200
# mean max of probabilities: 5.2065974e-05 - temperature 2.4490192
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1703 - val_loss: 0.1501
# Epoch 49/200
# mean max of probabilities: 5.2115032e-05 - temperature 2.3767967
# 149/149 [==============================] - 20s 135ms/step - loss: 0.1707 - val_loss: 0.1499
# Epoch 50/200
# mean max of probabilities: 5.2167612e-05 - temperature 2.306704
# 149/149 [==============================] - 14s 96ms/step - loss: 0.1710 - val_loss: 0.1499
# Epoch 51/200
# mean max of probabilities: 5.222016e-05 - temperature 2.2386785
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1707 - val_loss: 0.1504
# Epoch 52/200
# mean max of probabilities: 5.228466e-05 - temperature 2.172659
# 149/149 [==============================] - 12s 80ms/step - loss: 0.1703 - val_loss: 0.1501
# Epoch 53/200
# mean max of probabilities: 5.2347335e-05 - temperature 2.108586
# 149/149 [==============================] - 10s 69ms/step - loss: 0.1703 - val_loss: 0.1506
# Epoch 54/200
# mean max of probabilities: 5.2412233e-05 - temperature 2.0464027
# 149/149 [==============================] - 11s 72ms/step - loss: 0.1709 - val_loss: 0.1501
# Epoch 55/200
# mean max of probabilities: 5.247906e-05 - temperature 1.9860538
# 149/149 [==============================] - 12s 80ms/step - loss: 0.1749 - val_loss: 0.1521
# Epoch 56/200
# mean max of probabilities: 5.2552845e-05 - temperature 1.9274842
# 149/149 [==============================] - 11s 75ms/step - loss: 0.1717 - val_loss: 0.1505
# Epoch 57/200
# mean max of probabilities: 5.264025e-05 - temperature 1.8706421
# 149/149 [==============================] - 12s 83ms/step - loss: 0.1724 - val_loss: 0.1503
# Epoch 58/200
# mean max of probabilities: 5.2716874e-05 - temperature 1.8154762
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1725 - val_loss: 0.1506
# Epoch 59/200
# mean max of probabilities: 5.279056e-05 - temperature 1.761937
# 149/149 [==============================] - 17s 115ms/step - loss: 0.1717 - val_loss: 0.1508
# Epoch 60/200
# mean max of probabilities: 5.2876887e-05 - temperature 1.7099768
# 149/149 [==============================] - 16s 105ms/step - loss: 0.1701 - val_loss: 0.1509
# Epoch 61/200
# mean max of probabilities: 5.296168e-05 - temperature 1.659549
# 149/149 [==============================] - 13s 87ms/step - loss: 0.1721 - val_loss: 0.1507
# Epoch 62/200
# mean max of probabilities: 5.3058247e-05 - temperature 1.6106081
# 149/149 [==============================] - 15s 98ms/step - loss: 0.1709 - val_loss: 0.1506
# Epoch 63/200
# mean max of probabilities: 5.3166303e-05 - temperature 1.5631108
# 149/149 [==============================] - 11s 72ms/step - loss: 0.1713 - val_loss: 0.1507
# Epoch 64/200
# mean max of probabilities: 5.326992e-05 - temperature 1.5170141
# 149/149 [==============================] - 12s 81ms/step - loss: 0.1724 - val_loss: 0.1510
# Epoch 65/200
# mean max of probabilities: 5.3349817e-05 - temperature 1.4722769
# 149/149 [==============================] - 11s 72ms/step - loss: 0.1746 - val_loss: 0.1514
# Epoch 66/200
# mean max of probabilities: 5.346868e-05 - temperature 1.4288589
# 149/149 [==============================] - 11s 75ms/step - loss: 0.1743 - val_loss: 0.1517
# Epoch 67/200
# mean max of probabilities: 5.3565032e-05 - temperature 1.3867214
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1737 - val_loss: 0.1506
# Epoch 68/200
# mean max of probabilities: 5.367329e-05 - temperature 1.3458263
# 149/149 [==============================] - 10s 65ms/step - loss: 0.1734 - val_loss: 0.1520
# Epoch 69/200
# mean max of probabilities: 5.3775937e-05 - temperature 1.3061373
# 149/149 [==============================] - 13s 85ms/step - loss: 0.1709 - val_loss: 0.1527
# Epoch 70/200
# mean max of probabilities: 5.3885553e-05 - temperature 1.267619
# 149/149 [==============================] - 15s 101ms/step - loss: 0.1730 - val_loss: 0.1515
# Epoch 71/200
# mean max of probabilities: 5.4008633e-05 - temperature 1.2302365
# 149/149 [==============================] - 25s 169ms/step - loss: 0.1728 - val_loss: 0.1511
# Epoch 72/200
# mean max of probabilities: 5.4142947e-05 - temperature 1.1939563
#  48/149 [========>.....................] - ETA: 17s - loss: 0.2103
# /usr/local/lib/python3.7/site-packages/keras/callbacks/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.148305). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 149/149 [==============================] - 17s 115ms/step - loss: 0.1768 - val_loss: 0.1546
# Epoch 73/200
# mean max of probabilities: 5.4230848e-05 - temperature 1.158746
# 149/149 [==============================] - 9s 60ms/step - loss: 0.1804 - val_loss: 0.1548
# Epoch 74/200
# mean max of probabilities: 5.4331787e-05 - temperature 1.1245742
# 149/149 [==============================] - 8s 55ms/step - loss: 0.1854 - val_loss: 0.1561
# Epoch 75/200
# mean max of probabilities: 5.4420278e-05 - temperature 1.09141
# 149/149 [==============================] - 9s 62ms/step - loss: 0.1772 - val_loss: 0.1561
# Epoch 76/200
# mean max of probabilities: 5.450476e-05 - temperature 1.0592241
# 149/149 [==============================] - 10s 70ms/step - loss: 0.1784 - val_loss: 0.1551
# Epoch 77/200
# mean max of probabilities: 5.4611228e-05 - temperature 1.0279874
# 149/149 [==============================] - 10s 65ms/step - loss: 0.1777 - val_loss: 0.1540
# Epoch 78/200
# mean max of probabilities: 5.471002e-05 - temperature 0.9976718
# 149/149 [==============================] - 11s 74ms/step - loss: 0.1796 - val_loss: 0.1560
# Epoch 79/200
# mean max of probabilities: 5.4846518e-05 - temperature 0.96825004
# 149/149 [==============================] - 12s 81ms/step - loss: 0.1793 - val_loss: 0.1644
# Epoch 80/200
# mean max of probabilities: 5.4955635e-05 - temperature 0.939696
# 149/149 [==============================] - 15s 101ms/step - loss: 0.1792 - val_loss: 0.1542
# Epoch 81/200
# mean max of probabilities: 5.505831e-05 - temperature 0.911984
# 149/149 [==============================] - 10s 70ms/step - loss: 0.1794 - val_loss: 0.1599
# Epoch 82/200
# mean max of probabilities: 5.518424e-05 - temperature 0.8850892
# 149/149 [==============================] - 11s 73ms/step - loss: 0.1852 - val_loss: 0.1618
# Epoch 83/200
# mean max of probabilities: 5.5297995e-05 - temperature 0.85898757
# 149/149 [==============================] - 12s 81ms/step - loss: 0.1805 - val_loss: 0.1648
# Epoch 84/200
# mean max of probabilities: 5.5385502e-05 - temperature 0.83365566
# 149/149 [==============================] - 18s 122ms/step - loss: 0.1856 - val_loss: 0.1629
# Epoch 85/200
# mean max of probabilities: 5.54722e-05 - temperature 0.8090709
# 149/149 [==============================] - 13s 87ms/step - loss: 0.1947 - val_loss: 0.1729
# Epoch 86/200
# mean max of probabilities: 5.553712e-05 - temperature 0.7852111
# 149/149 [==============================] - 12s 80ms/step - loss: 0.1910 - val_loss: 0.1618
# Epoch 87/200
# mean max of probabilities: 5.5623306e-05 - temperature 0.762055
# 149/149 [==============================] - 11s 71ms/step - loss: 0.1936 - val_loss: 0.1749
# Epoch 88/200
# mean max of probabilities: 5.568147e-05 - temperature 0.7395817
# 149/149 [==============================] - 11s 75ms/step - loss: 0.1999 - val_loss: 0.1770
# Epoch 89/200
# mean max of probabilities: 5.574984e-05 - temperature 0.7177711
# 149/149 [==============================] - 9s 62ms/step - loss: 0.1998 - val_loss: 0.1659
# Epoch 90/200
# mean max of probabilities: 5.5848992e-05 - temperature 0.69660366
# 149/149 [==============================] - 9s 63ms/step - loss: 0.1936 - val_loss: 0.1763
# Epoch 91/200
# mean max of probabilities: 5.5942106e-05 - temperature 0.67606056
# 149/149 [==============================] - 10s 66ms/step - loss: 0.1956 - val_loss: 0.1881
# Epoch 92/200
# mean max of probabilities: 5.6007106e-05 - temperature 0.6561233
# 149/149 [==============================] - 12s 79ms/step - loss: 0.2160 - val_loss: 0.1719
# Epoch 93/200
# mean max of probabilities: 5.6090117e-05 - temperature 0.63677377
# 149/149 [==============================] - 10s 67ms/step - loss: 0.1912 - val_loss: 0.1799
# Epoch 94/200
# mean max of probabilities: 5.615395e-05 - temperature 0.617995
# 149/149 [==============================] - 11s 73ms/step - loss: 0.2207 - val_loss: 0.1946
# Epoch 95/200
# mean max of probabilities: 5.620806e-05 - temperature 0.5997701
# 149/149 [==============================] - 11s 76ms/step - loss: 0.1958 - val_loss: 0.1723
# Epoch 96/200
# mean max of probabilities: 5.62608e-05 - temperature 0.5820826
# 149/149 [==============================] - 14s 97ms/step - loss: 0.2041 - val_loss: 0.1806
# Epoch 97/200
# mean max of probabilities: 5.6301924e-05 - temperature 0.5649167
# 149/149 [==============================] - 11s 73ms/step - loss: 0.2006 - val_loss: 0.1724
# Epoch 98/200
# mean max of probabilities: 5.6356606e-05 - temperature 0.5482572
# 149/149 [==============================] - 13s 88ms/step - loss: 0.2060 - val_loss: 0.1728
# Epoch 99/200
# mean max of probabilities: 5.6392313e-05 - temperature 0.53208894
# 149/149 [==============================] - 11s 73ms/step - loss: 0.2007 - val_loss: 0.1766
# Epoch 100/200
# mean max of probabilities: 5.642535e-05 - temperature 0.51639754
# 149/149 [==============================] - 12s 84ms/step - loss: 0.1975 - val_loss: 0.1726
# Epoch 101/200
# mean max of probabilities: 5.6459096e-05 - temperature 0.50116867
# 149/149 [==============================] - 12s 78ms/step - loss: 0.2073 - val_loss: 0.2099
# Epoch 102/200
# mean max of probabilities: 5.64935e-05 - temperature 0.48638898
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1933 - val_loss: 0.2505
# Epoch 103/200
# mean max of probabilities: 5.6520636e-05 - temperature 0.47204518
# 149/149 [==============================] - 11s 74ms/step - loss: 0.2133 - val_loss: 0.1858
# Epoch 104/200
# mean max of probabilities: 5.6527184e-05 - temperature 0.45812437
# 149/149 [==============================] - 11s 73ms/step - loss: 0.2212 - val_loss: 0.1668
# Epoch 105/200
# mean max of probabilities: 5.6559325e-05 - temperature 0.4446141
# 149/149 [==============================] - 12s 83ms/step - loss: 0.2295 - val_loss: 0.2147
# Epoch 106/200
# mean max of probabilities: 5.657584e-05 - temperature 0.43150225
# 149/149 [==============================] - 11s 76ms/step - loss: 0.2615 - val_loss: 0.2690
# Epoch 107/200
# mean max of probabilities: 5.6595767e-05 - temperature 0.41877705
# 144/149 [===========================>..] - ETA: 0s - loss: 0.2285
