# %%
import numpy as np
import pandas as pd
import os

# %%
fold_path=['1_LS_CV','2_SPEC_CV','3_NDFS_CV','4_AEFS_CV','5_UDFS_CV','6_MCFS_CV','7_PFA_CV','8_InfFS_CV','9_AgnoSS_CV','10_CAE_CV','11_FAE_50_CV','12_FAE_36_CV']

# %%
cv_times_from=0
cv_times_to=5

# %%
file_path="/log/"

for fold_path_i in fold_path:
    fold_name=fold_path_i.split('_')[1]
    print(fold_name+":\n")
    
    if fold_path_i in ['11_FAE_50_CV','12_FAE_36_CV']:
        print("Do not use bias!",fold_path_i)
        p_is_use_bias=False
        path_results='./'+fold_path_i+file_path+"FAE_results_bias_"+str(p_is_use_bias)+".csv" 
        results_analysis=np.array(pd.read_csv(path_results,header=None))
        results_analysis_test_acc__=results_analysis[:,3]
        results_analysis_test_acc_=results_analysis_test_acc__[np.where(results_analysis[:,3]>=0)]
        cv_cal_times=len(results_analysis_test_acc__)
        if cv_cal_times >=(cv_times_to-cv_times_from):
        
            print("cv times: ",cv_cal_times)
        
            results_analysis_test_acc=results_analysis_test_acc_[cv_times_from:cv_times_to]
            results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]
        
            print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
            print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

            path_time='./'+fold_path_i+file_path+"FAE_time_bias_"+str(p_is_use_bias)+".csv"
            time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
            print("Calculation times: ", len(results_analysis_test_acc))  
        
            print("Use bias!",fold_path_i)
            p_is_use_bias=True
            path_results='./'+fold_path_i+file_path+"FAE_results_bias_"+str(p_is_use_bias)+".csv"  
            results_analysis=np.array(pd.read_csv(path_results,header=None))
            results_analysis_test_acc=results_analysis[:,3][np.where(results_analysis[:,3]>=0)][cv_times_from:cv_times_to]
            results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]
            
            print(results_analysis_test_acc)
            print(results_analysis_linear_rec)
            print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
            print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

            path_time='./'+fold_path_i+file_path+"FAE_time_bias_"+str(p_is_use_bias)+".csv"
            time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
            print("Calculation times: ", len(results_analysis_test_acc))          
    
    else:
        path_results='./'+fold_path_i+file_path+fold_name+'_results.csv'
        
        if os.path.exists(path_results):
            results_analysis=np.array(pd.read_csv(path_results,header=None))

            results_analysis_test_acc__=results_analysis[:,3]
            results_analysis_test_acc_=results_analysis_test_acc__[np.where(results_analysis[:,3]>=0)]
            cv_cal_times=len(results_analysis_test_acc__)
                
            cv_cal_times=len(results_analysis_test_acc_)
            if cv_cal_times>=(cv_times_to-cv_times_from):

                print("cv times: ",cv_cal_times)        
                
                results_analysis_test_acc=results_analysis_test_acc_[cv_times_from:cv_times_to]
                results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]

                print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
                print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

                path_time='./'+fold_path_i+file_path+fold_path_i.split('_')[1]+'_time.csv'
                time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
                print("Calculation times: ", len(results_analysis_test_acc))
    
                print("\n\n")
        else:
            print("Nan")
            print("\n\n")
# Out:
# LS:
#
# cv times:  50
# Testing accuarcy:0.342 ±0.0481
# Testing Linear reconstruction: 2.986 ±0.7332
# Calculation times:  5
#
#
#
# SPEC:
#
# cv times:  15
# Testing accuarcy:0.362 ±0.0692
# Testing Linear reconstruction: 1.275 ±0.1552
# Calculation times:  5
#
#
#
# NDFS:
#
# cv times:  7
# Testing accuarcy:0.106 ±0.0183
# Testing Linear reconstruction: 1.072 ±0.0786
# Calculation times:  5
#
#
#
# AEFS:
#
# cv times:  50
# Testing accuarcy:0.949 ±0.0069
# Testing Linear reconstruction: 0.027 ±0.0028
# Calculation times:  5
#
#
#
# UDFS:
#
# cv times:  9
# Testing accuarcy:0.945 ±0.0034
# Testing Linear reconstruction: 0.032 ±0.0016
# Calculation times:  5
#
#
#
# MCFS:
#
# cv times:  50
# Testing accuarcy:0.123 ±0.0335
# Testing Linear reconstruction: 1.065 ±0.0740
# Calculation times:  5
#
#
#
# PFA:
#
# cv times:  50
# Testing accuarcy:0.957 ±0.0030
# Testing Linear reconstruction: 0.018 ±0.0021
# Calculation times:  5
#
#
#
# InfFS:
#
# cv times:  50
# Testing accuarcy:0.182 ±0.0423
# Testing Linear reconstruction: 4.048 ±0.6308
# Calculation times:  5
#
#
#
# AgnoSS:
#
# cv times:  50
# Testing accuarcy:0.956 ±0.0035
# Testing Linear reconstruction: 0.017 ±0.0028
# Calculation times:  5
#
#
#
# CAE:
#
# cv times:  29
# Testing accuarcy:0.962 ±0.0039
# Testing Linear reconstruction: 0.012 ±0.0007
# Calculation times:  5
#
#
#
# FAE:
#
# Do not use bias! 11_FAE_50_CV
# cv times:  50
# Testing accuarcy:0.962 ±0.0026
# Testing Linear reconstruction: 0.011 ±0.0004
# Calculation times:  5
# Use bias! 11_FAE_50_CV
# [0.96182796 0.96397849 0.96236559 0.96075269 0.9655914 ]
# [0.01053051 0.01144611 0.01183389 0.01085835 0.01059196]
# Testing accuarcy:0.963 ±0.0017
# Testing Linear reconstruction: 0.011 ±0.0005
# Calculation times:  5
# FAE:
#
# Do not use bias! 12_FAE_36_CV
# cv times:  50
# Testing accuarcy:0.959 ±0.0014
# Testing Linear reconstruction: 0.023 ±0.0006
# Calculation times:  5
# Use bias! 12_FAE_36_CV
# [0.95806452 0.96397849 0.96451613 0.95752688 0.9655914 ]
# [0.01993529 0.02263295 0.02240799 0.02028994 0.01994634]
# Testing accuarcy:0.962 ±0.0034
# Testing Linear reconstruction: 0.021 ±0.0012
# Calculation times:  5
