# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
import scipy.sparse as sparse
import scipy.io

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
data_path="../Dataset/GLIOMA.mat"
Data = scipy.io.loadmat(data_path)

data_arr_=Data['X']
label_arr=Data['Y'][:, 0]

data_arr=MinMaxScaler(feature_range=(0,1)).fit_transform(data_arr_)

label_arr_onehot=label_arr

# %%
key_feture_number=64

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,50):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 4434)              0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                283777
# _________________________________________________________________
# dense_1 (Dense)              (None, 4434)              288210
# =================================================================
# Total params: 571,987
# Trainable params: 571,986
# Non-trainable params: 1
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 40 samples, validate on 10 samples
# Epoch 1/200
# mean max of probabilities: 0.00023653207 - temperature 10.0
# 40/40 [==============================] - 1s 13ms/step - loss: 0.2444 - val_loss: 0.1905
# Epoch 2/200
# mean max of probabilities: 0.0002365321 - temperature 9.697654
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1853 - val_loss: 0.1425
# Epoch 3/200
# mean max of probabilities: 0.00023653224 - temperature 9.4044485
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1386 - val_loss: 0.1046
# Epoch 4/200
# mean max of probabilities: 0.00023653303 - temperature 9.120109
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1012 - val_loss: 0.0777
# Epoch 5/200
# mean max of probabilities: 0.00023653539 - temperature 8.844365
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0759 - val_loss: 0.0602
# Epoch 6/200
# mean max of probabilities: 0.00023653891 - temperature 8.576959
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0586 - val_loss: 0.0502
# Epoch 7/200
# mean max of probabilities: 0.00023654336 - temperature 8.317637
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0493 - val_loss: 0.0453
# Epoch 8/200
# mean max of probabilities: 0.0002365484 - temperature 8.066157
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0449 - val_loss: 0.0434
# Epoch 9/200
# mean max of probabilities: 0.00023655288 - temperature 7.8222795
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0437 - val_loss: 0.0429
# Epoch 10/200
# mean max of probabilities: 0.0002365563 - temperature 7.585776
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0433 - val_loss: 0.0429
# Epoch 11/200
# mean max of probabilities: 0.00023655762 - temperature 7.356423
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0435 - val_loss: 0.0429
# Epoch 12/200
# mean max of probabilities: 0.00023655678 - temperature 7.134004
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0435 - val_loss: 0.0427
# Epoch 13/200
# mean max of probabilities: 0.00023655416 - temperature 6.91831
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0432 - val_loss: 0.0423
# Epoch 14/200
# mean max of probabilities: 0.00023655038 - temperature 6.7091374
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0427 - val_loss: 0.0417
# Epoch 15/200
# mean max of probabilities: 0.00023654595 - temperature 6.5062885
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0421 - val_loss: 0.0412
# Epoch 16/200
# mean max of probabilities: 0.0002365419 - temperature 6.309573
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0416 - val_loss: 0.0407
# Epoch 17/200
# mean max of probabilities: 0.00023653878 - temperature 6.1188054
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0412 - val_loss: 0.0404
# Epoch 18/200
# mean max of probabilities: 0.00023653673 - temperature 5.9338055
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0410 - val_loss: 0.0401
# Epoch 19/200
# mean max of probabilities: 0.00023653536 - temperature 5.754399
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0407 - val_loss: 0.0400
# Epoch 20/200
# mean max of probabilities: 0.00023653504 - temperature 5.5804167
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0406 - val_loss: 0.0400
# Epoch 21/200
# mean max of probabilities: 0.00023653507 - temperature 5.4116945
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0406 - val_loss: 0.0399
# Epoch 22/200
# mean max of probabilities: 0.00023653527 - temperature 5.248074
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0405 - val_loss: 0.0400
# Epoch 23/200
# mean max of probabilities: 0.00023653555 - temperature 5.089401
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0405 - val_loss: 0.0401
# Epoch 24/200
# mean max of probabilities: 0.00023653582 - temperature 4.9355245
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0405 - val_loss: 0.0402
# Epoch 25/200
# mean max of probabilities: 0.00023653617 - temperature 4.7863007
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0405 - val_loss: 0.0402
# Epoch 26/200
# mean max of probabilities: 0.00023653657 - temperature 4.641588
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0404 - val_loss: 0.0401
# Epoch 27/200
# mean max of probabilities: 0.00023653713 - temperature 4.5012517
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0404 - val_loss: 0.0400
# Epoch 28/200
# mean max of probabilities: 0.00023653771 - temperature 4.365158
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0403 - val_loss: 0.0400
# Epoch 29/200
# mean max of probabilities: 0.00023653841 - temperature 4.233179
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0403 - val_loss: 0.0399
# Epoch 30/200
# mean max of probabilities: 0.0002365392 - temperature 4.105191
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0404 - val_loss: 0.0399
# Epoch 31/200
# mean max of probabilities: 0.00023654 - temperature 3.9810724
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 32/200
# mean max of probabilities: 0.00023654081 - temperature 3.860706
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 33/200
# mean max of probabilities: 0.0002365417 - temperature 3.743979
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 34/200
# mean max of probabilities: 0.00023654269 - temperature 3.6307807
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 35/200
# mean max of probabilities: 0.00023654378 - temperature 3.5210054
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 36/200
# mean max of probabilities: 0.00023654493 - temperature 3.4145489
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 37/200
# mean max of probabilities: 0.00023654616 - temperature 3.3113112
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 38/200
# mean max of probabilities: 0.00023654771 - temperature 3.211195
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 39/200
# mean max of probabilities: 0.00023654962 - temperature 3.1141057
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 40/200
# mean max of probabilities: 0.00023655167 - temperature 3.0199518
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 41/200
# mean max of probabilities: 0.0002365541 - temperature 2.9286447
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 42/200
# mean max of probabilities: 0.00023655694 - temperature 2.8400981
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0403 - val_loss: 0.0398
# Epoch 43/200
# mean max of probabilities: 0.00023656004 - temperature 2.7542288
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 44/200
# mean max of probabilities: 0.00023656336 - temperature 2.6709554
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0402 - val_loss: 0.0399
# Epoch 45/200
# mean max of probabilities: 0.00023656736 - temperature 2.5901997
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0402 - val_loss: 0.0398
# Epoch 46/200
# mean max of probabilities: 0.00023657139 - temperature 2.511886
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0402 - val_loss: 0.0397
# Epoch 47/200
# mean max of probabilities: 0.0002365756 - temperature 2.43594
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0397
# Epoch 48/200
# mean max of probabilities: 0.00023657986 - temperature 2.3622901
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0401 - val_loss: 0.0397
# Epoch 49/200
# mean max of probabilities: 0.00023658447 - temperature 2.290867
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0396
# Epoch 50/200
# mean max of probabilities: 0.00023658921 - temperature 2.2216036
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0396
# Epoch 51/200
# mean max of probabilities: 0.00023659434 - temperature 2.1544344
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0397
# Epoch 52/200
# mean max of probabilities: 0.00023659959 - temperature 2.0892959
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0398
# Epoch 53/200
# mean max of probabilities: 0.00023660553 - temperature 2.0261269
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0401 - val_loss: 0.0399
# Epoch 54/200
# mean max of probabilities: 0.00023661183 - temperature 1.9648677
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0399
# Epoch 55/200
# mean max of probabilities: 0.00023661825 - temperature 1.9054606
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0400
# Epoch 56/200
# mean max of probabilities: 0.00023662488 - temperature 1.8478497
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0400
# Epoch 57/200
# mean max of probabilities: 0.00023663214 - temperature 1.7919806
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0401 - val_loss: 0.0401
# Epoch 58/200
# mean max of probabilities: 0.00023664293 - temperature 1.7378007
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0401 - val_loss: 0.0400
# Epoch 59/200
# mean max of probabilities: 0.00023665336 - temperature 1.6852589
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0400 - val_loss: 0.0398
# Epoch 60/200
# mean max of probabilities: 0.00023666321 - temperature 1.6343056
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0400 - val_loss: 0.0396
# Epoch 61/200
# mean max of probabilities: 0.00023667462 - temperature 1.584893
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0400 - val_loss: 0.0397
# Epoch 62/200
# mean max of probabilities: 0.00023668629 - temperature 1.5369743
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0396
# Epoch 63/200
# mean max of probabilities: 0.00023669985 - temperature 1.4905044
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0401 - val_loss: 0.0396
# Epoch 64/200
# mean max of probabilities: 0.00023671416 - temperature 1.4454395
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0400 - val_loss: 0.0397
# Epoch 65/200
# mean max of probabilities: 0.0002367289 - temperature 1.4017372
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0400 - val_loss: 0.0398
# Epoch 66/200
# mean max of probabilities: 0.00023674284 - temperature 1.3593562
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0400 - val_loss: 0.0399
# Epoch 67/200
# mean max of probabilities: 0.00023675631 - temperature 1.3182566
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0400 - val_loss: 0.0400
# Epoch 68/200
# mean max of probabilities: 0.0002367695 - temperature 1.2783996
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0400 - val_loss: 0.0398
# Epoch 69/200
# mean max of probabilities: 0.00023678233 - temperature 1.2397475
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0400 - val_loss: 0.0399
# Epoch 70/200
# mean max of probabilities: 0.00023679681 - temperature 1.2022641
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0401 - val_loss: 0.0401
# Epoch 71/200
# mean max of probabilities: 0.0002368143 - temperature 1.165914
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0400 - val_loss: 0.0400
# Epoch 72/200
# mean max of probabilities: 0.00023683388 - temperature 1.130663
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0402 - val_loss: 0.0400
# Epoch 73/200
# mean max of probabilities: 0.00023685851 - temperature 1.0964779
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0401 - val_loss: 0.0401
# Epoch 74/200
# mean max of probabilities: 0.00023688175 - temperature 1.0633262
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0401 - val_loss: 0.0399
# Epoch 75/200
# mean max of probabilities: 0.00023691279 - temperature 1.0311769
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0399
# Epoch 76/200
# mean max of probabilities: 0.0002369539 - temperature 0.9999997
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0401 - val_loss: 0.0399
# Epoch 77/200
# mean max of probabilities: 0.00023699977 - temperature 0.96976507
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0403 - val_loss: 0.0400
# Epoch 78/200
# mean max of probabilities: 0.00023704598 - temperature 0.9404445
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0401 - val_loss: 0.0400
# Epoch 79/200
# mean max of probabilities: 0.00023709473 - temperature 0.91201055
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0399
# Epoch 80/200
# mean max of probabilities: 0.00023714133 - temperature 0.88443625
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0401
# Epoch 81/200
# mean max of probabilities: 0.0002371865 - temperature 0.85769564
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0404 - val_loss: 0.0401
# Epoch 82/200
# mean max of probabilities: 0.0002372328 - temperature 0.8317635
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0404 - val_loss: 0.0401
# Epoch 83/200
# mean max of probabilities: 0.00023728074 - temperature 0.8066155
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0405 - val_loss: 0.0403
# Epoch 84/200
# mean max of probabilities: 0.00023733082 - temperature 0.78222775
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0403 - val_loss: 0.0406
# Epoch 85/200
# mean max of probabilities: 0.0002374004 - temperature 0.75857735
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0405 - val_loss: 0.0404
# Epoch 86/200
# mean max of probabilities: 0.00023747816 - temperature 0.735642
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0408 - val_loss: 0.0403
# Epoch 87/200
# mean max of probabilities: 0.00023756175 - temperature 0.7134002
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0407 - val_loss: 0.0407
# Epoch 88/200
# mean max of probabilities: 0.00023764145 - temperature 0.69183075
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0407 - val_loss: 0.0407
# Epoch 89/200
# mean max of probabilities: 0.00023773331 - temperature 0.6709135
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0407 - val_loss: 0.0409
# Epoch 90/200
# mean max of probabilities: 0.00023782955 - temperature 0.6506286
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0409 - val_loss: 0.0405
# Epoch 91/200
# mean max of probabilities: 0.00023793038 - temperature 0.63095707
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0407 - val_loss: 0.0417
# Epoch 92/200
# mean max of probabilities: 0.00023803391 - temperature 0.61188036
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0408 - val_loss: 0.0408
# Epoch 93/200
# mean max of probabilities: 0.00023813349 - temperature 0.59338033
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0408 - val_loss: 0.0406
# Epoch 94/200
# mean max of probabilities: 0.00023821201 - temperature 0.5754397
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0411 - val_loss: 0.0405
# Epoch 95/200
# mean max of probabilities: 0.00023827495 - temperature 0.5580415
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0410 - val_loss: 0.0421
# Epoch 96/200
# mean max of probabilities: 0.00023833741 - temperature 0.54116935
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0410 - val_loss: 0.0402
# Epoch 97/200
# mean max of probabilities: 0.00023840333 - temperature 0.5248073
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0412 - val_loss: 0.0404
# Epoch 98/200
# mean max of probabilities: 0.00023847638 - temperature 0.5089399
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0413 - val_loss: 0.0404
# Epoch 99/200
# mean max of probabilities: 0.00023853852 - temperature 0.49355233
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0412 - val_loss: 0.0407
# Epoch 100/200
# mean max of probabilities: 0.00023858913 - temperature 0.47862992
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0414 - val_loss: 0.0410
# Epoch 101/200
# mean max of probabilities: 0.00023863386 - temperature 0.4641587
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0412 - val_loss: 0.0408
# Epoch 102/200
# mean max of probabilities: 0.00023867286 - temperature 0.45012504
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0409 - val_loss: 0.0415
# Epoch 103/200
# mean max of probabilities: 0.00023871812 - temperature 0.4365157
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0412 - val_loss: 0.0410
# Epoch 104/200
# mean max of probabilities: 0.00023878107 - temperature 0.42331776
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0411 - val_loss: 0.0415
# Epoch 105/200
# mean max of probabilities: 0.00023884822 - temperature 0.4105189
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0413 - val_loss: 0.0408
# Epoch 106/200
# mean max of probabilities: 0.00023892317 - temperature 0.39810702
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0410 - val_loss: 0.0408
# Epoch 107/200
# mean max of probabilities: 0.0002389985 - temperature 0.3860704
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0410 - val_loss: 0.0411
# Epoch 108/200
# mean max of probabilities: 0.00023906078 - temperature 0.3743977
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0416 - val_loss: 0.0411
# Epoch 109/200
# mean max of probabilities: 0.0002391155 - temperature 0.3630779
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0416 - val_loss: 0.0408
# Epoch 110/200
# mean max of probabilities: 0.0002391754 - temperature 0.35210037
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0413 - val_loss: 0.0421
# Epoch 111/200
# mean max of probabilities: 0.00023922889 - temperature 0.3414547
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0412 - val_loss: 0.0429
# Epoch 112/200
# mean max of probabilities: 0.00023926943 - temperature 0.33113092
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0424 - val_loss: 0.0413
# Epoch 113/200
# mean max of probabilities: 0.00023929952 - temperature 0.3211193
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0424 - val_loss: 0.0412
# Epoch 114/200
# mean max of probabilities: 0.0002393281 - temperature 0.3114104
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0415 - val_loss: 0.0420
# Epoch 115/200
# mean max of probabilities: 0.00023937903 - temperature 0.30199498
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0412 - val_loss: 0.0416
# Epoch 116/200
# mean max of probabilities: 0.00023944919 - temperature 0.29286426
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0419 - val_loss: 0.0419
# Epoch 117/200
# mean max of probabilities: 0.0002395084 - temperature 0.28400964
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0414 - val_loss: 0.0411
# Epoch 118/200
# mean max of probabilities: 0.00023957068 - temperature 0.2754227
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0412 - val_loss: 0.0417
# Epoch 119/200
# mean max of probabilities: 0.00023962774 - temperature 0.2670954
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0415 - val_loss: 0.0415
# Epoch 120/200
# mean max of probabilities: 0.00023967368 - temperature 0.25901985
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0413 - val_loss: 0.0412
# Epoch 121/200
# mean max of probabilities: 0.00023971271 - temperature 0.2511885
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0421 - val_loss: 0.0412
# Epoch 122/200
# mean max of probabilities: 0.00023975212 - temperature 0.2435939
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0420 - val_loss: 0.0422
# Epoch 123/200
# mean max of probabilities: 0.00023979139 - temperature 0.23622893
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0415 - val_loss: 0.0409
# Epoch 124/200
# mean max of probabilities: 0.00023982744 - temperature 0.22908662
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0410 - val_loss: 0.0406
# Epoch 125/200
# mean max of probabilities: 0.00023985622 - temperature 0.22216026
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0417 - val_loss: 0.0410
# Epoch 126/200
# mean max of probabilities: 0.00023988281 - temperature 0.21544333
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0422 - val_loss: 0.0410
# Epoch 127/200
# mean max of probabilities: 0.00023990966 - temperature 0.20892948
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0410 - val_loss: 0.0413
# Epoch 128/200
# mean max of probabilities: 0.00023993899 - temperature 0.20261258
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0413 - val_loss: 0.0417
# Epoch 129/200
# mean max of probabilities: 0.00023996382 - temperature 0.19648667
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0421 - val_loss: 0.0412
# Epoch 130/200
# mean max of probabilities: 0.00024000567 - temperature 0.19054596
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0414 - val_loss: 0.0408
# Epoch 131/200
# mean max of probabilities: 0.00024003917 - temperature 0.18478487
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0413 - val_loss: 0.0417
# Epoch 132/200
# mean max of probabilities: 0.0002400704 - temperature 0.17919797
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0417 - val_loss: 0.0411
# Epoch 133/200
# mean max of probabilities: 0.00024010116 - temperature 0.17377998
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0416 - val_loss: 0.0414
# Epoch 134/200
# mean max of probabilities: 0.00024013213 - temperature 0.1685258
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0412 - val_loss: 0.0406
# Epoch 135/200
# mean max of probabilities: 0.00024015788 - temperature 0.16343047
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0411 - val_loss: 0.0423
# Epoch 136/200
# mean max of probabilities: 0.00024017671 - temperature 0.15848921
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0415 - val_loss: 0.0416
# Epoch 137/200
# mean max of probabilities: 0.00024019367 - temperature 0.15369736
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0413 - val_loss: 0.0417
# Epoch 138/200
# mean max of probabilities: 0.00024021257 - temperature 0.14905038
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0416 - val_loss: 0.0407
# Epoch 139/200
# mean max of probabilities: 0.0002402331 - temperature 0.1445439
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0416 - val_loss: 0.0428
# Epoch 140/200
# mean max of probabilities: 0.00024026241 - temperature 0.14017366
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0412 - val_loss: 0.0412
# Epoch 141/200
# mean max of probabilities: 0.00024030429 - temperature 0.13593556
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0413 - val_loss: 0.0411
# Epoch 142/200
# mean max of probabilities: 0.00024034845 - temperature 0.1318256
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0415 - val_loss: 0.0417
# Epoch 143/200
# mean max of probabilities: 0.00024038489 - temperature 0.1278399
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0417 - val_loss: 0.0409
# Epoch 144/200
# mean max of probabilities: 0.00024041164 - temperature 0.123974696
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0413 - val_loss: 0.0413
# Epoch 145/200
# mean max of probabilities: 0.00024043178 - temperature 0.12022636
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0418 - val_loss: 0.0411
# Epoch 146/200
# mean max of probabilities: 0.00024045 - temperature 0.11659136
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0408 - val_loss: 0.0413
# Epoch 147/200
# mean max of probabilities: 0.00024048047 - temperature 0.11306626
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0414 - val_loss: 0.0416
# Epoch 148/200
# mean max of probabilities: 0.00024051347 - temperature 0.10964775
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0415 - val_loss: 0.0409
# Epoch 149/200
# mean max of probabilities: 0.00024054485 - temperature 0.10633259
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0412 - val_loss: 0.0408
# Epoch 150/200
# mean max of probabilities: 0.00024057571 - temperature 0.10311767
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0417 - val_loss: 0.0418
# Epoch 151/200
# mean max of probabilities: 0.00024060991 - temperature 0.1
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0413 - val_loss: 0.0403
# Epoch 152/200
# mean max of probabilities: 0.000240637 - temperature 0.1
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0421 - val_loss: 0.0424
# Epoch 153/200
# mean max of probabilities: 0.00024065908 - temperature 0.1
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0413 - val_loss: 0.0415
# Epoch 154/200
# mean max of probabilities: 0.00024068065 - temperature 0.1
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0411 - val_loss: 0.0413
# Epoch 155/200
# mean max of probabilities: 0.00024069849 - temperature 0.1
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0422 - val_loss: 0.0414
# Epoch 156/200
# mean max of probabilities: 0.000240717 - temperature 0.1
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0413 - val_loss: 0.0413
# Epoch 157/200
# mean max of probabilities: 0.00024073421 - temperature 0.1
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0409 - val_loss: 0.0407
# Epoch 158/200
# mean max of probabilities: 0.00024075629 - temperature 0.1
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0408 - val_loss: 0.0417
# Epoch 159/200
# mean max of probabilities: 0.00024078047 - temperature 0.1
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0422 - val_loss: 0.0412
# Epoch 160/200
# mean max of probabilities: 0.00024079942 - temperature 0.1
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0408 - val_loss: 0.0424
# Epoch 161/200
# mean max of probabilities: 0.00024081662 - temperature 0.1
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0406 - val_loss: 0.0418
# Epoch 162/200
# mean max of probabilities: 0.00024084828 - temperature 0.1
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0416 - val_loss: 0.0429
# Epoch 163/200
# mean max of probabilities: 0.00024087518 - temperature 0.1
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0413 - val_loss: 0.0410
# Epoch 164/200
# mean max of probabilities: 0.00024089884 - temperature 0.1
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0411 - val_loss: 0.0411
# Epoch 165/200
# mean max of probabilities: 0.00024092093 - temperature 0.1
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0415 - val_loss: 0.0414
# Epoch 166/200
# mean max of probabilities: 0.00024093702 - temperature 0.1
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0406 - val_loss: 0.0401
# Epoch 167/200
# mean max of probabilities: 0.0002409543 - temperature 0.1
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0405 - val_loss: 0.0405
# Epoch 168/200
# mean max of probabilities: 0.00024098225 - temperature 0.1
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0410 - val_loss: 0.0408
# Epoch 169/200
# mean max of probabilities: 0.00024102353 - temperature 0.1
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0420 - val_loss: 0.0409
# Epoch 170/200
# mean max of probabilities: 0.00024107393 - temperature 0.1
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0407 - val_loss: 0.0403
# Epoch 171/200
# mean max of probabilities: 0.00024111339 - temperature 0.1
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0407 - val_loss: 0.0410
# Epoch 172/200
# mean max of probabilities: 0.00024114217 - temperature 0.1
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0407 - val_loss: 0.0415
# Epoch 173/200
# mean max of probabilities: 0.00024116319 - temperature 0.1
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0411 - val_loss: 0.0411
# Epoch 174/200
# mean max of probabilities: 0.00024118193 - temperature 0.1
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0414 - val_loss: 0.0405
# Epoch 175/200
# mean max of probabilities: 0.00024120178 - temperature 0.1
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0413 - val_loss: 0.0404
# Epoch 176/200
# mean max of probabilities: 0.00024122914 - temperature 0.1
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0413 - val_loss: 0.0417
# Epoch 177/200
# mean max of probabilities: 0.00024125815 - temperature 0.1
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0416 - val_loss: 0.0403
# Epoch 178/200
# mean max of probabilities: 0.0002412907 - temperature 0.1
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0416 - val_loss: 0.0404
# Epoch 179/200
# mean max of probabilities: 0.0002413197 - temperature 0.1
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0408 - val_loss: 0.0408
# Epoch 180/200
# mean max of probabilities: 0.00024134398 - temperature 0.1
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0406 - val_loss: 0.0411
# Epoch 181/200
# mean max of probabilities: 0.00024137067 - temperature 0.1
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0417 - val_loss: 0.0410
# Epoch 182/200
# mean max of probabilities: 0.00024139017 - temperature 0.1
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0406 - val_loss: 0.0417
# Epoch 183/200
# mean max of probabilities: 0.0002414049 - temperature 0.1
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0411 - val_loss: 0.0415
# Epoch 184/200
# mean max of probabilities: 0.00024141867 - temperature 0.1
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0416 - val_loss: 0.0401
# Epoch 185/200
# mean max of probabilities: 0.00024143046 - temperature 0.1
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0412 - val_loss: 0.0406
# Epoch 186/200
# mean max of probabilities: 0.00024145516 - temperature 0.1
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0408 - val_loss: 0.0407
# Epoch 187/200
# mean max of probabilities: 0.00024147847 - temperature 0.1
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0413 - val_loss: 0.0411
# Epoch 188/200
# mean max of probabilities: 0.00024150765 - temperature 0.1
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0408 - val_loss: 0.0407
# Epoch 189/200
# mean max of probabilities: 0.00024153657 - temperature 0.1
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0403 - val_loss: 0.0435
# Epoch 190/200
# mean max of probabilities: 0.00024156115 - temperature 0.1
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0402 - val_loss: 0.0404
# Epoch 191/200
# mean max of probabilities: 0.000241581 - temperature 0.1
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0404 - val_loss: 0.0400
# Epoch 192/200
# mean max of probabilities: 0.00024159587 - temperature 0.1
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0406 - val_loss: 0.0413
# Epoch 193/200
# mean max of probabilities: 0.0002416074 - temperature 0.1
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0400 - val_loss: 0.0396
# Epoch 194/200
# mean max of probabilities: 0.00024162183 - temperature 0.1
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0404 - val_loss: 0.0412
# Epoch 195/200
# mean max of probabilities: 0.00024163618 - temperature 0.1
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0407 - val_loss: 0.0403
# Epoch 196/200
# mean max of probabilities: 0.00024164662 - temperature 0.1
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0411 - val_loss: 0.0408
# Epoch 197/200
# mean max of probabilities: 0.0002416542 - temperature 0.1
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0410 - val_loss: 0.0430
# Epoch 198/200
# mean max of probabilities: 0.00024165965 - temperature 0.1
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0419 - val_loss: 0.0412
# Epoch 199/200
# mean max of probabilities: 0.00024166358 - temperature 0.1
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0414 - val_loss: 0.0407
# Epoch 200/200
# mean max of probabilities: 0.0002416664 - temperature 0.1
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0399 - val_loss: 0.0413
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9
# Testing accuracy： 0.9
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.8
# Testing accuracy： 0.8
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 4434)              0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                283777
# _________________________________________________________________
# dense_2 (Dense)              (None, 4434)              288210
# =================================================================
# Total params: 571,987
# Trainable params: 571,986
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 40 samples, validate on 10 samples
# Epoch 1/200
# mean max of probabilities: 0.00023654068 - temperature 10.0
# 40/40 [==============================] - 1s 33ms/step - loss: 0.2559 - val_loss: 0.1583
# Epoch 2/200
# mean max of probabilities: 0.00023654074 - temperature 9.697654
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1949 - val_loss: 0.1202
# Epoch 3/200
# mean max of probabilities: 0.00023654097 - temperature 9.4044485
# 40/40 [==============================] - 0s 12ms/step - loss: 0.1440 - val_loss: 0.0900
# Epoch 4/200
# mean max of probabilities: 0.00023654217 - temperature 9.120109
# 40/40 [==============================] - 1s 13ms/step - loss: 0.1042 - val_loss: 0.0683
# Epoch 5/200
# mean max of probabilities: 0.00023654511 - temperature 8.844365
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0770 - val_loss: 0.0542
# Epoch 6/200
# mean max of probabilities: 0.00023654976 - temperature 8.576959
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0598 - val_loss: 0.0461
# Epoch 7/200
# mean max of probabilities: 0.00023655561 - temperature 8.317637
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0500 - val_loss: 0.0423
# Epoch 8/200
# mean max of probabilities: 0.00023656193 - temperature 8.066157
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0457 - val_loss: 0.0407
# Epoch 9/200
# mean max of probabilities: 0.00023656746 - temperature 7.8222795
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0443 - val_loss: 0.0403
# Epoch 10/200
# mean max of probabilities: 0.00023657116 - temperature 7.585776
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0442 - val_loss: 0.0404
# Epoch 11/200
# mean max of probabilities: 0.00023657246 - temperature 7.356423
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0443 - val_loss: 0.0402
# Epoch 12/200
# mean max of probabilities: 0.00023657133 - temperature 7.134004
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0442 - val_loss: 0.0399
# Epoch 13/200
# mean max of probabilities: 0.00023656822 - temperature 6.91831
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0440 - val_loss: 0.0394
# Epoch 14/200
# mean max of probabilities: 0.00023656356 - temperature 6.7091374
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0435 - val_loss: 0.0388
# Epoch 15/200
# mean max of probabilities: 0.00023655829 - temperature 6.5062885
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0429 - val_loss: 0.0383
# Epoch 16/200
# mean max of probabilities: 0.00023655334 - temperature 6.309573
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0424 - val_loss: 0.0380
# Epoch 17/200
# mean max of probabilities: 0.00023654886 - temperature 6.1188054
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0419 - val_loss: 0.0377
# Epoch 18/200
# mean max of probabilities: 0.00023654598 - temperature 5.9338055
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0416 - val_loss: 0.0376
# Epoch 19/200
# mean max of probabilities: 0.00023654521 - temperature 5.754399
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0414 - val_loss: 0.0376
# Epoch 20/200
# mean max of probabilities: 0.00023654549 - temperature 5.5804167
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0413 - val_loss: 0.0377
# Epoch 21/200
# mean max of probabilities: 0.00023654656 - temperature 5.4116945
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0412 - val_loss: 0.0376
# Epoch 22/200
# mean max of probabilities: 0.00023654774 - temperature 5.248074
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0411 - val_loss: 0.0376
# Epoch 23/200
# mean max of probabilities: 0.00023654879 - temperature 5.089401
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0411 - val_loss: 0.0377
# Epoch 24/200
# mean max of probabilities: 0.00023654976 - temperature 4.9355245
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0410 - val_loss: 0.0376
# Epoch 25/200
# mean max of probabilities: 0.00023655072 - temperature 4.7863007
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0411 - val_loss: 0.0377
# Epoch 26/200
# mean max of probabilities: 0.00023655167 - temperature 4.641588
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0410 - val_loss: 0.0378
# Epoch 27/200
# mean max of probabilities: 0.00023655267 - temperature 4.5012517
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0410 - val_loss: 0.0379
# Epoch 28/200
# mean max of probabilities: 0.00023655385 - temperature 4.365158
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0410 - val_loss: 0.0379
# Epoch 29/200
# mean max of probabilities: 0.00023655518 - temperature 4.233179
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0410 - val_loss: 0.0379
# Epoch 30/200
# mean max of probabilities: 0.00023655675 - temperature 4.105191
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0409 - val_loss: 0.0380
# Epoch 31/200
# mean max of probabilities: 0.00023655844 - temperature 3.9810724
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0410 - val_loss: 0.0381
# Epoch 32/200
# mean max of probabilities: 0.00023656024 - temperature 3.860706
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0409 - val_loss: 0.0379
# Epoch 33/200
# mean max of probabilities: 0.00023656202 - temperature 3.743979
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0409 - val_loss: 0.0377
# Epoch 34/200
# mean max of probabilities: 0.00023656386 - temperature 3.6307807
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0409 - val_loss: 0.0375
# Epoch 35/200
# mean max of probabilities: 0.0002365659 - temperature 3.5210054
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0409 - val_loss: 0.0374
# Epoch 36/200
# mean max of probabilities: 0.00023656814 - temperature 3.4145489
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0409 - val_loss: 0.0373
# Epoch 37/200
# mean max of probabilities: 0.00023657075 - temperature 3.3113112
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0409 - val_loss: 0.0373
# Epoch 38/200
# mean max of probabilities: 0.00023657344 - temperature 3.211195
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0409 - val_loss: 0.0374
# Epoch 39/200
# mean max of probabilities: 0.00023657629 - temperature 3.1141057
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0408 - val_loss: 0.0376
# Epoch 40/200
# mean max of probabilities: 0.00023657925 - temperature 3.0199518
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0409 - val_loss: 0.0377
# Epoch 41/200
# mean max of probabilities: 0.00023658236 - temperature 2.9286447
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0409 - val_loss: 0.0377
# Epoch 42/200
# mean max of probabilities: 0.00023658587 - temperature 2.8400981
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0409 - val_loss: 0.0377
# Epoch 43/200
# mean max of probabilities: 0.00023658965 - temperature 2.7542288
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0408 - val_loss: 0.0377
# Epoch 44/200
# mean max of probabilities: 0.0002365936 - temperature 2.6709554
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0408 - val_loss: 0.0376
# Epoch 45/200
# mean max of probabilities: 0.0002365978 - temperature 2.5901997
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0408 - val_loss: 0.0375
# Epoch 46/200
# mean max of probabilities: 0.00023660249 - temperature 2.511886
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0409 - val_loss: 0.0376
# Epoch 47/200
# mean max of probabilities: 0.00023660745 - temperature 2.43594
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0408 - val_loss: 0.0376
# Epoch 48/200
# mean max of probabilities: 0.00023661244 - temperature 2.3622901
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0408 - val_loss: 0.0377
# Epoch 49/200
# mean max of probabilities: 0.00023661772 - temperature 2.290867
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0408 - val_loss: 0.0375
# Epoch 50/200
# mean max of probabilities: 0.00023662312 - temperature 2.2216036
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0408 - val_loss: 0.0374
# Epoch 51/200
# mean max of probabilities: 0.00023662862 - temperature 2.1544344
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0408 - val_loss: 0.0375
# Epoch 52/200
# mean max of probabilities: 0.00023663463 - temperature 2.0892959
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0408 - val_loss: 0.0377
# Epoch 53/200
# mean max of probabilities: 0.00023664124 - temperature 2.0261269
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0408 - val_loss: 0.0378
# Epoch 54/200
# mean max of probabilities: 0.00023664824 - temperature 1.9648677
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0408 - val_loss: 0.0379
# Epoch 55/200
# mean max of probabilities: 0.00023665576 - temperature 1.9054606
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0408 - val_loss: 0.0379
# Epoch 56/200
# mean max of probabilities: 0.00023666333 - temperature 1.8478497
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0408 - val_loss: 0.0378
# Epoch 57/200
# mean max of probabilities: 0.00023667092 - temperature 1.7919806
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0408 - val_loss: 0.0376
# Epoch 58/200
# mean max of probabilities: 0.00023667859 - temperature 1.7378007
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0407 - val_loss: 0.0374
# Epoch 59/200
# mean max of probabilities: 0.00023668646 - temperature 1.6852589
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0407 - val_loss: 0.0373
# Epoch 60/200
# mean max of probabilities: 0.00023669636 - temperature 1.6343056
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0408 - val_loss: 0.0373
# Epoch 61/200
# mean max of probabilities: 0.00023670861 - temperature 1.584893
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0408 - val_loss: 0.0376
# Epoch 62/200
# mean max of probabilities: 0.00023672121 - temperature 1.5369743
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0407 - val_loss: 0.0376
# Epoch 63/200
# mean max of probabilities: 0.00023673484 - temperature 1.4905044
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0408 - val_loss: 0.0376
# Epoch 64/200
# mean max of probabilities: 0.0002367485 - temperature 1.4454395
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0407 - val_loss: 0.0375
# Epoch 65/200
# mean max of probabilities: 0.00023676554 - temperature 1.4017372
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0407 - val_loss: 0.0375
# Epoch 66/200
# mean max of probabilities: 0.00023678363 - temperature 1.3593562
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0407 - val_loss: 0.0375
# Epoch 67/200
# mean max of probabilities: 0.0002367997 - temperature 1.3182566
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0408 - val_loss: 0.0374
# Epoch 68/200
# mean max of probabilities: 0.00023681483 - temperature 1.2783996
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0408 - val_loss: 0.0375
# Epoch 69/200
# mean max of probabilities: 0.0002368294 - temperature 1.2397475
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0408 - val_loss: 0.0377
# Epoch 70/200
# mean max of probabilities: 0.00023684153 - temperature 1.2022641
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0408 - val_loss: 0.0380
# Epoch 71/200
# mean max of probabilities: 0.00023685308 - temperature 1.165914
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0409 - val_loss: 0.0380
# Epoch 72/200
# mean max of probabilities: 0.00023686832 - temperature 1.130663
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0409 - val_loss: 0.0378
# Epoch 73/200
# mean max of probabilities: 0.0002368865 - temperature 1.0964779
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0408 - val_loss: 0.0378
# Epoch 74/200
# mean max of probabilities: 0.00023690751 - temperature 1.0633262
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0408 - val_loss: 0.0377
# Epoch 75/200
# mean max of probabilities: 0.00023693082 - temperature 1.0311769
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0409 - val_loss: 0.0376
# Epoch 76/200
# mean max of probabilities: 0.00023695824 - temperature 0.9999997
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0408 - val_loss: 0.0376
# Epoch 77/200
# mean max of probabilities: 0.00023698571 - temperature 0.96976507
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0410 - val_loss: 0.0374
# Epoch 78/200
# mean max of probabilities: 0.00023701257 - temperature 0.9404445
# ...
# mean max of probabilities: 0.00024045352 - temperature 0.10311767
# 40/40 [==============================] - 7s 173ms/step - loss: 0.0407 - val_loss: 0.0431
# Epoch 151/200
# mean max of probabilities: 0.00024046563 - temperature 0.1
# 40/40 [==============================] - 7s 174ms/step - loss: 0.0416 - val_loss: 0.0434
# Epoch 152/200
# mean max of probabilities: 0.00024048204 - temperature 0.1
# 40/40 [==============================] - 5s 119ms/step - loss: 0.0414 - val_loss: 0.0456
# Epoch 153/200
# mean max of probabilities: 0.00024049952 - temperature 0.1
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0411 - val_loss: 0.0427
# Epoch 154/200
# mean max of probabilities: 0.00024051493 - temperature 0.1
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0413 - val_loss: 0.0444
# Epoch 155/200
# mean max of probabilities: 0.00024052616 - temperature 0.1
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0407 - val_loss: 0.0425
# Epoch 156/200
# mean max of probabilities: 0.00024053433 - temperature 0.1
# 40/40 [==============================] - 3s 64ms/step - loss: 0.0403 - val_loss: 0.0435
# Epoch 157/200
# mean max of probabilities: 0.00024054185 - temperature 0.1
# 40/40 [==============================] - 5s 117ms/step - loss: 0.0417 - val_loss: 0.0452
# Epoch 158/200
# mean max of probabilities: 0.00024055335 - temperature 0.1
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0414 - val_loss: 0.0426
# Epoch 159/200
# mean max of probabilities: 0.00024056422 - temperature 0.1
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0417 - val_loss: 0.0434
# Epoch 160/200
# mean max of probabilities: 0.00024057354 - temperature 0.1
# 40/40 [==============================] - 4s 110ms/step - loss: 0.0403 - val_loss: 0.0431
# Epoch 161/200
# mean max of probabilities: 0.00024058226 - temperature 0.1
# 40/40 [==============================] - 4s 107ms/step - loss: 0.0407 - val_loss: 0.0416
# Epoch 162/200
# mean max of probabilities: 0.00024059415 - temperature 0.1
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0408 - val_loss: 0.0444
# Epoch 163/200
# mean max of probabilities: 0.000240617 - temperature 0.1
# 40/40 [==============================] - 5s 117ms/step - loss: 0.0414 - val_loss: 0.0435
# Epoch 164/200
# mean max of probabilities: 0.00024063652 - temperature 0.1
# 40/40 [==============================] - 5s 129ms/step - loss: 0.0407 - val_loss: 0.0439
# Epoch 165/200
# mean max of probabilities: 0.00024065076 - temperature 0.1
# 40/40 [==============================] - 3s 84ms/step - loss: 0.0410 - val_loss: 0.0433
# Epoch 166/200
# mean max of probabilities: 0.00024067209 - temperature 0.1
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0402 - val_loss: 0.0428
# Epoch 167/200
# mean max of probabilities: 0.00024070826 - temperature 0.1
# 40/40 [==============================] - 4s 105ms/step - loss: 0.0404 - val_loss: 0.0432
# Epoch 168/200
# mean max of probabilities: 0.0002407372 - temperature 0.1
# 40/40 [==============================] - 3s 83ms/step - loss: 0.0402 - val_loss: 0.0463
# Epoch 169/200
# mean max of probabilities: 0.00024075834 - temperature 0.1
# 40/40 [==============================] - 5s 114ms/step - loss: 0.0430 - val_loss: 0.0440
# Epoch 170/200
# mean max of probabilities: 0.00024077995 - temperature 0.1
# 40/40 [==============================] - 5s 114ms/step - loss: 0.0409 - val_loss: 0.0440
# Epoch 171/200
# mean max of probabilities: 0.0002407997 - temperature 0.1
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0409 - val_loss: 0.0448
# Epoch 172/200
# mean max of probabilities: 0.000240818 - temperature 0.1
# 40/40 [==============================] - 4s 101ms/step - loss: 0.0405 - val_loss: 0.0450
# Epoch 173/200
# mean max of probabilities: 0.00024083145 - temperature 0.1
# 40/40 [==============================] - 5s 116ms/step - loss: 0.0415 - val_loss: 0.0430
# Epoch 174/200
# mean max of probabilities: 0.00024084274 - temperature 0.1
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0418 - val_loss: 0.0438
# Epoch 175/200
# mean max of probabilities: 0.00024085236 - temperature 0.1
# 40/40 [==============================] - 3s 85ms/step - loss: 0.0399 - val_loss: 0.0431
# Epoch 176/200
# mean max of probabilities: 0.00024086014 - temperature 0.1
# 40/40 [==============================] - 5s 119ms/step - loss: 0.0410 - val_loss: 0.0432
# Epoch 177/200
# mean max of probabilities: 0.00024086832 - temperature 0.1
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0406 - val_loss: 0.0416
# Epoch 178/200
# mean max of probabilities: 0.00024087689 - temperature 0.1
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0412 - val_loss: 0.0451
# Epoch 179/200
# mean max of probabilities: 0.00024088673 - temperature 0.1
# 40/40 [==============================] - 4s 111ms/step - loss: 0.0410 - val_loss: 0.0440
# Epoch 180/200
# mean max of probabilities: 0.00024090167 - temperature 0.1
# 40/40 [==============================] - 5s 125ms/step - loss: 0.0406 - val_loss: 0.0436
# Epoch 181/200
# mean max of probabilities: 0.00024092212 - temperature 0.1
# 40/40 [==============================] - 4s 103ms/step - loss: 0.0404 - val_loss: 0.0434
# Epoch 182/200
# mean max of probabilities: 0.00024094728 - temperature 0.1
# 40/40 [==============================] - 3s 63ms/step - loss: 0.0401 - val_loss: 0.0425
# Epoch 183/200
# mean max of probabilities: 0.00024097675 - temperature 0.1
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0408 - val_loss: 0.0415
# Epoch 184/200
# mean max of probabilities: 0.00024100367 - temperature 0.1
# 40/40 [==============================] - 5s 114ms/step - loss: 0.0410 - val_loss: 0.0422
# Epoch 185/200
# mean max of probabilities: 0.00024102465 - temperature 0.1
# 40/40 [==============================] - 3s 81ms/step - loss: 0.0409 - val_loss: 0.0418
# Epoch 186/200
# mean max of probabilities: 0.00024104182 - temperature 0.1
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0409 - val_loss: 0.0424
# Epoch 187/200
# mean max of probabilities: 0.00024106298 - temperature 0.1
# 40/40 [==============================] - 4s 101ms/step - loss: 0.0394 - val_loss: 0.0414
# Epoch 188/200
# mean max of probabilities: 0.00024108535 - temperature 0.1
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0408 - val_loss: 0.0446
# Epoch 189/200
# mean max of probabilities: 0.00024110165 - temperature 0.1
# 40/40 [==============================] - 5s 114ms/step - loss: 0.0405 - val_loss: 0.0425
# Epoch 190/200
# mean max of probabilities: 0.0002411159 - temperature 0.1
# 40/40 [==============================] - 5s 120ms/step - loss: 0.0416 - val_loss: 0.0429
# Epoch 191/200
# mean max of probabilities: 0.000241135 - temperature 0.1
# 40/40 [==============================] - 3s 83ms/step - loss: 0.0401 - val_loss: 0.0460
# Epoch 192/200
# mean max of probabilities: 0.00024115945 - temperature 0.1
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0402 - val_loss: 0.0435
# Epoch 193/200
# mean max of probabilities: 0.00024117605 - temperature 0.1
# 40/40 [==============================] - 6s 140ms/step - loss: 0.0406 - val_loss: 0.0429
# Epoch 194/200
# mean max of probabilities: 0.00024118948 - temperature 0.1
# 40/40 [==============================] - 6s 143ms/step - loss: 0.0408 - val_loss: 0.0434
# Epoch 195/200
# mean max of probabilities: 0.00024120677 - temperature 0.1
# 40/40 [==============================] - 5s 136ms/step - loss: 0.0404 - val_loss: 0.0426
# Epoch 196/200
# mean max of probabilities: 0.00024122768 - temperature 0.1
# 40/40 [==============================] - 5s 130ms/step - loss: 0.0402 - val_loss: 0.0420
# Epoch 197/200
# mean max of probabilities: 0.0002412436 - temperature 0.1
# 40/40 [==============================] - 6s 159ms/step - loss: 0.0408 - val_loss: 0.0415
# Epoch 198/200
# mean max of probabilities: 0.00024125834 - temperature 0.1
# 40/40 [==============================] - 6s 160ms/step - loss: 0.0397 - val_loss: 0.0424
# Epoch 199/200
# mean max of probabilities: 0.00024127637 - temperature 0.1
# 40/40 [==============================] - 4s 108ms/step - loss: 0.0406 - val_loss: 0.0420
# Epoch 200/200
# mean max of probabilities: 0.00024129283 - temperature 0.1
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0404 - val_loss: 0.0427
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.7
# Testing accuracy： 0.7
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.6
# Testing accuracy： 0.6
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 4434)              0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                283777
# _________________________________________________________________
# dense_11 (Dense)             (None, 4434)              288210
# =================================================================
# Total params: 571,987
# Trainable params: 571,986
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 40 samples, validate on 10 samples
# Epoch 1/200
# mean max of probabilities: 0.00023652091 - temperature 10.0
# 40/40 [==============================] - 9s 218ms/step - loss: 0.2390 - val_loss: 0.1792
# Epoch 2/200
# mean max of probabilities: 0.00023652086 - temperature 9.697654
# 40/40 [==============================] - 4s 101ms/step - loss: 0.1782 - val_loss: 0.1315
# Epoch 3/200
# mean max of probabilities: 0.00023652091 - temperature 9.4044485
# 40/40 [==============================] - 4s 96ms/step - loss: 0.1307 - val_loss: 0.0960
# Epoch 4/200
# mean max of probabilities: 0.00023652165 - temperature 9.120109
# 40/40 [==============================] - 5s 121ms/step - loss: 0.0933 - val_loss: 0.0717
# Epoch 5/200
# mean max of probabilities: 0.000236524 - temperature 8.844365
# 40/40 [==============================] - 4s 109ms/step - loss: 0.0700 - val_loss: 0.0563
# Epoch 6/200
# mean max of probabilities: 0.00023652856 - temperature 8.576959
# 40/40 [==============================] - 5s 115ms/step - loss: 0.0549 - val_loss: 0.0479
# Epoch 7/200
# mean max of probabilities: 0.00023653425 - temperature 8.317637
# 40/40 [==============================] - 3s 83ms/step - loss: 0.0476 - val_loss: 0.0439
# Epoch 8/200
# mean max of probabilities: 0.00023654038 - temperature 8.066157
# 40/40 [==============================] - 5s 117ms/step - loss: 0.0441 - val_loss: 0.0428
# Epoch 9/200
# mean max of probabilities: 0.00023654544 - temperature 7.8222795
# 40/40 [==============================] - 5s 113ms/step - loss: 0.0431 - val_loss: 0.0428
# Epoch 10/200
# mean max of probabilities: 0.00023654863 - temperature 7.585776
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0432 - val_loss: 0.0430
# Epoch 11/200
# mean max of probabilities: 0.00023654939 - temperature 7.356423
# 40/40 [==============================] - 5s 116ms/step - loss: 0.0435 - val_loss: 0.0430
# Epoch 12/200
# mean max of probabilities: 0.00023654776 - temperature 7.134004
# 40/40 [==============================] - 5s 118ms/step - loss: 0.0433 - val_loss: 0.0427
# Epoch 13/200
# mean max of probabilities: 0.00023654405 - temperature 6.91831
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0429 - val_loss: 0.0423
# Epoch 14/200
# mean max of probabilities: 0.00023653891 - temperature 6.7091374
# 40/40 [==============================] - 3s 84ms/step - loss: 0.0424 - val_loss: 0.0418
# Epoch 15/200
# mean max of probabilities: 0.00023653322 - temperature 6.5062885
# 40/40 [==============================] - 4s 111ms/step - loss: 0.0418 - val_loss: 0.0414
# Epoch 16/200
# mean max of probabilities: 0.0002365282 - temperature 6.309573
# 40/40 [==============================] - 4s 109ms/step - loss: 0.0413 - val_loss: 0.0410
# Epoch 17/200
# mean max of probabilities: 0.00023652457 - temperature 6.1188054
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0409 - val_loss: 0.0408
# Epoch 18/200
# mean max of probabilities: 0.00023652281 - temperature 5.9338055
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0407 - val_loss: 0.0407
# Epoch 19/200
# mean max of probabilities: 0.00023652261 - temperature 5.754399
# 40/40 [==============================] - 4s 107ms/step - loss: 0.0406 - val_loss: 0.0405
# Epoch 20/200
# mean max of probabilities: 0.00023652322 - temperature 5.5804167
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0405 - val_loss: 0.0404
# Epoch 21/200
# mean max of probabilities: 0.00023652398 - temperature 5.4116945
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0405 - val_loss: 0.0404
# Epoch 22/200
# mean max of probabilities: 0.00023652465 - temperature 5.248074
# 40/40 [==============================] - 5s 126ms/step - loss: 0.0404 - val_loss: 0.0403
# Epoch 23/200
# mean max of probabilities: 0.00023652524 - temperature 5.089401
# 40/40 [==============================] - 4s 109ms/step - loss: 0.0404 - val_loss: 0.0402
# Epoch 24/200
# mean max of probabilities: 0.0002365258 - temperature 4.9355245
# 40/40 [==============================] - 3s 81ms/step - loss: 0.0404 - val_loss: 0.0401
# Epoch 25/200
# mean max of probabilities: 0.00023652651 - temperature 4.7863007
# 40/40 [==============================] - 5s 126ms/step - loss: 0.0403 - val_loss: 0.0401
# Epoch 26/200
# mean max of probabilities: 0.00023652734 - temperature 4.641588
# 40/40 [==============================] - 5s 121ms/step - loss: 0.0403 - val_loss: 0.0401
# Epoch 27/200
# mean max of probabilities: 0.0002365284 - temperature 4.5012517
# 40/40 [==============================] - 4s 107ms/step - loss: 0.0403 - val_loss: 0.0402
# Epoch 28/200
# mean max of probabilities: 0.00023652968 - temperature 4.365158
# 40/40 [==============================] - 3s 85ms/step - loss: 0.0403 - val_loss: 0.0402
# Epoch 29/200
# mean max of probabilities: 0.00023653114 - temperature 4.233179
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0403 - val_loss: 0.0401
# Epoch 30/200
# mean max of probabilities: 0.00023653264 - temperature 4.105191
# 40/40 [==============================] - 7s 176ms/step - loss: 0.0402 - val_loss: 0.0401
# Epoch 31/200
# mean max of probabilities: 0.0002365342 - temperature 3.9810724
# 40/40 [==============================] - 6s 147ms/step - loss: 0.0402 - val_loss: 0.0401
# Epoch 32/200
# mean max of probabilities: 0.00023653582 - temperature 3.860706
# 40/40 [==============================] - 5s 118ms/step - loss: 0.0402 - val_loss: 0.0400
# Epoch 33/200
# mean max of probabilities: 0.00023653747 - temperature 3.743979
# 40/40 [==============================] - 6s 154ms/step - loss: 0.0402 - val_loss: 0.0400
# Epoch 34/200
# mean max of probabilities: 0.00023653923 - temperature 3.6307807
# 40/40 [==============================] - 5s 123ms/step - loss: 0.0402 - val_loss: 0.0400
# Epoch 35/200
# mean max of probabilities: 0.00023654118 - temperature 3.5210054
# 40/40 [==============================] - 5s 117ms/step - loss: 0.0401 - val_loss: 0.0401
# Epoch 36/200
# mean max of probabilities: 0.00023654339 - temperature 3.4145489
# 40/40 [==============================] - 4s 105ms/step - loss: 0.0402 - val_loss: 0.0402
# Epoch 37/200
# mean max of probabilities: 0.00023654579 - temperature 3.3113112
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0402 - val_loss: 0.0403
# Epoch 38/200
# mean max of probabilities: 0.00023654822 - temperature 3.211195
# 40/40 [==============================] - 4s 105ms/step - loss: 0.0402 - val_loss: 0.0402
# Epoch 39/200
# mean max of probabilities: 0.00023655064 - temperature 3.1141057
# 40/40 [==============================] - 5s 127ms/step - loss: 0.0402 - val_loss: 0.0401
# Epoch 40/200
# mean max of probabilities: 0.00023655315 - temperature 3.0199518
# 40/40 [==============================] - 5s 125ms/step - loss: 0.0401 - val_loss: 0.0401
# Epoch 41/200
# mean max of probabilities: 0.00023655617 - temperature 2.9286447
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0401 - val_loss: 0.0400
