# %%
import numpy as np
import pandas as pd
import os

# %%
fold_path=['1_LS_CV','2_SPEC_CV','3_NDFS_CV','4_AEFS_CV','5_UDFS_CV','6_MCFS_CV','7_PFA_CV','8_InfFS_CV','9_AgnoSS_CV','10_CAE_CV','11_FAE_64_CV','12_FAE_50_CV']

# %%
cv_times_from=0
cv_times_to=5

# %%
file_path="/log/"

for fold_path_i in fold_path:
    fold_name=fold_path_i.split('_')[1]
    print(fold_name+":\n")
    
    if fold_path_i in ['11_FAE_64_CV','12_FAE_50_CV']:
        print("Do not use bias!",fold_path_i)
        p_is_use_bias=False
        path_results='./'+fold_path_i+file_path+"FAE_results_bias_"+str(p_is_use_bias)+".csv" 
        results_analysis=np.array(pd.read_csv(path_results,header=None))
        results_analysis_test_acc__=results_analysis[:,3]
        results_analysis_test_acc_=results_analysis_test_acc__[np.where(results_analysis[:,3]>=0)]
        cv_cal_times=len(results_analysis_test_acc__)
        if cv_cal_times >=(cv_times_to-cv_times_from):
        
            print("cv times: ",cv_cal_times)
        
            results_analysis_test_acc=results_analysis_test_acc_[cv_times_from:cv_times_to]
            results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]
        
            print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
            print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

            path_time='./'+fold_path_i+file_path+"FAE_time_bias_"+str(p_is_use_bias)+".csv"
            time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
            print("Calculation times: ", len(results_analysis_test_acc))  
        
            print("Use bias!",fold_path_i)
            p_is_use_bias=True
            path_results='./'+fold_path_i+file_path+"FAE_results_bias_"+str(p_is_use_bias)+".csv"  
            results_analysis=np.array(pd.read_csv(path_results,header=None))
            results_analysis_test_acc=results_analysis[:,3][np.where(results_analysis[:,3]>=0)][cv_times_from:cv_times_to]
            results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]
        
            print(results_analysis_test_acc)
            print(results_analysis_linear_rec)
            print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
            print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

            path_time='./'+fold_path_i+file_path+"FAE_time_bias_"+str(p_is_use_bias)+".csv"
            time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
            print("Calculation times: ", len(results_analysis_test_acc))          
    
    else:
        path_results='./'+fold_path_i+file_path+fold_name+'_results.csv'
        
        if os.path.exists(path_results):
            results_analysis=np.array(pd.read_csv(path_results,header=None))

            results_analysis_test_acc__=results_analysis[:,3]
            results_analysis_test_acc_=results_analysis_test_acc__[np.where(results_analysis[:,3]>=0)]
            cv_cal_times=len(results_analysis_test_acc__)
                
            cv_cal_times=len(results_analysis_test_acc_)
            if cv_cal_times>=(cv_times_to-cv_times_from):

                print("cv times: ",cv_cal_times)        
                
                results_analysis_test_acc=results_analysis_test_acc_[cv_times_from:cv_times_to]
                results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]

                print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
                print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

                path_time='./'+fold_path_i+file_path+fold_path_i.split('_')[1]+'_time.csv'
                time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
                print("Calculation times: ", len(results_analysis_test_acc))
    
                print("\n\n")
        else:
            print("Nan")
            print("\n\n")
# Out:
# LS:
#
# cv times:  50
# Testing accuarcy:0.460 ±0.1744
# Testing Linear reconstruction: 0.226 ±0.0333
# Calculation times:  5
#
#
#
# SPEC:
#
# cv times:  50
# Testing accuarcy:0.220 ±0.1600
# Testing Linear reconstruction: 0.259 ±0.0301
# Calculation times:  5
#
#
#
# NDFS:
#
# cv times:  50
# Testing accuarcy:0.340 ±0.0800
# Testing Linear reconstruction: 0.347 ±0.0442
# Calculation times:  5
#
#
#
# AEFS:
#
# cv times:  50
# Testing accuarcy:0.680 ±0.1327
# Testing Linear reconstruction: 0.065 ±0.0083
# Calculation times:  5
#
#
#
# UDFS:
#
# cv times:  12
# Testing accuarcy:0.760 ±0.2059
# Testing Linear reconstruction: 0.072 ±0.0043
# Calculation times:  5
#
#
#
# MCFS:
#
# cv times:  50
# Testing accuarcy:0.460 ±0.0800
# Testing Linear reconstruction: 0.249 ±0.0193
# Calculation times:  5
#
#
#
# PFA:
#
# cv times:  50
# Testing accuarcy:0.660 ±0.0800
# Testing Linear reconstruction: 0.067 ±0.0112
# Calculation times:  5
#
#
#
# InfFS:
#
# cv times:  50
# Testing accuarcy:0.420 ±0.1166
# Testing Linear reconstruction: 0.211 ±0.0650
# Calculation times:  5
#
#
#
# AgnoSS:
#
# cv times:  50
# Testing accuarcy:0.620 ±0.0748
# Testing Linear reconstruction: 0.068 ±0.0122
# Calculation times:  5
#
#
#
# CAE:
#
# cv times:  50
# Testing accuarcy:0.700 ±0.1673
# Testing Linear reconstruction: 0.066 ±0.0106
# Calculation times:  5
#
#
#
# FAE:
#
# Do not use bias! 11_FAE_64_CV
# cv times:  50
# Testing accuarcy:0.700 ±0.0894
# Testing Linear reconstruction: 0.069 ±0.0079
# Calculation times:  5
# Use bias! 11_FAE_64_CV
# [0.8 0.7 0.7 0.7 0.9]
# [0.05314332 0.06520148 0.07914995 0.07784229 0.06856619]
# Testing accuarcy:0.760 ±0.0800
# Testing Linear reconstruction: 0.069 ±0.0095
# Calculation times:  5
# FAE:
#
# Do not use bias! 12_FAE_50_CV
# cv times:  50
# Testing accuarcy:0.660 ±0.1855
# Testing Linear reconstruction: 0.125 ±0.0155
# Calculation times:  5
# Use bias! 12_FAE_50_CV
# [0.9 0.5 0.6 0.7 0.9]
# [0.11254783 0.16535459 0.18524577 0.14524264 0.0987155 ]
# Testing accuarcy:0.720 ±0.1600
# Testing Linear reconstruction: 0.141 ±0.0321
# Calculation times:  5
