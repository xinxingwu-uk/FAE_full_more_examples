# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd
from skimage import io
from PIL import Image
from sklearn.model_selection import train_test_split
import scipy.sparse as sparse

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
dataset_path='../Dataset/coil-20-proc/'

samples={}
for dirpath, dirnames, filenames in os.walk(dataset_path):
    #print(dirpath)
    #print(dirnames)
    #print(filenames)
    dirnames.sort()
    filenames.sort()
    for filename in [f for f in filenames if f.endswith(".png") and not f.find('checkpoint')>0]:
        full_path = os.path.join(dirpath, filename)
        file_identifier=filename.split('__')[0][3:]
        if file_identifier not in samples.keys():
            samples[file_identifier] = []
        # Direct read
        #image = io.imread(full_path)
        # Resize read
        image_=Image.open(full_path).resize((20, 20),Image.ANTIALIAS)
        image=np.asarray(image_)
        samples[file_identifier].append(image)
        
#plt.imshow(samples['1'][0].reshape(20,20))

# %%
data_arr_list=[]
label_arr_list=[]
for key_i in samples.keys():
    key_i_for_label=[int(key_i)-1]
    data_arr_list.append(np.array(samples[key_i]))
    label_arr_list.append(np.array(72*key_i_for_label))
    
data_arr=np.concatenate(data_arr_list).reshape(1440, 20*20).astype('float32') / 255.
label_arr_onehot=np.concatenate(label_arr_list)#to_categorical(np.concatenate(label_arr_list))

# %%
key_feture_number=50

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,50):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1702: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 50)                20001
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               20400
# =================================================================
# Total params: 40,401
# Trainable params: 40,400
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 1152 samples, validate on 288 samples
# Epoch 1/200
# mean max of probabilities: 0.0028931028 - temperature 10.0
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0768 - val_loss: 0.0488
# Epoch 2/200
# mean max of probabilities: 0.0029030314 - temperature 9.716257
# 1152/1152 [==============================] - 1s 857us/step - loss: 0.0495 - val_loss: 0.0485
# Epoch 3/200
# mean max of probabilities: 0.0029215678 - temperature 9.440558
# 1152/1152 [==============================] - 1s 670us/step - loss: 0.0492 - val_loss: 0.0481
# Epoch 4/200
# mean max of probabilities: 0.0029528756 - temperature 9.172705
# 1152/1152 [==============================] - 1s 875us/step - loss: 0.0489 - val_loss: 0.0479
# Epoch 5/200
# mean max of probabilities: 0.0029949269 - temperature 8.912436
# 1152/1152 [==============================] - 1s 538us/step - loss: 0.0486 - val_loss: 0.0476
# Epoch 6/200
# mean max of probabilities: 0.0030462593 - temperature 8.659551
# 1152/1152 [==============================] - 1s 534us/step - loss: 0.0483 - val_loss: 0.0473
# Epoch 7/200
# mean max of probabilities: 0.0031040078 - temperature 8.413841
# 1152/1152 [==============================] - 1s 576us/step - loss: 0.0480 - val_loss: 0.0472
# Epoch 8/200
# mean max of probabilities: 0.0031730097 - temperature 8.175103
# 1152/1152 [==============================] - 1s 679us/step - loss: 0.0478 - val_loss: 0.0472
# Epoch 9/200
# mean max of probabilities: 0.0032499593 - temperature 7.9431396
# 1152/1152 [==============================] - 1s 585us/step - loss: 0.0475 - val_loss: 0.0470
# Epoch 10/200
# mean max of probabilities: 0.0033348575 - temperature 7.7177577
# 1152/1152 [==============================] - 1s 759us/step - loss: 0.0473 - val_loss: 0.0468
# Epoch 11/200
# mean max of probabilities: 0.0034292329 - temperature 7.498771
# 1152/1152 [==============================] - 1s 453us/step - loss: 0.0472 - val_loss: 0.0465
# Epoch 12/200
# mean max of probabilities: 0.0035331685 - temperature 7.285998
# 1152/1152 [==============================] - 1s 656us/step - loss: 0.0471 - val_loss: 0.0464
# Epoch 13/200
# mean max of probabilities: 0.003646278 - temperature 7.079262
# 1152/1152 [==============================] - 1s 679us/step - loss: 0.0469 - val_loss: 0.0463
# Epoch 14/200
# mean max of probabilities: 0.0037709584 - temperature 6.8783927
# 1152/1152 [==============================] - 1s 660us/step - loss: 0.0467 - val_loss: 0.0466
# Epoch 15/200
# mean max of probabilities: 0.0039065382 - temperature 6.6832232
# 1152/1152 [==============================] - 1s 848us/step - loss: 0.0466 - val_loss: 0.0463
# Epoch 16/200
# mean max of probabilities: 0.0040536793 - temperature 6.49359
# 1152/1152 [==============================] - 1s 926us/step - loss: 0.0464 - val_loss: 0.0463
# Epoch 17/200
# mean max of probabilities: 0.0042111995 - temperature 6.309338
# 1152/1152 [==============================] - 1s 914us/step - loss: 0.0464 - val_loss: 0.0460
# Epoch 18/200
# mean max of probabilities: 0.0043883827 - temperature 6.1303163
# 1152/1152 [==============================] - 1s 801us/step - loss: 0.0461 - val_loss: 0.0462
# Epoch 19/200
# mean max of probabilities: 0.0045807236 - temperature 5.9563723
# 1152/1152 [==============================] - 1s 829us/step - loss: 0.0461 - val_loss: 0.0454
# Epoch 20/200
# mean max of probabilities: 0.0047923694 - temperature 5.7873635
# 1152/1152 [==============================] - 1s 911us/step - loss: 0.0458 - val_loss: 0.0456
# Epoch 21/200
# mean max of probabilities: 0.005027341 - temperature 5.6231513
# 1152/1152 [==============================] - 1s 802us/step - loss: 0.0457 - val_loss: 0.0457
# Epoch 22/200
# mean max of probabilities: 0.005284605 - temperature 5.463598
# 1152/1152 [==============================] - 1s 506us/step - loss: 0.0453 - val_loss: 0.0453
# Epoch 23/200
# mean max of probabilities: 0.005573336 - temperature 5.3085723
# 1152/1152 [==============================] - 1s 598us/step - loss: 0.0451 - val_loss: 0.0449
# Epoch 24/200
# mean max of probabilities: 0.0058848197 - temperature 5.157945
# 1152/1152 [==============================] - 1s 633us/step - loss: 0.0446 - val_loss: 0.0443
# Epoch 25/200
# mean max of probabilities: 0.0062240255 - temperature 5.011592
# 1152/1152 [==============================] - 1s 598us/step - loss: 0.0442 - val_loss: 0.0439
# Epoch 26/200
# mean max of probabilities: 0.0065927035 - temperature 4.8693905
# 1152/1152 [==============================] - 1s 675us/step - loss: 0.0437 - val_loss: 0.0432
# Epoch 27/200
# mean max of probabilities: 0.00698802 - temperature 4.7312264
# 1152/1152 [==============================] - 0s 372us/step - loss: 0.0431 - val_loss: 0.0424
# Epoch 28/200
# mean max of probabilities: 0.007398818 - temperature 4.596966
# 1152/1152 [==============================] - 1s 684us/step - loss: 0.0423 - val_loss: 0.0418
# Epoch 29/200
# mean max of probabilities: 0.00784369 - temperature 4.466531
# 1152/1152 [==============================] - 1s 631us/step - loss: 0.0417 - val_loss: 0.0407
# Epoch 30/200
# mean max of probabilities: 0.00829761 - temperature 4.3397956
# 1152/1152 [==============================] - 1s 737us/step - loss: 0.0406 - val_loss: 0.0398
# Epoch 31/200
# mean max of probabilities: 0.008770928 - temperature 4.216656
# 1152/1152 [==============================] - 1s 840us/step - loss: 0.0398 - val_loss: 0.0391
# Epoch 32/200
# mean max of probabilities: 0.009246881 - temperature 4.097012
# 1152/1152 [==============================] - 1s 692us/step - loss: 0.0389 - val_loss: 0.0379
# Epoch 33/200
# mean max of probabilities: 0.009729992 - temperature 3.980761
# 1152/1152 [==============================] - 1s 953us/step - loss: 0.0380 - val_loss: 0.0371
# Epoch 34/200
# mean max of probabilities: 0.010206972 - temperature 3.8678098
# 1152/1152 [==============================] - 1s 729us/step - loss: 0.0371 - val_loss: 0.0362
# Epoch 35/200
# mean max of probabilities: 0.010676343 - temperature 3.758063
# 1152/1152 [==============================] - 1s 722us/step - loss: 0.0363 - val_loss: 0.0354
# Epoch 36/200
# mean max of probabilities: 0.011109066 - temperature 3.6514304
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0357 - val_loss: 0.0348
# Epoch 37/200
# mean max of probabilities: 0.011508005 - temperature 3.5478234
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0352 - val_loss: 0.0343
# Epoch 38/200
# mean max of probabilities: 0.011899604 - temperature 3.4471545
# 1152/1152 [==============================] - 1s 949us/step - loss: 0.0347 - val_loss: 0.0342
# Epoch 39/200
# mean max of probabilities: 0.012258742 - temperature 3.3493438
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0344 - val_loss: 0.0337
# Epoch 40/200
# mean max of probabilities: 0.012597407 - temperature 3.2543082
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0341 - val_loss: 0.0332
# Epoch 41/200
# mean max of probabilities: 0.012946062 - temperature 3.1619697
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0337 - val_loss: 0.0330
# Epoch 42/200
# mean max of probabilities: 0.013320663 - temperature 3.072251
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0335 - val_loss: 0.0329
# Epoch 43/200
# mean max of probabilities: 0.013694798 - temperature 2.985078
# 1152/1152 [==============================] - 1s 939us/step - loss: 0.0331 - val_loss: 0.0323
# Epoch 44/200
# mean max of probabilities: 0.0140835 - temperature 2.9003782
# 1152/1152 [==============================] - 1s 655us/step - loss: 0.0327 - val_loss: 0.0322
# Epoch 45/200
# mean max of probabilities: 0.014513932 - temperature 2.8180816
# 1152/1152 [==============================] - 1s 612us/step - loss: 0.0324 - val_loss: 0.0315
# Epoch 46/200
# mean max of probabilities: 0.014984075 - temperature 2.7381203
# 1152/1152 [==============================] - 1s 666us/step - loss: 0.0318 - val_loss: 0.0313
# Epoch 47/200
# mean max of probabilities: 0.015509836 - temperature 2.660428
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0313 - val_loss: 0.0307
# Epoch 48/200
# mean max of probabilities: 0.016110715 - temperature 2.5849407
# 1152/1152 [==============================] - 1s 844us/step - loss: 0.0308 - val_loss: 0.0302
# Epoch 49/200
# mean max of probabilities: 0.016731706 - temperature 2.5115943
# 1152/1152 [==============================] - 1s 740us/step - loss: 0.0303 - val_loss: 0.0297
# Epoch 50/200
# mean max of probabilities: 0.017401118 - temperature 2.4403296
# 1152/1152 [==============================] - 1s 668us/step - loss: 0.0296 - val_loss: 0.0291
# Epoch 51/200
# mean max of probabilities: 0.018133352 - temperature 2.3710868
# 1152/1152 [==============================] - 1s 787us/step - loss: 0.0291 - val_loss: 0.0286
# Epoch 52/200
# mean max of probabilities: 0.018929398 - temperature 2.3038063
# 1152/1152 [==============================] - 1s 814us/step - loss: 0.0285 - val_loss: 0.0280
# Epoch 53/200
# mean max of probabilities: 0.019753143 - temperature 2.238438
# 1152/1152 [==============================] - 1s 798us/step - loss: 0.0280 - val_loss: 0.0278
# Epoch 54/200
# mean max of probabilities: 0.020627353 - temperature 2.1749234
# 1152/1152 [==============================] - 1s 863us/step - loss: 0.0274 - val_loss: 0.0272
# Epoch 55/200
# mean max of probabilities: 0.021534884 - temperature 2.1132112
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0270 - val_loss: 0.0266
# Epoch 56/200
# mean max of probabilities: 0.022482134 - temperature 2.0532503
# 1152/1152 [==============================] - 1s 896us/step - loss: 0.0266 - val_loss: 0.0264
# Epoch 57/200
# mean max of probabilities: 0.023437202 - temperature 1.9949908
# 1152/1152 [==============================] - 1s 865us/step - loss: 0.0261 - val_loss: 0.0260
# Epoch 58/200
# mean max of probabilities: 0.024409525 - temperature 1.9383844
# 1152/1152 [==============================] - 1s 859us/step - loss: 0.0257 - val_loss: 0.0256
# Epoch 59/200
# mean max of probabilities: 0.025397014 - temperature 1.883384
# 1152/1152 [==============================] - 1s 852us/step - loss: 0.0254 - val_loss: 0.0252
# Epoch 60/200
# mean max of probabilities: 0.026349105 - temperature 1.8299441
# 1152/1152 [==============================] - 1s 681us/step - loss: 0.0250 - val_loss: 0.0251
# Epoch 61/200
# mean max of probabilities: 0.027305126 - temperature 1.7780205
# 1152/1152 [==============================] - 1s 707us/step - loss: 0.0249 - val_loss: 0.0248
# Epoch 62/200
# mean max of probabilities: 0.028187575 - temperature 1.7275708
# 1152/1152 [==============================] - 1s 913us/step - loss: 0.0246 - val_loss: 0.0245
# Epoch 63/200
# mean max of probabilities: 0.029076679 - temperature 1.6785522
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0242 - val_loss: 0.0243
# Epoch 64/200
# mean max of probabilities: 0.030010972 - temperature 1.6309243
# 1152/1152 [==============================] - 1s 932us/step - loss: 0.0242 - val_loss: 0.0240
# Epoch 65/200
# mean max of probabilities: 0.030787034 - temperature 1.5846478
# 1152/1152 [==============================] - 1s 955us/step - loss: 0.0237 - val_loss: 0.0238
# Epoch 66/200
# mean max of probabilities: 0.03149265 - temperature 1.5396848
# 1152/1152 [==============================] - 1s 777us/step - loss: 0.0236 - val_loss: 0.0235
# Epoch 67/200
# mean max of probabilities: 0.032338675 - temperature 1.4959973
# 1152/1152 [==============================] - 1s 758us/step - loss: 0.0235 - val_loss: 0.0235
# Epoch 68/200
# mean max of probabilities: 0.033001587 - temperature 1.4535494
# 1152/1152 [==============================] - 1s 933us/step - loss: 0.0234 - val_loss: 0.0235
# Epoch 69/200
# mean max of probabilities: 0.033818122 - temperature 1.4123058
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0232 - val_loss: 0.0232
# Epoch 70/200
# mean max of probabilities: 0.0346817 - temperature 1.3722323
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0234 - val_loss: 0.0235
# Epoch 71/200
# mean max of probabilities: 0.035410095 - temperature 1.333296
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0229 - val_loss: 0.0235
# Epoch 72/200
# mean max of probabilities: 0.03626401 - temperature 1.2954646
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0228 - val_loss: 0.0226
# Epoch 73/200
# mean max of probabilities: 0.03712345 - temperature 1.2587066
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0230 - val_loss: 0.0230
# Epoch 74/200
# mean max of probabilities: 0.037975624 - temperature 1.2229917
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0230 - val_loss: 0.0232
# Epoch 75/200
# mean max of probabilities: 0.03878169 - temperature 1.1882898
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0231 - val_loss: 0.0233
# Epoch 76/200
# mean max of probabilities: 0.039562203 - temperature 1.1545738
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0233 - val_loss: 0.0236
# Epoch 77/200
# mean max of probabilities: 0.040281307 - temperature 1.1218139
# 1152/1152 [==============================] - 1s 943us/step - loss: 0.0231 - val_loss: 0.0236
# Epoch 78/200
# mean max of probabilities: 0.041155025 - temperature 1.0899832
# 1152/1152 [==============================] - 1s 914us/step - loss: 0.0232 - val_loss: 0.0241
# Epoch 79/200
# mean max of probabilities: 0.042014837 - temperature 1.0590558
# 1152/1152 [==============================] - 1s 858us/step - loss: 0.0234 - val_loss: 0.0239
# Epoch 80/200
# mean max of probabilities: 0.042960286 - temperature 1.029006
# 1152/1152 [==============================] - 1s 931us/step - loss: 0.0234 - val_loss: 0.0237
# Epoch 81/200
# mean max of probabilities: 0.044025127 - temperature 0.99980867
# 1152/1152 [==============================] - 1s 939us/step - loss: 0.0236 - val_loss: 0.0240
# Epoch 82/200
# mean max of probabilities: 0.044900108 - temperature 0.9714398
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0236 - val_loss: 0.0247
# Epoch 83/200
# mean max of probabilities: 0.04597126 - temperature 0.9438758
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0236 - val_loss: 0.0243
# Epoch 84/200
# mean max of probabilities: 0.04703473 - temperature 0.9170938
# 1152/1152 [==============================] - 1s 915us/step - loss: 0.0236 - val_loss: 0.0231
# Epoch 85/200
# mean max of probabilities: 0.048143305 - temperature 0.89107186
# 1152/1152 [==============================] - 1s 801us/step - loss: 0.0238 - val_loss: 0.0244
# Epoch 86/200
# mean max of probabilities: 0.049284868 - temperature 0.86578846
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0236 - val_loss: 0.0252
# Epoch 87/200
# mean max of probabilities: 0.050362367 - temperature 0.84122217
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0241 - val_loss: 0.0235
# Epoch 88/200
# mean max of probabilities: 0.051630393 - temperature 0.81735295
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0237 - val_loss: 0.0239
# Epoch 89/200
# mean max of probabilities: 0.0527866 - temperature 0.794161
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0236 - val_loss: 0.0240
# Epoch 90/200
# mean max of probabilities: 0.053949215 - temperature 0.77162725
# 1152/1152 [==============================] - 1s 948us/step - loss: 0.0239 - val_loss: 0.0246
# Epoch 91/200
# mean max of probabilities: 0.055248547 - temperature 0.74973285
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0240 - val_loss: 0.0242
# Epoch 92/200
# mean max of probabilities: 0.056484085 - temperature 0.7284597
# 1152/1152 [==============================] - 1s 955us/step - loss: 0.0238 - val_loss: 0.0246
# Epoch 93/200
# mean max of probabilities: 0.057924647 - temperature 0.70779014
# 1152/1152 [==============================] - 1s 881us/step - loss: 0.0238 - val_loss: 0.0249
# Epoch 94/200
# mean max of probabilities: 0.05933307 - temperature 0.6877071
# 1152/1152 [==============================] - 1s 889us/step - loss: 0.0239 - val_loss: 0.0239
# Epoch 95/200
# mean max of probabilities: 0.06065782 - temperature 0.66819394
# 1152/1152 [==============================] - 1s 932us/step - loss: 0.0242 - val_loss: 0.0243
# Epoch 96/200
# mean max of probabilities: 0.062066466 - temperature 0.6492344
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0243 - val_loss: 0.0236
# Epoch 97/200
# mean max of probabilities: 0.06362045 - temperature 0.6308128
# 1152/1152 [==============================] - 1s 910us/step - loss: 0.0243 - val_loss: 0.0237
# Epoch 98/200
# mean max of probabilities: 0.06509969 - temperature 0.6129139
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0244 - val_loss: 0.0250
# Epoch 99/200
# mean max of probabilities: 0.0664541 - temperature 0.595523
# 1152/1152 [==============================] - 1s 931us/step - loss: 0.0237 - val_loss: 0.0242
# Epoch 100/200
# mean max of probabilities: 0.067823954 - temperature 0.5786261
# 1152/1152 [==============================] - 1s 968us/step - loss: 0.0240 - val_loss: 0.0250
# Epoch 101/200
# mean max of probabilities: 0.069353044 - temperature 0.562208
# 1152/1152 [==============================] - 1s 925us/step - loss: 0.0244 - val_loss: 0.0246
# Epoch 102/200
# mean max of probabilities: 0.07075036 - temperature 0.54625577
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0246 - val_loss: 0.0241
# Epoch 103/200
# mean max of probabilities: 0.072343014 - temperature 0.5307561
# 1152/1152 [==============================] - 1s 848us/step - loss: 0.0245 - val_loss: 0.0242
# Epoch 104/200
# mean max of probabilities: 0.07403075 - temperature 0.51569617
# 1152/1152 [==============================] - 1s 900us/step - loss: 0.0243 - val_loss: 0.0244
# Epoch 105/200
# mean max of probabilities: 0.07545435 - temperature 0.5010635
# 1152/1152 [==============================] - 1s 984us/step - loss: 0.0240 - val_loss: 0.0239
# Epoch 106/200
# mean max of probabilities: 0.07691959 - temperature 0.48684615
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0241 - val_loss: 0.0246
# Epoch 107/200
# mean max of probabilities: 0.07829914 - temperature 0.4730321
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0249 - val_loss: 0.0248
# Epoch 108/200
# mean max of probabilities: 0.07989699 - temperature 0.45961002
# 1152/1152 [==============================] - 1s 908us/step - loss: 0.0244 - val_loss: 0.0248
# Epoch 109/200
# mean max of probabilities: 0.08149895 - temperature 0.4465689
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0243 - val_loss: 0.0238
# Epoch 110/200
# mean max of probabilities: 0.08314616 - temperature 0.43389767
# 1152/1152 [==============================] - 1s 980us/step - loss: 0.0240 - val_loss: 0.0241
# Epoch 111/200
# mean max of probabilities: 0.08471046 - temperature 0.42158613
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0241 - val_loss: 0.0249
# Epoch 112/200
# mean max of probabilities: 0.08620253 - temperature 0.40962386
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0241 - val_loss: 0.0246
# Epoch 113/200
# mean max of probabilities: 0.087873675 - temperature 0.3980011
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0243 - val_loss: 0.0249
# Epoch 114/200
# mean max of probabilities: 0.089485474 - temperature 0.3867081
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0242 - val_loss: 0.0244
# Epoch 115/200
# mean max of probabilities: 0.09125051 - temperature 0.3757355
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0247 - val_loss: 0.0247
# Epoch 116/200
# mean max of probabilities: 0.092825785 - temperature 0.36507428
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0241 - val_loss: 0.0237
# Epoch 117/200
# mean max of probabilities: 0.09424715 - temperature 0.35471553
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0238 - val_loss: 0.0241
# Epoch 118/200
# mean max of probabilities: 0.0956952 - temperature 0.34465063
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0243 - val_loss: 0.0242
# Epoch 119/200
# mean max of probabilities: 0.09742427 - temperature 0.3348714
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0242 - val_loss: 0.0251
# Epoch 120/200
# mean max of probabilities: 0.09912341 - temperature 0.32536966
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0242 - val_loss: 0.0252
# Epoch 121/200
# mean max of probabilities: 0.100791894 - temperature 0.3161375
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0239 - val_loss: 0.0241
# Epoch 122/200
# mean max of probabilities: 0.10220626 - temperature 0.30716732
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0242 - val_loss: 0.0237
# Epoch 123/200
# mean max of probabilities: 0.1040406 - temperature 0.29845157
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0241 - val_loss: 0.0247
# Epoch 124/200
# mean max of probabilities: 0.10570196 - temperature 0.28998315
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0242 - val_loss: 0.0246
# Epoch 125/200
# mean max of probabilities: 0.106993176 - temperature 0.28175476
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0242 - val_loss: 0.0247
# Epoch 126/200
# mean max of probabilities: 0.108645365 - temperature 0.27376017
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0236 - val_loss: 0.0247
# Epoch 127/200
# mean max of probabilities: 0.11028078 - temperature 0.26599237
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0242 - val_loss: 0.0239
# Epoch 128/200
# mean max of probabilities: 0.111640684 - temperature 0.258445
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0242 - val_loss: 0.0247
# Epoch 129/200
# mean max of probabilities: 0.113026105 - temperature 0.2511118
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0242 - val_loss: 0.0243
# Epoch 130/200
# mean max of probabilities: 0.11452691 - temperature 0.24398667
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0242 - val_loss: 0.0247
# Epoch 131/200
# mean max of probabilities: 0.116376296 - temperature 0.23706366
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0242 - val_loss: 0.0244
# Epoch 132/200
# mean max of probabilities: 0.117975205 - temperature 0.23033713
# 1152/1152 [==============================] - 1s 960us/step - loss: 0.0240 - val_loss: 0.0242
# Epoch 133/200
# mean max of probabilities: 0.1197985 - temperature 0.22380143
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0238 - val_loss: 0.0233
# Epoch 134/200
# mean max of probabilities: 0.121047884 - temperature 0.21745126
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0241 - val_loss: 0.0238
# Epoch 135/200
# mean max of probabilities: 0.12262004 - temperature 0.21128118
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0240 - val_loss: 0.0240
# Epoch 136/200
# mean max of probabilities: 0.124287374 - temperature 0.20528622
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0242 - val_loss: 0.0244
# Epoch 137/200
# mean max of probabilities: 0.12565199 - temperature 0.19946134
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0237 - val_loss: 0.0244
# Epoch 138/200
# mean max of probabilities: 0.12710056 - temperature 0.19380175
# 1152/1152 [==============================] - 1s 750us/step - loss: 0.0243 - val_loss: 0.0244
# Epoch 139/200
# mean max of probabilities: 0.12871961 - temperature 0.18830274
# 1152/1152 [==============================] - 1s 895us/step - loss: 0.0237 - val_loss: 0.0249
# Epoch 140/200
# mean max of probabilities: 0.13045378 - temperature 0.18295975
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0235 - val_loss: 0.0248
# Epoch 141/200
# mean max of probabilities: 0.13180332 - temperature 0.17776836
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0243 - val_loss: 0.0244
# Epoch 142/200
# mean max of probabilities: 0.13317531 - temperature 0.1727243
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0244 - val_loss: 0.0254
# Epoch 143/200
# mean max of probabilities: 0.13472 - temperature 0.16782336
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0241 - val_loss: 0.0241
# Epoch 144/200
# mean max of probabilities: 0.13603935 - temperature 0.16306145
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0238 - val_loss: 0.0239
# Epoch 145/200
# mean max of probabilities: 0.1372448 - temperature 0.1584347
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0238 - val_loss: 0.0240
# Epoch 146/200
# mean max of probabilities: 0.13893905 - temperature 0.15393922
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0239 - val_loss: 0.0239
# Epoch 147/200
# mean max of probabilities: 0.1402881 - temperature 0.14957133
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0238 - val_loss: 0.0237
# Epoch 148/200
# mean max of probabilities: 0.1417666 - temperature 0.14532721
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0238 - val_loss: 0.0238
# Epoch 149/200
# mean max of probabilities: 0.14314544 - temperature 0.14120358
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0238 - val_loss: 0.0234
# Epoch 150/200
# mean max of probabilities: 0.14441633 - temperature 0.13719703
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0239 - val_loss: 0.0235
# Epoch 151/200
# mean max of probabilities: 0.14587547 - temperature 0.13330416
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0232 - val_loss: 0.0241
# Epoch 152/200
# mean max of probabilities: 0.14705138 - temperature 0.12952176
# 1152/1152 [==============================] - 1s 832us/step - loss: 0.0239 - val_loss: 0.0242
# Epoch 153/200
# mean max of probabilities: 0.1486699 - temperature 0.12584665
# 1152/1152 [==============================] - 1s 959us/step - loss: 0.0236 - val_loss: 0.0243
# Epoch 154/200
# mean max of probabilities: 0.15000314 - temperature 0.12227585
# 1152/1152 [==============================] - 1s 895us/step - loss: 0.0236 - val_loss: 0.0241
# Epoch 155/200
# mean max of probabilities: 0.1514213 - temperature 0.11880635
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0240 - val_loss: 0.0233
# Epoch 156/200
# mean max of probabilities: 0.15280248 - temperature 0.115435295
# 1152/1152 [==============================] - 1s 781us/step - loss: 0.0234 - val_loss: 0.0243
# Epoch 157/200
# mean max of probabilities: 0.15403399 - temperature 0.112159885
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0231 - val_loss: 0.0243
# Epoch 158/200
# mean max of probabilities: 0.15537035 - temperature 0.10897743
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0233 - val_loss: 0.0224
# Epoch 159/200
# mean max of probabilities: 0.15670472 - temperature 0.105885275
# 1152/1152 [==============================] - 1s 921us/step - loss: 0.0235 - val_loss: 0.0244
# Epoch 160/200
# mean max of probabilities: 0.15795974 - temperature 0.10288084
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0233 - val_loss: 0.0247
# Epoch 161/200
# mean max of probabilities: 0.1590735 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0237 - val_loss: 0.0239
# Epoch 162/200
# mean max of probabilities: 0.16041805 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0231 - val_loss: 0.0238
# Epoch 163/200
# mean max of probabilities: 0.16148065 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0237 - val_loss: 0.0232
# Epoch 164/200
# mean max of probabilities: 0.16254924 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0233 - val_loss: 0.0230
# Epoch 165/200
# mean max of probabilities: 0.1639125 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0231 - val_loss: 0.0237
# Epoch 166/200
# mean max of probabilities: 0.16502644 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0233 - val_loss: 0.0233
# Epoch 167/200
# mean max of probabilities: 0.16646723 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0230 - val_loss: 0.0228
# Epoch 168/200
# mean max of probabilities: 0.16790737 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0230 - val_loss: 0.0226
# Epoch 169/200
# mean max of probabilities: 0.16919826 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0236 - val_loss: 0.0239
# Epoch 170/200
# mean max of probabilities: 0.17037344 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0231 - val_loss: 0.0238
# Epoch 171/200
# mean max of probabilities: 0.17151622 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0233 - val_loss: 0.0236
# Epoch 172/200
# mean max of probabilities: 0.1726502 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0229 - val_loss: 0.0229
# Epoch 173/200
# mean max of probabilities: 0.17399475 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0230 - val_loss: 0.0226
# Epoch 174/200
# mean max of probabilities: 0.17512447 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0228 - val_loss: 0.0229
# Epoch 175/200
# mean max of probabilities: 0.17662649 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0229 - val_loss: 0.0226
# Epoch 176/200
# mean max of probabilities: 0.17792012 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0228 - val_loss: 0.0229
# Epoch 177/200
# mean max of probabilities: 0.17908482 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0227 - val_loss: 0.0230
# Epoch 178/200
# mean max of probabilities: 0.18027456 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0229 - val_loss: 0.0223
# Epoch 179/200
# mean max of probabilities: 0.1816451 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0228 - val_loss: 0.0236
# Epoch 180/200
# mean max of probabilities: 0.18270901 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0229 - val_loss: 0.0229
# Epoch 181/200
# mean max of probabilities: 0.1841095 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0231 - val_loss: 0.0228
# Epoch 182/200
# mean max of probabilities: 0.1853734 - temperature 0.1
# 1152/1152 [==============================] - 1s 979us/step - loss: 0.0225 - val_loss: 0.0225
# Epoch 183/200
# mean max of probabilities: 0.1866586 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0230 - val_loss: 0.0222
# Epoch 184/200
# mean max of probabilities: 0.18793249 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0226 - val_loss: 0.0234
# Epoch 185/200
# mean max of probabilities: 0.18911643 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0224 - val_loss: 0.0234
# Epoch 186/200
# mean max of probabilities: 0.19038182 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0227 - val_loss: 0.0231
# Epoch 187/200
# mean max of probabilities: 0.19159754 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0224 - val_loss: 0.0223
# Epoch 188/200
# mean max of probabilities: 0.19293061 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0225 - val_loss: 0.0231
# Epoch 189/200
# mean max of probabilities: 0.19407225 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0224 - val_loss: 0.0222
# Epoch 190/200
# mean max of probabilities: 0.1953651 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0224 - val_loss: 0.0233
# Epoch 191/200
# mean max of probabilities: 0.19642855 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0224 - val_loss: 0.0216
# Epoch 192/200
# mean max of probabilities: 0.19763818 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0222 - val_loss: 0.0228
# Epoch 193/200
# mean max of probabilities: 0.19924797 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0219 - val_loss: 0.0225
# Epoch 194/200
# mean max of probabilities: 0.20076293 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0223 - val_loss: 0.0216
# Epoch 195/200
# mean max of probabilities: 0.20205995 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0224 - val_loss: 0.0230
# Epoch 196/200
# mean max of probabilities: 0.20351022 - temperature 0.1
# 1152/1152 [==============================] - 1s 960us/step - loss: 0.0224 - val_loss: 0.0231
# Epoch 197/200
# mean max of probabilities: 0.20489202 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0221 - val_loss: 0.0223
# Epoch 198/200
# mean max of probabilities: 0.20612252 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0219 - val_loss: 0.0232
# Epoch 199/200
# mean max of probabilities: 0.20733123 - temperature 0.1
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0218 - val_loss: 0.0220
# Epoch 200/200
# mean max of probabilities: 0.20880972 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0217 - val_loss: 0.0220
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 1.0
# Testing accuracy： 1.0
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9930555555555556
# Testing accuracy： 0.9930555555555556
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 50)                20001
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               20400
# =================================================================
# Total params: 40,401
# Trainable params: 40,400
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 1152 samples, validate on 288 samples
# Epoch 1/200
# mean max of probabilities: 0.0028949252 - temperature 10.0
# 1152/1152 [==============================] - 4s 4ms/step - loss: 0.0847 - val_loss: 0.0497
# Epoch 2/200
# mean max of probabilities: 0.0029083733 - temperature 9.716257
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0494 - val_loss: 0.0490
# Epoch 3/200
# mean max of probabilities: 0.0029267124 - temperature 9.440558
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0491 - val_loss: 0.0497
# Epoch 4/200
# mean max of probabilities: 0.0029551408 - temperature 9.172705
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0490 - val_loss: 0.0485
# Epoch 5/200
# mean max of probabilities: 0.0029977574 - temperature 8.912436
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0485 - val_loss: 0.0485
# Epoch 6/200
# mean max of probabilities: 0.003048508 - temperature 8.659551
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0482 - val_loss: 0.0478
# Epoch 7/200
# mean max of probabilities: 0.003109221 - temperature 8.413841
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0482 - val_loss: 0.0477
# Epoch 8/200
# mean max of probabilities: 0.0031736481 - temperature 8.175103
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0480 - val_loss: 0.0476
# Epoch 9/200
# mean max of probabilities: 0.0032476403 - temperature 7.9431396
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0478 - val_loss: 0.0472
# Epoch 10/200
# mean max of probabilities: 0.0033295802 - temperature 7.7177577
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0476 - val_loss: 0.0468
# Epoch 11/200
# mean max of probabilities: 0.003417393 - temperature 7.498771
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0474 - val_loss: 0.0471
# Epoch 12/200
# mean max of probabilities: 0.0035115338 - temperature 7.285998
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0473 - val_loss: 0.0468
# Epoch 13/200
# mean max of probabilities: 0.0036149567 - temperature 7.079262
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0471 - val_loss: 0.0465
# Epoch 14/200
# mean max of probabilities: 0.0037271942 - temperature 6.8783927
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0470 - val_loss: 0.0469
# Epoch 15/200
# mean max of probabilities: 0.0038479664 - temperature 6.6832232
# 1152/1152 [==============================] - 1s 899us/step - loss: 0.0472 - val_loss: 0.0465
# Epoch 16/200
# mean max of probabilities: 0.0039783656 - temperature 6.49359
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0468 - val_loss: 0.0464
# Epoch 17/200
# mean max of probabilities: 0.0041208733 - temperature 6.309338
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0466 - val_loss: 0.0457
# Epoch 18/200
# mean max of probabilities: 0.0042730244 - temperature 6.1303163
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0465 - val_loss: 0.0456
# Epoch 19/200
# mean max of probabilities: 0.004439614 - temperature 5.9563723
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0464 - val_loss: 0.0461
# Epoch 20/200
# mean max of probabilities: 0.004615013 - temperature 5.7873635
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0463 - val_loss: 0.0456
# Epoch 21/200
# mean max of probabilities: 0.004812137 - temperature 5.6231513
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0461 - val_loss: 0.0451
# Epoch 22/200
# mean max of probabilities: 0.0050343927 - temperature 5.463598
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0458 - val_loss: 0.0453
# Epoch 23/200
# mean max of probabilities: 0.0052754944 - temperature 5.3085723
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0455 - val_loss: 0.0446
# Epoch 24/200
# mean max of probabilities: 0.005541043 - temperature 5.157945
# 1152/1152 [==============================] - 1s 991us/step - loss: 0.0452 - val_loss: 0.0447
# Epoch 25/200
# mean max of probabilities: 0.0058311624 - temperature 5.011592
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0448 - val_loss: 0.0444
# Epoch 26/200
# mean max of probabilities: 0.0061546345 - temperature 4.8693905
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0444 - val_loss: 0.0434
# Epoch 27/200
# mean max of probabilities: 0.006512329 - temperature 4.7312264
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0439 - val_loss: 0.0437
# Epoch 28/200
# mean max of probabilities: 0.0068951445 - temperature 4.596966
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0432 - val_loss: 0.0426
# Epoch 29/200
# mean max of probabilities: 0.007310623 - temperature 4.466531
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0424 - val_loss: 0.0420
# Epoch 30/200
# mean max of probabilities: 0.007742712 - temperature 4.3397956
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0416 - val_loss: 0.0414
# Epoch 31/200
# mean max of probabilities: 0.0082102595 - temperature 4.216656
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0406 - val_loss: 0.0402
# Epoch 32/200
# mean max of probabilities: 0.008692557 - temperature 4.097012
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0395 - val_loss: 0.0394
# Epoch 33/200
# mean max of probabilities: 0.009178354 - temperature 3.980761
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0385 - val_loss: 0.0385
# Epoch 34/200
# mean max of probabilities: 0.00968314 - temperature 3.8678098
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0375 - val_loss: 0.0373
# Epoch 35/200
# mean max of probabilities: 0.010160056 - temperature 3.758063
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0365 - val_loss: 0.0368
# Epoch 36/200
# mean max of probabilities: 0.010614975 - temperature 3.6514304
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0356 - val_loss: 0.0360
# Epoch 37/200
# mean max of probabilities: 0.011051714 - temperature 3.5478234
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0350 - val_loss: 0.0357
# Epoch 38/200
# mean max of probabilities: 0.011448391 - temperature 3.4471545
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0345 - val_loss: 0.0350
# Epoch 39/200
# mean max of probabilities: 0.01181404 - temperature 3.3493438
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0340 - val_loss: 0.0349
# Epoch 40/200
# mean max of probabilities: 0.012162627 - temperature 3.2543082
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0336 - val_loss: 0.0346
# Epoch 41/200
# mean max of probabilities: 0.012485768 - temperature 3.1619697
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0334 - val_loss: 0.0343
# Epoch 42/200
# mean max of probabilities: 0.012783639 - temperature 3.072251
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0330 - val_loss: 0.0339
# Epoch 43/200
# mean max of probabilities: 0.013060106 - temperature 2.985078
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0327 - val_loss: 0.0339
# Epoch 44/200
# mean max of probabilities: 0.013327633 - temperature 2.9003782
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0323 - val_loss: 0.0333
# Epoch 45/200
# mean max of probabilities: 0.013609061 - temperature 2.8180816
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0319 - val_loss: 0.0328
# Epoch 46/200
# mean max of probabilities: 0.013929711 - temperature 2.7381203
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0315 - val_loss: 0.0325
# Epoch 47/200
# mean max of probabilities: 0.014297996 - temperature 2.660428
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0310 - val_loss: 0.0319
# Epoch 48/200
# mean max of probabilities: 0.014697304 - temperature 2.5849407
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0305 - val_loss: 0.0317
# Epoch 49/200
# mean max of probabilities: 0.015166632 - temperature 2.5115943
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0301 - val_loss: 0.0311
# Epoch 50/200
# mean max of probabilities: 0.01569589 - temperature 2.4403296
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0296 - val_loss: 0.0306
# Epoch 51/200
# mean max of probabilities: 0.016247688 - temperature 2.3710868
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0292 - val_loss: 0.0302
# Epoch 52/200
# mean max of probabilities: 0.016871523 - temperature 2.3038063
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0288 - val_loss: 0.0298
# Epoch 53/200
# mean max of probabilities: 0.01748178 - temperature 2.238438
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0284 - val_loss: 0.0293
# Epoch 54/200
# mean max of probabilities: 0.018165424 - temperature 2.1749234
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0280 - val_loss: 0.0290
# Epoch 55/200
# mean max of probabilities: 0.018903859 - temperature 2.1132112
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0276 - val_loss: 0.0286
# Epoch 56/200
# mean max of probabilities: 0.019658621 - temperature 2.0532503
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0272 - val_loss: 0.0283
# Epoch 57/200
# mean max of probabilities: 0.020451264 - temperature 1.9949908
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0268 - val_loss: 0.0280
# Epoch 58/200
# mean max of probabilities: 0.021274764 - temperature 1.9383844
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0264 - val_loss: 0.0275
# Epoch 59/200
# mean max of probabilities: 0.022161424 - temperature 1.883384
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0261 - val_loss: 0.0272
# Epoch 60/200
# mean max of probabilities: 0.0230514 - temperature 1.8299441
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0258 - val_loss: 0.0268
# Epoch 61/200
# mean max of probabilities: 0.023955364 - temperature 1.7780205
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0254 - val_loss: 0.0267
# Epoch 62/200
# mean max of probabilities: 0.024756387 - temperature 1.7275708
# 1152/1152 [==============================] - 1s 981us/step - loss: 0.0251 - val_loss: 0.0262
# Epoch 63/200
# mean max of probabilities: 0.0256193 - temperature 1.6785522
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0249 - val_loss: 0.0261
# Epoch 64/200
# mean max of probabilities: 0.026389413 - temperature 1.6309243
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0247 - val_loss: 0.0256
# Epoch 65/200
# mean max of probabilities: 0.027264385 - temperature 1.5846478
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0245 - val_loss: 0.0255
# Epoch 66/200
# mean max of probabilities: 0.028148206 - temperature 1.5396848
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0240 - val_loss: 0.0254
# Epoch 67/200
# mean max of probabilities: 0.029091083 - temperature 1.4959973
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0240 - val_loss: 0.0251
# Epoch 68/200
# mean max of probabilities: 0.030000456 - temperature 1.4535494
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0239 - val_loss: 0.0255
# Epoch 69/200
# mean max of probabilities: 0.030885119 - temperature 1.4123058
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0236 - val_loss: 0.0249
# Epoch 70/200
# mean max of probabilities: 0.031658716 - temperature 1.3722323
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0236 - val_loss: 0.0251
# Epoch 71/200
# ...
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0246 - val_loss: 0.0248
# Epoch 126/200
# mean max of probabilities: 0.111846454 - temperature 0.27376017
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0236 - val_loss: 0.0249
# Epoch 127/200
# mean max of probabilities: 0.1132772 - temperature 0.26599237
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0243 - val_loss: 0.0250
# Epoch 128/200
# mean max of probabilities: 0.11496728 - temperature 0.258445
# 1152/1152 [==============================] - 4s 3ms/step - loss: 0.0240 - val_loss: 0.0242
# Epoch 129/200
# mean max of probabilities: 0.11639353 - temperature 0.2511118
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0237 - val_loss: 0.0245
# Epoch 130/200
# mean max of probabilities: 0.117643766 - temperature 0.24398667
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0244 - val_loss: 0.0245
# Epoch 131/200
# mean max of probabilities: 0.11930221 - temperature 0.23706366
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0238 - val_loss: 0.0240
# Epoch 132/200
# mean max of probabilities: 0.12103807 - temperature 0.23033713
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0235 - val_loss: 0.0241
# Epoch 133/200
# mean max of probabilities: 0.12245495 - temperature 0.22380143
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0236 - val_loss: 0.0239
# Epoch 134/200
# mean max of probabilities: 0.12408806 - temperature 0.21745126
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0236 - val_loss: 0.0238
# Epoch 135/200
# mean max of probabilities: 0.12552565 - temperature 0.21128118
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0238 - val_loss: 0.0245
# Epoch 136/200
# mean max of probabilities: 0.12685972 - temperature 0.20528622
# 1152/1152 [==============================] - 3s 2ms/step - loss: 0.0240 - val_loss: 0.0251
# Epoch 137/200
# mean max of probabilities: 0.12849054 - temperature 0.19946134
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0234 - val_loss: 0.0243
# Epoch 138/200
# mean max of probabilities: 0.12992963 - temperature 0.19380175
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0235 - val_loss: 0.0242
# Epoch 139/200
# mean max of probabilities: 0.13146497 - temperature 0.18830274
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0239 - val_loss: 0.0240
# Epoch 140/200
# mean max of probabilities: 0.13288997 - temperature 0.18295975
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0235 - val_loss: 0.0241
# Epoch 141/200
# mean max of probabilities: 0.13473457 - temperature 0.17776836
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0237 - val_loss: 0.0244
# Epoch 142/200
# mean max of probabilities: 0.13617736 - temperature 0.1727243
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0233 - val_loss: 0.0239
# Epoch 143/200
# mean max of probabilities: 0.13764168 - temperature 0.16782336
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0236 - val_loss: 0.0241
# Epoch 144/200
# mean max of probabilities: 0.13905159 - temperature 0.16306145
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0238 - val_loss: 0.0250
# Epoch 145/200
# mean max of probabilities: 0.14057237 - temperature 0.1584347
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0241 - val_loss: 0.0236
# Epoch 146/200
# mean max of probabilities: 0.14240633 - temperature 0.15393922
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0234 - val_loss: 0.0246
# Epoch 147/200
# mean max of probabilities: 0.14393635 - temperature 0.14957133
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0236 - val_loss: 0.0235
# Epoch 148/200
# mean max of probabilities: 0.14547265 - temperature 0.14532721
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0238 - val_loss: 0.0243
# Epoch 149/200
# mean max of probabilities: 0.14666328 - temperature 0.14120358
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0233 - val_loss: 0.0247
# Epoch 150/200
# mean max of probabilities: 0.14791016 - temperature 0.13719703
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0233 - val_loss: 0.0243
# Epoch 151/200
# mean max of probabilities: 0.14907853 - temperature 0.13330416
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0232 - val_loss: 0.0236
# Epoch 152/200
# mean max of probabilities: 0.15068355 - temperature 0.12952176
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0234 - val_loss: 0.0242
# Epoch 153/200
# mean max of probabilities: 0.15199521 - temperature 0.12584665
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0232 - val_loss: 0.0238
# Epoch 154/200
# mean max of probabilities: 0.15321593 - temperature 0.12227585
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0233 - val_loss: 0.0245
# Epoch 155/200
# mean max of probabilities: 0.15478285 - temperature 0.11880635
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0233 - val_loss: 0.0232
# Epoch 156/200
# mean max of probabilities: 0.1560666 - temperature 0.115435295
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0236 - val_loss: 0.0241
# Epoch 157/200
# mean max of probabilities: 0.15760094 - temperature 0.112159885
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0238 - val_loss: 0.0242
# Epoch 158/200
# mean max of probabilities: 0.15870401 - temperature 0.10897743
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0228 - val_loss: 0.0241
# Epoch 159/200
# mean max of probabilities: 0.15997304 - temperature 0.105885275
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0232 - val_loss: 0.0243
# Epoch 160/200
# mean max of probabilities: 0.1612679 - temperature 0.10288084
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0236 - val_loss: 0.0244
# Epoch 161/200
# mean max of probabilities: 0.16259897 - temperature 0.1
# 1152/1152 [==============================] - 3s 2ms/step - loss: 0.0235 - val_loss: 0.0245
# Epoch 162/200
# mean max of probabilities: 0.16378307 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0228 - val_loss: 0.0239
# Epoch 163/200
# mean max of probabilities: 0.16499515 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0235 - val_loss: 0.0240
# Epoch 164/200
# mean max of probabilities: 0.16601127 - temperature 0.1
# 1152/1152 [==============================] - 3s 2ms/step - loss: 0.0229 - val_loss: 0.0235
# Epoch 165/200
# mean max of probabilities: 0.1673723 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0234 - val_loss: 0.0247
# Epoch 166/200
# mean max of probabilities: 0.16878518 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0228 - val_loss: 0.0245
# Epoch 167/200
# mean max of probabilities: 0.17002884 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0230 - val_loss: 0.0234
# Epoch 168/200
# mean max of probabilities: 0.17130914 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0224 - val_loss: 0.0228
# Epoch 169/200
# mean max of probabilities: 0.172128 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0227 - val_loss: 0.0239
# Epoch 170/200
# mean max of probabilities: 0.17308342 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0230 - val_loss: 0.0225
# Epoch 171/200
# mean max of probabilities: 0.17417528 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0231 - val_loss: 0.0226
# Epoch 172/200
# mean max of probabilities: 0.17574322 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0228 - val_loss: 0.0224
# Epoch 173/200
# mean max of probabilities: 0.17704514 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0224 - val_loss: 0.0227
# Epoch 174/200
# mean max of probabilities: 0.17803779 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0231 - val_loss: 0.0239
# Epoch 175/200
# mean max of probabilities: 0.17937556 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0229 - val_loss: 0.0231
# Epoch 176/200
# mean max of probabilities: 0.1807627 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0225 - val_loss: 0.0237
# Epoch 177/200
# mean max of probabilities: 0.18169616 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0224 - val_loss: 0.0236
# Epoch 178/200
# mean max of probabilities: 0.18287197 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0225 - val_loss: 0.0227
# Epoch 179/200
# mean max of probabilities: 0.18397197 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0224 - val_loss: 0.0229
# Epoch 180/200
# mean max of probabilities: 0.1855249 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0222 - val_loss: 0.0226
# Epoch 181/200
# mean max of probabilities: 0.1868887 - temperature 0.1
# 1152/1152 [==============================] - 3s 2ms/step - loss: 0.0221 - val_loss: 0.0236
# Epoch 182/200
# mean max of probabilities: 0.18817057 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 183/200
# mean max of probabilities: 0.18942347 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0226 - val_loss: 0.0237
# Epoch 184/200
# mean max of probabilities: 0.1907437 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0226 - val_loss: 0.0241
# Epoch 185/200
# mean max of probabilities: 0.19184911 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0225 - val_loss: 0.0228
# Epoch 186/200
# mean max of probabilities: 0.19285822 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0221 - val_loss: 0.0233
# Epoch 187/200
# mean max of probabilities: 0.19397591 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0222 - val_loss: 0.0236
# Epoch 188/200
# mean max of probabilities: 0.19564304 - temperature 0.1
# 1152/1152 [==============================] - 3s 2ms/step - loss: 0.0226 - val_loss: 0.0232
# Epoch 189/200
# mean max of probabilities: 0.19696465 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0222 - val_loss: 0.0232
# Epoch 190/200
# mean max of probabilities: 0.19824459 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0218 - val_loss: 0.0227
# Epoch 191/200
# mean max of probabilities: 0.19947857 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0219 - val_loss: 0.0217
# Epoch 192/200
# mean max of probabilities: 0.20058276 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0220 - val_loss: 0.0227
# Epoch 193/200
# mean max of probabilities: 0.20199838 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0216 - val_loss: 0.0222
# Epoch 194/200
# mean max of probabilities: 0.20350291 - temperature 0.1
# 1152/1152 [==============================] - 3s 2ms/step - loss: 0.0218 - val_loss: 0.0235
# Epoch 195/200
# mean max of probabilities: 0.20484194 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0220 - val_loss: 0.0221
# Epoch 196/200
# mean max of probabilities: 0.20596461 - temperature 0.1
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0220 - val_loss: 0.0221
# Epoch 197/200
# mean max of probabilities: 0.20716715 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0220 - val_loss: 0.0224
# Epoch 198/200
# mean max of probabilities: 0.2084586 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0215 - val_loss: 0.0225
# Epoch 199/200
# mean max of probabilities: 0.20959696 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0217 - val_loss: 0.0213
# Epoch 200/200
# mean max of probabilities: 0.21096504 - temperature 0.1
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0214 - val_loss: 0.0217
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9965277777777778
# Testing accuracy： 0.9965277777777778
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9826388888888888
# Testing accuracy： 0.9826388888888888
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 50)                20001
# _________________________________________________________________
# dense_4 (Dense)              (None, 400)               20400
# =================================================================
# Total params: 40,401
# Trainable params: 40,400
# Non-trainable params: 1
# _________________________________________________________________
# None
# Train on 1152 samples, validate on 288 samples
# Epoch 1/200
# mean max of probabilities: 0.002894992 - temperature 10.0
# 1152/1152 [==============================] - 7s 6ms/step - loss: 0.0785 - val_loss: 0.0498
# Epoch 2/200
# mean max of probabilities: 0.0029070482 - temperature 9.716257
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0492 - val_loss: 0.0497
# Epoch 3/200
# mean max of probabilities: 0.0029266027 - temperature 9.440558
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0491 - val_loss: 0.0494
# Epoch 4/200
# mean max of probabilities: 0.0029577822 - temperature 9.172705
# 1152/1152 [==============================] - 1s 1ms/step - loss: 0.0486 - val_loss: 0.0490
# Epoch 5/200
# mean max of probabilities: 0.0029996142 - temperature 8.912436
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0483 - val_loss: 0.0489
# Epoch 6/200
# mean max of probabilities: 0.003048873 - temperature 8.659551
# 1152/1152 [==============================] - 2s 1ms/step - loss: 0.0481 - val_loss: 0.0485
# Epoch 7/200
# mean max of probabilities: 0.0031043184 - temperature 8.413841
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0478 - val_loss: 0.0487
# Epoch 8/200
# mean max of probabilities: 0.0031707636 - temperature 8.175103
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0474 - val_loss: 0.0482
# Epoch 9/200
# mean max of probabilities: 0.0032429874 - temperature 7.9431396
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0474 - val_loss: 0.0480
# Epoch 10/200
# mean max of probabilities: 0.0033242817 - temperature 7.7177577
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0471 - val_loss: 0.0480
# Epoch 11/200
# mean max of probabilities: 0.003412236 - temperature 7.498771
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0469 - val_loss: 0.0477
# Epoch 12/200
# mean max of probabilities: 0.0035070863 - temperature 7.285998
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0467 - val_loss: 0.0476
# Epoch 13/200
# mean max of probabilities: 0.003609807 - temperature 7.079262
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0467 - val_loss: 0.0479
# Epoch 14/200
# mean max of probabilities: 0.003719984 - temperature 6.8783927
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0466 - val_loss: 0.0474
# Epoch 15/200
# mean max of probabilities: 0.003840065 - temperature 6.6832232
# 1152/1152 [==============================] - 2s 2ms/step - loss: 0.0465 - val_loss: 0.0472
# Epoch 16/200
