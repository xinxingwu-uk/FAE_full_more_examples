# %%
import numpy as np
import pandas as pd
import os

# %%
fold_path=['1_LS_CV','2_SPEC_CV','3_NDFS_CV','4_AEFS_CV','5_UDFS_CV','6_MCFS_CV','7_PFA_CV','8_InfFS_CV','9_AgnoSS_CV','10_CAE_CV','11_FAE_50_CV','12_FAE_36_CV']

# %%
cv_times_from=0
cv_times_to=5

# %%
file_path="/log/"

for fold_path_i in fold_path:
    fold_name=fold_path_i.split('_')[1]
    print(fold_name+":\n")
    
    if fold_path_i in ['11_FAE_50_CV','12_FAE_36_CV']:
        print("Do not use bias!",fold_path_i)
        p_is_use_bias=False
        path_results='./'+fold_path_i+file_path+"FAE_results_bias_"+str(p_is_use_bias)+".csv" 
        results_analysis=np.array(pd.read_csv(path_results,header=None))
        results_analysis_test_acc__=results_analysis[:,3]
        results_analysis_test_acc_=results_analysis_test_acc__[np.where(results_analysis[:,3]>=0)]
        cv_cal_times=len(results_analysis_test_acc__)
        if cv_cal_times >=(cv_times_to-cv_times_from):
        
            print("cv times: ",cv_cal_times)
        
            results_analysis_test_acc=results_analysis_test_acc_[cv_times_from:cv_times_to]
            results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]
        
            print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
            print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

            path_time='./'+fold_path_i+file_path+"FAE_time_bias_"+str(p_is_use_bias)+".csv"
            time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
            print("Calculation times: ", len(results_analysis_test_acc))  
        
            print("Use bias!",fold_path_i)
            p_is_use_bias=True
            path_results='./'+fold_path_i+file_path+"FAE_results_bias_"+str(p_is_use_bias)+".csv"  
            results_analysis=np.array(pd.read_csv(path_results,header=None))
            results_analysis_test_acc=results_analysis[:,3][np.where(results_analysis[:,3]>=0)][cv_times_from:cv_times_to]
            results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]
        
            print(results_analysis_test_acc)
            print(results_analysis_linear_rec)
            print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
            print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

            path_time='./'+fold_path_i+file_path+"FAE_time_bias_"+str(p_is_use_bias)+".csv"
            time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
            print("Calculation times: ", len(results_analysis_test_acc))          
    
    else:
        path_results='./'+fold_path_i+file_path+fold_name+'_results.csv'
        
        if os.path.exists(path_results):
            results_analysis=np.array(pd.read_csv(path_results,header=None))

            results_analysis_test_acc__=results_analysis[:,3]
            results_analysis_test_acc_=results_analysis_test_acc__[np.where(results_analysis[:,3]>=0)]
            cv_cal_times=len(results_analysis_test_acc__)
                
            cv_cal_times=len(results_analysis_test_acc_)
            if cv_cal_times>=(cv_times_to-cv_times_from):

                print("cv times: ",cv_cal_times)        
                
                results_analysis_test_acc=results_analysis_test_acc_[cv_times_from:cv_times_to]
                results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]

                print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
                print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

                path_time='./'+fold_path_i+file_path+fold_path_i.split('_')[1]+'_time.csv'
                time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
                print("Calculation times: ", len(results_analysis_test_acc))
    
                print("\n\n")
        else:
            print("Nan")
            print("\n\n")
# Out:
# LS:
#
# cv times:  50
# Testing accuarcy:0.171 ±0.0278
# Testing Linear reconstruction: 11.352 ±22.5123
# Calculation times:  5
#
#
#
# SPEC:
#
# cv times:  50
# Testing accuarcy:0.272 ±0.0174
# Testing Linear reconstruction: 0.109 ±0.0066
# Calculation times:  5
#
#
#
# NDFS:
#
# cv times:  9
# Testing accuarcy:0.152 ±0.0452
# Testing Linear reconstruction: 0.139 ±0.0099
# Calculation times:  5
#
#
#
# AEFS:
#
# cv times:  13
# Testing accuarcy:0.794 ±0.0149
# Testing Linear reconstruction: 0.023 ±0.0003
# Calculation times:  5
#
#
#
# UDFS:
#
# cv times:  6
# Testing accuarcy:0.793 ±0.0122
# Testing Linear reconstruction: 0.027 ±0.0025
# Calculation times:  5
#
#
#
# MCFS:
#
# cv times:  50
# Testing accuarcy:0.163 ±0.0085
# Testing Linear reconstruction: 0.458 ±0.6574
# Calculation times:  5
#
#
#
# PFA:
#
# cv times:  50
# Testing accuarcy:0.803 ±0.0105
# Testing Linear reconstruction: 0.022 ±0.0004
# Calculation times:  5
#
#
#
# InfFS:
#
# cv times:  50
# Testing accuarcy:0.188 ±0.0378
# Testing Linear reconstruction: 0.105 ±0.0059
# Calculation times:  5
#
#
#
# AgnoSS:
#
# cv times:  43
# Testing accuarcy:0.784 ±0.0128
# Testing Linear reconstruction: 0.025 ±0.0013
# Calculation times:  5
#
#
#
# CAE:
#
# cv times:  29
# Testing accuarcy:0.823 ±0.0101
# Testing Linear reconstruction: 0.019 ±0.0004
# Calculation times:  5
#
#
#
# FAE:
#
# Do not use bias! 11_FAE_50_CV
# cv times:  50
# Testing accuarcy:0.822 ±0.0089
# Testing Linear reconstruction: 0.019 ±0.0002
# Calculation times:  5
# Use bias! 11_FAE_50_CV
# [0.824  0.8315 0.814  0.8235 0.83  ]
# [0.01902177 0.01910991 0.01922637 0.01916993 0.01929098]
# Testing accuarcy:0.825 ±0.0062
# Testing Linear reconstruction: 0.019 ±0.0001
# Calculation times:  5
# FAE:
#
# Do not use bias! 12_FAE_36_CV
# cv times:  50
# Testing accuarcy:0.807 ±0.0096
# Testing Linear reconstruction: 0.022 ±0.0002
# Calculation times:  5
# Use bias! 12_FAE_36_CV
# [0.81   0.815  0.7905 0.815  0.808 ]
# [0.02207849 0.02222173 0.02227833 0.02245334 0.02208581]
# Testing accuarcy:0.808 ±0.0090
# Testing Linear reconstruction: 0.022 ±0.0001
# Calculation times:  5
