# %%
import numpy as np
import pandas as pd
import os

# %%
fold_path=['1_LS_CV','2_SPEC_CV','3_NDFS_CV','4_AEFS_CV','5_UDFS_CV','6_MCFS_CV','7_PFA_CV','8_InfFS_CV','9_AgnoSS_CV','10_CAE_CV','11_FAE_10_CV','12_FAE_8_CV']

# %%
cv_times_from=0
cv_times_to=5

# %%
file_path="/log/"

for fold_path_i in fold_path:
    fold_name=fold_path_i.split('_')[1]
    print(fold_name+":\n")
    
    if fold_path_i in ['11_FAE_10_CV','12_FAE_8_CV']:
        print("Do not use bias!",fold_path_i)
        p_is_use_bias=False
        path_results='./'+fold_path_i+file_path+"FAE_results_bias_"+str(p_is_use_bias)+".csv" 
        results_analysis=np.array(pd.read_csv(path_results,header=None))
        results_analysis_test_acc__=results_analysis[:,3]
        results_analysis_test_acc_=results_analysis_test_acc__[np.where(results_analysis[:,3]>=0)]
        cv_cal_times=len(results_analysis_test_acc__)
        if cv_cal_times >=(cv_times_to-cv_times_from):
        
            print("cv times: ",cv_cal_times)
        
            results_analysis_test_acc=results_analysis_test_acc_[cv_times_from:cv_times_to]
            results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]
            print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
            print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

            path_time='./'+fold_path_i+file_path+"FAE_time_bias_"+str(p_is_use_bias)+".csv"
            time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
            print("Calculation times: ", len(results_analysis_test_acc))  
        
            print("Use bias!",fold_path_i)
            p_is_use_bias=True
            path_results='./'+fold_path_i+file_path+"FAE_results_bias_"+str(p_is_use_bias)+".csv"  
            results_analysis=np.array(pd.read_csv(path_results,header=None))
            results_analysis_test_acc=results_analysis[:,3][np.where(results_analysis[:,3]>=0)][cv_times_from:cv_times_to]
            results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]
            print(results_analysis_test_acc)
            print(results_analysis_linear_rec)        
            print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
            print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

            path_time='./'+fold_path_i+file_path+"FAE_time_bias_"+str(p_is_use_bias)+".csv"
            time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
            print("Calculation times: ", len(results_analysis_test_acc))          
    
    else:
        path_results='./'+fold_path_i+file_path+fold_name+'_results.csv'
        
        if os.path.exists(path_results):
            results_analysis=np.array(pd.read_csv(path_results,header=None))

            results_analysis_test_acc__=results_analysis[:,3]
            results_analysis_test_acc_=results_analysis_test_acc__[np.where(results_analysis[:,3]>=0)]
            cv_cal_times=len(results_analysis_test_acc__)
                
            cv_cal_times=len(results_analysis_test_acc_)
            if cv_cal_times>=(cv_times_to-cv_times_from):

                print("cv times: ",cv_cal_times)        
                
                results_analysis_test_acc=results_analysis_test_acc_[cv_times_from:cv_times_to]
                results_analysis_linear_rec=results_analysis[:,4][np.where(results_analysis[:,4]>=0)][cv_times_from:cv_times_to]
                print("Testing accuarcy:%.3f"%np.mean(results_analysis_test_acc),"±%.4f"%np.std(results_analysis_test_acc))
                print("Testing Linear reconstruction: %.3f" % np.mean(results_analysis_linear_rec),"±%.4f"%np.std(results_analysis_linear_rec))

                path_time='./'+fold_path_i+file_path+fold_path_i.split('_')[1]+'_time.csv'
                time_analysis=np.array(pd.read_csv(path_time,header=None))[cv_times_from:cv_times_to]
    
                print("Calculation times: ", len(results_analysis_test_acc))
    
                print("\n\n")
        else:
            print("Nan")
            print("\n\n")
# Out:
# LS:
#
# cv times:  50
# Testing accuarcy:0.173 ±0.0404
# Testing Linear reconstruction: 0.575 ±0.1177
# Calculation times:  5
#
#
#
# SPEC:
#
# cv times:  50
# Testing accuarcy:0.137 ±0.0364
# Testing Linear reconstruction: 1.324 ±1.7774
# Calculation times:  5
#
#
#
# NDFS:
#
# cv times:  50
# Testing accuarcy:0.156 ±0.1052
# Testing Linear reconstruction: 1.686 ±0.9749
# Calculation times:  5
#
#
#
# AEFS:
#
# cv times:  50
# Testing accuarcy:0.885 ±0.0395
# Testing Linear reconstruction: 0.020 ±0.0070
# Calculation times:  5
#
#
#
# UDFS:
#
# cv times:  50
# Testing accuarcy:0.951 ±0.0402
# Testing Linear reconstruction: 0.009 ±0.0056
# Calculation times:  5
#
#
#
# MCFS:
#
# cv times:  50
# Testing accuarcy:0.174 ±0.0590
# Testing Linear reconstruction: 16.513 ±30.3574
# Calculation times:  5
#
#
#
# PFA:
#
# cv times:  50
# Testing accuarcy:0.928 ±0.0285
# Testing Linear reconstruction: 0.028 ±0.0017
# Calculation times:  5
#
#
#
# InfFS:
#
# cv times:  50
# Testing accuarcy:0.193 ±0.0685
# Testing Linear reconstruction: 0.443 ±0.0397
# Calculation times:  5
#
#
#
# AgnoSS:
#
# cv times:  21
# Testing accuarcy:0.632 ±0.3718
# Testing Linear reconstruction: 0.038 ±0.0137
# Calculation times:  5
#
#
#
# CAE:
#
# cv times:  29
# Testing accuarcy:0.669 ±0.0483
# Testing Linear reconstruction: 0.032 ±0.0010
# Calculation times:  5
#
#
#
# FAE:
#
# Do not use bias! 11_FAE_10_CV
# cv times:  50
# Testing accuarcy:0.919 ±0.0612
# Testing Linear reconstruction: 0.011 ±0.0046
# Calculation times:  5
# Use bias! 11_FAE_10_CV
# [0.875      0.9537037  0.74074074 0.9212963  0.89814815]
# [0.00946416 0.01836337 0.01884864 0.01477661 0.00614426]
# Testing accuarcy:0.878 ±0.0733
# Testing Linear reconstruction: 0.014 ±0.0050
# Calculation times:  5
# FAE:
#
# Do not use bias! 12_FAE_8_CV
# cv times:  50
# Testing accuarcy:0.874 ±0.0835
# Testing Linear reconstruction: 0.012 ±0.0046
# Calculation times:  5
# Use bias! 12_FAE_8_CV
# [0.90277778 0.83796296 0.42592593 0.85185185 0.91203704]
# [0.01117595 0.01478751 0.02218418 0.01584816 0.00864665]
# Testing accuarcy:0.786 ±0.1823
# Testing Linear reconstruction: 0.015 ±0.0046
# Calculation times:  5
