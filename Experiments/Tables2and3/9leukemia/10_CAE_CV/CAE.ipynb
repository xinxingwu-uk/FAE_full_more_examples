# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)

#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse
import scipy.io
import time
from keras.utils import to_categorical
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from skfeature.utility import construct_W
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from skfeature.utility.sparse_learning import feature_ranking
import time
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from concrete_autoencoder import ConcreteAutoencoderFeatureSelector
from keras.layers import Dense
import pandas as pd

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"../Defined")
import Functions as F
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
data_path="../Dataset/leukemia.mat"
Data = scipy.io.loadmat(data_path)

data_arr_=Data['X']
label_arr_=Data['Y'][:, 0]

label_arr_=np.array([0 if label_arr_i<0 else label_arr_i for label_arr_i in label_arr_])

Data=StandardScaler().fit_transform(data_arr_)
data_arr=Data

label_arr=label_arr_

label_arr_onehot=label_arr#to_categorical(label_arr)

# %%
key_feture_number=64

# %% [markdown]
# # 3. Calculation

# %%
#--------------------------------------------------------------------------------------------------------------------------------
def write_to_csv(p_data,p_path):
    dataframe = pd.DataFrame(p_data)
    dataframe.to_csv(p_path, mode='a',header=False,index=False,sep=',')
    del dataframe

#--------------------------------------------------------------------------------------------------------------------------------       
def mse_check(train, test):
    LR = LinearRegression(n_jobs = -1)
    LR.fit(train[0], train[1])
    MSELR = ((LR.predict(test[0]) - test[1]) ** 2).mean()
    return MSELR
 
#--------------------------------------------------------------------------------------------------------------------------------       
def cal(p_data_arr,\
        p_label_arr_onehot,\
        p_key_feture_number,\
        p_epochs_number,\
        p_seed):
    
    C_train_x,C_test_x,C_train_y,C_test_y= train_test_split(p_data_arr,p_label_arr_onehot,test_size=0.2,random_state=p_seed)

    os.environ['PYTHONHASHSEED'] = str(p_seed)
    np.random.seed(p_seed)
    rn.seed(p_seed)
    tf.compat.v1.set_random_seed(p_seed)
    
    #--------------------------------------------------------------------------------------------------------------------------------
    
    def decoder(x):
        #x = Dense(key_feture_number)(x)
        x = Dense(data_arr.shape[1])(x)
        return x

    t_start = time.time()
    selector = ConcreteAutoencoderFeatureSelector(K = p_key_feture_number, output_function = decoder, num_epochs = p_epochs_number)
    selector.fit(C_train_x, C_train_x, C_test_x, C_test_x)
    t_used=time.time() - t_start
    
    write_to_csv(np.array([t_used]),"./log/CAE_time.csv")
    
    train_compressed_Data=p_data_arr[:, selector.get_support(indices=True)]
    
    # Classification on original features
    train_feature=C_train_x
    train_label=C_train_y
    test_feature=C_test_x
    test_label=C_test_y 
    orig_train_acc,orig_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
        
    # Classification on selected features
    C_train_selected_x,C_test_selected_x,C_train_y,C_test_y= train_test_split(train_compressed_Data,p_label_arr_onehot,test_size=0.2,random_state=p_seed)
    
    train_feature=C_train_selected_x
    train_label=C_train_y
    test_feature=C_test_selected_x
    test_label=C_test_y
    selec_train_acc,selec_test_acc=F.ETree(train_feature,train_label,test_feature,test_label,0)
    
    # Linear reconstruction
    train_feature_tuple=(C_train_selected_x,C_train_x)
    test_feature_tuple=(C_test_selected_x,C_test_x)

    reconstruction_loss=mse_check(train_feature_tuple, test_feature_tuple)
    
    results=np.array([orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss])
    
    write_to_csv(results.reshape(1,len(results)),"./log/CAE_results.csv")
    
    return orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss

# %%
epochs_number=200

p_data_arr=data_arr
p_label_arr_onehot=label_arr_onehot
p_key_feture_number=key_feture_number
p_epochs_number=epochs_number

# %%
for p_seed in np.arange(0,50):
    orig_train_acc,orig_test_acc,selec_train_acc,selec_test_acc,reconstruction_loss=cal(p_data_arr,\
                                                                                        p_label_arr_onehot,\
                                                                                        p_key_feture_number,\
                                                                                        p_epochs_number,\
                                                                                        p_seed)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 7070)              0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 64)                452481
# _________________________________________________________________
# dense_1 (Dense)              (None, 7070)              459550
# =================================================================
# Total params: 912,031
# Trainable params: 912,030
# Non-trainable params: 1
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 57 samples, validate on 15 samples
# Epoch 1/200
# mean max of probabilities: 0.00014690743 - temperature 10.0
# 57/57 [==============================] - 1s 12ms/step - loss: 0.9878 - val_loss: 1.0247
# Epoch 2/200
# mean max of probabilities: 0.00014690746 - temperature 9.716279
# 57/57 [==============================] - 0s 5ms/step - loss: 0.9713 - val_loss: 1.0173
# Epoch 3/200
# mean max of probabilities: 0.00014690818 - temperature 9.440608
# 57/57 [==============================] - 0s 8ms/step - loss: 0.9551 - val_loss: 1.0110
# Epoch 4/200
# mean max of probabilities: 0.00014691072 - temperature 9.172758
# 57/57 [==============================] - 0s 6ms/step - loss: 0.9401 - val_loss: 1.0056
# Epoch 5/200
# mean max of probabilities: 0.00014691612 - temperature 8.912507
# 57/57 [==============================] - 0s 5ms/step - loss: 0.9277 - val_loss: 1.0016
# Epoch 6/200
# mean max of probabilities: 0.00014692775 - temperature 8.659641
# 57/57 [==============================] - 0s 5ms/step - loss: 0.9184 - val_loss: 0.9984
# Epoch 7/200
# mean max of probabilities: 0.00014694693 - temperature 8.413949
# 57/57 [==============================] - 0s 5ms/step - loss: 0.9091 - val_loss: 0.9962
# Epoch 8/200
# mean max of probabilities: 0.00014697312 - temperature 8.175228
# 57/57 [==============================] - 0s 5ms/step - loss: 0.9035 - val_loss: 0.9948
# Epoch 9/200
# mean max of probabilities: 0.0001470093 - temperature 7.9432807
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8981 - val_loss: 0.9939
# Epoch 10/200
# mean max of probabilities: 0.00014705211 - temperature 7.7179136
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8943 - val_loss: 0.9935
# Epoch 11/200
# mean max of probabilities: 0.00014710159 - temperature 7.4989405
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8914 - val_loss: 0.9934
# Epoch 12/200
# mean max of probabilities: 0.0001471589 - temperature 7.2861805
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8893 - val_loss: 0.9936
# Epoch 13/200
# mean max of probabilities: 0.00014722129 - temperature 7.079457
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8878 - val_loss: 0.9939
# Epoch 14/200
# mean max of probabilities: 0.0001472898 - temperature 6.878598
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8863 - val_loss: 0.9942
# Epoch 15/200
# mean max of probabilities: 0.0001473647 - temperature 6.683439
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8855 - val_loss: 0.9947
# Epoch 16/200
# mean max of probabilities: 0.00014744388 - temperature 6.493816
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8847 - val_loss: 0.9951
# Epoch 17/200
# mean max of probabilities: 0.00014752868 - temperature 6.3095727
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8844 - val_loss: 0.9956
# Epoch 18/200
# mean max of probabilities: 0.00014761803 - temperature 6.130557
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8840 - val_loss: 0.9962
# Epoch 19/200
# mean max of probabilities: 0.00014771367 - temperature 5.95662
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8837 - val_loss: 0.9966
# Epoch 20/200
# mean max of probabilities: 0.00014781531 - temperature 5.7876186
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8835 - val_loss: 0.9970
# Epoch 21/200
# mean max of probabilities: 0.0001479194 - temperature 5.6234117
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8832 - val_loss: 0.9977
# Epoch 22/200
# mean max of probabilities: 0.00014803364 - temperature 5.463864
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8829 - val_loss: 0.9981
# Epoch 23/200
# mean max of probabilities: 0.00014815308 - temperature 5.308843
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8828 - val_loss: 0.9985
# Epoch 24/200
# mean max of probabilities: 0.0001482825 - temperature 5.1582203
# 57/57 [==============================] - 0s 4ms/step - loss: 0.8830 - val_loss: 0.9989
# Epoch 25/200
# mean max of probabilities: 0.00014842466 - temperature 5.011871
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8828 - val_loss: 0.9995
# Epoch 26/200
# mean max of probabilities: 0.00014856498 - temperature 4.869674
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8826 - val_loss: 0.9999
# Epoch 27/200
# mean max of probabilities: 0.00014870543 - temperature 4.7315116
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8826 - val_loss: 1.0004
# Epoch 28/200
# mean max of probabilities: 0.00014885259 - temperature 4.5972686
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8825 - val_loss: 1.0006
# Epoch 29/200
# mean max of probabilities: 0.00014899479 - temperature 4.4668345
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8825 - val_loss: 1.0011
# Epoch 30/200
# mean max of probabilities: 0.00014914884 - temperature 4.340101
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8824 - val_loss: 1.0016
# Epoch 31/200
# mean max of probabilities: 0.00014930706 - temperature 4.2169633
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8824 - val_loss: 1.0017
# Epoch 32/200
# mean max of probabilities: 0.00014947535 - temperature 4.097319
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8823 - val_loss: 1.0020
# Epoch 33/200
# mean max of probabilities: 0.00014965971 - temperature 3.98107
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8822 - val_loss: 1.0023
# Epoch 34/200
# mean max of probabilities: 0.00014984809 - temperature 3.868119
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8820 - val_loss: 1.0026
# Epoch 35/200
# mean max of probabilities: 0.00015003714 - temperature 3.7583725
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8819 - val_loss: 1.0028
# Epoch 36/200
# mean max of probabilities: 0.00015023445 - temperature 3.6517398
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8819 - val_loss: 1.0035
# Epoch 37/200
# mean max of probabilities: 0.0001504476 - temperature 3.5481327
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8818 - val_loss: 1.0038
# Epoch 38/200
# mean max of probabilities: 0.00015066256 - temperature 3.447465
# 57/57 [==============================] - 0s 4ms/step - loss: 0.8817 - val_loss: 1.0042
# Epoch 39/200
# mean max of probabilities: 0.00015088911 - temperature 3.3496532
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8815 - val_loss: 1.0044
# Epoch 40/200
# mean max of probabilities: 0.00015111969 - temperature 3.2546167
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8815 - val_loss: 1.0047
# Epoch 41/200
# mean max of probabilities: 0.00015135821 - temperature 3.1622767
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8815 - val_loss: 1.0052
# Epoch 42/200
# mean max of probabilities: 0.0001516025 - temperature 3.0725565
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8815 - val_loss: 1.0051
# Epoch 43/200
# mean max of probabilities: 0.00015185804 - temperature 2.9853818
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8814 - val_loss: 1.0056
# Epoch 44/200
# mean max of probabilities: 0.00015211504 - temperature 2.9006803
# 57/57 [==============================] - 0s 4ms/step - loss: 0.8810 - val_loss: 1.0056
# Epoch 45/200
# mean max of probabilities: 0.0001523817 - temperature 2.8183823
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8814 - val_loss: 1.0062
# Epoch 46/200
# mean max of probabilities: 0.00015265784 - temperature 2.7384188
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8813 - val_loss: 1.0063
# Epoch 47/200
# mean max of probabilities: 0.00015295623 - temperature 2.6607242
# 57/57 [==============================] - 0s 9ms/step - loss: 0.8810 - val_loss: 1.0066
# Epoch 48/200
# mean max of probabilities: 0.00015326426 - temperature 2.585234
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8811 - val_loss: 1.0068
# Epoch 49/200
# mean max of probabilities: 0.0001535732 - temperature 2.5118854
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8808 - val_loss: 1.0067
# Epoch 50/200
# mean max of probabilities: 0.00015389544 - temperature 2.440618
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8808 - val_loss: 1.0074
# Epoch 51/200
# mean max of probabilities: 0.00015421389 - temperature 2.3713727
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8807 - val_loss: 1.0076
# Epoch 52/200
# mean max of probabilities: 0.00015454018 - temperature 2.3040922
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8803 - val_loss: 1.0076
# Epoch 53/200
# mean max of probabilities: 0.0001548671 - temperature 2.2387204
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8802 - val_loss: 1.0084
# Epoch 54/200
# mean max of probabilities: 0.00015519766 - temperature 2.1752036
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8805 - val_loss: 1.0081
# Epoch 55/200
# mean max of probabilities: 0.0001555468 - temperature 2.1134887
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8803 - val_loss: 1.0085
# Epoch 56/200
# mean max of probabilities: 0.00015589001 - temperature 2.0535247
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8801 - val_loss: 1.0090
# Epoch 57/200
# mean max of probabilities: 0.00015625848 - temperature 1.9952619
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8796 - val_loss: 1.0091
# Epoch 58/200
# mean max of probabilities: 0.00015663491 - temperature 1.9386523
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8797 - val_loss: 1.0092
# Epoch 59/200
# mean max of probabilities: 0.00015699762 - temperature 1.8836488
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8797 - val_loss: 1.0087
# Epoch 60/200
# mean max of probabilities: 0.00015737436 - temperature 1.8302058
# 57/57 [==============================] - 0s 3ms/step - loss: 0.8797 - val_loss: 1.0096
# Epoch 61/200
# mean max of probabilities: 0.00015774704 - temperature 1.7782791
# 57/57 [==============================] - 0s 8ms/step - loss: 0.8792 - val_loss: 1.0090
# Epoch 62/200
# mean max of probabilities: 0.00015812874 - temperature 1.7278256
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8790 - val_loss: 1.0088
# Epoch 63/200
# mean max of probabilities: 0.00015851509 - temperature 1.6788038
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8789 - val_loss: 1.0109
# Epoch 64/200
# mean max of probabilities: 0.0001589137 - temperature 1.6311729
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8794 - val_loss: 1.0091
# Epoch 65/200
# mean max of probabilities: 0.00015933716 - temperature 1.5848932
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8792 - val_loss: 1.0071
# Epoch 66/200
# mean max of probabilities: 0.00015976038 - temperature 1.5399264
# 57/57 [==============================] - 1s 9ms/step - loss: 0.8787 - val_loss: 1.0116
# Epoch 67/200
# mean max of probabilities: 0.0001601828 - temperature 1.4962355
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8787 - val_loss: 1.0134
# Epoch 68/200
# mean max of probabilities: 0.00016058993 - temperature 1.4537842
# 57/57 [==============================] - 1s 9ms/step - loss: 0.8775 - val_loss: 1.0111
# Epoch 69/200
# mean max of probabilities: 0.00016100303 - temperature 1.4125375
# 57/57 [==============================] - 1s 9ms/step - loss: 0.8785 - val_loss: 1.0117
# Epoch 70/200
# mean max of probabilities: 0.00016141616 - temperature 1.372461
# 57/57 [==============================] - 0s 8ms/step - loss: 0.8797 - val_loss: 1.0102
# Epoch 71/200
# mean max of probabilities: 0.0001618182 - temperature 1.3335212
# 57/57 [==============================] - 1s 10ms/step - loss: 0.8795 - val_loss: 1.0074
# Epoch 72/200
# mean max of probabilities: 0.00016223708 - temperature 1.2956866
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8784 - val_loss: 1.0074
# Epoch 73/200
# mean max of probabilities: 0.00016265502 - temperature 1.2589254
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8791 - val_loss: 1.0140
# Epoch 74/200
# mean max of probabilities: 0.00016306546 - temperature 1.2232074
# 57/57 [==============================] - 1s 9ms/step - loss: 0.8774 - val_loss: 1.0114
# Epoch 75/200
# mean max of probabilities: 0.00016348017 - temperature 1.1885026
# 57/57 [==============================] - 0s 9ms/step - loss: 0.8776 - val_loss: 1.0199
# Epoch 76/200
# mean max of probabilities: 0.00016386717 - temperature 1.1547823
# 57/57 [==============================] - 1s 9ms/step - loss: 0.8798 - val_loss: 1.0045
# Epoch 77/200
# mean max of probabilities: 0.00016425486 - temperature 1.1220187
# 57/57 [==============================] - 1s 9ms/step - loss: 0.8851 - val_loss: 1.0188
# Epoch 78/200
# mean max of probabilities: 0.00016463606 - temperature 1.0901848
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8840 - val_loss: 1.0167
# Epoch 79/200
# mean max of probabilities: 0.00016498579 - temperature 1.0592539
# 57/57 [==============================] - 1s 12ms/step - loss: 0.8803 - val_loss: 1.0245
# Epoch 80/200
# mean max of probabilities: 0.00016534777 - temperature 1.0292008
# 57/57 [==============================] - 1s 11ms/step - loss: 0.8841 - val_loss: 1.0187
# Epoch 81/200
# mean max of probabilities: 0.0001656891 - temperature 1.0000001
# 57/57 [==============================] - 1s 12ms/step - loss: 0.8813 - val_loss: 1.0139
# Epoch 82/200
# mean max of probabilities: 0.00016600732 - temperature 0.97162807
# 57/57 [==============================] - 1s 14ms/step - loss: 0.8876 - val_loss: 1.0127
# Epoch 83/200
# mean max of probabilities: 0.0001662925 - temperature 0.9440609
# 57/57 [==============================] - 1s 11ms/step - loss: 0.8855 - val_loss: 1.0181
# Epoch 84/200
# mean max of probabilities: 0.00016657014 - temperature 0.91727597
# 57/57 [==============================] - 1s 11ms/step - loss: 0.8819 - val_loss: 1.0141
# Epoch 85/200
# mean max of probabilities: 0.00016683756 - temperature 0.8912509
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8864 - val_loss: 1.0283
# Epoch 86/200
# mean max of probabilities: 0.00016710654 - temperature 0.8659643
# 57/57 [==============================] - 1s 10ms/step - loss: 0.8865 - val_loss: 1.0042
# Epoch 87/200
# mean max of probabilities: 0.00016735482 - temperature 0.8413951
# 57/57 [==============================] - 1s 11ms/step - loss: 0.8909 - val_loss: 1.0313
# Epoch 88/200
# mean max of probabilities: 0.00016755812 - temperature 0.817523
# 57/57 [==============================] - 1s 15ms/step - loss: 0.8837 - val_loss: 1.0275
# Epoch 89/200
# mean max of probabilities: 0.0001677321 - temperature 0.7943282
# 57/57 [==============================] - 1s 12ms/step - loss: 0.8848 - val_loss: 1.0178
# Epoch 90/200
# mean max of probabilities: 0.00016791828 - temperature 0.77179146
# 57/57 [==============================] - 1s 12ms/step - loss: 0.8925 - val_loss: 1.0196
# Epoch 91/200
# mean max of probabilities: 0.00016810608 - temperature 0.7498941
# 57/57 [==============================] - 1s 12ms/step - loss: 0.8905 - val_loss: 1.0235
# Epoch 92/200
# mean max of probabilities: 0.00016828446 - temperature 0.7286181
# 57/57 [==============================] - 1s 11ms/step - loss: 0.8930 - val_loss: 1.0505
# Epoch 93/200
# mean max of probabilities: 0.00016844049 - temperature 0.70794564
# 57/57 [==============================] - 1s 13ms/step - loss: 0.8891 - val_loss: 1.0390
# Epoch 94/200
# mean max of probabilities: 0.00016859549 - temperature 0.6878598
# 57/57 [==============================] - 1s 14ms/step - loss: 0.8985 - val_loss: 1.0262
# Epoch 95/200
# mean max of probabilities: 0.00016873074 - temperature 0.6683437
# 57/57 [==============================] - 1s 16ms/step - loss: 0.8980 - val_loss: 1.0412
# Epoch 96/200
# mean max of probabilities: 0.00016884631 - temperature 0.6493814
# 57/57 [==============================] - 1s 13ms/step - loss: 0.9014 - val_loss: 1.0266
# Epoch 97/200
# mean max of probabilities: 0.00016895778 - temperature 0.6309571
# 57/57 [==============================] - 1s 14ms/step - loss: 0.8803 - val_loss: 1.0228
# Epoch 98/200
# mean max of probabilities: 0.00016905039 - temperature 0.6130556
# 57/57 [==============================] - 1s 19ms/step - loss: 0.9050 - val_loss: 1.0408
# Epoch 99/200
# mean max of probabilities: 0.00016912239 - temperature 0.59566206
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8936 - val_loss: 1.0334
# Epoch 100/200
# mean max of probabilities: 0.00016919676 - temperature 0.5787619
# 57/57 [==============================] - 1s 17ms/step - loss: 0.9031 - val_loss: 1.0653
# Epoch 101/200
# mean max of probabilities: 0.00016926427 - temperature 0.56234115
# 57/57 [==============================] - 1s 19ms/step - loss: 0.9008 - val_loss: 1.0120
# Epoch 102/200
# mean max of probabilities: 0.00016933712 - temperature 0.54638636
# 57/57 [==============================] - 1s 18ms/step - loss: 0.9059 - val_loss: 1.0259
# Epoch 103/200
# mean max of probabilities: 0.00016942293 - temperature 0.53088427
# 57/57 [==============================] - 1s 20ms/step - loss: 0.9125 - val_loss: 1.0527
# Epoch 104/200
# mean max of probabilities: 0.00016950967 - temperature 0.515822
# 57/57 [==============================] - 1s 16ms/step - loss: 0.9041 - val_loss: 1.0491
# Epoch 105/200
# mean max of probabilities: 0.0001695839 - temperature 0.501187
# 57/57 [==============================] - 1s 17ms/step - loss: 0.9044 - val_loss: 1.0458
# Epoch 106/200
# mean max of probabilities: 0.00016964252 - temperature 0.4869673
# 57/57 [==============================] - 1s 15ms/step - loss: 0.9165 - val_loss: 1.0396
# Epoch 107/200
# mean max of probabilities: 0.00016970542 - temperature 0.47315103
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8914 - val_loss: 1.0979
# Epoch 108/200
# mean max of probabilities: 0.00016976046 - temperature 0.45972672
# 57/57 [==============================] - 1s 15ms/step - loss: 0.9160 - val_loss: 1.0521
# Epoch 109/200
# mean max of probabilities: 0.00016980298 - temperature 0.44668335
# 57/57 [==============================] - 1s 17ms/step - loss: 0.9075 - val_loss: 1.0079
# Epoch 110/200
# mean max of probabilities: 0.00016984768 - temperature 0.43401006
# 57/57 [==============================] - 1s 18ms/step - loss: 0.9069 - val_loss: 1.0366
# Epoch 111/200
# mean max of probabilities: 0.00016989876 - temperature 0.4216963
# 57/57 [==============================] - 1s 21ms/step - loss: 0.9001 - val_loss: 1.0283
# Epoch 112/200
# mean max of probabilities: 0.00016994328 - temperature 0.4097319
# 57/57 [==============================] - 1s 15ms/step - loss: 0.9036 - val_loss: 1.0621
# Epoch 113/200
# mean max of probabilities: 0.00016999265 - temperature 0.398107
# 57/57 [==============================] - 1s 16ms/step - loss: 0.9133 - val_loss: 1.0367
# Epoch 114/200
# mean max of probabilities: 0.00017003829 - temperature 0.38681188
# 57/57 [==============================] - 1s 18ms/step - loss: 0.8938 - val_loss: 1.0512
# Epoch 115/200
# mean max of probabilities: 0.00017007896 - temperature 0.37583727
# 57/57 [==============================] - 1s 22ms/step - loss: 0.9104 - val_loss: 1.0668
# Epoch 116/200
# mean max of probabilities: 0.0001701274 - temperature 0.36517397
# 57/57 [==============================] - 1s 20ms/step - loss: 0.9134 - val_loss: 1.0186
# Epoch 117/200
# mean max of probabilities: 0.00017018954 - temperature 0.35481322
# 57/57 [==============================] - 1s 20ms/step - loss: 0.8845 - val_loss: 1.0456
