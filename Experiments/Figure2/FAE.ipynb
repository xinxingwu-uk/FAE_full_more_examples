# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K

#tf.set_random_seed(seed)
tf.compat.v1.set_random_seed(seed)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)

K.set_session(sess)
#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Dense, Input, Flatten, Activation, Dropout, Layer
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical
from keras import optimizers,initializers,constraints,regularizers
from keras import backend as K
from keras.callbacks import LambdaCallback,ModelCheckpoint
from keras.utils import plot_model

from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

import h5py
import math
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
matplotlib.style.use('ggplot')

import random
import scipy.sparse as sparse

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"./Defined")
import Functions as F

# The following code should be added before the keras model
#np.random.seed(seed)
# Out:
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/calculation/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Loading data

# %%
Training_samples=5400
Validating_samples=600
Testing_samples=4000

(x_train_, y_train_), (x_test_, y_test_) = mnist.load_data()
x_train = x_train_.reshape(60000, 28*28).astype('float32')[0:Training_samples] / 255.
x_validate = x_train_.reshape(60000, 28*28).astype('float32')[Training_samples:Training_samples+Validating_samples] / 255.
x_test__ = x_test_.reshape(10000, 28*28).astype('float32') / 255.

np.random.seed(seed)
x_test__num,_=x_test__.shape
index=np.arange(x_test__num)
np.random.shuffle(index)

x_test=x_test__[index][0:Testing_samples]

y_train=y_train_[0:Training_samples]
y_validate=y_train_[Training_samples:Training_samples+Validating_samples]
y_test=y_test_[index][0:Testing_samples]

y_train_onehot_ = np.array(y_train)
y_validate_onehot_ = np.array(y_validate)
y_test_onehot_ = np.array(y_test)

C_train_x=x_train_.reshape(60000, 28*28).astype('float32')[0:Training_samples+Validating_samples] / 255.
C_train_y=y_train_[0:Training_samples+Validating_samples]
C_test_x=x_test
C_test_y=np.array(y_test)

y_train_onehot = to_categorical(y_train_onehot_)
y_validate_onehot = to_categorical(y_validate_onehot_)
y_test_onehot = to_categorical(y_test_onehot_)

print('Shape of x_train: ' + str(x_train.shape)) 
print('Shape of x_validate: ' + str(x_validate.shape)) 
print('Shape of x_test: ' + str(x_test.shape))
print('Shape of y_train: ' + str(y_train_onehot.shape))
print('Shape of y_validate: ' + str(y_validate_onehot.shape))
print('Shape of y_test: ' + str(y_test_onehot.shape))

print('Shape of C_train_x: ' + str(C_train_x.shape)) 
print('Shape of C_train_y: ' + str(C_train_y.shape)) 
print('Shape of C_test_x: ' + str(C_test_x.shape)) 
print('Shape of C_test_y: ' + str(C_test_y.shape)) 
#F.show_data_figures(x_train_[0:120],28,28,40)
# Out:
# Shape of x_train: (5400, 784)
# Shape of x_validate: (600, 784)
# Shape of x_test: (4000, 784)
# Shape of y_train: (5400, 10)
# Shape of y_validate: (600, 10)
# Shape of y_test: (4000, 10)
# Shape of C_train_x: (6000, 784)
# Shape of C_train_y: (6000,)
# Shape of C_test_x: (4000, 784)
# Shape of C_test_y: (4000,)

# %%
key_feture_number=50

# %% [markdown]
# # 3.Model

# %%
np.random.seed(seed)

#--------------------------------------------------------------------------------------------------------------------------------
class Feature_Select_Layer(Layer):
    
    def __init__(self, output_dim, l1_lambda, **kwargs):
        super(Feature_Select_Layer, self).__init__(**kwargs)
        self.output_dim = output_dim
        self.l1_lambda=l1_lambda

    def build(self, input_shape):
        self.kernel = self.add_weight(name='kernel',  
                                      shape=(input_shape[1],),
                                      initializer=initializers.RandomUniform(minval=0.999999, maxval=0.9999999, seed=seed),
                                      trainable=True,
                                      regularizer=regularizers.l1(self.l1_lambda),
                                      constraint=constraints.NonNeg())
        super(Feature_Select_Layer, self).build(input_shape)
    
    def call(self, x, selection=False,k=key_feture_number):
        kernel=self.kernel        
        if selection:
            kernel_=K.transpose(kernel)
            kth_largest = tf.math.top_k(kernel_, k=k)[0][-1]
            kernel = tf.where(condition=K.less(kernel,kth_largest),x=K.zeros_like(kernel),y=kernel)        
        return K.dot(x, tf.linalg.tensor_diag(kernel))

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

#--------------------------------------------------------------------------------------------------------------------------------
def Autoencoder(p_data_feature=x_train.shape[1],\
                p_encoding_dim=key_feture_number,\
                p_learning_rate= 1E-3):
    input_img = Input(shape=(p_data_feature,), name='input_img')

    encoded = Dense(p_encoding_dim, activation='linear',kernel_initializer=initializers.glorot_uniform(seed))(input_img)
    bottleneck=encoded
    decoded = Dense(p_data_feature, activation='linear',kernel_initializer=initializers.glorot_uniform(seed))(encoded)

    latent_encoder = Model(input_img, bottleneck)
    autoencoder = Model(input_img, decoded)
    
    autoencoder.compile(loss='mean_squared_error', optimizer=optimizers.Adam(lr=p_learning_rate))
    
    print('Autoencoder Structure-------------------------------------')
    autoencoder.summary()
    #print('Latent Encoder Structure-------------------------------------')
    #latent_encoder.summary()
    return autoencoder,latent_encoder

#--------------------------------------------------------------------------------------------------------------------------------
def Identity_Autoencoder(p_data_feature=x_train.shape[1],\
                         p_encoding_dim=key_feture_number,\
                         p_learning_rate= 1E-3,\
                         p_l1_lambda=0.1):
    
    input_img = Input(shape=(p_data_feature,), name='autoencoder_input')

    feature_selection = Feature_Select_Layer(output_dim=p_data_feature,\
                                             l1_lambda=p_l1_lambda,\
                                             input_shape=(p_data_feature,),\
                                             name='feature_selection')

    feature_selection_score=feature_selection(input_img)

    encoded = Dense(p_encoding_dim,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_hidden_layer')
    
    encoded_score=encoded(feature_selection_score)
    
    bottleneck_score=encoded_score
    
    decoded = Dense(p_data_feature,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_output')
    
    decoded_score =decoded(bottleneck_score)

    latent_encoder_score = Model(input_img, bottleneck_score)
    autoencoder = Model(input_img, decoded_score)
    
    autoencoder.compile(loss='mean_squared_error',\
                        optimizer=optimizers.Adam(lr=p_learning_rate))
    
    print('Autoencoder Structure-------------------------------------')
    autoencoder.summary()
    return autoencoder,latent_encoder_score

#--------------------------------------------------------------------------------------------------------------------------------
def Fractal_Autoencoder(p_data_feature=x_train.shape[1],\
                        p_feture_number=key_feture_number,\
                        p_encoding_dim=key_feture_number,\
                        p_learning_rate=1E-3,\
                        p_l1_lambda=0.1,\
                        p_loss_weight_1=1,\
                        p_loss_weight_2=2):
    
    input_img = Input(shape=(p_data_feature,), name='autoencoder_input')

    feature_selection = Feature_Select_Layer(output_dim=p_data_feature,\
                                             l1_lambda=p_l1_lambda,\
                                             input_shape=(p_data_feature,),\
                                             name='feature_selection')

    feature_selection_score=feature_selection(input_img)
    feature_selection_choose=feature_selection(input_img,selection=True,k=p_feture_number)

    encoded = Dense(p_encoding_dim,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_hidden_layer')
    
    encoded_score=encoded(feature_selection_score)
    encoded_choose=encoded(feature_selection_choose)
    
    bottleneck_score=encoded_score
    bottleneck_choose=encoded_choose
    
    decoded = Dense(p_data_feature,\
                    activation='linear',\
                    kernel_initializer=initializers.glorot_uniform(seed),\
                    name='autoencoder_output')
    
    decoded_score =decoded(bottleneck_score)
    decoded_choose =decoded(bottleneck_choose)

    latent_encoder_score = Model(input_img, bottleneck_score)
    latent_encoder_choose = Model(input_img, bottleneck_choose)
    feature_selection_output=Model(input_img,feature_selection_choose)
    autoencoder = Model(input_img, [decoded_score,decoded_choose])
    
    autoencoder.compile(loss=['mean_squared_error','mean_squared_error'],\
                        loss_weights=[p_loss_weight_1, p_loss_weight_2],\
                        optimizer=optimizers.Adam(lr=p_learning_rate))
    
    print('Autoencoder Structure-------------------------------------')
    autoencoder.summary()
    return autoencoder,feature_selection_output,latent_encoder_score,latent_encoder_choose

# %% [markdown]
# ## 3.1 Structure and paramter testing

# %%
epochs_number=1000
batch_size_value=256

# %% [markdown]
# ---
# ### 3.1.1 Fractal Autoencoder
# ---

# %%
F_AE,\
feature_selection_output,\
latent_encoder_score_F_AE,\
latent_encoder_choose_F_AE=Fractal_Autoencoder(p_data_feature=x_train.shape[1],\
                                               p_feture_number=key_feture_number,\
                                               p_encoding_dim=key_feture_number,\
                                               p_learning_rate= 1E-3,\
                                               p_l1_lambda=0.1,\
                                               p_loss_weight_1=1,\
                                               p_loss_weight_2=2)

file_name="./log/F_AE_"+str(key_feture_number)+".png"
plot_model(F_AE, to_file=file_name,show_shapes=True)
# Out:
# WARNING:tensorflow:From <ipython-input-4-f7a6b2232bbe>:25: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Autoencoder Structure-------------------------------------
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# autoencoder_input (InputLayer)  (None, 784)          0
# __________________________________________________________________________________________________
# feature_selection (Feature_Sele (None, 784)          784         autoencoder_input[0][0]
#                                                                  autoencoder_input[0][0]
# __________________________________________________________________________________________________
# autoencoder_hidden_layer (Dense (None, 50)           39250       feature_selection[0][0]
#                                                                  feature_selection[1][0]
# __________________________________________________________________________________________________
# autoencoder_output (Dense)      (None, 784)          39984       autoencoder_hidden_layer[0][0]
#                                                                  autoencoder_hidden_layer[1][0]
# ==================================================================================================
# Total params: 80,018
# Trainable params: 80,018
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_checkpoint=ModelCheckpoint('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST{epoch:04d}.hdf5',period=100,save_weights_only=True,verbose=1)
#print_weights = LambdaCallback(on_epoch_end=lambda batch, logs: print(F_AE.layers[1].get_weights()))

F_AE_history = F_AE.fit(x_train, [x_train,x_train],\
                        epochs=epochs_number,\
                        batch_size=batch_size_value,\
                        shuffle=True,\
                        validation_data=(x_validate, [x_validate,x_validate]),\
                        callbacks=[model_checkpoint])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 5400 samples, validate on 600 samples
# Epoch 1/1000
# 5400/5400 [==============================] - 4s 673us/step - loss: 77.9419 - autoencoder_output_loss: 0.0930 - val_loss: 76.9285 - val_autoencoder_output_loss: 0.0693
# Epoch 2/1000
# 5400/5400 [==============================] - 3s 588us/step - loss: 76.1180 - autoencoder_output_loss: 0.0649 - val_loss: 75.1576 - val_autoencoder_output_loss: 0.0613
# Epoch 3/1000
# 5400/5400 [==============================] - 3s 513us/step - loss: 74.3553 - autoencoder_output_loss: 0.0594 - val_loss: 73.3980 - val_autoencoder_output_loss: 0.0557
# Epoch 4/1000
# 5400/5400 [==============================] - 3s 479us/step - loss: 72.5979 - autoencoder_output_loss: 0.0534 - val_loss: 71.6439 - val_autoencoder_output_loss: 0.0500
# Epoch 5/1000
# 5400/5400 [==============================] - 3s 500us/step - loss: 70.8477 - autoencoder_output_loss: 0.0483 - val_loss: 69.8994 - val_autoencoder_output_loss: 0.0451
# Epoch 6/1000
# 5400/5400 [==============================] - 3s 477us/step - loss: 69.1091 - autoencoder_output_loss: 0.0440 - val_loss: 68.1645 - val_autoencoder_output_loss: 0.0416
# Epoch 7/1000
# 5400/5400 [==============================] - 3s 554us/step - loss: 67.3755 - autoencoder_output_loss: 0.0412 - val_loss: 66.4323 - val_autoencoder_output_loss: 0.0390
# Epoch 8/1000
# 5400/5400 [==============================] - 3s 505us/step - loss: 65.6438 - autoencoder_output_loss: 0.0388 - val_loss: 64.7015 - val_autoencoder_output_loss: 0.0370
# Epoch 9/1000
# 5400/5400 [==============================] - 3s 552us/step - loss: 63.9136 - autoencoder_output_loss: 0.0368 - val_loss: 62.9720 - val_autoencoder_output_loss: 0.0354
# Epoch 10/1000
# 5400/5400 [==============================] - 3s 548us/step - loss: 62.1843 - autoencoder_output_loss: 0.0355 - val_loss: 61.2433 - val_autoencoder_output_loss: 0.0341
# Epoch 11/1000
# 5400/5400 [==============================] - 3s 529us/step - loss: 60.4561 - autoencoder_output_loss: 0.0344 - val_loss: 59.5157 - val_autoencoder_output_loss: 0.0332
# Epoch 12/1000
# 5400/5400 [==============================] - 3s 538us/step - loss: 58.7282 - autoencoder_output_loss: 0.0332 - val_loss: 57.7881 - val_autoencoder_output_loss: 0.0322
# Epoch 13/1000
# 5400/5400 [==============================] - 3s 621us/step - loss: 57.0007 - autoencoder_output_loss: 0.0322 - val_loss: 56.0609 - val_autoencoder_output_loss: 0.0314
# Epoch 14/1000
# 5400/5400 [==============================] - 3s 520us/step - loss: 55.2738 - autoencoder_output_loss: 0.0315 - val_loss: 54.3343 - val_autoencoder_output_loss: 0.0307
# Epoch 15/1000
# 5400/5400 [==============================] - 3s 482us/step - loss: 53.5471 - autoencoder_output_loss: 0.0311 - val_loss: 52.6079 - val_autoencoder_output_loss: 0.0302
# Epoch 16/1000
# 5400/5400 [==============================] - 3s 509us/step - loss: 51.8208 - autoencoder_output_loss: 0.0304 - val_loss: 50.8817 - val_autoencoder_output_loss: 0.0297
# Epoch 17/1000
# 5400/5400 [==============================] - 3s 514us/step - loss: 50.0946 - autoencoder_output_loss: 0.0301 - val_loss: 49.1557 - val_autoencoder_output_loss: 0.0293
# Epoch 18/1000
# 5400/5400 [==============================] - 3s 519us/step - loss: 48.3690 - autoencoder_output_loss: 0.0297 - val_loss: 47.4306 - val_autoencoder_output_loss: 0.0293
# Epoch 19/1000
# 5400/5400 [==============================] - 3s 555us/step - loss: 46.6433 - autoencoder_output_loss: 0.0295 - val_loss: 45.7045 - val_autoencoder_output_loss: 0.0287
# Epoch 20/1000
# 5400/5400 [==============================] - 3s 536us/step - loss: 44.9174 - autoencoder_output_loss: 0.0289 - val_loss: 43.9788 - val_autoencoder_output_loss: 0.0283
# Epoch 21/1000
# 5400/5400 [==============================] - 3s 480us/step - loss: 43.1917 - autoencoder_output_loss: 0.0286 - val_loss: 42.2533 - val_autoencoder_output_loss: 0.0281
# Epoch 22/1000
# 5400/5400 [==============================] - 3s 480us/step - loss: 41.4663 - autoencoder_output_loss: 0.0285 - val_loss: 40.5280 - val_autoencoder_output_loss: 0.0279
# Epoch 23/1000
# 5400/5400 [==============================] - 3s 502us/step - loss: 39.7410 - autoencoder_output_loss: 0.0280 - val_loss: 38.8029 - val_autoencoder_output_loss: 0.0277
# Epoch 24/1000
# 5400/5400 [==============================] - 3s 523us/step - loss: 38.0158 - autoencoder_output_loss: 0.0279 - val_loss: 37.0778 - val_autoencoder_output_loss: 0.0276
# Epoch 25/1000
# 5400/5400 [==============================] - 3s 515us/step - loss: 36.2908 - autoencoder_output_loss: 0.0279 - val_loss: 35.3529 - val_autoencoder_output_loss: 0.0274
# Epoch 26/1000
# 5400/5400 [==============================] - 3s 480us/step - loss: 34.5660 - autoencoder_output_loss: 0.0279 - val_loss: 33.6281 - val_autoencoder_output_loss: 0.0273
# Epoch 27/1000
# 5400/5400 [==============================] - 3s 559us/step - loss: 32.8413 - autoencoder_output_loss: 0.0277 - val_loss: 31.9036 - val_autoencoder_output_loss: 0.0273
# Epoch 28/1000
# 5400/5400 [==============================] - 3s 525us/step - loss: 31.1167 - autoencoder_output_loss: 0.0276 - val_loss: 30.1791 - val_autoencoder_output_loss: 0.0273
# Epoch 29/1000
# 5400/5400 [==============================] - 3s 532us/step - loss: 29.3923 - autoencoder_output_loss: 0.0274 - val_loss: 28.4548 - val_autoencoder_output_loss: 0.0273
# Epoch 30/1000
# 5400/5400 [==============================] - 3s 563us/step - loss: 27.6681 - autoencoder_output_loss: 0.0275 - val_loss: 26.7307 - val_autoencoder_output_loss: 0.0274
# Epoch 31/1000
# 5400/5400 [==============================] - 3s 551us/step - loss: 25.9442 - autoencoder_output_loss: 0.0277 - val_loss: 25.0069 - val_autoencoder_output_loss: 0.0274
# Epoch 32/1000
# 5400/5400 [==============================] - 3s 526us/step - loss: 24.2204 - autoencoder_output_loss: 0.0278 - val_loss: 23.2834 - val_autoencoder_output_loss: 0.0276
# Epoch 33/1000
# 5400/5400 [==============================] - 3s 482us/step - loss: 22.4970 - autoencoder_output_loss: 0.0281 - val_loss: 21.5601 - val_autoencoder_output_loss: 0.0278
# Epoch 34/1000
# 5400/5400 [==============================] - 3s 609us/step - loss: 20.7739 - autoencoder_output_loss: 0.0282 - val_loss: 19.8374 - val_autoencoder_output_loss: 0.0281
# Epoch 35/1000
# 5400/5400 [==============================] - 3s 588us/step - loss: 19.0514 - autoencoder_output_loss: 0.0284 - val_loss: 18.1151 - val_autoencoder_output_loss: 0.0284
# Epoch 36/1000
# 5400/5400 [==============================] - 3s 569us/step - loss: 17.3293 - autoencoder_output_loss: 0.0288 - val_loss: 16.3934 - val_autoencoder_output_loss: 0.0288
# Epoch 37/1000
# 5400/5400 [==============================] - 3s 514us/step - loss: 15.6081 - autoencoder_output_loss: 0.0293 - val_loss: 14.6726 - val_autoencoder_output_loss: 0.0294
# Epoch 38/1000
# 5400/5400 [==============================] - 3s 527us/step - loss: 13.8878 - autoencoder_output_loss: 0.0300 - val_loss: 12.9531 - val_autoencoder_output_loss: 0.0302
# Epoch 39/1000
# 5400/5400 [==============================] - 3s 490us/step - loss: 12.1689 - autoencoder_output_loss: 0.0308 - val_loss: 11.2351 - val_autoencoder_output_loss: 0.0312
# Epoch 40/1000
# 5400/5400 [==============================] - 3s 486us/step - loss: 10.4519 - autoencoder_output_loss: 0.0318 - val_loss: 9.5193 - val_autoencoder_output_loss: 0.0325
# Epoch 41/1000
# 5400/5400 [==============================] - 3s 518us/step - loss: 8.7374 - autoencoder_output_loss: 0.0335 - val_loss: 7.8066 - val_autoencoder_output_loss: 0.0343
# Epoch 42/1000
# 5400/5400 [==============================] - 3s 487us/step - loss: 7.0266 - autoencoder_output_loss: 0.0354 - val_loss: 6.0986 - val_autoencoder_output_loss: 0.0367
# Epoch 43/1000
# 5400/5400 [==============================] - 3s 480us/step - loss: 5.3215 - autoencoder_output_loss: 0.0382 - val_loss: 4.3978 - val_autoencoder_output_loss: 0.0402
# Epoch 44/1000
# 5400/5400 [==============================] - 3s 538us/step - loss: 3.6251 - autoencoder_output_loss: 0.0420 - val_loss: 2.7079 - val_autoencoder_output_loss: 0.0449
# Epoch 45/1000
# 5400/5400 [==============================] - 3s 531us/step - loss: 1.9427 - autoencoder_output_loss: 0.0474 - val_loss: 1.0365 - val_autoencoder_output_loss: 0.0512
# Epoch 46/1000
# 5400/5400 [==============================] - 3s 476us/step - loss: 0.4640 - autoencoder_output_loss: 0.0543 - val_loss: 0.2355 - val_autoencoder_output_loss: 0.0594
# Epoch 47/1000
# 5400/5400 [==============================] - 3s 490us/step - loss: 0.2178 - autoencoder_output_loss: 0.0621 - val_loss: 0.2073 - val_autoencoder_output_loss: 0.0663
# Epoch 48/1000
# 5400/5400 [==============================] - 3s 542us/step - loss: 0.2038 - autoencoder_output_loss: 0.0661 - val_loss: 0.2035 - val_autoencoder_output_loss: 0.0678
# Epoch 49/1000
# 5400/5400 [==============================] - 3s 508us/step - loss: 0.2025 - autoencoder_output_loss: 0.0671 - val_loss: 0.2032 - val_autoencoder_output_loss: 0.0679
# Epoch 50/1000
# 5400/5400 [==============================] - 3s 473us/step - loss: 0.2024 - autoencoder_output_loss: 0.0675 - val_loss: 0.2034 - val_autoencoder_output_loss: 0.0681
# Epoch 51/1000
# 5400/5400 [==============================] - 3s 537us/step - loss: 0.2024 - autoencoder_output_loss: 0.0673 - val_loss: 0.2037 - val_autoencoder_output_loss: 0.0683
# Epoch 52/1000
# 5400/5400 [==============================] - 3s 527us/step - loss: 0.2023 - autoencoder_output_loss: 0.0671 - val_loss: 0.2036 - val_autoencoder_output_loss: 0.0683
# Epoch 53/1000
# 5400/5400 [==============================] - 3s 478us/step - loss: 0.2022 - autoencoder_output_loss: 0.0673 - val_loss: 0.2032 - val_autoencoder_output_loss: 0.0682
# Epoch 54/1000
# 5400/5400 [==============================] - 2s 458us/step - loss: 0.2022 - autoencoder_output_loss: 0.0668 - val_loss: 0.2036 - val_autoencoder_output_loss: 0.0683
# Epoch 55/1000
# 5400/5400 [==============================] - 3s 506us/step - loss: 0.2023 - autoencoder_output_loss: 0.0672 - val_loss: 0.2031 - val_autoencoder_output_loss: 0.0681
# Epoch 56/1000
# 5400/5400 [==============================] - 3s 515us/step - loss: 0.2023 - autoencoder_output_loss: 0.0670 - val_loss: 0.2032 - val_autoencoder_output_loss: 0.0682
# Epoch 57/1000
# 5400/5400 [==============================] - 3s 477us/step - loss: 0.2022 - autoencoder_output_loss: 0.0669 - val_loss: 0.2034 - val_autoencoder_output_loss: 0.0682
# Epoch 58/1000
# 5400/5400 [==============================] - 2s 438us/step - loss: 0.2022 - autoencoder_output_loss: 0.0670 - val_loss: 0.2034 - val_autoencoder_output_loss: 0.0682
# Epoch 59/1000
# 5400/5400 [==============================] - 3s 541us/step - loss: 0.2022 - autoencoder_output_loss: 0.0673 - val_loss: 0.2032 - val_autoencoder_output_loss: 0.0681
# Epoch 60/1000
# 5400/5400 [==============================] - 2s 428us/step - loss: 0.2022 - autoencoder_output_loss: 0.0669 - val_loss: 0.2032 - val_autoencoder_output_loss: 0.0680
# Epoch 61/1000
# 5400/5400 [==============================] - 3s 486us/step - loss: 0.2021 - autoencoder_output_loss: 0.0669 - val_loss: 0.2031 - val_autoencoder_output_loss: 0.0679
# Epoch 62/1000
# 5400/5400 [==============================] - 3s 465us/step - loss: 0.2021 - autoencoder_output_loss: 0.0671 - val_loss: 0.2029 - val_autoencoder_output_loss: 0.0678
# Epoch 63/1000
# 5400/5400 [==============================] - 3s 486us/step - loss: 0.2020 - autoencoder_output_loss: 0.0668 - val_loss: 0.2028 - val_autoencoder_output_loss: 0.0677
# Epoch 64/1000
# 5400/5400 [==============================] - 2s 460us/step - loss: 0.2019 - autoencoder_output_loss: 0.0666 - val_loss: 0.2029 - val_autoencoder_output_loss: 0.0677
# Epoch 65/1000
# 5400/5400 [==============================] - 3s 495us/step - loss: 0.2018 - autoencoder_output_loss: 0.0664 - val_loss: 0.2025 - val_autoencoder_output_loss: 0.0674
# Epoch 66/1000
# 5400/5400 [==============================] - 3s 486us/step - loss: 0.2016 - autoencoder_output_loss: 0.0663 - val_loss: 0.2027 - val_autoencoder_output_loss: 0.0674
# Epoch 67/1000
# 5400/5400 [==============================] - 3s 469us/step - loss: 0.2015 - autoencoder_output_loss: 0.0662 - val_loss: 0.2021 - val_autoencoder_output_loss: 0.0671
# Epoch 68/1000
# 5400/5400 [==============================] - 2s 416us/step - loss: 0.2012 - autoencoder_output_loss: 0.0661 - val_loss: 0.2017 - val_autoencoder_output_loss: 0.0668
# Epoch 69/1000
# 5400/5400 [==============================] - 3s 500us/step - loss: 0.2010 - autoencoder_output_loss: 0.0659 - val_loss: 0.2018 - val_autoencoder_output_loss: 0.0667
# Epoch 70/1000
# 5400/5400 [==============================] - 2s 460us/step - loss: 0.2008 - autoencoder_output_loss: 0.0655 - val_loss: 0.2012 - val_autoencoder_output_loss: 0.0664
# Epoch 71/1000
# 5400/5400 [==============================] - 3s 489us/step - loss: 0.2005 - autoencoder_output_loss: 0.0656 - val_loss: 0.2008 - val_autoencoder_output_loss: 0.0662
# Epoch 72/1000
# 5400/5400 [==============================] - 3s 465us/step - loss: 0.2002 - autoencoder_output_loss: 0.0651 - val_loss: 0.2010 - val_autoencoder_output_loss: 0.0663
# Epoch 73/1000
# 5400/5400 [==============================] - 3s 533us/step - loss: 0.2000 - autoencoder_output_loss: 0.0653 - val_loss: 0.2002 - val_autoencoder_output_loss: 0.0659
# Epoch 74/1000
# 5400/5400 [==============================] - 3s 495us/step - loss: 0.1997 - autoencoder_output_loss: 0.0653 - val_loss: 0.2002 - val_autoencoder_output_loss: 0.0659
# Epoch 75/1000
# 5400/5400 [==============================] - 3s 527us/step - loss: 0.1995 - autoencoder_output_loss: 0.0652 - val_loss: 0.1999 - val_autoencoder_output_loss: 0.0658
# Epoch 76/1000
# 5400/5400 [==============================] - 3s 524us/step - loss: 0.1992 - autoencoder_output_loss: 0.0651 - val_loss: 0.1994 - val_autoencoder_output_loss: 0.0656
# Epoch 77/1000
# 5400/5400 [==============================] - 3s 491us/step - loss: 0.1990 - autoencoder_output_loss: 0.0647 - val_loss: 0.1993 - val_autoencoder_output_loss: 0.0656
# Epoch 78/1000
# 5400/5400 [==============================] - 3s 476us/step - loss: 0.1988 - autoencoder_output_loss: 0.0647 - val_loss: 0.1990 - val_autoencoder_output_loss: 0.0655
# Epoch 79/1000
# 5400/5400 [==============================] - 3s 479us/step - loss: 0.1986 - autoencoder_output_loss: 0.0646 - val_loss: 0.1991 - val_autoencoder_output_loss: 0.0656
# Epoch 80/1000
# 5400/5400 [==============================] - 3s 474us/step - loss: 0.1985 - autoencoder_output_loss: 0.0646 - val_loss: 0.1988 - val_autoencoder_output_loss: 0.0655
# Epoch 81/1000
# 5400/5400 [==============================] - 3s 473us/step - loss: 0.1983 - autoencoder_output_loss: 0.0645 - val_loss: 0.1988 - val_autoencoder_output_loss: 0.0655
# Epoch 82/1000
# 5400/5400 [==============================] - 2s 455us/step - loss: 0.1982 - autoencoder_output_loss: 0.0648 - val_loss: 0.1982 - val_autoencoder_output_loss: 0.0653
# Epoch 83/1000
# 5400/5400 [==============================] - 3s 472us/step - loss: 0.1981 - autoencoder_output_loss: 0.0645 - val_loss: 0.1982 - val_autoencoder_output_loss: 0.0654
# Epoch 84/1000
# 5400/5400 [==============================] - 2s 441us/step - loss: 0.1979 - autoencoder_output_loss: 0.0649 - val_loss: 0.1984 - val_autoencoder_output_loss: 0.0655
# Epoch 85/1000
# 5400/5400 [==============================] - 2s 446us/step - loss: 0.1978 - autoencoder_output_loss: 0.0645 - val_loss: 0.1979 - val_autoencoder_output_loss: 0.0653
# Epoch 86/1000
# 5400/5400 [==============================] - 3s 512us/step - loss: 0.1977 - autoencoder_output_loss: 0.0646 - val_loss: 0.1979 - val_autoencoder_output_loss: 0.0654
# Epoch 87/1000
# 5400/5400 [==============================] - 2s 457us/step - loss: 0.1975 - autoencoder_output_loss: 0.0649 - val_loss: 0.1978 - val_autoencoder_output_loss: 0.0653
# Epoch 88/1000
# 5400/5400 [==============================] - 2s 406us/step - loss: 0.1974 - autoencoder_output_loss: 0.0645 - val_loss: 0.1976 - val_autoencoder_output_loss: 0.0653
# Epoch 89/1000
# 5400/5400 [==============================] - 3s 496us/step - loss: 0.1974 - autoencoder_output_loss: 0.0644 - val_loss: 0.1975 - val_autoencoder_output_loss: 0.0653
# Epoch 90/1000
# 5400/5400 [==============================] - 3s 482us/step - loss: 0.1972 - autoencoder_output_loss: 0.0643 - val_loss: 0.1974 - val_autoencoder_output_loss: 0.0653
# Epoch 91/1000
# 5400/5400 [==============================] - 3s 475us/step - loss: 0.1971 - autoencoder_output_loss: 0.0644 - val_loss: 0.1974 - val_autoencoder_output_loss: 0.0653
# Epoch 92/1000
# 5400/5400 [==============================] - 2s 437us/step - loss: 0.1970 - autoencoder_output_loss: 0.0644 - val_loss: 0.1974 - val_autoencoder_output_loss: 0.0653
# Epoch 93/1000
# 5400/5400 [==============================] - 2s 457us/step - loss: 0.1970 - autoencoder_output_loss: 0.0644 - val_loss: 0.1970 - val_autoencoder_output_loss: 0.0652
# Epoch 94/1000
# 5400/5400 [==============================] - 3s 496us/step - loss: 0.1969 - autoencoder_output_loss: 0.0646 - val_loss: 0.1970 - val_autoencoder_output_loss: 0.0652
# Epoch 95/1000
# 5400/5400 [==============================] - 3s 474us/step - loss: 0.1968 - autoencoder_output_loss: 0.0646 - val_loss: 0.1971 - val_autoencoder_output_loss: 0.0653
# Epoch 96/1000
# 5400/5400 [==============================] - 3s 542us/step - loss: 0.1968 - autoencoder_output_loss: 0.0643 - val_loss: 0.1968 - val_autoencoder_output_loss: 0.0652
# Epoch 97/1000
# 5400/5400 [==============================] - 3s 523us/step - loss: 0.1967 - autoencoder_output_loss: 0.0642 - val_loss: 0.1969 - val_autoencoder_output_loss: 0.0652
# Epoch 98/1000
# 5400/5400 [==============================] - 3s 537us/step - loss: 0.1966 - autoencoder_output_loss: 0.0644 - val_loss: 0.1968 - val_autoencoder_output_loss: 0.0652
# Epoch 99/1000
# 5400/5400 [==============================] - 3s 568us/step - loss: 0.1965 - autoencoder_output_loss: 0.0646 - val_loss: 0.1967 - val_autoencoder_output_loss: 0.0652
# Epoch 100/1000
# 5400/5400 [==============================] - 3s 574us/step - loss: 0.1965 - autoencoder_output_loss: 0.0643 - val_loss: 0.1967 - val_autoencoder_output_loss: 0.0652
#
# Epoch 00100: saving model to ./log_weights/F_AE_50_weights.MNIST0100.hdf5
# Epoch 101/1000
# 5400/5400 [==============================] - 3s 545us/step - loss: 0.1964 - autoencoder_output_loss: 0.0646 - val_loss: 0.1964 - val_autoencoder_output_loss: 0.0651
# Epoch 102/1000
# 5400/5400 [==============================] - 3s 589us/step - loss: 0.1964 - autoencoder_output_loss: 0.0645 - val_loss: 0.1964 - val_autoencoder_output_loss: 0.0651
# Epoch 103/1000
# 5400/5400 [==============================] - 3s 596us/step - loss: 0.1963 - autoencoder_output_loss: 0.0646 - val_loss: 0.1966 - val_autoencoder_output_loss: 0.0652
# Epoch 104/1000
# 5400/5400 [==============================] - 3s 550us/step - loss: 0.1962 - autoencoder_output_loss: 0.0643 - val_loss: 0.1966 - val_autoencoder_output_loss: 0.0653
# Epoch 105/1000
# 5400/5400 [==============================] - 3s 529us/step - loss: 0.1962 - autoencoder_output_loss: 0.0644 - val_loss: 0.1967 - val_autoencoder_output_loss: 0.0653
# Epoch 106/1000
# 5400/5400 [==============================] - 3s 599us/step - loss: 0.1961 - autoencoder_output_loss: 0.0646 - val_loss: 0.1962 - val_autoencoder_output_loss: 0.0651
# Epoch 107/1000
# 5400/5400 [==============================] - 3s 609us/step - loss: 0.1962 - autoencoder_output_loss: 0.0645 - val_loss: 0.1962 - val_autoencoder_output_loss: 0.0651
# Epoch 108/1000
# 5400/5400 [==============================] - 4s 677us/step - loss: 0.1961 - autoencoder_output_loss: 0.0644 - val_loss: 0.1962 - val_autoencoder_output_loss: 0.0651
# Epoch 109/1000
# 5400/5400 [==============================] - 3s 628us/step - loss: 0.1961 - autoencoder_output_loss: 0.0644 - val_loss: 0.1961 - val_autoencoder_output_loss: 0.0651
# Epoch 110/1000
# 5400/5400 [==============================] - 3s 646us/step - loss: 0.1960 - autoencoder_output_loss: 0.0643 - val_loss: 0.1964 - val_autoencoder_output_loss: 0.0652
# Epoch 111/1000
# 5400/5400 [==============================] - 3s 636us/step - loss: 0.1959 - autoencoder_output_loss: 0.0641 - val_loss: 0.1961 - val_autoencoder_output_loss: 0.0652
# Epoch 112/1000
# 5400/5400 [==============================] - 4s 649us/step - loss: 0.1959 - autoencoder_output_loss: 0.0642 - val_loss: 0.1959 - val_autoencoder_output_loss: 0.0651
# Epoch 113/1000
# 5400/5400 [==============================] - 4s 649us/step - loss: 0.1958 - autoencoder_output_loss: 0.0645 - val_loss: 0.1961 - val_autoencoder_output_loss: 0.0651
# Epoch 114/1000
# 5400/5400 [==============================] - 4s 654us/step - loss: 0.1958 - autoencoder_output_loss: 0.0646 - val_loss: 0.1958 - val_autoencoder_output_loss: 0.0650
# Epoch 115/1000
# 5400/5400 [==============================] - 3s 618us/step - loss: 0.1958 - autoencoder_output_loss: 0.0643 - val_loss: 0.1958 - val_autoencoder_output_loss: 0.0651
# Epoch 116/1000
# 5400/5400 [==============================] - 4s 681us/step - loss: 0.1958 - autoencoder_output_loss: 0.0644 - val_loss: 0.1960 - val_autoencoder_output_loss: 0.0651
# Epoch 117/1000
# 5400/5400 [==============================] - 3s 569us/step - loss: 0.1958 - autoencoder_output_loss: 0.0642 - val_loss: 0.1958 - val_autoencoder_output_loss: 0.0651
# Epoch 118/1000
# 5400/5400 [==============================] - 3s 593us/step - loss: 0.1957 - autoencoder_output_loss: 0.0645 - val_loss: 0.1958 - val_autoencoder_output_loss: 0.0651
# Epoch 119/1000
# 5400/5400 [==============================] - 3s 630us/step - loss: 0.1956 - autoencoder_output_loss: 0.0643 - val_loss: 0.1958 - val_autoencoder_output_loss: 0.0651
# Epoch 120/1000
# 5400/5400 [==============================] - 3s 565us/step - loss: 0.1956 - autoencoder_output_loss: 0.0646 - val_loss: 0.1957 - val_autoencoder_output_loss: 0.0651
# Epoch 121/1000
# 5400/5400 [==============================] - 3s 646us/step - loss: 0.1956 - autoencoder_output_loss: 0.0643 - val_loss: 0.1956 - val_autoencoder_output_loss: 0.0651
# Epoch 122/1000
# 5400/5400 [==============================] - 4s 684us/step - loss: 0.1955 - autoencoder_output_loss: 0.0642 - val_loss: 0.1957 - val_autoencoder_output_loss: 0.0651
# Epoch 123/1000
# 5400/5400 [==============================] - 4s 704us/step - loss: 0.1955 - autoencoder_output_loss: 0.0643 - val_loss: 0.1957 - val_autoencoder_output_loss: 0.0651
# Epoch 124/1000
# 5400/5400 [==============================] - 3s 593us/step - loss: 0.1955 - autoencoder_output_loss: 0.0643 - val_loss: 0.1956 - val_autoencoder_output_loss: 0.0651
# Epoch 125/1000
# 5400/5400 [==============================] - 3s 584us/step - loss: 0.1955 - autoencoder_output_loss: 0.0641 - val_loss: 0.1959 - val_autoencoder_output_loss: 0.0652
# Epoch 126/1000
# 5400/5400 [==============================] - 3s 566us/step - loss: 0.1955 - autoencoder_output_loss: 0.0643 - val_loss: 0.1954 - val_autoencoder_output_loss: 0.0651
# Epoch 127/1000
# 5400/5400 [==============================] - 3s 492us/step - loss: 0.1954 - autoencoder_output_loss: 0.0642 - val_loss: 0.1958 - val_autoencoder_output_loss: 0.0652
# Epoch 128/1000
# 5400/5400 [==============================] - 3s 629us/step - loss: 0.1953 - autoencoder_output_loss: 0.0643 - val_loss: 0.1957 - val_autoencoder_output_loss: 0.0652
# Epoch 129/1000
# 5400/5400 [==============================] - 3s 629us/step - loss: 0.1953 - autoencoder_output_loss: 0.0643 - val_loss: 0.1953 - val_autoencoder_output_loss: 0.0650
# Epoch 130/1000
# 5400/5400 [==============================] - 3s 500us/step - loss: 0.1953 - autoencoder_output_loss: 0.0644 - val_loss: 0.1955 - val_autoencoder_output_loss: 0.0651
# Epoch 131/1000
# 5400/5400 [==============================] - 3s 471us/step - loss: 0.1953 - autoencoder_output_loss: 0.0643 - val_loss: 0.1954 - val_autoencoder_output_loss: 0.0651
# Epoch 132/1000
# 5400/5400 [==============================] - 3s 481us/step - loss: 0.1952 - autoencoder_output_loss: 0.0643 - val_loss: 0.1957 - val_autoencoder_output_loss: 0.0652
# Epoch 133/1000
# 5400/5400 [==============================] - 3s 478us/step - loss: 0.1953 - autoencoder_output_loss: 0.0643 - val_loss: 0.1952 - val_autoencoder_output_loss: 0.0650
# Epoch 134/1000
# 5400/5400 [==============================] - 3s 476us/step - loss: 0.1953 - autoencoder_output_loss: 0.0645 - val_loss: 0.1952 - val_autoencoder_output_loss: 0.0650
# Epoch 135/1000
# 5400/5400 [==============================] - 3s 518us/step - loss: 0.1952 - autoencoder_output_loss: 0.0643 - val_loss: 0.1956 - val_autoencoder_output_loss: 0.0652
# Epoch 136/1000
# 5400/5400 [==============================] - 3s 477us/step - loss: 0.1952 - autoencoder_output_loss: 0.0645 - val_loss: 0.1951 - val_autoencoder_output_loss: 0.0650
# Epoch 137/1000
# 5400/5400 [==============================] - 3s 548us/step - loss: 0.1952 - autoencoder_output_loss: 0.0643 - val_loss: 0.1953 - val_autoencoder_output_loss: 0.0651
# Epoch 138/1000
# 5400/5400 [==============================] - 3s 557us/step - loss: 0.1951 - autoencoder_output_loss: 0.0643 - val_loss: 0.1951 - val_autoencoder_output_loss: 0.0650
# Epoch 139/1000
# 5400/5400 [==============================] - 3s 583us/step - loss: 0.1951 - autoencoder_output_loss: 0.0642 - val_loss: 0.1954 - val_autoencoder_output_loss: 0.0651
# Epoch 140/1000
# 5400/5400 [==============================] - 3s 570us/step - loss: 0.1951 - autoencoder_output_loss: 0.0643 - val_loss: 0.1954 - val_autoencoder_output_loss: 0.0651
# Epoch 141/1000
# 5400/5400 [==============================] - 3s 570us/step - loss: 0.1951 - autoencoder_output_loss: 0.0642 - val_loss: 0.1950 - val_autoencoder_output_loss: 0.0650
# Epoch 142/1000
# 5400/5400 [==============================] - 3s 618us/step - loss: 0.1950 - autoencoder_output_loss: 0.0641 - val_loss: 0.1951 - val_autoencoder_output_loss: 0.0651
# Epoch 143/1000
# 5400/5400 [==============================] - 4s 683us/step - loss: 0.1951 - autoencoder_output_loss: 0.0640 - val_loss: 0.1952 - val_autoencoder_output_loss: 0.0650
# Epoch 144/1000
# 5400/5400 [==============================] - 4s 655us/step - loss: 0.1950 - autoencoder_output_loss: 0.0644 - val_loss: 0.1950 - val_autoencoder_output_loss: 0.0651
# Epoch 145/1000
# 5400/5400 [==============================] - 4s 678us/step - loss: 0.1950 - autoencoder_output_loss: 0.0643 - val_loss: 0.1949 - val_autoencoder_output_loss: 0.0650
# Epoch 146/1000
# 5400/5400 [==============================] - 3s 581us/step - loss: 0.1950 - autoencoder_output_loss: 0.0643 - val_loss: 0.1952 - val_autoencoder_output_loss: 0.0651
# Epoch 147/1000
# 5400/5400 [==============================] - 4s 654us/step - loss: 0.1950 - autoencoder_output_loss: 0.0644 - val_loss: 0.1951 - val_autoencoder_output_loss: 0.0650
# Epoch 148/1000
# 5400/5400 [==============================] - 3s 632us/step - loss: 0.1950 - autoencoder_output_loss: 0.0642 - val_loss: 0.1951 - val_autoencoder_output_loss: 0.0651
# Epoch 149/1000
# 5400/5400 [==============================] - 4s 649us/step - loss: 0.1950 - autoencoder_output_loss: 0.0643 - val_loss: 0.1953 - val_autoencoder_output_loss: 0.0651
# Epoch 150/1000
# 5400/5400 [==============================] - 4s 702us/step - loss: 0.1949 - autoencoder_output_loss: 0.0646 - val_loss: 0.1951 - val_autoencoder_output_loss: 0.0650
# Epoch 151/1000
# 5400/5400 [==============================] - 3s 626us/step - loss: 0.1951 - autoencoder_output_loss: 0.0643 - val_loss: 0.1950 - val_autoencoder_output_loss: 0.0651
# Epoch 152/1000
# 5400/5400 [==============================] - 3s 648us/step - loss: 0.1949 - autoencoder_output_loss: 0.0641 - val_loss: 0.1951 - val_autoencoder_output_loss: 0.0650
# Epoch 153/1000
# 5400/5400 [==============================] - 4s 685us/step - loss: 0.1949 - autoencoder_output_loss: 0.0644 - val_loss: 0.1950 - val_autoencoder_output_loss: 0.0650
# Epoch 154/1000
# 5400/5400 [==============================] - 3s 630us/step - loss: 0.1948 - autoencoder_output_loss: 0.0641 - val_loss: 0.1952 - val_autoencoder_output_loss: 0.0651
# Epoch 155/1000
# 5400/5400 [==============================] - 4s 655us/step - loss: 0.1950 - autoencoder_output_loss: 0.0642 - val_loss: 0.1954 - val_autoencoder_output_loss: 0.0652
# Epoch 156/1000
# 5400/5400 [==============================] - 3s 640us/step - loss: 0.1949 - autoencoder_output_loss: 0.0642 - val_loss: 0.1948 - val_autoencoder_output_loss: 0.0650
# Epoch 157/1000
# 5400/5400 [==============================] - 3s 590us/step - loss: 0.1948 - autoencoder_output_loss: 0.0642 - val_loss: 0.1954 - val_autoencoder_output_loss: 0.0652
# Epoch 158/1000
# 5400/5400 [==============================] - 3s 624us/step - loss: 0.1948 - autoencoder_output_loss: 0.0643 - val_loss: 0.1948 - val_autoencoder_output_loss: 0.0650
# Epoch 159/1000
# 5400/5400 [==============================] - 4s 657us/step - loss: 0.1948 - autoencoder_output_loss: 0.0644 - val_loss: 0.1956 - val_autoencoder_output_loss: 0.0652
# Epoch 160/1000
# 5400/5400 [==============================] - 4s 675us/step - loss: 0.1948 - autoencoder_output_loss: 0.0646 - val_loss: 0.1949 - val_autoencoder_output_loss: 0.0649
# Epoch 161/1000
# 5400/5400 [==============================] - 4s 674us/step - loss: 0.1949 - autoencoder_output_loss: 0.0638 - val_loss: 0.1952 - val_autoencoder_output_loss: 0.0652
# Epoch 162/1000
# 5400/5400 [==============================] - 4s 684us/step - loss: 0.1949 - autoencoder_output_loss: 0.0641 - val_loss: 0.1950 - val_autoencoder_output_loss: 0.0651
# Epoch 163/1000
# 5400/5400 [==============================] - 3s 595us/step - loss: 0.1947 - autoencoder_output_loss: 0.0642 - val_loss: 0.1948 - val_autoencoder_output_loss: 0.0651
# Epoch 164/1000
# 5400/5400 [==============================] - 3s 577us/step - loss: 0.1947 - autoencoder_output_loss: 0.0645 - val_loss: 0.1952 - val_autoencoder_output_loss: 0.0652
# Epoch 165/1000
# 5400/5400 [==============================] - 3s 646us/step - loss: 0.1947 - autoencoder_output_loss: 0.0644 - val_loss: 0.1949 - val_autoencoder_output_loss: 0.0651
# Epoch 166/1000
# 5400/5400 [==============================] - 3s 637us/step - loss: 0.1947 - autoencoder_output_loss: 0.0643 - val_loss: 0.1948 - val_autoencoder_output_loss: 0.0650
# Epoch 167/1000
# 5400/5400 [==============================] - 3s 499us/step - loss: 0.1947 - autoencoder_output_loss: 0.0643 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0650
# Epoch 168/1000
# 5400/5400 [==============================] - 3s 504us/step - loss: 0.1946 - autoencoder_output_loss: 0.0644 - val_loss: 0.1949 - val_autoencoder_output_loss: 0.0651
# Epoch 169/1000
# 5400/5400 [==============================] - 3s 513us/step - loss: 0.1947 - autoencoder_output_loss: 0.0644 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0650
# Epoch 170/1000
# 5400/5400 [==============================] - 3s 472us/step - loss: 0.1947 - autoencoder_output_loss: 0.0644 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0650
# Epoch 171/1000
# 5400/5400 [==============================] - 3s 508us/step - loss: 0.1947 - autoencoder_output_loss: 0.0643 - val_loss: 0.1948 - val_autoencoder_output_loss: 0.0651
# Epoch 172/1000
# 5400/5400 [==============================] - 3s 463us/step - loss: 0.1946 - autoencoder_output_loss: 0.0645 - val_loss: 0.1945 - val_autoencoder_output_loss: 0.0650
# Epoch 173/1000
# 5400/5400 [==============================] - 3s 480us/step - loss: 0.1946 - autoencoder_output_loss: 0.0644 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0650
# Epoch 174/1000
# 5400/5400 [==============================] - 3s 513us/step - loss: 0.1946 - autoencoder_output_loss: 0.0644 - val_loss: 0.1948 - val_autoencoder_output_loss: 0.0651
# Epoch 175/1000
# 5400/5400 [==============================] - 3s 523us/step - loss: 0.1946 - autoencoder_output_loss: 0.0641 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0650
# Epoch 176/1000
# 5400/5400 [==============================] - 3s 511us/step - loss: 0.1946 - autoencoder_output_loss: 0.0642 - val_loss: 0.1948 - val_autoencoder_output_loss: 0.0651
# Epoch 177/1000
# 5400/5400 [==============================] - 2s 460us/step - loss: 0.1946 - autoencoder_output_loss: 0.0646 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0650
# Epoch 178/1000
# 5400/5400 [==============================] - 3s 487us/step - loss: 0.1947 - autoencoder_output_loss: 0.0641 - val_loss: 0.1947 - val_autoencoder_output_loss: 0.0651
# Epoch 179/1000
# 5400/5400 [==============================] - 3s 518us/step - loss: 0.1945 - autoencoder_output_loss: 0.0643 - val_loss: 0.1948 - val_autoencoder_output_loss: 0.0651
# Epoch 180/1000
# 5400/5400 [==============================] - 3s 492us/step - loss: 0.1945 - autoencoder_output_loss: 0.0643 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0651
# Epoch 181/1000
# 5400/5400 [==============================] - 2s 436us/step - loss: 0.1945 - autoencoder_output_loss: 0.0643 - val_loss: 0.1945 - val_autoencoder_output_loss: 0.0650
# Epoch 182/1000
# 5400/5400 [==============================] - 2s 449us/step - loss: 0.1946 - autoencoder_output_loss: 0.0643 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0651
# Epoch 183/1000
# 5400/5400 [==============================] - 3s 477us/step - loss: 0.1945 - autoencoder_output_loss: 0.0642 - val_loss: 0.1945 - val_autoencoder_output_loss: 0.0650
# Epoch 184/1000
# 5400/5400 [==============================] - 2s 452us/step - loss: 0.1944 - autoencoder_output_loss: 0.0641 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0651
# Epoch 185/1000
# 5400/5400 [==============================] - 3s 503us/step - loss: 0.1944 - autoencoder_output_loss: 0.0642 - val_loss: 0.1947 - val_autoencoder_output_loss: 0.0651
# Epoch 186/1000
# 5400/5400 [==============================] - 2s 445us/step - loss: 0.1945 - autoencoder_output_loss: 0.0644 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0650
# Epoch 187/1000
# 5400/5400 [==============================] - 2s 442us/step - loss: 0.1944 - autoencoder_output_loss: 0.0640 - val_loss: 0.1943 - val_autoencoder_output_loss: 0.0649
# Epoch 188/1000
# 5400/5400 [==============================] - 2s 457us/step - loss: 0.1944 - autoencoder_output_loss: 0.0642 - val_loss: 0.1944 - val_autoencoder_output_loss: 0.0650
# Epoch 189/1000
# 5400/5400 [==============================] - 3s 473us/step - loss: 0.1944 - autoencoder_output_loss: 0.0642 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0651
# Epoch 190/1000
# 5400/5400 [==============================] - 3s 499us/step - loss: 0.1944 - autoencoder_output_loss: 0.0645 - val_loss: 0.1944 - val_autoencoder_output_loss: 0.0649
# Epoch 191/1000
# 5400/5400 [==============================] - 3s 497us/step - loss: 0.1945 - autoencoder_output_loss: 0.0641 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0651
# Epoch 192/1000
# 5400/5400 [==============================] - 2s 433us/step - loss: 0.1944 - autoencoder_output_loss: 0.0643 - val_loss: 0.1947 - val_autoencoder_output_loss: 0.0651
# Epoch 193/1000
# 5400/5400 [==============================] - 3s 465us/step - loss: 0.1944 - autoencoder_output_loss: 0.0642 - val_loss: 0.1943 - val_autoencoder_output_loss: 0.0650
# Epoch 194/1000
# 5400/5400 [==============================] - 3s 468us/step - loss: 0.1945 - autoencoder_output_loss: 0.0644 - val_loss: 0.1948 - val_autoencoder_output_loss: 0.0651
# Epoch 195/1000
# 5400/5400 [==============================] - 3s 469us/step - loss: 0.1944 - autoencoder_output_loss: 0.0642 - val_loss: 0.1943 - val_autoencoder_output_loss: 0.0649
# Epoch 196/1000
# 5400/5400 [==============================] - 3s 488us/step - loss: 0.1944 - autoencoder_output_loss: 0.0645 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0650
# Epoch 197/1000
# 5400/5400 [==============================] - 3s 519us/step - loss: 0.1944 - autoencoder_output_loss: 0.0642 - val_loss: 0.1944 - val_autoencoder_output_loss: 0.0650
# Epoch 198/1000
# 5400/5400 [==============================] - 2s 457us/step - loss: 0.1944 - autoencoder_output_loss: 0.0644 - val_loss: 0.1945 - val_autoencoder_output_loss: 0.0650
# Epoch 199/1000
# 5400/5400 [==============================] - 3s 498us/step - loss: 0.1944 - autoencoder_output_loss: 0.0643 - val_loss: 0.1947 - val_autoencoder_output_loss: 0.0652
# Epoch 200/1000
# 5400/5400 [==============================] - 3s 498us/step - loss: 0.1944 - autoencoder_output_loss: 0.0641 - val_loss: 0.1944 - val_autoencoder_output_loss: 0.0650
#
# Epoch 00200: saving model to ./log_weights/F_AE_50_weights.MNIST0200.hdf5
# Epoch 201/1000
# 5400/5400 [==============================] - 2s 434us/step - loss: 0.1943 - autoencoder_output_loss: 0.0641 - val_loss: 0.1945 - val_autoencoder_output_loss: 0.0650
# Epoch 202/1000
# 5400/5400 [==============================] - 3s 479us/step - loss: 0.1943 - autoencoder_output_loss: 0.0643 - val_loss: 0.1944 - val_autoencoder_output_loss: 0.0651
# Epoch 203/1000
# 5400/5400 [==============================] - 3s 483us/step - loss: 0.1943 - autoencoder_output_loss: 0.0642 - val_loss: 0.1942 - val_autoencoder_output_loss: 0.0649
# Epoch 204/1000
# 5400/5400 [==============================] - 3s 476us/step - loss: 0.1943 - autoencoder_output_loss: 0.0643 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0650
# Epoch 205/1000
# 5400/5400 [==============================] - 2s 460us/step - loss: 0.1943 - autoencoder_output_loss: 0.0644 - val_loss: 0.1943 - val_autoencoder_output_loss: 0.0649
# Epoch 206/1000
# 5400/5400 [==============================] - 3s 472us/step - loss: 0.1943 - autoencoder_output_loss: 0.0643 - val_loss: 0.1947 - val_autoencoder_output_loss: 0.0651
# Epoch 207/1000
# 5400/5400 [==============================] - 3s 493us/step - loss: 0.1944 - autoencoder_output_loss: 0.0643 - val_loss: 0.1945 - val_autoencoder_output_loss: 0.0650
# Epoch 208/1000
# 5400/5400 [==============================] - 3s 496us/step - loss: 0.1943 - autoencoder_output_loss: 0.0644 - val_loss: 0.1944 - val_autoencoder_output_loss: 0.0650
# Epoch 209/1000
# 5400/5400 [==============================] - 3s 496us/step - loss: 0.1942 - autoencoder_output_loss: 0.0643 - val_loss: 0.1944 - val_autoencoder_output_loss: 0.0649
# Epoch 210/1000
# 5400/5400 [==============================] - 3s 472us/step - loss: 0.1943 - autoencoder_output_loss: 0.0641 - val_loss: 0.1945 - val_autoencoder_output_loss: 0.0650
# Epoch 211/1000
# 5400/5400 [==============================] - 3s 548us/step - loss: 0.1944 - autoencoder_output_loss: 0.0640 - val_loss: 0.1942 - val_autoencoder_output_loss: 0.0649
# Epoch 212/1000
# 5400/5400 [==============================] - 3s 531us/step - loss: 0.1942 - autoencoder_output_loss: 0.0643 - val_loss: 0.1943 - val_autoencoder_output_loss: 0.0649
# Epoch 213/1000
# 5400/5400 [==============================] - 3s 599us/step - loss: 0.1942 - autoencoder_output_loss: 0.0641 - val_loss: 0.1946 - val_autoencoder_output_loss: 0.0649
# Epoch 214/1000
# 5400/5400 [==============================] - 4s 653us/step - loss: 0.1942 - autoencoder_output_loss: 0.0641 - val_loss: 0.1940 - val_autoencoder_output_loss: 0.0647
# Epoch 215/1000
# 5400/5400 [==============================] - 3s 634us/step - loss: 0.1941 - autoencoder_output_loss: 0.0640 - val_loss: 0.1945 - val_autoencoder_output_loss: 0.0648
# Epoch 216/1000
# 5400/5400 [==============================] - 4s 649us/step - loss: 0.1941 - autoencoder_output_loss: 0.0638 - val_loss: 0.1945 - val_autoencoder_output_loss: 0.0647
# Epoch 217/1000
# 5400/5400 [==============================] - 4s 669us/step - loss: 0.1940 - autoencoder_output_loss: 0.0639 - val_loss: 0.1942 - val_autoencoder_output_loss: 0.0645
# Epoch 218/1000
# 5400/5400 [==============================] - 3s 628us/step - loss: 0.1938 - autoencoder_output_loss: 0.0637 - val_loss: 0.1941 - val_autoencoder_output_loss: 0.0644
# Epoch 219/1000
# 5400/5400 [==============================] - 3s 635us/step - loss: 0.1936 - autoencoder_output_loss: 0.0637 - val_loss: 0.1938 - val_autoencoder_output_loss: 0.0643
# Epoch 220/1000
# 5400/5400 [==============================] - 3s 595us/step - loss: 0.1935 - autoencoder_output_loss: 0.0636 - val_loss: 0.1936 - val_autoencoder_output_loss: 0.0641
# Epoch 221/1000
# 5400/5400 [==============================] - 4s 673us/step - loss: 0.1933 - autoencoder_output_loss: 0.0637 - val_loss: 0.1934 - val_autoencoder_output_loss: 0.0640
# Epoch 222/1000
# 5400/5400 [==============================] - 4s 696us/step - loss: 0.1930 - autoencoder_output_loss: 0.0634 - val_loss: 0.1931 - val_autoencoder_output_loss: 0.0639
# Epoch 223/1000
# 5400/5400 [==============================] - 4s 655us/step - loss: 0.1928 - autoencoder_output_loss: 0.0631 - val_loss: 0.1929 - val_autoencoder_output_loss: 0.0638
# Epoch 224/1000
# 5400/5400 [==============================] - 4s 668us/step - loss: 0.1925 - autoencoder_output_loss: 0.0633 - val_loss: 0.1928 - val_autoencoder_output_loss: 0.0635
# Epoch 225/1000
# 5400/5400 [==============================] - 3s 647us/step - loss: 0.1924 - autoencoder_output_loss: 0.0630 - val_loss: 0.1922 - val_autoencoder_output_loss: 0.0635
# Epoch 226/1000
# 5400/5400 [==============================] - 3s 597us/step - loss: 0.1921 - autoencoder_output_loss: 0.0628 - val_loss: 0.1919 - val_autoencoder_output_loss: 0.0634
# Epoch 227/1000
# 5400/5400 [==============================] - 4s 669us/step - loss: 0.1918 - autoencoder_output_loss: 0.0626 - val_loss: 0.1917 - val_autoencoder_output_loss: 0.0632
# Epoch 228/1000
# 5400/5400 [==============================] - 4s 691us/step - loss: 0.1916 - autoencoder_output_loss: 0.0626 - val_loss: 0.1915 - val_autoencoder_output_loss: 0.0631
# Epoch 229/1000
# 5400/5400 [==============================] - 4s 689us/step - loss: 0.1913 - autoencoder_output_loss: 0.0624 - val_loss: 0.1914 - val_autoencoder_output_loss: 0.0630
# Epoch 230/1000
# 5400/5400 [==============================] - 4s 707us/step - loss: 0.1911 - autoencoder_output_loss: 0.0622 - val_loss: 0.1911 - val_autoencoder_output_loss: 0.0629
# Epoch 231/1000
# 5400/5400 [==============================] - 3s 643us/step - loss: 0.1910 - autoencoder_output_loss: 0.0623 - val_loss: 0.1911 - val_autoencoder_output_loss: 0.0630
# Epoch 232/1000
# 5400/5400 [==============================] - 3s 645us/step - loss: 0.1909 - autoencoder_output_loss: 0.0624 - val_loss: 0.1910 - val_autoencoder_output_loss: 0.0629
# Epoch 233/1000
# 5400/5400 [==============================] - 3s 605us/step - loss: 0.1907 - autoencoder_output_loss: 0.0622 - val_loss: 0.1905 - val_autoencoder_output_loss: 0.0627
# Epoch 234/1000
# 5400/5400 [==============================] - 3s 635us/step - loss: 0.1906 - autoencoder_output_loss: 0.0623 - val_loss: 0.1905 - val_autoencoder_output_loss: 0.0627
# Epoch 235/1000
# 5400/5400 [==============================] - 4s 650us/step - loss: 0.1905 - autoencoder_output_loss: 0.0622 - val_loss: 0.1905 - val_autoencoder_output_loss: 0.0627
# Epoch 236/1000
# 5400/5400 [==============================] - 3s 639us/step - loss: 0.1904 - autoencoder_output_loss: 0.0621 - val_loss: 0.1902 - val_autoencoder_output_loss: 0.0626
# Epoch 237/1000
# 5400/5400 [==============================] - 3s 590us/step - loss: 0.1903 - autoencoder_output_loss: 0.0620 - val_loss: 0.1901 - val_autoencoder_output_loss: 0.0627
# Epoch 238/1000
# 5400/5400 [==============================] - 3s 553us/step - loss: 0.1901 - autoencoder_output_loss: 0.0621 - val_loss: 0.1901 - val_autoencoder_output_loss: 0.0627
# Epoch 239/1000
# 5400/5400 [==============================] - 4s 658us/step - loss: 0.1901 - autoencoder_output_loss: 0.0620 - val_loss: 0.1899 - val_autoencoder_output_loss: 0.0627
# Epoch 240/1000
# 5400/5400 [==============================] - 3s 542us/step - loss: 0.1900 - autoencoder_output_loss: 0.0619 - val_loss: 0.1901 - val_autoencoder_output_loss: 0.0628
# Epoch 241/1000
# 5400/5400 [==============================] - 3s 492us/step - loss: 0.1900 - autoencoder_output_loss: 0.0622 - val_loss: 0.1899 - val_autoencoder_output_loss: 0.0626
# Epoch 242/1000
# 5400/5400 [==============================] - 3s 505us/step - loss: 0.1899 - autoencoder_output_loss: 0.0618 - val_loss: 0.1899 - val_autoencoder_output_loss: 0.0628
# Epoch 243/1000
# 5400/5400 [==============================] - 3s 544us/step - loss: 0.1899 - autoencoder_output_loss: 0.0620 - val_loss: 0.1896 - val_autoencoder_output_loss: 0.0626
# Epoch 244/1000
# 5400/5400 [==============================] - 3s 481us/step - loss: 0.1897 - autoencoder_output_loss: 0.0622 - val_loss: 0.1896 - val_autoencoder_output_loss: 0.0625
# Epoch 245/1000
# 5400/5400 [==============================] - 3s 487us/step - loss: 0.1897 - autoencoder_output_loss: 0.0619 - val_loss: 0.1896 - val_autoencoder_output_loss: 0.0624
# Epoch 246/1000
# 5400/5400 [==============================] - 2s 456us/step - loss: 0.1895 - autoencoder_output_loss: 0.0619 - val_loss: 0.1893 - val_autoencoder_output_loss: 0.0622
# Epoch 247/1000
# 5400/5400 [==============================] - 2s 450us/step - loss: 0.1893 - autoencoder_output_loss: 0.0618 - val_loss: 0.1894 - val_autoencoder_output_loss: 0.0622
# Epoch 248/1000
# 5400/5400 [==============================] - 3s 476us/step - loss: 0.1891 - autoencoder_output_loss: 0.0617 - val_loss: 0.1889 - val_autoencoder_output_loss: 0.0616
# Epoch 249/1000
# 5400/5400 [==============================] - 2s 459us/step - loss: 0.1888 - autoencoder_output_loss: 0.0614 - val_loss: 0.1887 - val_autoencoder_output_loss: 0.0616
# Epoch 250/1000
# 5400/5400 [==============================] - 3s 486us/step - loss: 0.1883 - autoencoder_output_loss: 0.0609 - val_loss: 0.1879 - val_autoencoder_output_loss: 0.0612
# Epoch 251/1000
# 5400/5400 [==============================] - 3s 502us/step - loss: 0.1877 - autoencoder_output_loss: 0.0606 - val_loss: 0.1875 - val_autoencoder_output_loss: 0.0611
# Epoch 252/1000
# 5400/5400 [==============================] - 3s 472us/step - loss: 0.1872 - autoencoder_output_loss: 0.0603 - val_loss: 0.1872 - val_autoencoder_output_loss: 0.0608
# Epoch 253/1000
# 5400/5400 [==============================] - 2s 436us/step - loss: 0.1866 - autoencoder_output_loss: 0.0600 - val_loss: 0.1863 - val_autoencoder_output_loss: 0.0605
# Epoch 254/1000
# 5400/5400 [==============================] - 2s 435us/step - loss: 0.1862 - autoencoder_output_loss: 0.0602 - val_loss: 0.1862 - val_autoencoder_output_loss: 0.0603
# Epoch 255/1000
# 5400/5400 [==============================] - 2s 458us/step - loss: 0.1857 - autoencoder_output_loss: 0.0598 - val_loss: 0.1859 - val_autoencoder_output_loss: 0.0602
# Epoch 256/1000
# 5400/5400 [==============================] - 2s 440us/step - loss: 0.1854 - autoencoder_output_loss: 0.0596 - val_loss: 0.1857 - val_autoencoder_output_loss: 0.0602
# Epoch 257/1000
# 5400/5400 [==============================] - 3s 463us/step - loss: 0.1851 - autoencoder_output_loss: 0.0596 - val_loss: 0.1855 - val_autoencoder_output_loss: 0.0601
# Epoch 258/1000
# 5400/5400 [==============================] - 3s 474us/step - loss: 0.1848 - autoencoder_output_loss: 0.0596 - val_loss: 0.1853 - val_autoencoder_output_loss: 0.0602
# Epoch 259/1000
# 5400/5400 [==============================] - 2s 428us/step - loss: 0.1845 - autoencoder_output_loss: 0.0595 - val_loss: 0.1849 - val_autoencoder_output_loss: 0.0600
# Epoch 260/1000
# 5400/5400 [==============================] - 2s 379us/step - loss: 0.1844 - autoencoder_output_loss: 0.0594 - val_loss: 0.1850 - val_autoencoder_output_loss: 0.0600
# Epoch 261/1000
# 5400/5400 [==============================] - 2s 424us/step - loss: 0.1841 - autoencoder_output_loss: 0.0593 - val_loss: 0.1843 - val_autoencoder_output_loss: 0.0598
# Epoch 262/1000
# 5400/5400 [==============================] - 2s 363us/step - loss: 0.1839 - autoencoder_output_loss: 0.0594 - val_loss: 0.1840 - val_autoencoder_output_loss: 0.0596
# Epoch 263/1000
# 5400/5400 [==============================] - 2s 409us/step - loss: 0.1837 - autoencoder_output_loss: 0.0591 - val_loss: 0.1842 - val_autoencoder_output_loss: 0.0597
# Epoch 264/1000
# 5400/5400 [==============================] - 2s 416us/step - loss: 0.1834 - autoencoder_output_loss: 0.0589 - val_loss: 0.1838 - val_autoencoder_output_loss: 0.0596
# Epoch 265/1000
# ...
# Epoch 913/1000
# 5400/5400 [==============================] - 2s 330us/step - loss: 0.0765 - autoencoder_output_loss: 0.0223 - val_loss: 0.0751 - val_autoencoder_output_loss: 0.0218
# Epoch 914/1000
# 5400/5400 [==============================] - 2s 316us/step - loss: 0.0761 - autoencoder_output_loss: 0.0220 - val_loss: 0.0757 - val_autoencoder_output_loss: 0.0221
# Epoch 915/1000
# 5400/5400 [==============================] - 2s 317us/step - loss: 0.0762 - autoencoder_output_loss: 0.0222 - val_loss: 0.0751 - val_autoencoder_output_loss: 0.0218
# Epoch 916/1000
# 5400/5400 [==============================] - 2s 326us/step - loss: 0.0760 - autoencoder_output_loss: 0.0220 - val_loss: 0.0750 - val_autoencoder_output_loss: 0.0217
# Epoch 917/1000
# 5400/5400 [==============================] - 2s 326us/step - loss: 0.0760 - autoencoder_output_loss: 0.0221 - val_loss: 0.0755 - val_autoencoder_output_loss: 0.0219
# Epoch 918/1000
# 5400/5400 [==============================] - 1s 272us/step - loss: 0.0762 - autoencoder_output_loss: 0.0221 - val_loss: 0.0750 - val_autoencoder_output_loss: 0.0217
# Epoch 919/1000
# 5400/5400 [==============================] - 2s 292us/step - loss: 0.0760 - autoencoder_output_loss: 0.0222 - val_loss: 0.0762 - val_autoencoder_output_loss: 0.0220
# Epoch 920/1000
# 5400/5400 [==============================] - 2s 306us/step - loss: 0.0763 - autoencoder_output_loss: 0.0222 - val_loss: 0.0750 - val_autoencoder_output_loss: 0.0218
# Epoch 921/1000
# 5400/5400 [==============================] - 1s 204us/step - loss: 0.0760 - autoencoder_output_loss: 0.0221 - val_loss: 0.0754 - val_autoencoder_output_loss: 0.0219
# Epoch 922/1000
# 5400/5400 [==============================] - 1s 272us/step - loss: 0.0760 - autoencoder_output_loss: 0.0221 - val_loss: 0.0753 - val_autoencoder_output_loss: 0.0219
# Epoch 923/1000
# 5400/5400 [==============================] - 1s 268us/step - loss: 0.0761 - autoencoder_output_loss: 0.0222 - val_loss: 0.0750 - val_autoencoder_output_loss: 0.0218
# Epoch 924/1000
# 5400/5400 [==============================] - 1s 247us/step - loss: 0.0761 - autoencoder_output_loss: 0.0221 - val_loss: 0.0754 - val_autoencoder_output_loss: 0.0220
# Epoch 925/1000
# 5400/5400 [==============================] - 1s 267us/step - loss: 0.0760 - autoencoder_output_loss: 0.0220 - val_loss: 0.0755 - val_autoencoder_output_loss: 0.0219
# Epoch 926/1000
# 5400/5400 [==============================] - 1s 235us/step - loss: 0.0760 - autoencoder_output_loss: 0.0220 - val_loss: 0.0751 - val_autoencoder_output_loss: 0.0219
# Epoch 927/1000
# 5400/5400 [==============================] - 2s 295us/step - loss: 0.0758 - autoencoder_output_loss: 0.0221 - val_loss: 0.0751 - val_autoencoder_output_loss: 0.0218
# Epoch 928/1000
# 5400/5400 [==============================] - 1s 181us/step - loss: 0.0758 - autoencoder_output_loss: 0.0221 - val_loss: 0.0753 - val_autoencoder_output_loss: 0.0220
# Epoch 929/1000
# 5400/5400 [==============================] - 1s 274us/step - loss: 0.0760 - autoencoder_output_loss: 0.0221 - val_loss: 0.0753 - val_autoencoder_output_loss: 0.0218
# Epoch 930/1000
# 5400/5400 [==============================] - 1s 262us/step - loss: 0.0760 - autoencoder_output_loss: 0.0221 - val_loss: 0.0757 - val_autoencoder_output_loss: 0.0220
# Epoch 931/1000
# 5400/5400 [==============================] - 2s 295us/step - loss: 0.0759 - autoencoder_output_loss: 0.0221 - val_loss: 0.0750 - val_autoencoder_output_loss: 0.0219
# Epoch 932/1000
# 5400/5400 [==============================] - 1s 242us/step - loss: 0.0757 - autoencoder_output_loss: 0.0221 - val_loss: 0.0751 - val_autoencoder_output_loss: 0.0218
# Epoch 933/1000
# 5400/5400 [==============================] - 2s 352us/step - loss: 0.0759 - autoencoder_output_loss: 0.0219 - val_loss: 0.0751 - val_autoencoder_output_loss: 0.0218
# Epoch 934/1000
# 5400/5400 [==============================] - 1s 249us/step - loss: 0.0757 - autoencoder_output_loss: 0.0220 - val_loss: 0.0753 - val_autoencoder_output_loss: 0.0219
# Epoch 935/1000
# 5400/5400 [==============================] - 2s 329us/step - loss: 0.0759 - autoencoder_output_loss: 0.0221 - val_loss: 0.0751 - val_autoencoder_output_loss: 0.0218
# Epoch 936/1000
# 5400/5400 [==============================] - 1s 267us/step - loss: 0.0758 - autoencoder_output_loss: 0.0220 - val_loss: 0.0750 - val_autoencoder_output_loss: 0.0219
# Epoch 937/1000
# 5400/5400 [==============================] - 2s 309us/step - loss: 0.0757 - autoencoder_output_loss: 0.0220 - val_loss: 0.0752 - val_autoencoder_output_loss: 0.0219
# Epoch 938/1000
# 5400/5400 [==============================] - 2s 312us/step - loss: 0.0756 - autoencoder_output_loss: 0.0220 - val_loss: 0.0744 - val_autoencoder_output_loss: 0.0216
# Epoch 939/1000
# 5400/5400 [==============================] - 1s 204us/step - loss: 0.0755 - autoencoder_output_loss: 0.0220 - val_loss: 0.0753 - val_autoencoder_output_loss: 0.0219
# Epoch 940/1000
# 5400/5400 [==============================] - 2s 321us/step - loss: 0.0755 - autoencoder_output_loss: 0.0219 - val_loss: 0.0750 - val_autoencoder_output_loss: 0.0217
# Epoch 941/1000
# 5400/5400 [==============================] - 2s 332us/step - loss: 0.0755 - autoencoder_output_loss: 0.0218 - val_loss: 0.0747 - val_autoencoder_output_loss: 0.0218
# Epoch 942/1000
# 5400/5400 [==============================] - 2s 322us/step - loss: 0.0755 - autoencoder_output_loss: 0.0221 - val_loss: 0.0750 - val_autoencoder_output_loss: 0.0218
# Epoch 943/1000
# 5400/5400 [==============================] - 2s 343us/step - loss: 0.0755 - autoencoder_output_loss: 0.0220 - val_loss: 0.0750 - val_autoencoder_output_loss: 0.0218
# Epoch 944/1000
# 5400/5400 [==============================] - 2s 340us/step - loss: 0.0754 - autoencoder_output_loss: 0.0220 - val_loss: 0.0743 - val_autoencoder_output_loss: 0.0216
# Epoch 945/1000
# 5400/5400 [==============================] - 2s 315us/step - loss: 0.0753 - autoencoder_output_loss: 0.0220 - val_loss: 0.0748 - val_autoencoder_output_loss: 0.0218
# Epoch 946/1000
# 5400/5400 [==============================] - 2s 333us/step - loss: 0.0754 - autoencoder_output_loss: 0.0220 - val_loss: 0.0747 - val_autoencoder_output_loss: 0.0217
# Epoch 947/1000
# 5400/5400 [==============================] - 2s 281us/step - loss: 0.0753 - autoencoder_output_loss: 0.0219 - val_loss: 0.0745 - val_autoencoder_output_loss: 0.0218
# Epoch 948/1000
# 5400/5400 [==============================] - 2s 297us/step - loss: 0.0752 - autoencoder_output_loss: 0.0218 - val_loss: 0.0742 - val_autoencoder_output_loss: 0.0216
# Epoch 949/1000
# 5400/5400 [==============================] - 2s 336us/step - loss: 0.0753 - autoencoder_output_loss: 0.0219 - val_loss: 0.0748 - val_autoencoder_output_loss: 0.0219
# Epoch 950/1000
# 5400/5400 [==============================] - 2s 314us/step - loss: 0.0754 - autoencoder_output_loss: 0.0220 - val_loss: 0.0745 - val_autoencoder_output_loss: 0.0218
# Epoch 951/1000
# 5400/5400 [==============================] - 2s 333us/step - loss: 0.0753 - autoencoder_output_loss: 0.0220 - val_loss: 0.0744 - val_autoencoder_output_loss: 0.0217
# Epoch 952/1000
# 5400/5400 [==============================] - 2s 313us/step - loss: 0.0753 - autoencoder_output_loss: 0.0220 - val_loss: 0.0748 - val_autoencoder_output_loss: 0.0217
# Epoch 953/1000
# 5400/5400 [==============================] - 2s 301us/step - loss: 0.0753 - autoencoder_output_loss: 0.0219 - val_loss: 0.0752 - val_autoencoder_output_loss: 0.0220
# Epoch 954/1000
# 5400/5400 [==============================] - 2s 320us/step - loss: 0.0752 - autoencoder_output_loss: 0.0219 - val_loss: 0.0741 - val_autoencoder_output_loss: 0.0216
# Epoch 955/1000
# 5400/5400 [==============================] - 2s 326us/step - loss: 0.0751 - autoencoder_output_loss: 0.0219 - val_loss: 0.0740 - val_autoencoder_output_loss: 0.0216
# Epoch 956/1000
# 5400/5400 [==============================] - 2s 332us/step - loss: 0.0750 - autoencoder_output_loss: 0.0220 - val_loss: 0.0743 - val_autoencoder_output_loss: 0.0216
# Epoch 957/1000
# 5400/5400 [==============================] - 2s 323us/step - loss: 0.0749 - autoencoder_output_loss: 0.0219 - val_loss: 0.0750 - val_autoencoder_output_loss: 0.0218
# Epoch 958/1000
# 5400/5400 [==============================] - 2s 319us/step - loss: 0.0753 - autoencoder_output_loss: 0.0220 - val_loss: 0.0747 - val_autoencoder_output_loss: 0.0218
# Epoch 959/1000
# 5400/5400 [==============================] - 2s 329us/step - loss: 0.0751 - autoencoder_output_loss: 0.0220 - val_loss: 0.0751 - val_autoencoder_output_loss: 0.0218
# Epoch 960/1000
# 5400/5400 [==============================] - 2s 308us/step - loss: 0.0752 - autoencoder_output_loss: 0.0218 - val_loss: 0.0745 - val_autoencoder_output_loss: 0.0218
# Epoch 961/1000
# 5400/5400 [==============================] - 2s 312us/step - loss: 0.0750 - autoencoder_output_loss: 0.0218 - val_loss: 0.0741 - val_autoencoder_output_loss: 0.0216
# Epoch 962/1000
# 5400/5400 [==============================] - 2s 326us/step - loss: 0.0748 - autoencoder_output_loss: 0.0218 - val_loss: 0.0745 - val_autoencoder_output_loss: 0.0218
# Epoch 963/1000
# 5400/5400 [==============================] - 2s 322us/step - loss: 0.0749 - autoencoder_output_loss: 0.0218 - val_loss: 0.0744 - val_autoencoder_output_loss: 0.0218
# Epoch 964/1000
# 5400/5400 [==============================] - 2s 316us/step - loss: 0.0748 - autoencoder_output_loss: 0.0219 - val_loss: 0.0743 - val_autoencoder_output_loss: 0.0216
# Epoch 965/1000
# 5400/5400 [==============================] - 2s 305us/step - loss: 0.0749 - autoencoder_output_loss: 0.0219 - val_loss: 0.0740 - val_autoencoder_output_loss: 0.0215
# Epoch 966/1000
# 5400/5400 [==============================] - 2s 332us/step - loss: 0.0747 - autoencoder_output_loss: 0.0218 - val_loss: 0.0740 - val_autoencoder_output_loss: 0.0217
# Epoch 967/1000
# 5400/5400 [==============================] - 1s 272us/step - loss: 0.0748 - autoencoder_output_loss: 0.0218 - val_loss: 0.0741 - val_autoencoder_output_loss: 0.0217
# Epoch 968/1000
# 5400/5400 [==============================] - 2s 317us/step - loss: 0.0750 - autoencoder_output_loss: 0.0219 - val_loss: 0.0745 - val_autoencoder_output_loss: 0.0219
# Epoch 969/1000
# 5400/5400 [==============================] - 2s 313us/step - loss: 0.0748 - autoencoder_output_loss: 0.0218 - val_loss: 0.0743 - val_autoencoder_output_loss: 0.0217
# Epoch 970/1000
# 5400/5400 [==============================] - 2s 305us/step - loss: 0.0746 - autoencoder_output_loss: 0.0219 - val_loss: 0.0745 - val_autoencoder_output_loss: 0.0217
# Epoch 971/1000
# 5400/5400 [==============================] - 2s 332us/step - loss: 0.0748 - autoencoder_output_loss: 0.0218 - val_loss: 0.0742 - val_autoencoder_output_loss: 0.0216
# Epoch 972/1000
# 5400/5400 [==============================] - 2s 303us/step - loss: 0.0746 - autoencoder_output_loss: 0.0217 - val_loss: 0.0736 - val_autoencoder_output_loss: 0.0215
# Epoch 973/1000
# 5400/5400 [==============================] - 2s 326us/step - loss: 0.0745 - autoencoder_output_loss: 0.0218 - val_loss: 0.0739 - val_autoencoder_output_loss: 0.0216
# Epoch 974/1000
# 5400/5400 [==============================] - 2s 306us/step - loss: 0.0745 - autoencoder_output_loss: 0.0216 - val_loss: 0.0736 - val_autoencoder_output_loss: 0.0215
# Epoch 975/1000
# 5400/5400 [==============================] - 2s 331us/step - loss: 0.0746 - autoencoder_output_loss: 0.0217 - val_loss: 0.0739 - val_autoencoder_output_loss: 0.0215
# Epoch 976/1000
# 5400/5400 [==============================] - 2s 317us/step - loss: 0.0745 - autoencoder_output_loss: 0.0217 - val_loss: 0.0740 - val_autoencoder_output_loss: 0.0216
# Epoch 977/1000
# 5400/5400 [==============================] - 2s 316us/step - loss: 0.0745 - autoencoder_output_loss: 0.0218 - val_loss: 0.0739 - val_autoencoder_output_loss: 0.0214
# Epoch 978/1000
# 5400/5400 [==============================] - 2s 321us/step - loss: 0.0745 - autoencoder_output_loss: 0.0219 - val_loss: 0.0742 - val_autoencoder_output_loss: 0.0216
# Epoch 979/1000
# 5400/5400 [==============================] - 2s 323us/step - loss: 0.0745 - autoencoder_output_loss: 0.0219 - val_loss: 0.0740 - val_autoencoder_output_loss: 0.0215
# Epoch 980/1000
# 5400/5400 [==============================] - 2s 313us/step - loss: 0.0744 - autoencoder_output_loss: 0.0217 - val_loss: 0.0737 - val_autoencoder_output_loss: 0.0215
# Epoch 981/1000
# 5400/5400 [==============================] - 2s 317us/step - loss: 0.0744 - autoencoder_output_loss: 0.0217 - val_loss: 0.0735 - val_autoencoder_output_loss: 0.0215
# Epoch 982/1000
# 5400/5400 [==============================] - 2s 321us/step - loss: 0.0743 - autoencoder_output_loss: 0.0217 - val_loss: 0.0746 - val_autoencoder_output_loss: 0.0218
# Epoch 983/1000
# 5400/5400 [==============================] - 2s 316us/step - loss: 0.0747 - autoencoder_output_loss: 0.0218 - val_loss: 0.0738 - val_autoencoder_output_loss: 0.0216
# Epoch 984/1000
# 5400/5400 [==============================] - 2s 331us/step - loss: 0.0745 - autoencoder_output_loss: 0.0218 - val_loss: 0.0737 - val_autoencoder_output_loss: 0.0216
# Epoch 985/1000
# 5400/5400 [==============================] - 2s 317us/step - loss: 0.0742 - autoencoder_output_loss: 0.0217 - val_loss: 0.0737 - val_autoencoder_output_loss: 0.0215
# Epoch 986/1000
# 5400/5400 [==============================] - 2s 325us/step - loss: 0.0742 - autoencoder_output_loss: 0.0217 - val_loss: 0.0737 - val_autoencoder_output_loss: 0.0214
# Epoch 987/1000
# 5400/5400 [==============================] - 2s 330us/step - loss: 0.0743 - autoencoder_output_loss: 0.0217 - val_loss: 0.0744 - val_autoencoder_output_loss: 0.0217
# Epoch 988/1000
# 5400/5400 [==============================] - 2s 307us/step - loss: 0.0743 - autoencoder_output_loss: 0.0217 - val_loss: 0.0735 - val_autoencoder_output_loss: 0.0214
# Epoch 989/1000
# 5400/5400 [==============================] - 2s 347us/step - loss: 0.0743 - autoencoder_output_loss: 0.0216 - val_loss: 0.0737 - val_autoencoder_output_loss: 0.0215
# Epoch 990/1000
# 5400/5400 [==============================] - 2s 335us/step - loss: 0.0742 - autoencoder_output_loss: 0.0217 - val_loss: 0.0732 - val_autoencoder_output_loss: 0.0215
# Epoch 991/1000
# 5400/5400 [==============================] - 2s 298us/step - loss: 0.0741 - autoencoder_output_loss: 0.0217 - val_loss: 0.0745 - val_autoencoder_output_loss: 0.0217
# Epoch 992/1000
# 5400/5400 [==============================] - 2s 329us/step - loss: 0.0744 - autoencoder_output_loss: 0.0217 - val_loss: 0.0735 - val_autoencoder_output_loss: 0.0216
# Epoch 993/1000
# 5400/5400 [==============================] - 2s 411us/step - loss: 0.0741 - autoencoder_output_loss: 0.0216 - val_loss: 0.0732 - val_autoencoder_output_loss: 0.0214
# Epoch 994/1000
# 5400/5400 [==============================] - 2s 401us/step - loss: 0.0740 - autoencoder_output_loss: 0.0218 - val_loss: 0.0737 - val_autoencoder_output_loss: 0.0215
# Epoch 995/1000
# 5400/5400 [==============================] - 2s 338us/step - loss: 0.0743 - autoencoder_output_loss: 0.0217 - val_loss: 0.0734 - val_autoencoder_output_loss: 0.0214
# Epoch 996/1000
# 5400/5400 [==============================] - 2s 387us/step - loss: 0.0741 - autoencoder_output_loss: 0.0216 - val_loss: 0.0732 - val_autoencoder_output_loss: 0.0214
# Epoch 997/1000
# 5400/5400 [==============================] - 2s 388us/step - loss: 0.0740 - autoencoder_output_loss: 0.0217 - val_loss: 0.0737 - val_autoencoder_output_loss: 0.0214
# Epoch 998/1000
# 5400/5400 [==============================] - 2s 419us/step - loss: 0.0740 - autoencoder_output_loss: 0.0216 - val_loss: 0.0736 - val_autoencoder_output_loss: 0.0215
# Epoch 999/1000
# 5400/5400 [==============================] - 2s 446us/step - loss: 0.0740 - autoencoder_output_loss: 0.0216 - val_loss: 0.0732 - val_autoencoder_output_loss: 0.0214
# Epoch 1000/1000
# 5400/5400 [==============================] - 3s 475us/step - loss: 0.0740 - autoencoder_output_loss: 0.0217 - val_loss: 0.0737 - val_autoencoder_output_loss: 0.0215
#
# Epoch 01000: saving model to ./log_weights/F_AE_50_weights.MNIST1000.hdf5

# %%
loss = F_AE_history.history['loss']
val_loss = F_AE_history.history['val_loss']

epochs = range(epochs_number)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(epochs[250:], loss[250:], 'bo', label='Training Loss')
plt.plot(epochs[250:], val_loss[250:], 'r', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
p_data=F_AE.predict(x_test)
numbers=x_test.shape[0]*x_test.shape[1]

print("MSE for one-to-one map layer",np.sum(np.power(np.array(p_data)[0]-x_test,2))/numbers)
print("MSE for feature selection layer",np.sum(np.power(np.array(p_data)[1]-x_test,2))/numbers)
# Out:
# MSE for one-to-one map layer 0.021983298788265306
# MSE for feature selection layer 0.022017495914381378

# %%
F.show_data_figures(p_data[0][0:160],w=28,h=28,columns = 20)

# %%
F.show_data_figures(p_data[1][0:160],w=28,h=28,columns = 20)

# %%
F.show_feature_selection('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST0200.hdf5',x_test,p_sample_number=160,p_key_number=key_feture_number)

# %%
F.show_feature_selection('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST0400.hdf5',x_test,p_sample_number=160,p_key_number=key_feture_number)

# %%
F.show_feature_selection('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST0600.hdf5',x_test,p_sample_number=160,p_key_number=key_feture_number)

# %%
F.show_feature_selection('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST0800.hdf5',x_test,p_sample_number=160,p_key_number=key_feture_number)

# %%
F.show_feature_selection('./log_weights/F_AE_'+str(key_feture_number)+'_weights.MNIST1000.hdf5',x_test,p_sample_number=160,p_key_number=key_feture_number)

# %% [markdown]
# ---
# ### 3.1.2 Feature selection layer output
# ---

# %%
FS_layer_output=feature_selection_output.predict(x_test)
F.show_data_figures(FS_layer_output[0:160],w=28,h=28,columns = 20)

print(np.sum(FS_layer_output[0]>0))
# Out:
# 30

# %% [markdown]
# ---
# ### 3.1.3 Key features show
# ---

# %%
# Gray
'''
key_features=F.top_k_keepWeights_1(F_AE.get_layer(index=1).get_weights()[0],key_feture_number)
plt.axis('off')
plt.imshow(key_features.reshape((28, 28)),plt.cm.gray)
print(np.sum(F_AE.get_layer(index=1).get_weights()[0]>0))
'''

# Red
key_features=F.top_k_keepWeights_1(F_AE.get_layer(index=1).get_weights()[0],key_feture_number)
key_features_=key_features.reshape((28, 28))

plt.axis('off')
canvas=np.zeros((28,28))
plt.imshow(canvas,plt.cm.gray)

for index_i in np.arange(key_features_.shape[0]):
    for index_j in np.arange(key_features_.shape[1]): 
        if key_features_[index_i,index_j]==1:
            plt.scatter(index_j,index_i,s=100,color='r',marker="s")
plt.tight_layout()
plt.show()
print(np.sum(F_AE.get_layer(index=1).get_weights()[0]>0))
print(np.sum(key_features>0))
# Out:
# 97
# 50

# %% [markdown]
# # 4 Classifying

# %% [markdown]
# ### 4.1. Extra Trees

# %%
train_feature=C_train_x
train_label=C_train_y
test_feature=C_test_x
test_label=C_test_y
p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.943
# Testing accuracy： 0.943

# %%
F.show_data_figures(C_test_x[0:160],w=28,h=28,columns = 20)

# %%
C_test_y[0:160]
# Out:
# array([8, 7, 1, 7, 1, 2, 1, 9, 5, 4, 5, 6, 3, 2, 0, 7, 6, 4, 6, 4, 5, 7,
#        8, 9, 8, 7, 4, 3, 9, 4, 2, 2, 9, 7, 6, 7, 1, 2, 8, 3, 0, 6, 4, 0,
#        8, 7, 8, 2, 9, 0, 4, 3, 4, 0, 7, 0, 7, 4, 6, 1, 9, 7, 2, 8, 8, 0,
#        1, 0, 5, 1, 5, 1, 4, 9, 4, 8, 7, 3, 7, 8, 9, 1, 4, 4, 0, 2, 5, 7,
#        7, 5, 3, 0, 6, 2, 4, 1, 6, 8, 6, 9, 3, 3, 0, 3, 6, 6, 4, 8, 8, 7,
#        4, 6, 3, 6, 0, 4, 8, 5, 7, 8, 6, 7, 5, 5, 1, 0, 7, 4, 5, 6, 5, 9,
#        1, 4, 4, 9, 4, 5, 4, 8, 9, 8, 6, 7, 8, 2, 1, 1, 1, 4, 9, 4, 8, 3,
#        4, 0, 3, 4, 5, 9], dtype=uint8)

# %%
print(np.sum(FS_layer_output[0]>0))
# Out:
# 30

# %%
row=np.where(key_features_>0)[0]
column=np.where(key_features_>0)[1]

selected_position_list=[]
for i in np.arange(key_feture_number):
    selected_position_list.append((row[i],column[i]))

# %% [markdown]
# ---
# #### 4.1.1. On Identity Selection layer
# ---
#
# a) with zeros

# %%
train_feature=feature_selection_output.predict(C_train_x)
print("train_feature>0: ",np.sum(train_feature[0]>0))
print(train_feature.shape)
train_label=C_train_y

test_feature=feature_selection_output.predict(C_test_x)
print("test_feature>0: ",np.sum(test_feature[0]>0))
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# train_feature>0:  27
# (6000, 784)
# test_feature>0:  30
# (4000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9155
# Testing accuracy： 0.9155

# %%
F.show_data_figures(test_feature[0:160],w=28,h=28,columns = 20)

# %% [markdown]
# ---
#
# b) Sparse matrix

# %%
train_feature=feature_selection_output.predict(C_train_x)
print(train_feature.shape)
train_label=C_train_y

test_feature=feature_selection_output.predict(C_test_x)
print(test_feature.shape)
test_label=C_test_y

train_feature_sparse=sparse.coo_matrix(train_feature)
test_feature_sparse=sparse.coo_matrix(test_feature)

p_seed=seed
F.ETree(train_feature_sparse,train_label,test_feature_sparse,test_label,p_seed)
# Out:
# (6000, 784)
# (4000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9155
# Testing accuracy： 0.9155

# %% [markdown]
# ---
#
# c) Compression

# %%
train_feature_=feature_selection_output.predict(C_train_x)
train_feature=F.compress_zero(train_feature_,key_feture_number)
print(train_feature.shape)
train_label=C_train_y

test_feature_=feature_selection_output.predict(C_test_x)
test_feature=F.compress_zero(test_feature_,key_feture_number)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.4375
# Testing accuracy： 0.4375

# %% [markdown]
# ---
#
# d) Compression with structure

# %%
train_feature_=feature_selection_output.predict(C_train_x)
train_feature=F.compress_zero_withkeystructure(train_feature_,selected_position_list,w=28,h=28)
print(train_feature.shape)
train_label=C_train_y

test_feature_=feature_selection_output.predict(C_test_x)
test_feature=F.compress_zero_withkeystructure(test_feature_,selected_position_list,w=28,h=28)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9265
# Testing accuracy： 0.9265

# %% [markdown]
# ---
# #### 4.1.2. On Original Selection
# ---
#
# a) with zeros

# %%
train_feature=np.multiply(C_train_x, key_features)
print("train_feature>0: ",np.sum(train_feature[0]>0))
print(train_feature.shape)
train_label=C_train_y

test_feature=np.multiply(C_test_x, key_features)
print("test_feature>0: ",np.sum(test_feature[0]>0))
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# train_feature>0:  27
# (6000, 784)
# test_feature>0:  30
# (4000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9155
# Testing accuracy： 0.9155

# %%
F.show_data_figures(test_feature[0:160],w=28,h=28,columns = 20)

# %% [markdown]
# ---
#
# b) Sparse matrix

# %%
train_feature=np.multiply(C_train_x, key_features)
print(train_feature.shape)
train_label=C_train_y

test_feature=np.multiply(C_test_x, key_features)
print(test_feature.shape)
test_label=C_test_y

train_feature_sparse=sparse.coo_matrix(train_feature)
test_feature_sparse=sparse.coo_matrix(test_feature)

p_seed=seed
F.ETree(train_feature_sparse,train_label,test_feature_sparse,test_label,p_seed)
# Out:
# (6000, 784)
# (4000, 784)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9155
# Testing accuracy： 0.9155

# %% [markdown]
# ---
#
# c) Compression

# %%
train_feature_=np.multiply(C_train_x, key_features)
train_feature=F.compress_zero(train_feature_,key_feture_number)
print(train_feature.shape)
train_label=C_train_y

test_feature_=np.multiply(C_test_x, key_features)
test_feature=F.compress_zero(test_feature_,key_feture_number)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.34225
# Testing accuracy： 0.34225

# %% [markdown]
# ---
#
# d) Compression with structure

# %%
train_feature_=np.multiply(C_train_x, key_features)
train_feature=F.compress_zero_withkeystructure(train_feature_,selected_position_list,w=28,h=28)
print(train_feature.shape)
train_label=C_train_y

test_feature_=np.multiply(C_test_x, key_features)
test_feature=F.compress_zero_withkeystructure(test_feature_,selected_position_list,w=28,h=28)
print(test_feature.shape)
test_label=C_test_y

p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.9265
# Testing accuracy： 0.9265

# %% [markdown]
# ---
# #### 4.1.3. Latent space
# ---

# %%
train_feature=latent_encoder_score_F_AE.predict(C_train_x)
print(train_feature.shape)
train_label=C_train_y
test_feature=latent_encoder_score_F_AE.predict(C_test_x)
print(test_feature.shape)
test_label=C_test_y
p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.89725
# Testing accuracy： 0.89725

# %%
train_feature=latent_encoder_choose_F_AE.predict(C_train_x)
print(train_feature.shape)
train_label=C_train_y
test_feature=latent_encoder_choose_F_AE.predict(C_test_x)
print(test_feature.shape)
test_label=C_test_y
p_seed=seed
F.ETree(train_feature,train_label,test_feature,test_label,p_seed)
# Out:
# (6000, 50)
# (4000, 50)
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.898
# Testing accuracy： 0.898

# %% [markdown]
# ---
# # 5 Merge features
# ---

# %%
key_feature_catch_index=[]
for key_feature_catch_i in FS_layer_output[0:160]:
    key_feature_catch_i_=key_feature_catch_i.reshape(28,28)
    key_feature_catch_i_nonzeros_index=np.where(key_feature_catch_i_>0)
    key_feature_catch_i_nonzeros_index_pair=[]
    for i in np.arange(len(key_feature_catch_i_nonzeros_index[0])):
        key_feature_catch_i_nonzeros_index_pair.append([key_feature_catch_i_nonzeros_index[0][i],key_feature_catch_i_nonzeros_index[1][i]])
    key_feature_catch_index.append(key_feature_catch_i_nonzeros_index_pair)

# %%
F.show_data_figures_with_hierarchy_keyfeature(x_test[0:160],key_feature_catch_index,w=28,h=28,columns = 20)

# %% [markdown]
# ---
# # 6 Feature group compare
#
# ---

# %%
Selected_Weights=F.top_k_keep(F_AE.get_layer(index=1).get_weights()[0],key_feture_number)

# %%
print(np.sum(Selected_Weights>0))

Selected_Weights_=Selected_Weights.reshape((28, 28))

print(len(np.unique(Selected_Weights_)))

selected_position_for_group=F.k_index_argsort(Selected_Weights_,key_feture_number)
selected_position_group=[tuple(i) for i in selected_position_for_group]
# Out:
# 50
# 51

# %%
train_feature_=np.multiply(C_train_x, key_features)
train_feature=F.compress_zero_withkeystructure(train_feature_,selected_position_group,w=28,h=28)
print(train_feature.shape)
train_label=C_train_y

test_feature_=np.multiply(C_test_x, key_features)
test_feature=F.compress_zero_withkeystructure(test_feature_,selected_position_group,w=28,h=28)
print(test_feature.shape)
test_label=C_test_y
# Out:
# (6000, 50)
# (4000, 50)

# %%
p_seed=seed
F.ETree(train_feature[:,0:25],train_label,test_feature[:,0:25],test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.8655
# Testing accuracy： 0.8655

# %%
p_seed=seed
F.ETree(train_feature[:,25:],train_label,test_feature[:,25:],test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.82275
# Testing accuracy： 0.82275

# %%
p_seed=seed
F.ETree(train_feature[:,0:30],train_label,test_feature[:,0:30],test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.883
# Testing accuracy： 0.883

# %%
p_seed=seed
F.ETree(train_feature[:,30:],train_label,test_feature[:,30:],test_label,p_seed)
# Out:
# Training accuracy： 1.0
# Training accuracy： 1.0
# Testing accuracy： 0.7765
# Testing accuracy： 0.7765
